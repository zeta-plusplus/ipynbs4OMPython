# %% [markdown]
# <h1>Visualize: SystemModels.VirtualExperiments.CollidingPendulum_001</h1>
# <h2>notebook: rev004</h2>
# <p>compatability with OpenModelica v1.17</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='SystemModels.VirtualExperiments.CollidingPendulum_001'
nmModel='CollidingPendulum_001'
stopTime=10.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/SystemModels
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: SystemModels.VirtualExperiments.CollidingPendulum_001
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/VirtualExperiments/CollidingPendulum_001.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/SystemModels
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/SystemModels
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/SystemModels.VirtualExperiments.CollidingPendulum_001_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/SystemModels
#          time  damper.phi_rel  damper1.phi_rel  revolute.w   revolute1.w  \
# 0       0.000       -1.221730        -1.570796    0.000000  0.000000e+00
# 1       0.001       -1.221734        -1.570796   -0.006681  9.042533e-18
# 2       0.002       -1.221744        -1.570796   -0.013363  1.808505e-17
# 3       0.003       -1.221761        -1.570796   -0.020044  2.712753e-17
# 4       0.004       -1.221784        -1.570796   -0.026724  3.616996e-17
# ...       ...             ...              ...         ...           ...
# 40221  39.997       -1.263204        -1.570796    0.722813 -1.268007e-05
# 40222  39.998       -1.262484        -1.570796    0.716892 -1.268087e-05
# 40223  39.999       -1.261770        -1.570796    0.710957 -1.268142e-05
# 40224  40.000       -1.261062        -1.570796    0.705009 -1.268172e-05
# 40225  40.000       -1.261062        -1.570796    0.705009 -1.268172e-05
#
#        der(damper.phi_rel)  der(damper1.phi_rel)  der(revolute.w)  \
# 0                 0.000000          0.000000e+00        -6.681418
# 1                -0.006681          9.042533e-18        -6.681357
# 2                -0.013363          1.808505e-17        -6.681173
# 3                -0.020044          2.712753e-17        -6.680866
# 4                -0.026724          3.616996e-17        -6.680437
# ...                    ...                   ...              ...
# 40221             0.722813         -1.268007e-05        -5.914564
# 40222             0.716892         -1.268087e-05        -5.927964
# 40223             0.710957         -1.268142e-05        -5.941252
# 40224             0.705009         -1.268172e-05        -5.954426
# 40225             0.705009         -1.268172e-05        -5.954426
#
#        der(revolute1.w)  der(der(bodyShape.frame_b.r_0[1]))  ...  \
# 0          9.042536e-15                           -3.139240  ...
# 1          9.042528e-15                           -3.139222  ...
# 2          9.042502e-15                           -3.139170  ...
# 3          9.042458e-15                           -3.139083  ...
# 4          9.042398e-15                           -3.138962  ...
# ...                 ...                                 ...  ...
# 40221     -9.243715e-07                           -2.897574  ...
# 40222     -6.766562e-07                           -2.902199  ...
# 40223     -4.289276e-07                           -2.906771  ...
# 40224     -1.811907e-07                           -2.911291  ...
# 40225     -1.811907e-07                           -2.911291  ...
#
#        bodyShape1.body.cylinderColor[3]  bodyShape1.sphereColor[1]  \
# 0                                   255                          0
# 1                                   255                          0
# 2                                   255                          0
# 3                                   255                          0
# 4                                   255                          0
# ...                                 ...                        ...
# 40221                               255                          0
# 40222                               255                          0
# 40223                               255                          0
# 40224                               255                          0
# 40225                               255                          0
#
#        bodyShape1.sphereColor[2]  bodyShape1.sphereColor[3]  \
# 0                            128                        255
# 1                            128                        255
# 2                            128                        255
# 3                            128                        255
# 4                            128                        255
# ...                          ...                        ...
# 40221                        128                        255
# 40222                        128                        255
# 40223                        128                        255
# 40224                        128                        255
# 40225                        128                        255
#
#        world.axisColor_y[1]  world.axisColor_y[2]  world.axisColor_y[3]  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 40221                     0                     0                     0
# 40222                     0                     0                     0
# 40223                     0                     0                     0
# 40224                     0                     0                     0
# 40225                     0                     0                     0
#
#        world.axisColor_z[1]  world.axisColor_z[2]  world.axisColor_z[3]
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 40221                     0                     0                     0
# 40222                     0                     0                     0
# 40223                     0                     0                     0
# 40224                     0                     0                     0
# 40225                     0                     0                     0
#
# [40226 rows x 666 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'damper.phi_rel',
#  'damper1.phi_rel',
#  'revolute.w',
#  'revolute1.w',
#  'der(damper.phi_rel)',
#  'der(damper1.phi_rel)',
#  'der(revolute.w)',
#  'der(revolute1.w)',
#  'der(der(bodyShape.frame_b.r_0[1]))',
#  'der(der(bodyShape.frame_b.r_0[2]))',
#  'der(der(bodyShape.frame_b.r_0[3]))',
#  'der(der(bodyShape1.frame_b.r_0[1]))',
#  'der(der(bodyShape1.frame_b.r_0[2]))',
#  'der(der(bodyShape1.frame_b.r_0[3]))',
#  'der(der(lineForceWithMass.r_rel_0[1]))',
#  'der(der(lineForceWithMass.r_rel_0[2]))',
#  'der(der(lineForceWithMass.r_rel_0[3]))',
#  'der(bodyShape.body.w_a[3])',
#  'der(bodyShape.frame_b.r_0[1])',
#  'der(bodyShape.frame_b.r_0[2])',
#  'der(bodyShape.frame_b.r_0[3])',
#  'der(bodyShape1.body.w_a[3])',
#  'der(bodyShape1.frame_b.r_0[1])',
#  'der(bodyShape1.frame_b.r_0[2])',
#  'der(bodyShape1.frame_b.r_0[3])',
#  'der(elastoGap.s_rel)',
#  'der(elastoGap.v_rel)',
#  'der(lineForceWithMass.r_rel_0[1])',
#  'der(lineForceWithMass.r_rel_0[2])',
#  'der(lineForceWithMass.r_rel_0[3])',
#  'KE1',
#  'KE2',
#  'bodyShape.a_0[1]',
#  'bodyShape.a_0[2]',
#  'bodyShape.a_0[3]',
#  'bodyShape.body.frame_a.f[1]',
#  'bodyShape.body.frame_a.f[2]',
#  'bodyShape.body.frame_a.f[3]',
#  'bodyShape.body.frame_a.r_0[1]',
#  'bodyShape.body.frame_a.r_0[2]',
#  'bodyShape.body.frame_a.r_0[3]',
#  'bodyShape.body.frame_a.t[2]',
#  'bodyShape.body.g_0[1]',
#  'bodyShape.body.g_0[2]',
#  'bodyShape.body.g_0[3]',
#  'bodyShape.body.specularCoefficient',
#  'bodyShape.body.w_a[1]',
#  'bodyShape.body.w_a[2]',
#  'bodyShape.body.w_a[3]',
#  'bodyShape.body.z_a[1]',
#  'bodyShape.body.z_a[2]',
#  'bodyShape.body.z_a[3]',
#  'bodyShape.frameTranslation.frame_a.f[3]',
#  'bodyShape.frameTranslation.frame_a.t[1]',
#  'bodyShape.frameTranslation.frame_a.t[2]',
#  'bodyShape.frameTranslation.frame_a.t[3]',
#  'bodyShape.frameTranslation.specularCoefficient',
#  'bodyShape.frame_a.f[1]',
#  'bodyShape.frame_a.f[2]',
#  'bodyShape.frame_a.f[3]',
#  'bodyShape.frame_a.t[1]',
#  'bodyShape.frame_a.t[2]',
#  'bodyShape.frame_a.t[3]',
#  'bodyShape.frame_b.R.T[1,1]',
#  'bodyShape.frame_b.R.T[1,2]',
#  'bodyShape.frame_b.R.T[1,3]',
#  'bodyShape.frame_b.R.T[2,3]',
#  'bodyShape.frame_b.R.T[3,1]',
#  'bodyShape.frame_b.R.T[3,2]',
#  'bodyShape.frame_b.R.T[3,3]',
#  'bodyShape.frame_b.f[1]',
#  'bodyShape.frame_b.f[2]',
#  'bodyShape.frame_b.f[3]',
#  'bodyShape.frame_b.r_0[1]',
#  'bodyShape.frame_b.r_0[2]',
#  'bodyShape.frame_b.r_0[3]',
#  'bodyShape.frame_b.t[1]',
#  'bodyShape.frame_b.t[2]',
#  'bodyShape.frame_b.t[3]',
#  'bodyShape.specularCoefficient',
#  'bodyShape.v_0[1]',
#  'bodyShape.v_0[2]',
#  'bodyShape.v_0[3]',
#  'bodyShape1.a_0[1]',
#  'bodyShape1.a_0[2]',
#  'bodyShape1.a_0[3]',
#  'bodyShape1.body.a_0[1]',
#  'bodyShape1.body.a_0[2]',
#  'bodyShape1.body.a_0[3]',
#  'bodyShape1.body.frame_a.f[1]',
#  'bodyShape1.body.frame_a.f[2]',
#  'bodyShape1.body.frame_a.f[3]',
#  'bodyShape1.body.frame_a.t[1]',
#  'bodyShape1.body.frame_a.t[2]',
#  'bodyShape1.body.g_0[1]',
#  'bodyShape1.body.g_0[2]',
#  'bodyShape1.body.g_0[3]',
#  'bodyShape1.body.specularCoefficient',
#  'bodyShape1.body.v_0[1]',
#  'bodyShape1.body.v_0[2]',
#  'bodyShape1.body.v_0[3]',
#  'bodyShape1.body.w_a[1]',
#  'bodyShape1.body.w_a[2]',
#  'bodyShape1.body.w_a[3]',
#  'bodyShape1.body.z_a[1]',
#  'bodyShape1.body.z_a[2]',
#  'bodyShape1.body.z_a[3]',
#  'bodyShape1.frameTranslation.frame_a.f[3]',
#  'bodyShape1.frameTranslation.frame_a.t[1]',
#  'bodyShape1.frameTranslation.frame_a.t[2]',
#  'bodyShape1.frameTranslation.frame_a.t[3]',
#  'bodyShape1.frameTranslation.specularCoefficient',
#  'bodyShape1.frame_a.f[3]',
#  'bodyShape1.frame_a.t[1]',
#  'bodyShape1.frame_a.t[2]',
#  'bodyShape1.frame_a.t[3]',
#  'bodyShape1.frame_b.R.T[1,1]',
#  'bodyShape1.frame_b.R.T[1,2]',
#  'bodyShape1.frame_b.R.T[1,3]',
#  'bodyShape1.frame_b.R.T[2,3]',
#  'bodyShape1.frame_b.R.T[3,1]',
#  'bodyShape1.frame_b.R.T[3,2]',
#  'bodyShape1.frame_b.R.T[3,3]',
#  'bodyShape1.frame_b.f[1]',
#  'bodyShape1.frame_b.f[2]',
#  'bodyShape1.frame_b.f[3]',
#  'bodyShape1.frame_b.r_0[1]',
#  'bodyShape1.frame_b.r_0[2]',
#  'bodyShape1.frame_b.r_0[3]',
#  'bodyShape1.frame_b.t[1]',
#  'bodyShape1.frame_b.t[2]',
#  'bodyShape1.frame_b.t[3]',
#  'bodyShape1.specularCoefficient',
#  'bodyShape1.v_0[1]',
#  'bodyShape1.v_0[2]',
#  'bodyShape1.v_0[3]',
#  'damper.a_rel',
#  'damper.flange_a.tau',
#  'damper.lossPower',
#  'damper.tau',
#  'damper1.a_rel',
#  'damper1.flange_a.tau',
#  'damper1.lossPower',
#  'damper1.tau',
#  'distance.arrowDiameter',
#  'distance.distance',
#  'distance.frame_a.f[1]',
#  'distance.frame_a.f[2]',
#  'distance.frame_a.f[3]',
#  'distance.frame_a.t[1]',
#  'distance.frame_a.t[2]',
#  'distance.frame_a.t[3]',
#  'distance.frame_b.f[1]',
#  'distance.frame_b.f[2]',
#  'distance.frame_b.f[3]',
#  'distance.frame_b.t[1]',
#  'distance.frame_b.t[2]',
#  'distance.frame_b.t[3]',
#  'distance.s_small',
#  'distance.specularCoefficient',
#  'elastoGap.f',
#  'elastoGap.lossPower',
#  'elastoGap.s_rel',
#  'elastoGap.v_rel',
#  'fixedTranslation.frame_a.t[2]',
#  'fixedTranslation.frame_a.t[3]',
#  'fixedTranslation.frame_b.f[3]',
#  'fixedTranslation.frame_b.t[1]',
#  'fixedTranslation.frame_b.t[2]',
#  'fixedTranslation.frame_b.t[3]',
#  'fixedTranslation.specularCoefficient',
#  'lineForceWithMass.e_rel_0[1]',
#  'lineForceWithMass.e_rel_0[2]',
#  'lineForceWithMass.e_rel_0[3]',
#  'lineForceWithMass.flange_a.s',
#  'lineForceWithMass.frame_a.f[3]',
#  'lineForceWithMass.frame_a.t[1]',
#  'lineForceWithMass.frame_a.t[2]',
#  'lineForceWithMass.frame_a.t[3]',
#  'lineForceWithMass.frame_b.f[3]',
#  'lineForceWithMass.frame_b.t[1]',
#  'lineForceWithMass.frame_b.t[2]',
#  'lineForceWithMass.frame_b.t[3]',
#  'lineForceWithMass.lineShapeWidth',
#  'lineForceWithMass.massDiameter',
#  'lineForceWithMass.r_rel_0[1]',
#  'lineForceWithMass.r_rel_0[2]',
#  'lineForceWithMass.r_rel_0[3]',
#  'lineForceWithMass.s',
#  'lineForceWithMass.specularCoefficient',
#  'revolute.axis.tau',
#  'revolute.fixed.flange.phi',
#  'revolute.frame_a.f[1]',
#  'revolute.frame_a.f[2]',
#  'revolute.frame_a.f[3]',
#  'revolute.frame_a.t[1]',
#  'revolute.frame_a.t[2]',
#  'revolute.frame_a.t[3]',
#  'revolute.frame_b.f[3]',
#  'revolute.frame_b.t[1]',
#  'revolute.frame_b.t[2]',
#  'revolute.specularCoefficient',
#  'revolute.tau',
#  'revolute1.axis.tau',
#  'revolute1.fixed.flange.phi',
#  'revolute1.frame_a.f[1]',
#  'revolute1.frame_a.f[2]',
#  'revolute1.frame_a.f[3]',
#  'revolute1.frame_a.t[1]',
#  'revolute1.frame_a.t[2]',
#  'revolute1.frame_a.t[3]',
#  'revolute1.frame_b.f[1]',
#  'revolute1.frame_b.f[2]',
#  'revolute1.frame_b.f[3]',
#  'revolute1.frame_b.t[1]',
#  'revolute1.frame_b.t[2]',
#  'revolute1.specularCoefficient',
#  'revolute1.tau',
#  'world.frame_b.R.T[1,1]',
#  'world.frame_b.R.T[1,2]',
#  'world.frame_b.R.T[1,3]',
#  'world.frame_b.R.T[2,1]',
#  'world.frame_b.R.T[2,2]',
#  'world.frame_b.R.T[2,3]',
#  'world.frame_b.R.T[3,1]',
#  'world.frame_b.R.T[3,2]',
#  'world.frame_b.R.T[3,3]',
#  'world.frame_b.R.w[1]',
#  'world.frame_b.R.w[2]',
#  'world.frame_b.R.w[3]',
#  'world.frame_b.f[1]',
#  'world.frame_b.f[2]',
#  'world.frame_b.f[3]',
#  'world.frame_b.r_0[1]',
#  'world.frame_b.r_0[2]',
#  'world.frame_b.r_0[3]',
#  'world.frame_b.t[1]',
#  'world.frame_b.t[2]',
#  'world.frame_b.t[3]',
#  'bodyShape.body.sphereColor[1]',
#  'bodyShape.body.sphereColor[2]',
#  'bodyShape.body.sphereColor[3]',
#  'bodyShape.color[1]',
#  'bodyShape.color[2]',
#  'bodyShape.color[3]',
#  'bodyShape.frameTranslation.color[1]',
#  'bodyShape.frameTranslation.color[2]',
#  'bodyShape.frameTranslation.color[3]',
#  'bodyShape1.body.sphereColor[1]',
#  'bodyShape1.body.sphereColor[2]',
#  'bodyShape1.body.sphereColor[3]',
#  'bodyShape1.color[1]',
#  'bodyShape1.color[2]',
#  'bodyShape1.color[3]',
#  'bodyShape1.frameTranslation.color[1]',
#  'bodyShape1.frameTranslation.color[2]',
#  'bodyShape1.frameTranslation.color[3]',
#  'distance.arrowColor[1]',
#  'distance.arrowColor[2]',
#  'distance.arrowColor[3]',
#  'fixedTranslation.color[1]',
#  'fixedTranslation.color[2]',
#  'fixedTranslation.color[3]',
#  'lineForceWithMass.lineShapeColor[1]',
#  'lineForceWithMass.lineShapeColor[2]',
#  'lineForceWithMass.lineShapeColor[3]',
#  'lineForceWithMass.massColor[1]',
#  'lineForceWithMass.massColor[2]',
#  'lineForceWithMass.massColor[3]',
#  'revolute.cylinderColor[1]',
#  'revolute.cylinderColor[2]',
#  'revolute.cylinderColor[3]',
#  'revolute1.cylinderColor[1]',
#  'revolute1.cylinderColor[2]',
#  'revolute1.cylinderColor[3]',
#  'world.axisColor_x[1]',
#  'world.axisColor_x[2]',
#  'world.axisColor_x[3]',
#  'world.gravityArrowColor[1]',
#  'world.gravityArrowColor[2]',
#  'world.gravityArrowColor[3]',
#  'world.gravitySphereColor[1]',
#  'world.gravitySphereColor[2]',
#  'world.gravitySphereColor[3]',
#  'world.groundColor[1]',
#  'world.groundColor[2]',
#  'world.groundColor[3]',
#  'elastoGap.contact',
#  'bodyShape.body.a_0[1]',
#  'bodyShape.body.a_0[2]',
#  'bodyShape.body.a_0[3]',
#  'bodyShape.body.frame_a.R.T[1,1]',
#  'bodyShape.body.frame_a.R.T[1,2]',
#  'bodyShape.body.frame_a.R.T[1,3]',
#  'bodyShape.body.frame_a.R.T[2,1]',
#  'bodyShape.body.frame_a.R.T[2,2]',
#  'bodyShape.body.frame_a.R.T[2,3]',
#  'bodyShape.body.frame_a.R.T[3,1]',
#  'bodyShape.body.frame_a.R.T[3,2]',
#  'bodyShape.body.frame_a.R.T[3,3]',
#  'bodyShape.body.frame_a.R.w[1]',
#  'bodyShape.body.frame_a.R.w[2]',
#  'bodyShape.body.frame_a.R.w[3]',
#  'bodyShape.body.frame_a.t[1]',
#  'bodyShape.body.frame_a.t[3]',
#  'bodyShape.body.r_0[1]',
#  'bodyShape.body.r_0[2]',
#  'bodyShape.body.r_0[3]',
#  'bodyShape.body.v_0[1]',
#  'bodyShape.body.v_0[2]',
#  'bodyShape.body.v_0[3]',
#  'bodyShape.frameTranslation.frame_a.R.T[1,1]',
#  'bodyShape.frameTranslation.frame_a.R.T[1,2]',
#  'bodyShape.frameTranslation.frame_a.R.T[1,3]',
#  'bodyShape.frameTranslation.frame_a.R.T[2,1]',
#  'bodyShape.frameTranslation.frame_a.R.T[2,2]',
#  'bodyShape.frameTranslation.frame_a.R.T[2,3]',
#  'bodyShape.frameTranslation.frame_a.R.T[3,1]',
#  'bodyShape.frameTranslation.frame_a.R.T[3,2]',
#  'bodyShape.frameTranslation.frame_a.R.T[3,3]',
#  'bodyShape.frameTranslation.frame_a.R.w[1]',
#  'bodyShape.frameTranslation.frame_a.R.w[2]',
#  'bodyShape.frameTranslation.frame_a.R.w[3]',
#  'bodyShape.frameTranslation.frame_a.f[1]',
#  'bodyShape.frameTranslation.frame_a.f[2]',
#  'bodyShape.frameTranslation.frame_a.r_0[1]',
#  'bodyShape.frameTranslation.frame_a.r_0[2]',
#  'bodyShape.frameTranslation.frame_a.r_0[3]',
#  'bodyShape.frameTranslation.frame_b.R.T[1,1]',
#  'bodyShape.frameTranslation.frame_b.R.T[1,2]',
#  'bodyShape.frameTranslation.frame_b.R.T[1,3]',
#  'bodyShape.frameTranslation.frame_b.R.T[2,1]',
#  'bodyShape.frameTranslation.frame_b.R.T[2,2]',
#  'bodyShape.frameTranslation.frame_b.R.T[2,3]',
#  'bodyShape.frameTranslation.frame_b.R.T[3,1]',
#  'bodyShape.frameTranslation.frame_b.R.T[3,2]',
#  'bodyShape.frameTranslation.frame_b.R.T[3,3]',
#  'bodyShape.frameTranslation.frame_b.R.w[1]',
#  'bodyShape.frameTranslation.frame_b.R.w[2]',
#  'bodyShape.frameTranslation.frame_b.R.w[3]',
#  'bodyShape.frameTranslation.frame_b.f[1]',
#  'bodyShape.frameTranslation.frame_b.f[2]',
#  'bodyShape.frameTranslation.frame_b.f[3]',
#  'bodyShape.frameTranslation.frame_b.r_0[1]',
#  'bodyShape.frameTranslation.frame_b.r_0[2]',
#  'bodyShape.frameTranslation.frame_b.r_0[3]',
#  'bodyShape.frameTranslation.frame_b.t[1]',
#  'bodyShape.frameTranslation.frame_b.t[2]',
#  'bodyShape.frameTranslation.frame_b.t[3]',
#  'bodyShape.frame_a.R.T[1,1]',
#  'bodyShape.frame_a.R.T[1,2]',
#  'bodyShape.frame_a.R.T[1,3]',
#  'bodyShape.frame_a.R.T[2,1]',
#  'bodyShape.frame_a.R.T[2,2]',
#  'bodyShape.frame_a.R.T[2,3]',
#  'bodyShape.frame_a.R.T[3,1]',
#  'bodyShape.frame_a.R.T[3,2]',
#  'bodyShape.frame_a.R.T[3,3]',
#  'bodyShape.frame_a.R.w[1]',
#  'bodyShape.frame_a.R.w[2]',
#  'bodyShape.frame_a.R.w[3]',
#  'bodyShape.frame_a.r_0[1]',
#  'bodyShape.frame_a.r_0[2]',
#  'bodyShape.frame_a.r_0[3]',
#  'bodyShape.frame_b.R.T[2,1]',
#  'bodyShape.frame_b.R.T[2,2]',
#  'bodyShape.frame_b.R.w[1]',
#  'bodyShape.frame_b.R.w[2]',
#  'bodyShape.frame_b.R.w[3]',
#  'bodyShape.r_0[1]',
#  'bodyShape.r_0[2]',
#  'bodyShape.r_0[3]',
#  'bodyShape1.body.frame_a.R.T[1,1]',
#  'bodyShape1.body.frame_a.R.T[1,2]',
#  'bodyShape1.body.frame_a.R.T[1,3]',
#  'bodyShape1.body.frame_a.R.T[2,1]',
#  'bodyShape1.body.frame_a.R.T[2,2]',
#  'bodyShape1.body.frame_a.R.T[2,3]',
#  'bodyShape1.body.frame_a.R.T[3,1]',
#  'bodyShape1.body.frame_a.R.T[3,2]',
#  'bodyShape1.body.frame_a.R.T[3,3]',
#  'bodyShape1.body.frame_a.R.w[1]',
#  'bodyShape1.body.frame_a.R.w[2]',
#  'bodyShape1.body.frame_a.R.w[3]',
#  'bodyShape1.body.frame_a.r_0[1]',
#  'bodyShape1.body.frame_a.r_0[2]',
#  'bodyShape1.body.frame_a.r_0[3]',
#  'bodyShape1.body.frame_a.t[3]',
#  'bodyShape1.body.r_0[1]',
#  'bodyShape1.body.r_0[2]',
#  'bodyShape1.body.r_0[3]',
#  'bodyShape1.frameTranslation.frame_a.R.T[1,1]',
#  'bodyShape1.frameTranslation.frame_a.R.T[1,2]',
#  'bodyShape1.frameTranslation.frame_a.R.T[1,3]',
#  'bodyShape1.frameTranslation.frame_a.R.T[2,1]',
#  'bodyShape1.frameTranslation.frame_a.R.T[2,2]',
#  'bodyShape1.frameTranslation.frame_a.R.T[2,3]',
#  'bodyShape1.frameTranslation.frame_a.R.T[3,1]',
#  'bodyShape1.frameTranslation.frame_a.R.T[3,2]',
#  'bodyShape1.frameTranslation.frame_a.R.T[3,3]',
#  'bodyShape1.frameTranslation.frame_a.R.w[1]',
#  'bodyShape1.frameTranslation.frame_a.R.w[2]',
#  'bodyShape1.frameTranslation.frame_a.R.w[3]',
#  'bodyShape1.frameTranslation.frame_a.f[1]',
#  'bodyShape1.frameTranslation.frame_a.f[2]',
#  'bodyShape1.frameTranslation.frame_a.r_0[1]',
#  'bodyShape1.frameTranslation.frame_a.r_0[2]',
#  'bodyShape1.frameTranslation.frame_a.r_0[3]',
#  'bodyShape1.frameTranslation.frame_b.R.T[1,1]',
#  'bodyShape1.frameTranslation.frame_b.R.T[1,2]',
#  'bodyShape1.frameTranslation.frame_b.R.T[1,3]',
#  'bodyShape1.frameTranslation.frame_b.R.T[2,1]',
#  'bodyShape1.frameTranslation.frame_b.R.T[2,2]',
#  'bodyShape1.frameTranslation.frame_b.R.T[2,3]',
#  'bodyShape1.frameTranslation.frame_b.R.T[3,1]',
#  'bodyShape1.frameTranslation.frame_b.R.T[3,2]',
#  'bodyShape1.frameTranslation.frame_b.R.T[3,3]',
#  'bodyShape1.frameTranslation.frame_b.R.w[1]',
#  'bodyShape1.frameTranslation.frame_b.R.w[2]',
#  'bodyShape1.frameTranslation.frame_b.R.w[3]',
#  'bodyShape1.frameTranslation.frame_b.f[1]',
#  'bodyShape1.frameTranslation.frame_b.f[2]',
#  'bodyShape1.frameTranslation.frame_b.f[3]',
#  'bodyShape1.frameTranslation.frame_b.r_0[1]',
#  'bodyShape1.frameTranslation.frame_b.r_0[2]',
#  'bodyShape1.frameTranslation.frame_b.r_0[3]',
#  'bodyShape1.frameTranslation.frame_b.t[1]',
#  'bodyShape1.frameTranslation.frame_b.t[2]',
#  'bodyShape1.frameTranslation.frame_b.t[3]',
#  'bodyShape1.frame_a.R.T[1,1]',
#  'bodyShape1.frame_a.R.T[1,2]',
#  'bodyShape1.frame_a.R.T[1,3]',
#  'bodyShape1.frame_a.R.T[2,1]',
#  'bodyShape1.frame_a.R.T[2,2]',
#  'bodyShape1.frame_a.R.T[2,3]',
#  'bodyShape1.frame_a.R.T[3,1]',
#  'bodyShape1.frame_a.R.T[3,2]',
#  'bodyShape1.frame_a.R.T[3,3]',
#  'bodyShape1.frame_a.R.w[1]',
#  'bodyShape1.frame_a.R.w[2]',
#  'bodyShape1.frame_a.R.w[3]',
#  'bodyShape1.frame_a.f[1]',
#  'bodyShape1.frame_a.f[2]',
#  'bodyShape1.frame_a.r_0[1]',
#  'bodyShape1.frame_a.r_0[2]',
#  'bodyShape1.frame_a.r_0[3]',
#  'bodyShape1.frame_b.R.T[2,1]',
#  'bodyShape1.frame_b.R.T[2,2]',
#  'bodyShape1.frame_b.R.w[1]',
#  'bodyShape1.frame_b.R.w[2]',
#  'bodyShape1.frame_b.R.w[3]',
#  'bodyShape1.r_0[1]',
#  'bodyShape1.r_0[2]',
#  'bodyShape1.r_0[3]',
#  'damper.flange_a.phi',
#  'damper.flange_b.phi',
#  'damper.flange_b.tau',
#  'damper.w_rel',
#  'damper1.flange_a.phi',
#  'damper1.flange_b.phi',
#  'damper1.flange_b.tau',
#  'damper1.w_rel',
#  'distance.frame_a.R.T[1,1]',
#  'distance.frame_a.R.T[1,2]',
#  'distance.frame_a.R.T[1,3]',
#  'distance.frame_a.R.T[2,1]',
#  'distance.frame_a.R.T[2,2]',
#  'distance.frame_a.R.T[2,3]',
#  'distance.frame_a.R.T[3,1]',
#  'distance.frame_a.R.T[3,2]',
#  'distance.frame_a.R.T[3,3]',
#  'distance.frame_a.R.w[1]',
#  'distance.frame_a.R.w[2]',
#  'distance.frame_a.R.w[3]',
#  'distance.frame_a.r_0[1]',
#  'distance.frame_a.r_0[2]',
#  'distance.frame_a.r_0[3]',
#  'distance.frame_b.R.T[1,1]',
#  'distance.frame_b.R.T[1,2]',
#  'distance.frame_b.R.T[1,3]',
#  'distance.frame_b.R.T[2,1]',
#  'distance.frame_b.R.T[2,2]',
#  'distance.frame_b.R.T[2,3]',
#  'distance.frame_b.R.T[3,1]',
#  'distance.frame_b.R.T[3,2]',
#  'distance.frame_b.R.T[3,3]',
#  'distance.frame_b.R.w[1]',
#  'distance.frame_b.R.w[2]',
#  'distance.frame_b.R.w[3]',
#  'distance.frame_b.r_0[1]',
#  'distance.frame_b.r_0[2]',
#  'distance.frame_b.r_0[3]',
#  'elastoGap.flange_a.f',
#  'elastoGap.flange_a.s',
#  'elastoGap.flange_b.f',
#  'elastoGap.flange_b.s',
#  'fixedTranslation.frame_a.R.T[1,1]',
#  'fixedTranslation.frame_a.R.T[1,2]',
#  'fixedTranslation.frame_a.R.T[1,3]',
#  'fixedTranslation.frame_a.R.T[2,1]',
#  'fixedTranslation.frame_a.R.T[2,2]',
#  'fixedTranslation.frame_a.R.T[2,3]',
#  'fixedTranslation.frame_a.R.T[3,1]',
#  'fixedTranslation.frame_a.R.T[3,2]',
#  'fixedTranslation.frame_a.R.T[3,3]',
#  'fixedTranslation.frame_a.R.w[1]',
#  'fixedTranslation.frame_a.R.w[2]',
#  'fixedTranslation.frame_a.R.w[3]',
#  'fixedTranslation.frame_a.f[1]',
#  'fixedTranslation.frame_a.f[2]',
#  'fixedTranslation.frame_a.f[3]',
#  'fixedTranslation.frame_a.r_0[1]',
#  'fixedTranslation.frame_a.r_0[2]',
#  'fixedTranslation.frame_a.r_0[3]',
#  'fixedTranslation.frame_a.t[1]',
#  'fixedTranslation.frame_b.R.T[1,1]',
#  'fixedTranslation.frame_b.R.T[1,2]',
#  'fixedTranslation.frame_b.R.T[1,3]',
#  'fixedTranslation.frame_b.R.T[2,1]',
#  'fixedTranslation.frame_b.R.T[2,2]',
#  'fixedTranslation.frame_b.R.T[2,3]',
#  'fixedTranslation.frame_b.R.T[3,1]',
#  'fixedTranslation.frame_b.R.T[3,2]',
#  'fixedTranslation.frame_b.R.T[3,3]',
#  'fixedTranslation.frame_b.R.w[1]',
#  'fixedTranslation.frame_b.R.w[2]',
#  'fixedTranslation.frame_b.R.w[3]',
#  'fixedTranslation.frame_b.f[1]',
#  'fixedTranslation.frame_b.f[2]',
#  'fixedTranslation.frame_b.r_0[1]',
#  'fixedTranslation.frame_b.r_0[2]',
#  'fixedTranslation.frame_b.r_0[3]',
#  'lineForceWithMass.flange_a.f',
#  'lineForceWithMass.flange_b.f',
#  'lineForceWithMass.flange_b.s',
#  'lineForceWithMass.frame_a.R.T[1,1]',
#  'lineForceWithMass.frame_a.R.T[1,2]',
#  'lineForceWithMass.frame_a.R.T[1,3]',
#  'lineForceWithMass.frame_a.R.T[2,1]',
#  'lineForceWithMass.frame_a.R.T[2,2]',
#  'lineForceWithMass.frame_a.R.T[2,3]',
#  'lineForceWithMass.frame_a.R.T[3,1]',
#  'lineForceWithMass.frame_a.R.T[3,2]',
#  'lineForceWithMass.frame_a.R.T[3,3]',
#  'lineForceWithMass.frame_a.R.w[1]',
#  'lineForceWithMass.frame_a.R.w[2]',
#  'lineForceWithMass.frame_a.R.w[3]',
#  'lineForceWithMass.frame_a.f[1]',
#  'lineForceWithMass.frame_a.f[2]',
#  'lineForceWithMass.frame_a.r_0[1]',
#  'lineForceWithMass.frame_a.r_0[2]',
#  'lineForceWithMass.frame_a.r_0[3]',
#  'lineForceWithMass.frame_b.R.T[1,1]',
#  'lineForceWithMass.frame_b.R.T[1,2]',
#  'lineForceWithMass.frame_b.R.T[1,3]',
#  'lineForceWithMass.frame_b.R.T[2,1]',
#  'lineForceWithMass.frame_b.R.T[2,2]',
#  'lineForceWithMass.frame_b.R.T[2,3]',
#  'lineForceWithMass.frame_b.R.T[3,1]',
#  'lineForceWithMass.frame_b.R.T[3,2]',
#  'lineForceWithMass.frame_b.R.T[3,3]',
#  'lineForceWithMass.frame_b.R.w[1]',
#  'lineForceWithMass.frame_b.R.w[2]',
#  'lineForceWithMass.frame_b.R.w[3]',
#  'lineForceWithMass.frame_b.f[1]',
#  'lineForceWithMass.frame_b.f[2]',
#  'lineForceWithMass.frame_b.r_0[1]',
#  'lineForceWithMass.frame_b.r_0[2]',
#  'lineForceWithMass.frame_b.r_0[3]',
#  'lineForceWithMass.length',
#  'lineForceWithMass.lineShapeHeight',
#  'revolute.a',
#  'revolute.angle',
#  'revolute.axis.phi',
#  'revolute.frame_a.R.T[1,1]',
#  'revolute.frame_a.R.T[1,2]',
#  'revolute.frame_a.R.T[1,3]',
#  'revolute.frame_a.R.T[2,1]',
#  'revolute.frame_a.R.T[2,2]',
#  'revolute.frame_a.R.T[2,3]',
#  'revolute.frame_a.R.T[3,1]',
#  'revolute.frame_a.R.T[3,2]',
#  'revolute.frame_a.R.T[3,3]',
#  'revolute.frame_a.R.w[1]',
#  'revolute.frame_a.R.w[2]',
#  'revolute.frame_a.R.w[3]',
#  'revolute.frame_a.r_0[1]',
#  'revolute.frame_a.r_0[2]',
#  'revolute.frame_a.r_0[3]',
#  'revolute.frame_b.R.T[1,1]',
#  'revolute.frame_b.R.T[1,2]',
#  'revolute.frame_b.R.T[1,3]',
#  'revolute.frame_b.R.T[2,1]',
#  'revolute.frame_b.R.T[2,2]',
#  'revolute.frame_b.R.T[2,3]',
#  'revolute.frame_b.R.T[3,1]',
#  'revolute.frame_b.R.T[3,2]',
#  'revolute.frame_b.R.T[3,3]',
#  'revolute.frame_b.R.w[1]',
#  'revolute.frame_b.R.w[2]',
#  'revolute.frame_b.R.w[3]',
#  'revolute.frame_b.f[1]',
#  'revolute.frame_b.f[2]',
#  'revolute.frame_b.r_0[1]',
#  'revolute.frame_b.r_0[2]',
#  'revolute.frame_b.r_0[3]',
#  'revolute.frame_b.t[3]',
#  'revolute.phi',
#  'revolute.support.phi',
#  'revolute.support.tau',
#  'revolute1.a',
#  'revolute1.angle',
#  'revolute1.axis.phi',
#  'revolute1.frame_a.R.T[1,1]',
#  'revolute1.frame_a.R.T[1,2]',
#  'revolute1.frame_a.R.T[1,3]',
#  'revolute1.frame_a.R.T[2,1]',
#  'revolute1.frame_a.R.T[2,2]',
#  'revolute1.frame_a.R.T[2,3]',
#  'revolute1.frame_a.R.T[3,1]',
#  'revolute1.frame_a.R.T[3,2]',
#  'revolute1.frame_a.R.T[3,3]',
#  'revolute1.frame_a.R.w[1]',
#  'revolute1.frame_a.R.w[2]',
#  'revolute1.frame_a.R.w[3]',
#  'revolute1.frame_a.r_0[1]',
#  'revolute1.frame_a.r_0[2]',
#  'revolute1.frame_a.r_0[3]',
#  'revolute1.frame_b.R.T[1,1]',
#  'revolute1.frame_b.R.T[1,2]',
#  'revolute1.frame_b.R.T[1,3]',
#  'revolute1.frame_b.R.T[2,1]',
#  'revolute1.frame_b.R.T[2,2]',
#  'revolute1.frame_b.R.T[2,3]',
#  'revolute1.frame_b.R.T[3,1]',
#  'revolute1.frame_b.R.T[3,2]',
#  'revolute1.frame_b.R.T[3,3]',
#  'revolute1.frame_b.R.w[1]',
#  'revolute1.frame_b.R.w[2]',
#  'revolute1.frame_b.R.w[3]',
#  'revolute1.frame_b.r_0[1]',
#  'revolute1.frame_b.r_0[2]',
#  'revolute1.frame_b.r_0[3]',
#  'revolute1.frame_b.t[3]',
#  'revolute1.phi',
#  'revolute1.support.phi',
#  'revolute1.support.tau',
#  'bodyShape.body.cylinderColor[1]',
#  'bodyShape.body.cylinderColor[2]',
#  'bodyShape.body.cylinderColor[3]',
#  'bodyShape.sphereColor[1]',
#  'bodyShape.sphereColor[2]',
#  'bodyShape.sphereColor[3]',
#  'bodyShape1.body.cylinderColor[1]',
#  'bodyShape1.body.cylinderColor[2]',
#  'bodyShape1.body.cylinderColor[3]',
#  'bodyShape1.sphereColor[1]',
#  'bodyShape1.sphereColor[2]',
#  'bodyShape1.sphereColor[3]',
#  'world.axisColor_y[1]',
#  'world.axisColor_y[2]',
#  'world.axisColor_y[3]',
#  'world.axisColor_z[1]',
#  'world.axisColor_z[2]',
#  'world.axisColor_z[3]']

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=3


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/SystemModels.VirtualExperiments.CollidingPendulum_001_res_2.csv
# i_df=3
# data read: /home/ubuntu/OMPythonWork/SystemModels.VirtualExperiments.CollidingPendulum_001_res_3.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/SystemModels

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/SystemModels.VirtualExperiments.CollidingPendulum_001_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/SystemModels
#          time  damper.phi_rel  damper1.phi_rel  revolute.w   revolute1.w  \
# 0       0.000       -1.221730        -1.570796    0.000000  0.000000e+00
# 1       0.001       -1.221734        -1.570796   -0.006681  9.042533e-18
# 2       0.002       -1.221744        -1.570796   -0.013363  1.808505e-17
# 3       0.003       -1.221761        -1.570796   -0.020044  2.712753e-17
# 4       0.004       -1.221784        -1.570796   -0.026724  3.616996e-17
# ...       ...             ...              ...         ...           ...
# 40221  39.997       -1.263204        -1.570796    0.722813 -1.268007e-05
# 40222  39.998       -1.262484        -1.570796    0.716892 -1.268087e-05
# 40223  39.999       -1.261770        -1.570796    0.710957 -1.268142e-05
# 40224  40.000       -1.261062        -1.570796    0.705009 -1.268172e-05
# 40225  40.000       -1.261062        -1.570796    0.705009 -1.268172e-05
#
#        der(damper.phi_rel)  der(damper1.phi_rel)  der(revolute.w)  \
# 0                 0.000000          0.000000e+00        -6.681418
# 1                -0.006681          9.042533e-18        -6.681357
# 2                -0.013363          1.808505e-17        -6.681173
# 3                -0.020044          2.712753e-17        -6.680866
# 4                -0.026724          3.616996e-17        -6.680437
# ...                    ...                   ...              ...
# 40221             0.722813         -1.268007e-05        -5.914564
# 40222             0.716892         -1.268087e-05        -5.927964
# 40223             0.710957         -1.268142e-05        -5.941252
# 40224             0.705009         -1.268172e-05        -5.954426
# 40225             0.705009         -1.268172e-05        -5.954426
#
#        der(revolute1.w)  der(der(bodyShape.frame_b.r_0[1]))  ...  \
# 0          9.042536e-15                           -3.139240  ...
# 1          9.042528e-15                           -3.139222  ...
# 2          9.042502e-15                           -3.139170  ...
# 3          9.042458e-15                           -3.139083  ...
# 4          9.042398e-15                           -3.138962  ...
# ...                 ...                                 ...  ...
# 40221     -9.243715e-07                           -2.897574  ...
# 40222     -6.766562e-07                           -2.902199  ...
# 40223     -4.289276e-07                           -2.906771  ...
# 40224     -1.811907e-07                           -2.911291  ...
# 40225     -1.811907e-07                           -2.911291  ...
#
#        bodyShape1.body.cylinderColor[3]  bodyShape1.sphereColor[1]  \
# 0                                   255                          0
# 1                                   255                          0
# 2                                   255                          0
# 3                                   255                          0
# 4                                   255                          0
# ...                                 ...                        ...
# 40221                               255                          0
# 40222                               255                          0
# 40223                               255                          0
# 40224                               255                          0
# 40225                               255                          0
#
#        bodyShape1.sphereColor[2]  bodyShape1.sphereColor[3]  \
# 0                            128                        255
# 1                            128                        255
# 2                            128                        255
# 3                            128                        255
# 4                            128                        255
# ...                          ...                        ...
# 40221                        128                        255
# 40222                        128                        255
# 40223                        128                        255
# 40224                        128                        255
# 40225                        128                        255
#
#        world.axisColor_y[1]  world.axisColor_y[2]  world.axisColor_y[3]  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 40221                     0                     0                     0
# 40222                     0                     0                     0
# 40223                     0                     0                     0
# 40224                     0                     0                     0
# 40225                     0                     0                     0
#
#        world.axisColor_z[1]  world.axisColor_z[2]  world.axisColor_z[3]
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 40221                     0                     0                     0
# 40222                     0                     0                     0
# 40223                     0                     0                     0
# 40224                     0                     0                     0
# 40225                     0                     0                     0
#
# [40226 rows x 666 columns]

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="bodyShape.frame_b.r_0[1]"
label="pendulum 1 (red)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='red')

i_df=0
varName="bodyShape1.frame_b.r_0[1]"
label="pendulum 2 (blue)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='blue')

i_df=0
varName="distance.distance"
label="distance btwn 2 center of mass"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='green')

#----------
plt.xlabel('time [s]')
plt.ylabel('position [m]')
plt.title('x of mass centers')

plt.legend(loc='lower right', fontsize=12)
plt.xlim(0.0, 30)
#plt.ylim(0.0, 1.4)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="elastoGap.f"
label=""
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='red')

#----------
plt.xlabel('time [s]')
plt.ylabel('force [N]')
plt.title(varName)

plt.legend(loc='lower right', fontsize=12)
plt.xlim(0.0, 30)
#plt.ylim(0.0, 1.4)
plt.grid()
print('------------------------------')
# Out:
# No handles with labels found to put in legend.
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="elastoGap.v_rel"
label=""
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='red')

#----------
plt.xlabel('time [s]')
plt.ylabel('position [m]')
plt.title(varName)

plt.legend(loc='lower right', fontsize=12)
plt.xlim(0.0, 30)
#plt.ylim(0.0, 1.4)
plt.grid()
print('------------------------------')
# Out:
# No handles with labels found to put in legend.
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="KE1"
label="pendulum 1"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='red')

i_df=0
varName="KE2"
label="pendulum 2"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('energy [J]')
plt.title('kinetic energy')

plt.legend(loc='center right', fontsize=12)
plt.xlim(0.0, 4.0)
plt.ylim(0.0, 0.8)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>-------------------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/SystemModels
# ------------------------------
