# %% [markdown]
# <h1>Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02</h1>
# <p>rev003</p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Use settings</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02'
nmModel='PistonCylinderIdealOttoMV01_ex02'
stopTime=70.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/Examples/Elements/BasicElements/PistonCylinderIdealOttoMV01_ex02.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- load Modelica Standard Library
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Building Model</h1>

# %%
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
print(''); print('...moving OMshell to temporary working directry')
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- build the model
print(''); print('...building the model, wait...')
strcmd= 'buildModel(' + fullpathModel + ', stopTime='+str(stopTime) + ', outputFormat="csv"' + ')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...model build finished.')

#-- save original parameter setting file
print(''); print('...Saving original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (fullpathModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# ...moving OMshell to temporary working directry
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...building the model, wait...
# send: buildModel(PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02, stopTime=70.0, outputFormat="csv")
# OMShell: ('/home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02', 'PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml')
# ...model build finished.
#
# ...Saving original parameter setting file...
# send: system("cp PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_org.xml")
# OMShell: 0
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Print source code of model built</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

strcmd= 'list('+fullpathModel+')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print('source code of model build:')
print('')
print(str(msgOMShell)); 

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: list(PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02)
# source code of model build:
#
# model PistonCylinderIdealOttoMV01_ex02
#   extends Modelica.Icons.Example;
#   //-----
#   package engineAir = Modelica.Media.Air.DryAirNasa;
#   //package engineAir = PropulsionSystem.Media.EngineBreathingAir.DryAirMethaneMixture00;
#   //redeclare package Medium = engineAir
#   //-----
#   inner Modelica.Fluid.System system(allowFlowReversal = false) annotation(
#     Placement(visible = true, transformation(origin = {-90, 90}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Fluid.Sources.Boundary_pT boundary(redeclare package Medium = engineAir, T = 15 + 273.15, nPorts = 2, p = 101.325 * 1000, use_T_in = true, use_p_in = true) annotation(
#     Placement(visible = true, transformation(origin = {-90, 20}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_fracFuel(duration = 10, height = 0, offset = 0.01, startTime = 10) annotation(
#     Placement(visible = true, transformation(origin = {-70, -30}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_T1(duration = 10, height = 0, offset = 15 + 273.15, startTime = 30) annotation(
#     Placement(visible = true, transformation(origin = {-130, 0}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   inner PropulsionSystem.EngineSimEnvironment environment annotation(
#     Placement(visible = true, transformation(origin = {-70, 90}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Mechanics.Rotational.Sensors.PowerSensor powerSensor1 annotation(
#     Placement(visible = true, transformation(origin = {20, -30}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_trq(duration = 10, height = 0, offset = 0, startTime = 50) annotation(
#     Placement(visible = true, transformation(origin = {110, -30}, extent = {{10, -10}, {-10, 10}}, rotation = 0)));
#   Modelica.Fluid.Sources.Boundary_pT boundary1(redeclare package Medium = engineAir, T = 15 + 273.15, nPorts = 1, p = 101.325 * 1000) annotation(
#     Placement(visible = true, transformation(origin = {56, 60}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   PropulsionSystem.Elements.BasicElements.PistonCylinderIdealOttoMV01 PistonCylinder(redeclare package Medium = engineAir) annotation(
#     Placement(visible = true, transformation(origin = {-20.3333, -10.6}, extent = {{-19.6667, -23.6}, {19.6667, 23.6}}, rotation = 0)));
#   FluidSystemComponents.CommonAnyFluid.Components.VariableZetaOrifice00 Orifice(redeclare package Medium = engineAir, AmechTh_paramInput = Modelica.Constants.pi / 4.0 * 0.05 ^ 2) annotation(
#     Placement(visible = true, transformation(origin = {-60, 20}, extent = {{-10, 10}, {10, -10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_zeta(duration = 10, height = 1, offset = 1, startTime = 10) annotation(
#     Placement(visible = true, transformation(origin = {-80, 50}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   FluidSystemComponents.CommonAnyFluid.Components.VariableZetaOrifice00 Orifice1(redeclare package Medium = engineAir, AmechTh_paramInput = Modelica.Constants.pi / 4.0 * 0.05 ^ 2) annotation(
#     Placement(visible = true, transformation(origin = {30, 10}, extent = {{-10, 10}, {10, -10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_zeta1(duration = 10, height = 1, offset = 1, startTime = 30) annotation(
#     Placement(visible = true, transformation(origin = {10, 50}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_p1(duration = 10, height = 5 * 1000, offset = 101.325 * 1000, startTime = 50) annotation(
#     Placement(visible = true, transformation(origin = {-130, 40}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Mechanics.Rotational.Components.Inertia inertia1(J = 1e-3, w(fixed = true, start = 2000 * (2 * Modelica.Constants.pi / 60))) annotation(
#     Placement(visible = true, transformation(origin = {50, -30}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Mechanics.Rotational.Sources.Torque torque1 annotation(
#     Placement(visible = true, transformation(origin = {80, -30}, extent = {{10, -10}, {-10, 10}}, rotation = 0)));
#   Modelica.Mechanics.Rotational.Components.Damper damper1(d = 1e-2) annotation(
#     Placement(visible = true, transformation(origin = {80, -60}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Mechanics.Rotational.Components.Fixed fixed1 annotation(
#     Placement(visible = true, transformation(origin = {110, -60}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
# equation
#   connect(powerSensor1.flange_b, inertia1.flange_a) annotation(
#     Line(points = {{30, -30}, {40, -30}, {40, -30}, {40, -30}}));
#   connect(inertia1.flange_b, damper1.flange_a) annotation(
#     Line(points = {{60, -30}, {64, -30}, {64, -60}, {70, -60}, {70, -60}}));
#   connect(torque1.tau, ramp_trq.y) annotation(
#     Line(points = {{92, -30}, {100, -30}, {100, -30}, {100, -30}}, color = {0, 0, 127}));
#   connect(inertia1.flange_b, torque1.flange) annotation(
#     Line(points = {{60, -30}, {70, -30}, {70, -30}, {70, -30}}));
#   connect(damper1.flange_b, fixed1.flange) annotation(
#     Line(points = {{90, -60}, {110, -60}, {110, -60}, {110, -60}}));
#   connect(ramp_p1.y, boundary.p_in) annotation(
#     Line(points = {{-118, 40}, {-110, 40}, {-110, 28}, {-102, 28}, {-102, 28}}, color = {0, 0, 127}));
#   connect(ramp_zeta1.y, Orifice1.u_zeta) annotation(
#     Line(points = {{22, 50}, {26, 50}, {26, 20}, {26, 20}}, color = {0, 0, 127}));
#   connect(ramp_zeta.y, Orifice.u_zeta) annotation(
#     Line(points = {{-68, 50}, {-64, 50}, {-64, 30}, {-64, 30}}, color = {0, 0, 127}));
#   connect(Orifice1.port_2, boundary1.ports[1]) annotation(
#     Line(points = {{40, 10}, {56, 10}, {56, 50}, {56, 50}}, color = {0, 127, 255}));
#   connect(PistonCylinder.port_2, Orifice1.port_1) annotation(
#     Line(points = {{0, 10}, {20, 10}, {20, 10}, {20, 10}}, color = {0, 127, 255}));
#   connect(Orifice.port_2, PistonCylinder.port_1) annotation(
#     Line(points = {{-50, 20}, {-40, 20}, {-40, 10}, {-40, 10}}, color = {0, 127, 255}));
#   connect(boundary.ports[1], Orifice.port_1) annotation(
#     Line(points = {{-80, 20}, {-70, 20}, {-70, 20}, {-70, 20}}, color = {0, 127, 255}));
#   connect(ramp_fracFuel.y, PistonCylinder.u_fracFuel) annotation(
#     Line(points = {{-59, -30}, {-50, -30}, {-50, 3}, {-35, 3}}, color = {0, 0, 127}));
#   connect(ramp_T1.y, boundary.T_in) annotation(
#     Line(points = {{-119, 0}, {-115, 0}, {-115, 24}, {-103, 24}, {-103, 24}, {-103, 24}, {-103, 24}}, color = {0, 0, 127}));
#   connect(PistonCylinder.flange_2, powerSensor1.flange_a) annotation(
#     Line(points = {{-1, -30}, {10, -30}}));
#   annotation(
#     experiment(StartTime = 0, StopTime = 70, Tolerance = 1e-06, Interval = 0.140562),
#     __OpenModelica_simulationFlags(lv = "LOG_STATS", outputFormat = "mat", s = "dassl"),
#     Diagram(coordinateSystem(extent = {{-140, -100}, {120, 100}})),
#     __OpenModelica_commandLineOptions = "");
# end PistonCylinderIdealOttoMV01_ex02;
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Run simulation, default setting</h1>

# %%
stopTime=70

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- reset _init.xml
print('...calling original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#-- run simulation with default parameter setting
print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
##### end if #####
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# ...calling original parameter setting file...
# send: system("cp PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_org.xml PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02 -override stopTime=70 -r=PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>parameter sweep, 1 parameter </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunBegin=2
iRunEnd=3
param2change="PistonCylinder.CR_paramInput"
valBegin=5.0
deltaVal=1
stopTime=70.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    iRun=i
    value2set=valBegin+(i-1)*deltaVal
    filenameXmlOrg=fullpathModel+'_init_org.xml'
    filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
    
    print(''); print('-----')
    print('iRun= '+ str(iRun))
    
    #-- overwrite parameter setting xml file
    print('...Overwriting parameter setting file...')
    strcmd= 'setInitXmlStartValue("' + filenameXmlOrg+'", '+ '"'+param2change+'", ' + '"'+str(value2set)+'", '+ '"'+fullpathModel+'_init.xml"' +')'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- save parameter setting file after overwriting
    print(''); print('...Saving parameter setting file...')
    strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- run simulation with default parameter setting
    print(''); print("...running simulation, wait...")
    if(os.name=='nt'):
        strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    elif(os.name=='posix'):
        strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    ##### end if #####

    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
    print('...simulation run finished.')
##### end for #####

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# -----
# iRun= 2
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_org.xml", "PistonCylinder.CR_paramInput", "6.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_2.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02 -override stopTime=70.0 -r=PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res_2.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 3
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_org.xml", "PistonCylinder.CR_paramInput", "7.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_3.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02 -override stopTime=70.0 -r=PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res_3.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Change multiple parameters </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRun=1
param2change=[
    'ramp_zeta.height', 'ramp_zeta.startTime',
    'ramp_zeta1.height', 'ramp_zeta1.startTime',
    'ramp_p1.height', 'ramp_p1.startTime',
    'ramp_fracFuel.offset',
]
value2set=[
    9.0, 10.0,
    9.0, 30.0,
    100.0*1000.0, 50.0,
    0.05,
]
stopTime=70.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2change)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(fullpathModel+'_init.xml')+'", '+ '"'+param2change[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(fullpathModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# iRun=1
# ...Saving parameter setting file...
# send: system("cp PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_org.xml PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml", "ramp_zeta.height", "9.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml", "ramp_zeta.startTime", "10.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml", "ramp_zeta1.height", "9.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml", "ramp_zeta1.startTime", "30.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml", "ramp_p1.height", "100000.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml", "ramp_p1.startTime", "50.0", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml", "ramp_fracFuel.offset", "0.05", "PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init.xml PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_init_1.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02 -override stopTime=70.0 -r=PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res_1.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process</h1>

# %%
n_df=100
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#           time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0     0.000000         0.000000    -209.439510           -209.439510
# 1     0.140562       -33.810002    -260.126988           -260.126988
# 2     0.281124       -71.445771    -272.555840           -272.555840
# 3     0.421687      -110.019635    -275.603488           -275.603488
# 4     0.562249      -148.823532    -276.350734           -276.350734
# ..         ...              ...            ...                   ...
# 507  69.578313    -19493.209466    -294.216128           -294.216128
# 508  69.718876    -19534.565146    -294.216128           -294.216128
# 509  69.859438    -19575.920827    -294.216128           -294.216128
# 510  70.000000    -19617.276507    -294.216128           -294.216128
# 511  70.000000    -19617.276507    -294.216128           -294.216128
#
#      der(damper1.w_rel)  der(PistonCylinder.phi)  der(inertia1.w)  Orifice.PR  \
# 0         -6.715574e+02               209.439510     6.715574e+02    1.000004
# 1         -1.646707e+02               260.126988     1.646707e+02    1.000007
# 2         -4.037882e+01               272.555840     4.037882e+01    1.000007
# 3         -9.901510e+00               275.603488     9.901510e+00    1.000008
# 4         -2.428837e+00               276.350734     2.428837e+00    1.000008
# ..                  ...                      ...              ...         ...
# 507        7.274181e-10               294.216128    -7.274181e-10    1.000017
# 508        7.012169e-10               294.216128    -7.012169e-10    1.000017
# 509        6.723511e-10               294.216128    -6.723511e-10    1.000017
# 510        6.474821e-10               294.216128    -6.474821e-10    1.000017
# 511        6.474821e-10               294.216128    -6.474821e-10    1.000017
#
#      Orifice.Vth  Orifice.dp  ...  powerSensor1.flange_b.phi  \
# 0       0.848823   -0.441309  ...                   0.000000
# 1       1.054248   -0.680760  ...                  33.810002
# 2       1.104619   -0.747367  ...                  71.445771
# 3       1.116970   -0.764173  ...                 110.019635
# 4       1.119999   -0.768323  ...                 148.823532
# ..           ...         ...  ...                        ...
# 507     1.192393   -1.827662  ...               19493.209466
# 508     1.192393   -1.827662  ...               19534.565146
# 509     1.192393   -1.827662  ...               19575.920827
# 510     1.192393   -1.827662  ...               19617.276507
# 511     1.192393   -1.827662  ...               19617.276507
#
#      powerSensor1.flange_b.tau  ramp_T1.y  ramp_fracFuel.y  ramp_p1.y  \
# 0                    -2.765952     288.15             0.01   101325.0
# 1                    -2.765941     288.15             0.01   101325.0
# 2                    -2.765937     288.15             0.01   101325.0
# 3                    -2.765936     288.15             0.01   101325.0
# 4                    -2.765936     288.15             0.01   101325.0
# ..                         ...        ...              ...        ...
# 507                  -2.942161     288.15             0.01   106325.0
# 508                  -2.942161     288.15             0.01   106325.0
# 509                  -2.942161     288.15             0.01   106325.0
# 510                  -2.942161     288.15             0.01   106325.0
# 511                  -2.942161     288.15             0.01   106325.0
#
#      ramp_zeta.y  ramp_zeta1.y  torque1.flange.phi  torque1.flange.tau  \
# 0            1.0           1.0            0.000000                   0
# 1            1.0           1.0           33.810002                   0
# 2            1.0           1.0           71.445771                   0
# 3            1.0           1.0          110.019635                   0
# 4            1.0           1.0          148.823532                   0
# ..           ...           ...                 ...                 ...
# 507          2.0           2.0        19493.209466                   0
# 508          2.0           2.0        19534.565146                   0
# 509          2.0           2.0        19575.920827                   0
# 510          2.0           2.0        19617.276507                   0
# 511          2.0           2.0        19617.276507                   0
#
#      torque1.tau
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 507            0
# 508            0
# 509            0
# 510            0
# 511            0
#
# [512 rows x 889 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'damper1.phi_rel',
#  'damper1.w_rel',
#  'der(damper1.phi_rel)',
#  'der(damper1.w_rel)',
#  'der(PistonCylinder.phi)',
#  'der(inertia1.w)',
#  'Orifice.PR',
#  'Orifice.Vth',
#  'Orifice.dp',
#  'Orifice.fluid_1.MM',
#  'Orifice.fluid_1.R',
#  'Orifice.fluid_1.T',
#  'Orifice.fluid_1.T_degC',
#  'Orifice.fluid_1.X[1]',
#  'Orifice.fluid_1.d',
#  'Orifice.fluid_1.h',
#  'Orifice.fluid_1.p_bar',
#  'Orifice.fluid_1.u',
#  'Orifice.fluid_2.MM',
#  'Orifice.fluid_2.R',
#  'Orifice.fluid_2.T',
#  'Orifice.fluid_2.T_degC',
#  'Orifice.fluid_2.X[1]',
#  'Orifice.fluid_2.d',
#  'Orifice.fluid_2.h',
#  'Orifice.fluid_2.p_bar',
#  'Orifice.fluid_2.u',
#  'Orifice.m_flow_max',
#  'Orifice.m_flow_min',
#  'Orifice.port_2.h_outflow',
#  'Orifice.s_fluid_1',
#  'Orifice.s_fluid_2',
#  'Orifice.u_zeta',
#  'Orifice1.PR',
#  'Orifice1.Vth',
#  'Orifice1.dp',
#  'Orifice1.fluid_1.MM',
#  'Orifice1.fluid_1.R',
#  'Orifice1.fluid_1.T',
#  'Orifice1.fluid_1.T_degC',
#  'Orifice1.fluid_1.X[1]',
#  'Orifice1.fluid_1.d',
#  'Orifice1.fluid_1.h',
#  'Orifice1.fluid_1.p_bar',
#  'Orifice1.fluid_1.u',
#  'Orifice1.fluid_2.MM',
#  'Orifice1.fluid_2.R',
#  'Orifice1.fluid_2.T',
#  'Orifice1.fluid_2.T_degC',
#  'Orifice1.fluid_2.X[1]',
#  'Orifice1.fluid_2.d',
#  'Orifice1.fluid_2.h',
#  'Orifice1.fluid_2.p_bar',
#  'Orifice1.fluid_2.u',
#  'Orifice1.m_flow_max',
#  'Orifice1.m_flow_min',
#  'Orifice1.port_2.h_outflow',
#  'Orifice1.s_fluid_1',
#  'Orifice1.s_fluid_2',
#  'Orifice1.u_zeta',
#  'PistonCylinder.Nmech',
#  'PistonCylinder.OttoCycle.ER',
#  'PistonCylinder.OttoCycle.W_1_2',
#  'PistonCylinder.OttoCycle.W_3_4',
#  'PistonCylinder.OttoCycle.arr_T[2]',
#  'PistonCylinder.OttoCycle.arr_T[3]',
#  'PistonCylinder.OttoCycle.arr_T[4]',
#  'PistonCylinder.OttoCycle.arr_T[5]',
#  'PistonCylinder.OttoCycle.arr_h[2]',
#  'PistonCylinder.OttoCycle.arr_h[3]',
#  'PistonCylinder.OttoCycle.arr_h[4]',
#  'PistonCylinder.OttoCycle.arr_h[5]',
#  'PistonCylinder.OttoCycle.arr_s[3]',
#  'PistonCylinder.OttoCycle.arr_s[5]',
#  'PistonCylinder.OttoCycle.arr_u[2]',
#  'PistonCylinder.OttoCycle.arr_u[3]',
#  'PistonCylinder.OttoCycle.arr_u[4]',
#  'PistonCylinder.OttoCycle.arr_u[5]',
#  'PistonCylinder.OttoCycle.arr_v[2]',
#  'PistonCylinder.OttoCycle.arr_v[3]',
#  'PistonCylinder.OttoCycle.arr_v[4]',
#  'PistonCylinder.OttoCycle.arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[2].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[3].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[1].ds',
#  'PistonCylinder.OttoCycle.curve_hs[2].ds',
#  'PistonCylinder.OttoCycle.curve_hs[3].ds',
#  'PistonCylinder.OttoCycle.curve_hs[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[2].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[3].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[4].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[1].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[2].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[3].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[4].hUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[2].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[3].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[4].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[1].u_m',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].dp',
#  'PistonCylinder.OttoCycle.curve_pv[2].dp',
#  'PistonCylinder.OttoCycle.curve_pv[3].dp',
#  'PistonCylinder.OttoCycle.curve_pv[4].dp',
#  'PistonCylinder.OttoCycle.curve_pv[1].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[2].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[3].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[4].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[1].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[2].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[3].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[4].vUpper',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].ds',
#  'PistonCylinder.OttoCycle.curve_us[2].ds',
#  'PistonCylinder.OttoCycle.curve_us[3].ds',
#  'PistonCylinder.OttoCycle.curve_us[4].ds',
#  'PistonCylinder.OttoCycle.curve_us[1].uLower',
#  'PistonCylinder.OttoCycle.curve_us[2].uLower',
#  'PistonCylinder.OttoCycle.curve_us[3].uLower',
#  'PistonCylinder.OttoCycle.curve_us[4].uLower',
#  'PistonCylinder.OttoCycle.curve_us[1].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[2].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[3].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[4].uUpper',
#  'PistonCylinder.OttoCycle.effThermal',
#  'PistonCylinder.OttoCycle.fluidState_1.MM',
#  'PistonCylinder.OttoCycle.fluidState_1.R',
#  'PistonCylinder.OttoCycle.fluidState_1.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_1.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_1.d',
#  'PistonCylinder.OttoCycle.fluidState_1.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_2.MM',
#  'PistonCylinder.OttoCycle.fluidState_2.R',
#  'PistonCylinder.OttoCycle.fluidState_2.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_2.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_2.d',
#  'PistonCylinder.OttoCycle.fluidState_2.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_3.MM',
#  'PistonCylinder.OttoCycle.fluidState_3.R',
#  'PistonCylinder.OttoCycle.fluidState_3.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_3.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_3.d',
#  'PistonCylinder.OttoCycle.fluidState_3.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_4.MM',
#  'PistonCylinder.OttoCycle.fluidState_4.R',
#  'PistonCylinder.OttoCycle.fluidState_4.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_4.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_4.d',
#  'PistonCylinder.OttoCycle.fluidState_4.p_bar',
#  'PistonCylinder.OttoCycle.y_Q_2_3',
#  'PistonCylinder.OttoCycle.y_Q_4_1',
#  'PistonCylinder.OttoCycle.y_m_fuel',
#  'PistonCylinder.Q_add',
#  'PistonCylinder.Q_reject',
#  'PistonCylinder.V_flow',
#  'PistonCylinder.VolBDC',
#  'PistonCylinder.VolTDC',
#  'PistonCylinder.WexhCycle',
#  'PistonCylinder.WintkCycle',
#  'PistonCylinder.WoutCycle',
#  'PistonCylinder.arr_V[7]',
#  'PistonCylinder.arr_V[8]',
#  'PistonCylinder.arr_p[2]',
#  'PistonCylinder.arr_p[3]',
#  'PistonCylinder.arr_p[4]',
#  'PistonCylinder.arr_p[6]',
#  'PistonCylinder.arr_p[7]',
#  'PistonCylinder.dH_1_2_cycle',
#  'PistonCylinder.dU_1_2_cycle',
#  'PistonCylinder.dh_state4_port2',
#  'PistonCylinder.flange_1.tau',
#  'PistonCylinder.fluid_1.MM',
#  'PistonCylinder.fluid_1.R',
#  'PistonCylinder.fluid_1.T',
#  'PistonCylinder.fluid_1.T_degC',
#  'PistonCylinder.fluid_1.X[1]',
#  'PistonCylinder.fluid_1.d',
#  'PistonCylinder.fluid_1.p_bar',
#  'PistonCylinder.fluid_2.MM',
#  'PistonCylinder.fluid_2.R',
#  'PistonCylinder.fluid_2.T',
#  'PistonCylinder.fluid_2.T_degC',
#  'PistonCylinder.fluid_2.X[1]',
#  'PistonCylinder.fluid_2.d',
#  'PistonCylinder.fluid_2.p_bar',
#  'PistonCylinder.fluid_2.u',
#  'PistonCylinder.m_flow',
#  'PistonCylinder.m_flow_max',
#  'PistonCylinder.m_flow_min',
#  'PistonCylinder.phi',
#  'PistonCylinder.port_2.h_outflow',
#  'PistonCylinder.pwrCycle',
#  'PistonCylinder.pwrExh',
#  'PistonCylinder.pwrIntk',
#  'PistonCylinder.pwrOut',
#  'PistonCylinder.pwrPumping',
#  'PistonCylinder.pwrPumpingqPwrCycle',
#  'PistonCylinder.pwr_cmp',
#  'PistonCylinder.pwr_exp',
#  'PistonCylinder.s_fluid_1',
#  'PistonCylinder.s_fluid_2',
#  'PistonCylinder.trqOut',
#  'PistonCylinder.u_fracFuel',
#  'PistonCylinder.y_m_flow_fuel',
#  'boundary.T_in',
#  'boundary.medium.MM',
#  'boundary.medium.R',
#  'boundary.medium.T_degC',
#  'boundary.medium.X[1]',
#  'boundary.medium.d',
#  'boundary.medium.p_bar',
#  'boundary.medium.u',
#  'boundary.p_in',
#  'boundary.ports[2].h_outflow',
#  'boundary.ports[2].m_flow',
#  'boundary1.medium.MM',
#  'boundary1.medium.R',
#  'boundary1.medium.T_degC',
#  'boundary1.medium.X[1]',
#  'boundary1.medium.d',
#  'boundary1.medium.p_bar',
#  'boundary1.medium.u',
#  'boundary1.ports[1].h_outflow',
#  'damper1.a_rel',
#  'damper1.lossPower',
#  'damper1.tau',
#  'inertia1.a',
#  'inertia1.flange_b.tau',
#  'inertia1.w',
#  'powerSensor1.power',
#  'ramp_trq.y',
#  'PistonCylinder.OttoCycle.curve_Ts[1].nPts',
#  'PistonCylinder.OttoCycle.curve_Ts[2].nPts',
#  'PistonCylinder.OttoCycle.curve_Ts[3].nPts',
#  'PistonCylinder.OttoCycle.curve_Ts[4].nPts',
#  'PistonCylinder.OttoCycle.curve_hs[1].nPts',
#  'PistonCylinder.OttoCycle.curve_hs[2].nPts',
#  'PistonCylinder.OttoCycle.curve_hs[3].nPts',
#  'PistonCylinder.OttoCycle.curve_hs[4].nPts',
#  'PistonCylinder.OttoCycle.curve_pVol[1].nPts',
#  'PistonCylinder.OttoCycle.curve_pVol[2].nPts',
#  'PistonCylinder.OttoCycle.curve_pVol[3].nPts',
#  'PistonCylinder.OttoCycle.curve_pVol[4].nPts',
#  'PistonCylinder.OttoCycle.curve_pv[1].nPts',
#  'PistonCylinder.OttoCycle.curve_pv[2].nPts',
#  'PistonCylinder.OttoCycle.curve_pv[3].nPts',
#  'PistonCylinder.OttoCycle.curve_pv[4].nPts',
#  'PistonCylinder.OttoCycle.curve_us[1].nPts',
#  'PistonCylinder.OttoCycle.curve_us[2].nPts',
#  'PistonCylinder.OttoCycle.curve_us[3].nPts',
#  'PistonCylinder.OttoCycle.curve_us[4].nPts',
#  'PistonCylinder.OttoCycle.flag_W34_gt_Q23',
#  'Orifice.fluid_1.p',
#  'Orifice.fluid_1.state.T',
#  'Orifice.fluid_1.state.p',
#  'Orifice.fluid_2.p',
#  'Orifice.fluid_2.state.T',
#  'Orifice.fluid_2.state.p',
#  'Orifice.port_1.h_outflow',
#  'Orifice.port_1.m_flow',
#  'Orifice.port_1.p',
#  'Orifice.port_2.m_flow',
#  'Orifice.port_2.p',
#  'Orifice.zeta',
#  'Orifice1.fluid_1.p',
#  'Orifice1.fluid_1.state.T',
#  'Orifice1.fluid_1.state.p',
#  'Orifice1.fluid_2.state.T',
#  'Orifice1.port_1.h_outflow',
#  'Orifice1.port_1.m_flow',
#  'Orifice1.port_1.p',
#  'Orifice1.port_2.m_flow',
#  'Orifice1.zeta',
#  'PistonCylinder.OttoCycle.Q_2_3',
#  'PistonCylinder.OttoCycle.Q_4_1',
#  'PistonCylinder.OttoCycle.Vol1',
#  'PistonCylinder.OttoCycle.Vol2',
#  'PistonCylinder.OttoCycle.Vol3',
#  'PistonCylinder.OttoCycle.Vol4',
#  'PistonCylinder.OttoCycle.WoutCycle',
#  'PistonCylinder.OttoCycle.arr_T[1]',
#  'PistonCylinder.OttoCycle.arr_V[1]',
#  'PistonCylinder.OttoCycle.arr_V[2]',
#  'PistonCylinder.OttoCycle.arr_V[3]',
#  'PistonCylinder.OttoCycle.arr_V[4]',
#  'PistonCylinder.OttoCycle.arr_V[5]',
#  'PistonCylinder.OttoCycle.arr_h[1]',
#  'PistonCylinder.OttoCycle.arr_p[1]',
#  'PistonCylinder.OttoCycle.arr_p[2]',
#  'PistonCylinder.OttoCycle.arr_p[3]',
#  'PistonCylinder.OttoCycle.arr_p[4]',
#  'PistonCylinder.OttoCycle.arr_p[5]',
#  'PistonCylinder.OttoCycle.arr_s[1]',
#  'PistonCylinder.OttoCycle.arr_s[2]',
#  'PistonCylinder.OttoCycle.arr_s[4]',
#  'PistonCylinder.OttoCycle.arr_u[1]',
#  'PistonCylinder.OttoCycle.arr_v[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].u_p',
#  'PistonCylinder.OttoCycle.curve_Ts[2].u_p',
#  'PistonCylinder.OttoCycle.curve_Ts[3].u_p',
#  'PistonCylinder.OttoCycle.curve_Ts[4].u_p',
#  'PistonCylinder.OttoCycle.curve_Ts[1].u_sLower',
#  'PistonCylinder.OttoCycle.curve_Ts[2].u_sLower',
#  'PistonCylinder.OttoCycle.curve_Ts[3].u_sLower',
#  'PistonCylinder.OttoCycle.curve_Ts[4].u_sLower',
#  'PistonCylinder.OttoCycle.curve_Ts[1].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[2].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[3].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[4].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[1]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[10]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[1]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[10]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[1]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[10]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[1]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[10]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_hs[1].u_p',
#  'PistonCylinder.OttoCycle.curve_hs[2].u_p',
#  'PistonCylinder.OttoCycle.curve_hs[3].u_p',
#  'PistonCylinder.OttoCycle.curve_hs[4].u_p',
#  'PistonCylinder.OttoCycle.curve_hs[1].u_sLower',
#  'PistonCylinder.OttoCycle.curve_hs[2].u_sLower',
#  'PistonCylinder.OttoCycle.curve_hs[3].u_sLower',
#  'PistonCylinder.OttoCycle.curve_hs[4].u_sLower',
#  'PistonCylinder.OttoCycle.curve_hs[1].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_hs[2].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_hs[3].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_hs[4].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].u_m',
#  'PistonCylinder.OttoCycle.curve_pVol[3].u_m',
#  'PistonCylinder.OttoCycle.curve_pVol[4].u_m',
#  'PistonCylinder.OttoCycle.curve_pVol[1].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pVol[2].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pVol[3].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pVol[4].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pVol[1].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[2].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[3].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[4].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].u_s',
#  'PistonCylinder.OttoCycle.curve_pVol[2].u_s',
#  'PistonCylinder.OttoCycle.curve_pVol[3].u_s',
#  'PistonCylinder.OttoCycle.curve_pVol[4].u_s',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[1]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[1]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[10]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[1]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[10]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[1]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[10]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[1]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[10]',
#  'PistonCylinder.OttoCycle.curve_pv[1].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pv[2].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pv[3].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pv[4].u_pLower',
#  'PistonCylinder.OttoCycle.curve_pv[1].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pv[2].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pv[3].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pv[4].u_pUpper',
#  'PistonCylinder.OttoCycle.curve_pv[1].u_s',
#  'PistonCylinder.OttoCycle.curve_pv[2].u_s',
#  'PistonCylinder.OttoCycle.curve_pv[3].u_s',
#  'PistonCylinder.OttoCycle.curve_pv[4].u_s',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[1]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[1]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[10]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[1]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[10]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[1]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[10]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[1]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[10]',
#  'PistonCylinder.OttoCycle.curve_us[1].u_p',
#  'PistonCylinder.OttoCycle.curve_us[2].u_p',
#  'PistonCylinder.OttoCycle.curve_us[3].u_p',
#  'PistonCylinder.OttoCycle.curve_us[4].u_p',
#  'PistonCylinder.OttoCycle.curve_us[1].u_sLower',
#  'PistonCylinder.OttoCycle.curve_us[2].u_sLower',
#  'PistonCylinder.OttoCycle.curve_us[3].u_sLower',
#  'PistonCylinder.OttoCycle.curve_us[4].u_sLower',
#  'PistonCylinder.OttoCycle.curve_us[1].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_us[2].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_us[3].u_sUpper',
#  'PistonCylinder.OttoCycle.curve_us[4].u_sUpper',
#  'PistonCylinder.OttoCycle.fluidState_1.T',
#  'PistonCylinder.OttoCycle.fluidState_1.h',
#  'PistonCylinder.OttoCycle.fluidState_1.p',
#  'PistonCylinder.OttoCycle.fluidState_1.state.T',
#  'PistonCylinder.OttoCycle.fluidState_1.state.p',
#  'PistonCylinder.OttoCycle.fluidState_1.u',
#  'PistonCylinder.OttoCycle.fluidState_2.T',
#  'PistonCylinder.OttoCycle.fluidState_2.h',
#  'PistonCylinder.OttoCycle.fluidState_2.p',
#  'PistonCylinder.OttoCycle.fluidState_2.state.T',
#  'PistonCylinder.OttoCycle.fluidState_2.state.p',
#  'PistonCylinder.OttoCycle.fluidState_2.u',
#  'PistonCylinder.OttoCycle.fluidState_3.T',
#  'PistonCylinder.OttoCycle.fluidState_3.h',
#  'PistonCylinder.OttoCycle.fluidState_3.p',
#  'PistonCylinder.OttoCycle.fluidState_3.state.T',
#  'PistonCylinder.OttoCycle.fluidState_3.state.p',
#  'PistonCylinder.OttoCycle.fluidState_3.u',
#  'PistonCylinder.OttoCycle.fluidState_4.T',
#  'PistonCylinder.OttoCycle.fluidState_4.h',
#  'PistonCylinder.OttoCycle.fluidState_4.p',
#  'PistonCylinder.OttoCycle.fluidState_4.state.T',
#  'PistonCylinder.OttoCycle.fluidState_4.state.p',
#  'PistonCylinder.OttoCycle.fluidState_4.u',
#  'PistonCylinder.OttoCycle.fracFuel',
#  'PistonCylinder.OttoCycle.massFluidCycle',
#  'PistonCylinder.OttoCycle.massFuelCycle',
#  'PistonCylinder.OttoCycle.s_state_1',
#  'PistonCylinder.OttoCycle.s_state_2',
#  'PistonCylinder.OttoCycle.s_state_3',
#  'PistonCylinder.OttoCycle.s_state_4',
#  'PistonCylinder.OttoCycle.u_fracFuel',
#  'PistonCylinder.OttoCycle.u_p_fluidState_1',
#  'PistonCylinder.OttoCycle.u_u_fluidState_1',
#  'PistonCylinder.OttoCycle.v1',
#  'PistonCylinder.OttoCycle.v2',
#  'PistonCylinder.OttoCycle.v3',
#  'PistonCylinder.OttoCycle.v4',
#  'PistonCylinder.OttoCycle.y_T_fluidState_2',
#  'PistonCylinder.OttoCycle.y_T_fluidState_3',
#  'PistonCylinder.OttoCycle.y_T_fluidState_4',
#  'PistonCylinder.OttoCycle.y_WoutCycle',
#  'PistonCylinder.OttoCycle.y_h_fluidState_4',
#  'PistonCylinder.OttoCycle.y_m_fluid',
#  'PistonCylinder.OttoCycle.y_p_fluidState_2',
#  'PistonCylinder.OttoCycle.y_p_fluidState_3',
#  'PistonCylinder.OttoCycle.y_p_fluidState_4',
#  'PistonCylinder.OttoCycle.y_u_fluidState_4',
#  'PistonCylinder.arr_V[1]',
#  'PistonCylinder.arr_V[2]',
#  'PistonCylinder.arr_V[3]',
#  'PistonCylinder.arr_V[4]',
#  'PistonCylinder.arr_V[5]',
#  'PistonCylinder.arr_V[6]',
#  'PistonCylinder.arr_p[1]',
#  'PistonCylinder.arr_p[5]',
#  'PistonCylinder.arr_p[8]',
#  'PistonCylinder.flange_1.phi',
#  'PistonCylinder.flange_2.phi',
#  'PistonCylinder.flange_2.tau',
#  'PistonCylinder.fluid_1.h',
#  'PistonCylinder.fluid_1.p',
#  'PistonCylinder.fluid_1.state.T',
#  'PistonCylinder.fluid_1.state.p',
#  'PistonCylinder.fluid_1.u',
#  'PistonCylinder.fluid_2.h',
#  'PistonCylinder.fluid_2.p',
#  'PistonCylinder.fluid_2.state.T',
#  'PistonCylinder.fluid_2.state.p',
#  'PistonCylinder.m_flow_fuel',
#  'PistonCylinder.omega',
#  'PistonCylinder.port_1.h_outflow',
#  'PistonCylinder.port_1.m_flow',
#  'PistonCylinder.port_1.p',
#  'PistonCylinder.port_2.m_flow',
#  'PistonCylinder.port_2.p',
#  'PistonCylinder.pwr',
#  'PistonCylinder.trq',
#  'boundary.medium.T',
#  'boundary.medium.h',
#  'boundary.medium.p',
#  'boundary.medium.state.T',
#  'boundary.medium.state.p',
#  'boundary.ports[1].h_outflow',
#  'boundary.ports[1].m_flow',
#  'boundary.ports[1].p',
#  'boundary.ports[2].p',
#  'boundary1.medium.h',
#  'boundary1.ports[1].m_flow',
#  'damper1.flange_a.phi',
#  'damper1.flange_a.tau',
#  'damper1.flange_b.tau',
#  'fixed1.flange.tau',
#  'inertia1.flange_a.phi',
#  'inertia1.flange_a.tau',
#  'inertia1.flange_b.phi',
#  'inertia1.phi',
#  'powerSensor1.flange_a.phi',
#  'powerSensor1.flange_a.tau',
#  'powerSensor1.flange_b.phi',
#  'powerSensor1.flange_b.tau',
#  'ramp_T1.y',
#  'ramp_fracFuel.y',
#  'ramp_p1.y',
#  'ramp_zeta.y',
#  'ramp_zeta1.y',
#  'torque1.flange.phi',
#  'torque1.flange.tau',
#  'torque1.tau']

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=3


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res_2.csv
# i_df=3
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res_3.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderIdealOttoMV01_ex02_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#           time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0     0.000000         0.000000    -209.439510           -209.439510
# 1     0.140562       -99.118690   -1017.488429          -1017.488429
# 2     0.281124      -259.218286   -1215.542951          -1215.542951
# 3     0.421687      -434.263368   -1264.080769          -1264.080769
# 4     0.562249      -612.971139   -1275.975555          -1275.975555
# ..         ...              ...            ...                   ...
# 507  69.578313   -107934.728071   -2595.865949          -2595.865949
# 508  69.718876   -108299.608827   -2595.865949          -2595.865949
# 509  69.859438   -108664.489583   -2595.865949          -2595.865949
# 510  70.000000   -109029.370339   -2595.865949          -2595.865949
# 511  70.000000   -109029.370339   -2595.865949          -2595.865949
#
#      der(damper1.w_rel)  der(PistonCylinder.phi)  der(inertia1.w)  Orifice.PR  \
# 0         -1.070677e+04               209.439510     1.070677e+04    1.000004
# 1         -2.624541e+03              1017.488429     2.624541e+03    1.000103
# 2         -6.432187e+02              1215.542951     6.432187e+02    1.000147
# 3         -1.576291e+02              1264.080769     1.576291e+02    1.000159
# 4         -3.862822e+01              1275.975555     3.862822e+01    1.000162
# ..                  ...                      ...              ...         ...
# 507       -1.121734e-07              2595.865949     1.121734e-07    1.006647
# 508       -1.083755e-07              2595.865949     1.083755e-07    1.006647
# 509       -1.045919e-07              2595.865949     1.045919e-07    1.006647
# 510       -1.007407e-07              2595.865949     1.007407e-07    1.006647
# 511       -1.007052e-07              2595.865949     1.007052e-07    1.006647
#
#      Orifice.Vth   Orifice.dp  ...  powerSensor1.flange_b.phi  \
# 0       0.848823    -0.441309  ...                   0.000000
# 1       4.123301   -10.413549  ...                  99.118690
# 2       4.925687   -14.860804  ...                 259.218286
# 3       5.122314   -16.070928  ...                 434.263368
# 4       5.170498   -16.374702  ...                 612.971139
# ..           ...          ...  ...                        ...
# 507    10.451184 -1329.292736  ...              107934.728071
# 508    10.451184 -1329.292736  ...              108299.608827
# 509    10.451184 -1329.292736  ...              108664.489583
# 510    10.451184 -1329.292736  ...              109029.370339
# 511    10.451184 -1329.292736  ...              109029.370339
#
#      powerSensor1.flange_b.tau  ramp_T1.y  ramp_fracFuel.y  ramp_p1.y  \
# 0                   -12.801167     288.15             0.05   101325.0
# 1                   -12.799425     288.15             0.05   101325.0
# 2                   -12.798648     288.15             0.05   101325.0
# 3                   -12.798437     288.15             0.05   101325.0
# 4                   -12.798384     288.15             0.05   101325.0
# ..                         ...        ...              ...        ...
# 507                 -25.958659     288.15             0.05   201325.0
# 508                 -25.958659     288.15             0.05   201325.0
# 509                 -25.958659     288.15             0.05   201325.0
# 510                 -25.958659     288.15             0.05   201325.0
# 511                 -25.958659     288.15             0.05   201325.0
#
#      ramp_zeta.y  ramp_zeta1.y  torque1.flange.phi  torque1.flange.tau  \
# 0            1.0           1.0            0.000000                   0
# 1            1.0           1.0           99.118690                   0
# 2            1.0           1.0          259.218286                   0
# 3            1.0           1.0          434.263368                   0
# 4            1.0           1.0          612.971139                   0
# ..           ...           ...                 ...                 ...
# 507         10.0          10.0       107934.728071                   0
# 508         10.0          10.0       108299.608827                   0
# 509         10.0          10.0       108664.489583                   0
# 510         10.0          10.0       109029.370339                   0
# 511         10.0          10.0       109029.370339                   0
#
#      torque1.tau
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 507            0
# 508            0
# 509            0
# 510            0
# 511            0
#
# [512 rows x 889 columns]

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
i_df=1
varName="Orifice.zeta"
ylabel='dp coefficient [nond]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="Orifice1.zeta"
ylabel='dp coefficient [nond]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="boundary.p_in"
ylabel='Pressure [kPa]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=1
varName="PistonCylinder.Nmech"
ylabel='Rotation speed [rpm]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.Nmech"
ylabel='Rotation speed [rpm]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(12100, 12300)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.pwrOut"
ylabel='Power [W]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.pwrOut"
ylabel='Power [W]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(16000, 16500)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.trqOut"
ylabel='Torque [N*m]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.trqOut"
ylabel='Torque [N*m]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(12.7, 12.9)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.pwrPumping"
ylabel='power [W]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.pwrPumping"
ylabel='power [W]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(0, 12)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.pwrPumpingqPwrCycle"
ylabel='fraction [nond]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.pwrPumpingqPwrCycle"
ylabel='fraction [nond]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(0, 0.001)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.port_1.p"
ylabel='Pressure [kPa]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.port_1.p"
ylabel='Pressure [kPa]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(101, 102)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.port_2.p"
ylabel='Pressure [kPa]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="PistonCylinder.port_2.p"
ylabel='Pressure [kPa]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(101, 101.5)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %%
i_df=1
tgtTime=45
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 328
# time of extracted = 44.97991967871486
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

'''or(i==3)or(i==4)or(i==5)or(i==6)or(i==7)'''
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
tgtTime=70
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 511
# time of extracted = 70.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------
