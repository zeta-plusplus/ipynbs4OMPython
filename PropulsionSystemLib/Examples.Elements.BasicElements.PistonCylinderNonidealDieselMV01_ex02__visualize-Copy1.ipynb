# %% [markdown]
# <h1>Visualize: PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderNonidealDieselMV01_ex02</h1>
# <h2>notebook: rev004</h2>
# <p>compatability with OpenModelica v1.17</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderNonidealDieselMV01_ex02'
nmModel='PistonCylinderNonidealDieselMV01_ex02'
stopTime=100.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderNonidealDieselMV01_ex02
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/Examples/Elements/BasicElements/PistonCylinderNonidealDieselMV01_ex02.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderNonidealDieselMV01_ex02_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#         time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0       0.00         0.000000    -209.439510           -209.439510
# 1       0.05       -10.415597    -207.213935           -207.213935
# 2       0.10       -20.724239    -205.159650           -205.159650
# 3       0.15       -30.934189    -203.264469           -203.264469
# 4       0.20       -41.053119    -201.516940           -201.516940
# ...      ...              ...            ...                   ...
# 2001   99.85    -18891.366748    -192.295785           -192.295785
# 2002   99.90    -18900.981537    -192.295785           -192.295785
# 2003   99.95    -18910.596326    -192.295785           -192.295785
# 2004  100.00    -18920.211115    -192.295785           -192.295785
# 2005  100.00    -18920.211115    -192.295785           -192.295785
#
#       der(damper1.w_rel)  Orifice.AmechTh  Orifice.PR  Orifice.V_flow  \
# 0           4.630919e+01         0.000079    1.002715        0.001662
# 1           4.275688e+01         0.000079    1.002658        0.001645
# 2           3.945560e+01         0.000079    1.002605        0.001628
# 3           3.639047e+01         0.000079    1.002557        0.001613
# 4           3.354713e+01         0.000079    1.002514        0.001600
# ...                  ...              ...         ...             ...
# 2001        4.649436e-10         0.000079    1.002289        0.001527
# 2002        4.632028e-10         0.000079    1.002289        0.001527
# 2003        4.586909e-10         0.000079    1.002289        0.001527
# 2004        4.571277e-10         0.000079    1.002289        0.001527
# 2005        4.594014e-10         0.000079    1.002289        0.001527
#
#       Orifice.Vth  Orifice.dp  ...  torque1.flange.phi  torque1.tau  \
# 0       21.163206  274.328864  ...           -0.000000            0
# 1       20.939514  268.560276  ...           10.415597            0
# 2       20.733004  263.289211  ...           20.724239            0
# 3       20.542460  258.472002  ...           30.934189            0
# 4       20.366738  254.068912  ...           41.053119            0
# ...           ...         ...  ...                 ...          ...
# 2001    19.439131  231.452713  ...        18891.366748            0
# 2002    19.439131  231.452713  ...        18900.981537            0
# 2003    19.439131  231.452713  ...        18910.596326            0
# 2004    19.439131  231.452713  ...        18920.211115            0
# 2005    19.439131  231.452713  ...        18920.211115            0
#
#       volumeFlowRate_fuel.V_flow  volumeFlowRate_fuel.d  \
# 0                   7.069061e-08            1000.737381
# 1                   7.063540e-08            1000.737540
# 2                   7.058491e-08            1000.737684
# 3                   7.053873e-08            1000.737817
# 4                   7.049650e-08            1000.737938
# ...                          ...                    ...
# 2001                7.964973e-08            1000.738559
# 2002                7.964973e-08            1000.738559
# 2003                7.964973e-08            1000.738559
# 2004                7.964973e-08            1000.738559
# 2005                7.964973e-08            1000.738559
#
#       volumeFlowRate_fuel.port_a.h_outflow  volumeFlowRate_fuel.port_a.m_flow  \
# 0                             88995.382650                           0.000071
# 1                             88995.672039                           0.000071
# 2                             88995.936470                           0.000071
# 3                             88996.178132                           0.000071
# 4                             88996.399019                           0.000071
# ...                                    ...                                ...
# 2001                          88997.533592                           0.000080
# 2002                          88997.533592                           0.000080
# 2003                          88997.533592                           0.000080
# 2004                          88997.533592                           0.000080
# 2005                          88997.533592                           0.000080
#
#       volumeFlowRate_fuel.port_a.p  volumeFlowRate_fuel.port_b.m_flow  \
# 0                     5.474046e+06                          -0.000071
# 1                     5.474358e+06                          -0.000071
# 2                     5.474644e+06                          -0.000071
# 3                     5.474905e+06                          -0.000071
# 4                     5.475143e+06                          -0.000071
# ...                            ...                                ...
# 2001                  5.476368e+06                          -0.000080
# 2002                  5.476368e+06                          -0.000080
# 2003                  5.476368e+06                          -0.000080
# 2004                  5.476368e+06                          -0.000080
# 2005                  5.476368e+06                          -0.000080
#
#       volumeFlowRate_fuel.port_b.p  volumeFlowRate_fuel.rho_a_inflow
# 0                     5.474046e+06                       1000.737381
# 1                     5.474358e+06                       1000.737540
# 2                     5.474644e+06                       1000.737684
# 3                     5.474905e+06                       1000.737817
# 4                     5.475143e+06                       1000.737938
# ...                            ...                               ...
# 2001                  5.476368e+06                       1000.738559
# 2002                  5.476368e+06                       1000.738559
# 2003                  5.476368e+06                       1000.738559
# 2004                  5.476368e+06                       1000.738559
# 2005                  5.476368e+06                       1000.738559
#
# [2006 rows x 1196 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'damper1.phi_rel',
#  'damper1.w_rel',
#  'der(damper1.phi_rel)',
#  'der(damper1.w_rel)',
#  'Orifice.AmechTh',
#  'Orifice.PR',
#  'Orifice.V_flow',
#  'Orifice.Vth',
#  'Orifice.dp',
#  'Orifice.fluidStat_th.MM',
#  'Orifice.fluidStat_th.R',
#  'Orifice.fluidStat_th.T',
#  'Orifice.fluidStat_th.T_degC',
#  'Orifice.fluidStat_th.X[1]',
#  'Orifice.fluidStat_th.d',
#  'Orifice.fluidStat_th.h',
#  'Orifice.fluidStat_th.p',
#  'Orifice.fluidStat_th.p_bar',
#  'Orifice.fluidStat_th.u',
#  'Orifice.fluid_1.MM',
#  'Orifice.fluid_1.R',
#  'Orifice.fluid_1.T',
#  'Orifice.fluid_1.T_degC',
#  'Orifice.fluid_1.X[1]',
#  'Orifice.fluid_1.d',
#  'Orifice.fluid_1.h',
#  'Orifice.fluid_1.p_bar',
#  'Orifice.fluid_1.u',
#  'Orifice.fluid_2.MM',
#  'Orifice.fluid_2.R',
#  'Orifice.fluid_2.T',
#  'Orifice.fluid_2.T_degC',
#  'Orifice.fluid_2.X[1]',
#  'Orifice.fluid_2.d',
#  'Orifice.fluid_2.h',
#  'Orifice.fluid_2.p_bar',
#  'Orifice.fluid_2.u',
#  'Orifice.fluid_th.MM',
#  'Orifice.fluid_th.R',
#  'Orifice.fluid_th.T',
#  'Orifice.fluid_th.T_degC',
#  'Orifice.fluid_th.X[1]',
#  'Orifice.fluid_th.d',
#  'Orifice.fluid_th.h',
#  'Orifice.fluid_th.p',
#  'Orifice.fluid_th.p_bar',
#  'Orifice.fluid_th.u',
#  'Orifice.m_flow',
#  'Orifice.m_flow_max',
#  'Orifice.m_flow_min',
#  'Orifice.s_fluid_1',
#  'Orifice.s_fluid_2',
#  'Orifice.s_fluid_th',
#  'Orifice1.AmechTh',
#  'Orifice1.PR',
#  'Orifice1.V_flow',
#  'Orifice1.Vth',
#  'Orifice1.dp',
#  'Orifice1.fluidStat_th.MM',
#  'Orifice1.fluidStat_th.R',
#  'Orifice1.fluidStat_th.T',
#  'Orifice1.fluidStat_th.T_degC',
#  'Orifice1.fluidStat_th.X[1]',
#  'Orifice1.fluidStat_th.d',
#  'Orifice1.fluidStat_th.h',
#  'Orifice1.fluidStat_th.p',
#  'Orifice1.fluidStat_th.p_bar',
#  'Orifice1.fluidStat_th.u',
#  'Orifice1.fluid_1.MM',
#  'Orifice1.fluid_1.R',
#  'Orifice1.fluid_1.T',
#  'Orifice1.fluid_1.T_degC',
#  'Orifice1.fluid_1.X[1]',
#  'Orifice1.fluid_1.d',
#  'Orifice1.fluid_1.p_bar',
#  'Orifice1.fluid_1.u',
#  'Orifice1.fluid_2.MM',
#  'Orifice1.fluid_2.R',
#  'Orifice1.fluid_2.T',
#  'Orifice1.fluid_2.T_degC',
#  'Orifice1.fluid_2.X[1]',
#  'Orifice1.fluid_2.d',
#  'Orifice1.fluid_2.h',
#  'Orifice1.fluid_2.p_bar',
#  'Orifice1.fluid_2.u',
#  'Orifice1.fluid_th.MM',
#  'Orifice1.fluid_th.R',
#  'Orifice1.fluid_th.T',
#  'Orifice1.fluid_th.T_degC',
#  'Orifice1.fluid_th.X[1]',
#  'Orifice1.fluid_th.d',
#  'Orifice1.fluid_th.h',
#  'Orifice1.fluid_th.p',
#  'Orifice1.fluid_th.p_bar',
#  'Orifice1.fluid_th.u',
#  'Orifice1.m_flow',
#  'Orifice1.m_flow_max',
#  'Orifice1.m_flow_min',
#  'Orifice1.port_2.h_outflow',
#  'Orifice1.s_fluid_1',
#  'Orifice1.s_fluid_2',
#  'Orifice1.s_fluid_th',
#  'PistonCylinder.CR',
#  'PistonCylinder.DieselCycle.ER_2_3',
#  'PistonCylinder.DieselCycle.ER_3_4',
#  'PistonCylinder.DieselCycle.PR_1_2',
#  'PistonCylinder.DieselCycle.PR_3_4',
#  'PistonCylinder.DieselCycle.Qqm_2_3',
#  'PistonCylinder.DieselCycle.Qqm_4_1',
#  'PistonCylinder.DieselCycle.W_1_2',
#  'PistonCylinder.DieselCycle.W_2_3',
#  'PistonCylinder.DieselCycle.W_3_4',
#  'PistonCylinder.DieselCycle.WqmOutCycle',
#  'PistonCylinder.DieselCycle.Wqm_1_2',
#  'PistonCylinder.DieselCycle.Wqm_2_3',
#  'PistonCylinder.DieselCycle.Wqm_3_4',
#  'PistonCylinder.DieselCycle.alpha',
#  'PistonCylinder.DieselCycle.arr_T[2]',
#  'PistonCylinder.DieselCycle.arr_T[3]',
#  'PistonCylinder.DieselCycle.arr_T[4]',
#  'PistonCylinder.DieselCycle.arr_T[5]',
#  'PistonCylinder.DieselCycle.arr_h[2]',
#  'PistonCylinder.DieselCycle.arr_h[3]',
#  'PistonCylinder.DieselCycle.arr_h[4]',
#  'PistonCylinder.DieselCycle.arr_h[5]',
#  'PistonCylinder.DieselCycle.arr_s[2]',
#  'PistonCylinder.DieselCycle.arr_s[3]',
#  'PistonCylinder.DieselCycle.arr_u[2]',
#  'PistonCylinder.DieselCycle.arr_u[3]',
#  'PistonCylinder.DieselCycle.arr_u[4]',
#  'PistonCylinder.DieselCycle.arr_u[5]',
#  'PistonCylinder.DieselCycle.arr_v[2]',
#  'PistonCylinder.DieselCycle.arr_v[3]',
#  'PistonCylinder.DieselCycle.arr_v[4]',
#  'PistonCylinder.DieselCycle.arr_v[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].TLower',
#  'PistonCylinder.DieselCycle.curve_Ts[2].TLower',
#  'PistonCylinder.DieselCycle.curve_Ts[3].TLower',
#  'PistonCylinder.DieselCycle.curve_Ts[4].TLower',
#  'PistonCylinder.DieselCycle.curve_Ts[1].TUpper',
#  'PistonCylinder.DieselCycle.curve_Ts[2].TUpper',
#  'PistonCylinder.DieselCycle.curve_Ts[3].TUpper',
#  'PistonCylinder.DieselCycle.curve_Ts[4].TUpper',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].ds',
#  'PistonCylinder.DieselCycle.curve_Ts[2].ds',
#  'PistonCylinder.DieselCycle.curve_Ts[3].ds',
#  'PistonCylinder.DieselCycle.curve_Ts[4].ds',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_hs[1].ds',
#  'PistonCylinder.DieselCycle.curve_hs[2].ds',
#  'PistonCylinder.DieselCycle.curve_hs[3].ds',
#  'PistonCylinder.DieselCycle.curve_hs[4].ds',
#  'PistonCylinder.DieselCycle.curve_hs[1].hLower',
#  'PistonCylinder.DieselCycle.curve_hs[2].hLower',
#  'PistonCylinder.DieselCycle.curve_hs[3].hLower',
#  'PistonCylinder.DieselCycle.curve_hs[4].hLower',
#  'PistonCylinder.DieselCycle.curve_hs[1].hUpper',
#  'PistonCylinder.DieselCycle.curve_hs[2].hUpper',
#  'PistonCylinder.DieselCycle.curve_hs[3].hUpper',
#  'PistonCylinder.DieselCycle.curve_hs[4].hUpper',
#  'PistonCylinder.DieselCycle.curve_pVol[1].Vlower',
#  'PistonCylinder.DieselCycle.curve_pVol[2].Vlower',
#  'PistonCylinder.DieselCycle.curve_pVol[3].Vlower',
#  'PistonCylinder.DieselCycle.curve_pVol[4].Vlower',
#  'PistonCylinder.DieselCycle.curve_pVol[1].Vupper',
#  'PistonCylinder.DieselCycle.curve_pVol[2].Vupper',
#  'PistonCylinder.DieselCycle.curve_pVol[3].Vupper',
#  'PistonCylinder.DieselCycle.curve_pVol[4].Vupper',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].dp',
#  'PistonCylinder.DieselCycle.curve_pVol[2].dp',
#  'PistonCylinder.DieselCycle.curve_pVol[3].dp',
#  'PistonCylinder.DieselCycle.curve_pVol[4].dp',
#  'PistonCylinder.DieselCycle.curve_pVol[1].u_m',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[9]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[2]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[3]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[4]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[5]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[6]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[7]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[8]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[9]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[2]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[3]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[4]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[5]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[6]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[7]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[8]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[9]',
#  'PistonCylinder.DieselCycle.curve_pv[1].dp',
#  'PistonCylinder.DieselCycle.curve_pv[2].dp',
#  'PistonCylinder.DieselCycle.curve_pv[3].dp',
#  'PistonCylinder.DieselCycle.curve_pv[4].dp',
#  'PistonCylinder.DieselCycle.curve_pv[1].vLower',
#  'PistonCylinder.DieselCycle.curve_pv[2].vLower',
#  'PistonCylinder.DieselCycle.curve_pv[3].vLower',
#  'PistonCylinder.DieselCycle.curve_pv[4].vLower',
#  'PistonCylinder.DieselCycle.curve_pv[1].vUpper',
#  'PistonCylinder.DieselCycle.curve_pv[2].vUpper',
#  'PistonCylinder.DieselCycle.curve_pv[3].vUpper',
#  'PistonCylinder.DieselCycle.curve_pv[4].vUpper',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[2]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[3]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[4]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[5]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[6]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[7]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[8]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[9]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[10]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[2]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[3]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[4]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[5]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[6]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[7]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[8]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[9]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[2]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[3]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[4]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[5]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[6]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[7]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[8]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[9]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[2]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[3]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[4]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[5]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[6]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[7]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[8]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[9]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[2]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[3]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[4]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[5]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[6]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[7]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[8]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[9]',
#  'PistonCylinder.DieselCycle.curve_us[1].ds',
#  'PistonCylinder.DieselCycle.curve_us[2].ds',
#  'PistonCylinder.DieselCycle.curve_us[3].ds',
#  'PistonCylinder.DieselCycle.curve_us[4].ds',
#  'PistonCylinder.DieselCycle.curve_us[1].uLower',
#  'PistonCylinder.DieselCycle.curve_us[2].uLower',
#  'PistonCylinder.DieselCycle.curve_us[3].uLower',
#  'PistonCylinder.DieselCycle.curve_us[4].uLower',
#  'PistonCylinder.DieselCycle.curve_us[1].uUpper',
#  'PistonCylinder.DieselCycle.curve_us[2].uUpper',
#  'PistonCylinder.DieselCycle.curve_us[3].uUpper',
#  'PistonCylinder.DieselCycle.curve_us[4].uUpper',
#  'PistonCylinder.DieselCycle.dT_1_2',
#  'PistonCylinder.DieselCycle.dT_2_3',
#  'PistonCylinder.DieselCycle.dT_3_4',
#  'PistonCylinder.DieselCycle.dT_4_1',
#  'PistonCylinder.DieselCycle.dh_1_2',
#  'PistonCylinder.DieselCycle.dh_2_3',
#  'PistonCylinder.DieselCycle.dh_3_4',
#  'PistonCylinder.DieselCycle.dh_4_1',
#  'PistonCylinder.DieselCycle.effThermal',
#  'PistonCylinder.DieselCycle.fluidState_1.MM',
#  'PistonCylinder.DieselCycle.fluidState_1.R',
#  'PistonCylinder.DieselCycle.fluidState_1.T_degC',
#  'PistonCylinder.DieselCycle.fluidState_1.X[1]',
#  'PistonCylinder.DieselCycle.fluidState_1.d',
#  'PistonCylinder.DieselCycle.fluidState_1.p_bar',
#  'PistonCylinder.DieselCycle.fluidState_2.MM',
#  'PistonCylinder.DieselCycle.fluidState_2.R',
#  'PistonCylinder.DieselCycle.fluidState_2.T_degC',
#  'PistonCylinder.DieselCycle.fluidState_2.X[1]',
#  'PistonCylinder.DieselCycle.fluidState_2.d',
#  'PistonCylinder.DieselCycle.fluidState_2.p_bar',
#  'PistonCylinder.DieselCycle.fluidState_3.MM',
#  'PistonCylinder.DieselCycle.fluidState_3.R',
#  'PistonCylinder.DieselCycle.fluidState_3.T_degC',
#  'PistonCylinder.DieselCycle.fluidState_3.X[1]',
#  'PistonCylinder.DieselCycle.fluidState_3.d',
#  'PistonCylinder.DieselCycle.fluidState_3.p_bar',
#  'PistonCylinder.DieselCycle.fluidState_4.MM',
#  'PistonCylinder.DieselCycle.fluidState_4.R',
#  'PistonCylinder.DieselCycle.fluidState_4.T_degC',
#  'PistonCylinder.DieselCycle.fluidState_4.X[1]',
#  'PistonCylinder.DieselCycle.fluidState_4.d',
#  'PistonCylinder.DieselCycle.fluidState_4.p_bar',
#  'PistonCylinder.DieselCycle.par_CR',
#  'PistonCylinder.DieselCycle.par_LHV_fuel',
#  'PistonCylinder.DieselCycle.pme',
#  'PistonCylinder.DieselCycle.u_effComb',
#  'PistonCylinder.DieselCycle.u_fracFuel',
#  'PistonCylinder.DieselCycle.y_Q_2_3',
#  'PistonCylinder.DieselCycle.y_Q_4_1',
#  'PistonCylinder.DieselCycle.y_m_fuel',
#  'PistonCylinder.Nmech',
#  'PistonCylinder.Q_add',
#  'PistonCylinder.Q_reject',
#  'PistonCylinder.V_flow',
#  'PistonCylinder.VolBDC',
#  'PistonCylinder.VolDisp',
#  'PistonCylinder.VolTDC',
#  'PistonCylinder.WexhCycle',
#  'PistonCylinder.WintkCycle',
#  'PistonCylinder.Wout',
#  'PistonCylinder.WoutCycle',
#  'PistonCylinder.arr_V[3]',
#  'PistonCylinder.arr_V[7]',
#  'PistonCylinder.arr_V[8]',
#  'PistonCylinder.arr_p[2]',
#  'PistonCylinder.arr_p[4]',
#  'PistonCylinder.arr_p[6]',
#  'PistonCylinder.arr_p[8]',
#  'PistonCylinder.calcEffComb.AFRsat',
#  'PistonCylinder.calcEffComb.AFRstoi',
#  'PistonCylinder.calcEffComb.FAR',
#  'PistonCylinder.calcEffComb.FARsat',
#  'PistonCylinder.calcEffComb.FARstoi',
#  'PistonCylinder.calcEffComb.flagValid',
#  'PistonCylinder.calcEffComb.fracAirStoi',
#  'PistonCylinder.calcEffComb.fracFuelStoi',
#  'PistonCylinder.calcEffComb.fracTot',
#  'PistonCylinder.calcEffComb.y_AFR',
#  'PistonCylinder.calcEffComb.y_effComb',
#  'PistonCylinder.calcEffComb.y_lambda',
#  'PistonCylinder.const.y',
#  'PistonCylinder.dH_1_2_cycle',
#  'PistonCylinder.dU_1_2_cycle',
#  'PistonCylinder.dh_state4_port2',
#  'PistonCylinder.flange_1.tau',
#  'PistonCylinder.fluid_1.MM',
#  'PistonCylinder.fluid_1.R',
#  'PistonCylinder.fluid_1.T',
#  'PistonCylinder.fluid_1.T_degC',
#  'PistonCylinder.fluid_1.X[1]',
#  'PistonCylinder.fluid_1.d',
#  'PistonCylinder.fluid_1.h',
#  'PistonCylinder.fluid_1.p_bar',
#  'PistonCylinder.fluid_2.MM',
#  'PistonCylinder.fluid_2.R',
#  'PistonCylinder.fluid_2.T',
#  'PistonCylinder.fluid_2.T_degC',
#  'PistonCylinder.fluid_2.X[1]',
#  'PistonCylinder.fluid_2.d',
#  'PistonCylinder.fluid_2.h',
#  'PistonCylinder.fluid_2.p_bar',
#  'PistonCylinder.fluid_2.u',
#  'PistonCylinder.m_flow_max',
#  'PistonCylinder.m_flow_min',
#  'PistonCylinder.port_2.h_outflow',
#  'PistonCylinder.pwrCycle',
#  'PistonCylinder.pwrExh',
#  'PistonCylinder.pwrFuelSply',
#  'PistonCylinder.pwrIntk',
#  'PistonCylinder.pwrOut',
#  'PistonCylinder.pwrPumping',
#  'PistonCylinder.pwrPumpingqPwrCycle',
#  'PistonCylinder.pwrQm',
#  'PistonCylinder.pwrQmOut',
#  'PistonCylinder.pwr_cmp',
#  'PistonCylinder.pwr_exp',
#  'PistonCylinder.s_fluid_1',
#  'PistonCylinder.s_fluid_2',
#  'PistonCylinder.trqOut',
#  'PistonCylinder.trqQm',
#  'PistonCylinder.trqQmOut',
#  'PistonCylinder.u_fracAir',
#  'PistonCylinder.u_fracFuel',
#  'PistonCylinder.y_m_flow_fuel',
#  'V_flow_fuel_usgph.u',
#  'V_flow_fuel_usgph.y',
#  'add2.u1',
#  'add2.u2',
#  'add2.y',
#  'boundary.X_in_internal[1]',
#  'boundary.medium.MM',
#  'boundary.medium.R',
#  'boundary.medium.T_degC',
#  'boundary.medium.X[1]',
#  'boundary.medium.d',
#  'boundary.medium.p_bar',
#  'boundary.medium.u',
#  'boundary.ports[1].h_outflow',
#  'boundary1.T_in_internal',
#  'boundary1.X_in_internal[1]',
#  'boundary1.medium.MM',
#  'boundary1.medium.R',
#  'boundary1.medium.T_degC',
#  'boundary1.medium.X[1]',
#  'boundary1.medium.d',
#  'boundary1.medium.p_bar',
#  'boundary1.medium.u',
#  'boundary1.p_in_internal',
#  'const_Cd_mixture.y',
#  'damper1.a_rel',
#  'damper1.lossPower',
#  'damper1.tau',
#  'fixed1.flange.phi',
#  'fuelEnd.T_in_internal',
#  'fuelEnd.X_in_internal[1]',
#  'fuelEnd.medium.MM',
#  'fuelEnd.medium.R',
#  'fuelEnd.medium.T_degC',
#  'fuelEnd.medium.X[1]',
#  'fuelEnd.medium.d',
#  'fuelEnd.medium.p_bar',
#  'fuelEnd.medium.u',
#  'fuelEnd.ports[1].h_outflow',
#  'fuelStart.T_in_internal',
#  'fuelStart.X_in_internal[1]',
#  'fuelStart.medium.MM',
#  'fuelStart.medium.R',
#  'fuelStart.medium.T_degC',
#  'fuelStart.medium.X[1]',
#  'fuelStart.medium.d',
#  'fuelStart.medium.p_bar',
#  'fuelStart.medium.u',
#  'fuelStart.p_in',
#  'fuelStart.ports[1].h_outflow',
#  'fuelThrottle.AactualTh',
#  'fuelThrottle.AmechPort',
#  'fuelThrottle.AmechTh',
#  'fuelThrottle.PR',
#  'fuelThrottle.V_flow',
#  'fuelThrottle.Vport1',
#  'fuelThrottle.Vport2',
#  'fuelThrottle.Vth',
#  'fuelThrottle.dp',
#  'fuelThrottle.fluidStat_1.MM',
#  'fuelThrottle.fluidStat_1.R',
#  'fuelThrottle.fluidStat_1.T',
#  'fuelThrottle.fluidStat_1.T_degC',
#  'fuelThrottle.fluidStat_1.X[1]',
#  'fuelThrottle.fluidStat_1.d',
#  'fuelThrottle.fluidStat_1.h',
#  'fuelThrottle.fluidStat_1.p_bar',
#  'fuelThrottle.fluidStat_1.u',
#  'fuelThrottle.fluidStat_2.MM',
#  'fuelThrottle.fluidStat_2.R',
#  'fuelThrottle.fluidStat_2.T',
#  'fuelThrottle.fluidStat_2.T_degC',
#  'fuelThrottle.fluidStat_2.X[1]',
#  'fuelThrottle.fluidStat_2.d',
#  'fuelThrottle.fluidStat_2.h',
#  'fuelThrottle.fluidStat_2.p_bar',
#  'fuelThrottle.fluidStat_2.u',
#  'fuelThrottle.fluidStat_th.MM',
#  'fuelThrottle.fluidStat_th.R',
#  'fuelThrottle.fluidStat_th.T',
#  'fuelThrottle.fluidStat_th.T_degC',
#  'fuelThrottle.fluidStat_th.X[1]',
#  'fuelThrottle.fluidStat_th.d',
#  'fuelThrottle.fluidStat_th.h',
#  'fuelThrottle.fluidStat_th.p_bar',
#  'fuelThrottle.fluidStat_th.u',
#  'fuelThrottle.fluid_1.MM',
#  'fuelThrottle.fluid_1.R',
#  'fuelThrottle.fluid_1.T',
#  'fuelThrottle.fluid_1.T_degC',
#  'fuelThrottle.fluid_1.X[1]',
#  'fuelThrottle.fluid_1.d',
#  'fuelThrottle.fluid_1.h',
#  'fuelThrottle.fluid_1.p_bar',
#  'fuelThrottle.fluid_1.u',
#  'fuelThrottle.fluid_2.MM',
#  'fuelThrottle.fluid_2.R',
#  'fuelThrottle.fluid_2.T',
#  'fuelThrottle.fluid_2.T_degC',
#  'fuelThrottle.fluid_2.X[1]',
#  'fuelThrottle.fluid_2.d',
#  'fuelThrottle.fluid_2.h',
#  'fuelThrottle.fluid_2.p_bar',
#  'fuelThrottle.fluid_2.u',
#  'fuelThrottle.fluid_th.MM',
#  'fuelThrottle.fluid_th.R',
#  'fuelThrottle.fluid_th.T',
#  'fuelThrottle.fluid_th.T_degC',
#  'fuelThrottle.fluid_th.X[1]',
#  'fuelThrottle.fluid_th.d',
#  'fuelThrottle.fluid_th.h',
#  'fuelThrottle.fluid_th.p',
#  'fuelThrottle.fluid_th.p_bar',
#  'fuelThrottle.fluid_th.u',
#  'fuelThrottle.m_flow',
#  'fuelThrottle.m_flow_max',
#  'fuelThrottle.m_flow_min',
#  'fuelThrottle.s_fluid_1',
#  'fuelThrottle.s_fluid_2',
#  'fuelThrottle.s_fluid_th',
#  'fuelThrottle.u_kArea',
#  'fuelThrottle.y_ps_1',
#  'fuelThrottle.y_ps_2',
#  'fuelThrottle.y_ps_th',
#  'fuelThrottle.zeta',
#  'inertia1.a',
#  'massFlowRate_air.port_b.h_outflow',
#  'powerSensor1.power',
#  'pressure3.port.h_outflow',
#  'pressure3.port.m_flow',
#  'ramp_T1.y',
#  'ramp_p1.y',
#  'ramp_trq.y',
#  'ramp_zeta.y',
#  'ramp_zeta1.y',
#  'torque1.flange.tau',
#  'torque1.phi_support',
#  'volumeFlowRate_fuel.port_b.h_outflow',
#  'volumeFlowRate_fuel.rho_b_inflow',
#  'PistonCylinder.DieselCycle.curve_Ts[1].nPts',
#  'PistonCylinder.DieselCycle.curve_Ts[2].nPts',
#  'PistonCylinder.DieselCycle.curve_Ts[3].nPts',
#  'PistonCylinder.DieselCycle.curve_Ts[4].nPts',
#  'PistonCylinder.DieselCycle.curve_hs[1].nPts',
#  'PistonCylinder.DieselCycle.curve_hs[2].nPts',
#  'PistonCylinder.DieselCycle.curve_hs[3].nPts',
#  'PistonCylinder.DieselCycle.curve_hs[4].nPts',
#  'PistonCylinder.DieselCycle.curve_pVol[1].nPts',
#  'PistonCylinder.DieselCycle.curve_pVol[2].nPts',
#  'PistonCylinder.DieselCycle.curve_pVol[3].nPts',
#  'PistonCylinder.DieselCycle.curve_pVol[4].nPts',
#  'PistonCylinder.DieselCycle.curve_pv[1].nPts',
#  'PistonCylinder.DieselCycle.curve_pv[2].nPts',
#  'PistonCylinder.DieselCycle.curve_pv[3].nPts',
#  'PistonCylinder.DieselCycle.curve_pv[4].nPts',
#  'PistonCylinder.DieselCycle.curve_us[1].nPts',
#  'PistonCylinder.DieselCycle.curve_us[2].nPts',
#  'PistonCylinder.DieselCycle.curve_us[3].nPts',
#  'PistonCylinder.DieselCycle.curve_us[4].nPts',
#  'PistonCylinder.DieselCycle.flag_Wexp_gt_Q23',
#  'PistonCylinder.switch1.u2',
#  'Orifice.fluidStat_th.state.T',
#  'Orifice.fluidStat_th.state.p',
#  'Orifice.fluid_1.p',
#  'Orifice.fluid_1.state.T',
#  'Orifice.fluid_1.state.p',
#  'Orifice.fluid_2.p',
#  'Orifice.fluid_2.state.T',
#  'Orifice.fluid_2.state.p',
#  'Orifice.fluid_th.state.T',
#  'Orifice.fluid_th.state.p',
#  'Orifice.port_1.h_outflow',
#  'Orifice.port_1.m_flow',
#  'Orifice.port_1.p',
#  'Orifice.port_2.h_outflow',
#  'Orifice.port_2.m_flow',
#  'Orifice.port_2.p',
#  'Orifice.u_zeta',
#  'Orifice.zeta',
#  'Orifice1.fluidStat_th.state.T',
#  'Orifice1.fluidStat_th.state.p',
#  'Orifice1.fluid_1.h',
#  'Orifice1.fluid_1.p',
#  'Orifice1.fluid_1.state.T',
#  'Orifice1.fluid_1.state.p',
#  'Orifice1.fluid_2.p',
#  'Orifice1.fluid_2.state.T',
#  'Orifice1.fluid_2.state.p',
#  'Orifice1.fluid_th.state.T',
#  'Orifice1.fluid_th.state.p',
#  'Orifice1.port_1.h_outflow',
#  'Orifice1.port_1.m_flow',
#  'Orifice1.port_1.p',
#  'Orifice1.port_2.m_flow',
#  'Orifice1.port_2.p',
#  'Orifice1.u_zeta',
#  'Orifice1.zeta',
#  'PistonCylinder.DieselCycle.CR',
#  'PistonCylinder.DieselCycle.LHV_fuel',
#  'PistonCylinder.DieselCycle.Q_2_3',
#  'PistonCylinder.DieselCycle.Q_4_1',
#  'PistonCylinder.DieselCycle.Vol1',
#  'PistonCylinder.DieselCycle.Vol2',
#  'PistonCylinder.DieselCycle.Vol3',
#  'PistonCylinder.DieselCycle.Vol4',
#  'PistonCylinder.DieselCycle.VolDisp',
#  'PistonCylinder.DieselCycle.WoutCycle',
#  'PistonCylinder.DieselCycle.arr_T[1]',
#  'PistonCylinder.DieselCycle.arr_V[1]',
#  'PistonCylinder.DieselCycle.arr_V[2]',
#  'PistonCylinder.DieselCycle.arr_V[3]',
#  'PistonCylinder.DieselCycle.arr_V[4]',
#  'PistonCylinder.DieselCycle.arr_V[5]',
#  'PistonCylinder.DieselCycle.arr_h[1]',
#  'PistonCylinder.DieselCycle.arr_p[1]',
#  'PistonCylinder.DieselCycle.arr_p[2]',
#  'PistonCylinder.DieselCycle.arr_p[3]',
#  'PistonCylinder.DieselCycle.arr_p[4]',
#  'PistonCylinder.DieselCycle.arr_p[5]',
#  'PistonCylinder.DieselCycle.arr_s[1]',
#  'PistonCylinder.DieselCycle.arr_s[4]',
#  'PistonCylinder.DieselCycle.arr_s[5]',
#  'PistonCylinder.DieselCycle.arr_u[1]',
#  'PistonCylinder.DieselCycle.arr_v[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_T[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_T[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_T[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_T[10]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[2].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[3].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[4].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_Ts[1].u_p',
#  'PistonCylinder.DieselCycle.curve_Ts[2].u_p',
#  'PistonCylinder.DieselCycle.curve_Ts[3].u_p',
#  'PistonCylinder.DieselCycle.curve_Ts[4].u_p',
#  'PistonCylinder.DieselCycle.curve_Ts[1].u_sLower',
#  'PistonCylinder.DieselCycle.curve_Ts[2].u_sLower',
#  'PistonCylinder.DieselCycle.curve_Ts[3].u_sLower',
#  'PistonCylinder.DieselCycle.curve_Ts[4].u_sLower',
#  'PistonCylinder.DieselCycle.curve_Ts[1].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_Ts[2].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_Ts[3].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_Ts[4].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[1]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_h[10]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[1]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_h[10]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[1]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_h[10]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[1]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_h[10]',
#  'PistonCylinder.DieselCycle.curve_hs[1].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_hs[2].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_hs[3].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_hs[4].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_hs[1].u_p',
#  'PistonCylinder.DieselCycle.curve_hs[2].u_p',
#  'PistonCylinder.DieselCycle.curve_hs[3].u_p',
#  'PistonCylinder.DieselCycle.curve_hs[4].u_p',
#  'PistonCylinder.DieselCycle.curve_hs[1].u_sLower',
#  'PistonCylinder.DieselCycle.curve_hs[2].u_sLower',
#  'PistonCylinder.DieselCycle.curve_hs[3].u_sLower',
#  'PistonCylinder.DieselCycle.curve_hs[4].u_sLower',
#  'PistonCylinder.DieselCycle.curve_hs[1].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_hs[2].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_hs[3].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_hs[4].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_V[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_V[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_V[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_V[10]',
#  'PistonCylinder.DieselCycle.curve_pVol[1].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[3].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[4].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pVol[2].u_m',
#  'PistonCylinder.DieselCycle.curve_pVol[3].u_m',
#  'PistonCylinder.DieselCycle.curve_pVol[4].u_m',
#  'PistonCylinder.DieselCycle.curve_pVol[1].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pVol[2].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pVol[3].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pVol[4].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pVol[1].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pVol[2].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pVol[3].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pVol[4].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pVol[1].u_s',
#  'PistonCylinder.DieselCycle.curve_pVol[2].u_s',
#  'PistonCylinder.DieselCycle.curve_pVol[3].u_s',
#  'PistonCylinder.DieselCycle.curve_pVol[4].u_s',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_p[1]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[1]',
#  'PistonCylinder.DieselCycle.curve_pv[1].arr_v[10]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[1]',
#  'PistonCylinder.DieselCycle.curve_pv[2].arr_v[10]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[1]',
#  'PistonCylinder.DieselCycle.curve_pv[3].arr_v[10]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[1]',
#  'PistonCylinder.DieselCycle.curve_pv[4].arr_v[10]',
#  'PistonCylinder.DieselCycle.curve_pv[1].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pv[2].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pv[3].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pv[4].u_pLower',
#  'PistonCylinder.DieselCycle.curve_pv[1].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pv[2].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pv[3].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pv[4].u_pUpper',
#  'PistonCylinder.DieselCycle.curve_pv[1].u_s',
#  'PistonCylinder.DieselCycle.curve_pv[2].u_s',
#  'PistonCylinder.DieselCycle.curve_pv[3].u_s',
#  'PistonCylinder.DieselCycle.curve_pv[4].u_s',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_s[1]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[1]',
#  'PistonCylinder.DieselCycle.curve_us[1].arr_u[10]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[1]',
#  'PistonCylinder.DieselCycle.curve_us[2].arr_u[10]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[1]',
#  'PistonCylinder.DieselCycle.curve_us[3].arr_u[10]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[1]',
#  'PistonCylinder.DieselCycle.curve_us[4].arr_u[10]',
#  'PistonCylinder.DieselCycle.curve_us[1].u_p',
#  'PistonCylinder.DieselCycle.curve_us[2].u_p',
#  'PistonCylinder.DieselCycle.curve_us[3].u_p',
#  'PistonCylinder.DieselCycle.curve_us[4].u_p',
#  'PistonCylinder.DieselCycle.curve_us[1].u_sLower',
#  'PistonCylinder.DieselCycle.curve_us[2].u_sLower',
#  'PistonCylinder.DieselCycle.curve_us[3].u_sLower',
#  'PistonCylinder.DieselCycle.curve_us[4].u_sLower',
#  'PistonCylinder.DieselCycle.curve_us[1].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_us[2].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_us[3].u_sUpper',
#  'PistonCylinder.DieselCycle.curve_us[4].u_sUpper',
#  'PistonCylinder.DieselCycle.effComb',
#  ...]

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=3


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderNonidealDieselMV01_ex02_res_2.csv
# i_df=3
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderNonidealDieselMV01_ex02_res_3.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Elements.BasicElements.PistonCylinderNonidealDieselMV01_ex02_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#         time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0       0.00         0.000000    -209.439510           -209.439510
# 1       0.05       -10.415597    -207.213935           -207.213935
# 2       0.10       -20.724239    -205.159650           -205.159650
# 3       0.15       -30.934189    -203.264469           -203.264469
# 4       0.20       -41.053119    -201.516940           -201.516940
# ...      ...              ...            ...                   ...
# 2001   99.85    -18891.366748    -192.295785           -192.295785
# 2002   99.90    -18900.981537    -192.295785           -192.295785
# 2003   99.95    -18910.596326    -192.295785           -192.295785
# 2004  100.00    -18920.211115    -192.295785           -192.295785
# 2005  100.00    -18920.211115    -192.295785           -192.295785
#
#       der(damper1.w_rel)  Orifice.AmechTh  Orifice.PR  Orifice.V_flow  \
# 0           4.630919e+01         0.000079    1.002715        0.001662
# 1           4.275688e+01         0.000079    1.002658        0.001645
# 2           3.945560e+01         0.000079    1.002605        0.001628
# 3           3.639047e+01         0.000079    1.002557        0.001613
# 4           3.354713e+01         0.000079    1.002514        0.001600
# ...                  ...              ...         ...             ...
# 2001        4.649436e-10         0.000079    1.002289        0.001527
# 2002        4.632028e-10         0.000079    1.002289        0.001527
# 2003        4.586909e-10         0.000079    1.002289        0.001527
# 2004        4.571277e-10         0.000079    1.002289        0.001527
# 2005        4.594014e-10         0.000079    1.002289        0.001527
#
#       Orifice.Vth  Orifice.dp  ...  torque1.flange.phi  torque1.tau  \
# 0       21.163206  274.328864  ...           -0.000000            0
# 1       20.939514  268.560276  ...           10.415597            0
# 2       20.733004  263.289211  ...           20.724239            0
# 3       20.542460  258.472002  ...           30.934189            0
# 4       20.366738  254.068912  ...           41.053119            0
# ...           ...         ...  ...                 ...          ...
# 2001    19.439131  231.452713  ...        18891.366748            0
# 2002    19.439131  231.452713  ...        18900.981537            0
# 2003    19.439131  231.452713  ...        18910.596326            0
# 2004    19.439131  231.452713  ...        18920.211115            0
# 2005    19.439131  231.452713  ...        18920.211115            0
#
#       volumeFlowRate_fuel.V_flow  volumeFlowRate_fuel.d  \
# 0                   7.069061e-08            1000.737381
# 1                   7.063540e-08            1000.737540
# 2                   7.058491e-08            1000.737684
# 3                   7.053873e-08            1000.737817
# 4                   7.049650e-08            1000.737938
# ...                          ...                    ...
# 2001                7.964973e-08            1000.738559
# 2002                7.964973e-08            1000.738559
# 2003                7.964973e-08            1000.738559
# 2004                7.964973e-08            1000.738559
# 2005                7.964973e-08            1000.738559
#
#       volumeFlowRate_fuel.port_a.h_outflow  volumeFlowRate_fuel.port_a.m_flow  \
# 0                             88995.382650                           0.000071
# 1                             88995.672039                           0.000071
# 2                             88995.936470                           0.000071
# 3                             88996.178132                           0.000071
# 4                             88996.399019                           0.000071
# ...                                    ...                                ...
# 2001                          88997.533592                           0.000080
# 2002                          88997.533592                           0.000080
# 2003                          88997.533592                           0.000080
# 2004                          88997.533592                           0.000080
# 2005                          88997.533592                           0.000080
#
#       volumeFlowRate_fuel.port_a.p  volumeFlowRate_fuel.port_b.m_flow  \
# 0                     5.474046e+06                          -0.000071
# 1                     5.474358e+06                          -0.000071
# 2                     5.474644e+06                          -0.000071
# 3                     5.474905e+06                          -0.000071
# 4                     5.475143e+06                          -0.000071
# ...                            ...                                ...
# 2001                  5.476368e+06                          -0.000080
# 2002                  5.476368e+06                          -0.000080
# 2003                  5.476368e+06                          -0.000080
# 2004                  5.476368e+06                          -0.000080
# 2005                  5.476368e+06                          -0.000080
#
#       volumeFlowRate_fuel.port_b.p  volumeFlowRate_fuel.rho_a_inflow
# 0                     5.474046e+06                       1000.737381
# 1                     5.474358e+06                       1000.737540
# 2                     5.474644e+06                       1000.737684
# 3                     5.474905e+06                       1000.737817
# 4                     5.475143e+06                       1000.737938
# ...                            ...                               ...
# 2001                  5.476368e+06                       1000.738559
# 2002                  5.476368e+06                       1000.738559
# 2003                  5.476368e+06                       1000.738559
# 2004                  5.476368e+06                       1000.738559
# 2005                  5.476368e+06                       1000.738559
#
# [2006 rows x 1196 columns]

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="fuelThrottle.u_kArea"
label="fuelThrottle.u_kArea"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('valve opening [nond]')
plt.title(varName)

#plt.legend(loc='upper right', fontsize=12)
plt.xlim(0.0, 50.0)
plt.ylim(0.5, 1.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.Nmech"
label="PistonCylinder.Nmech"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('angular speed [rpm]')
plt.title(label)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0,50)
plt.ylim(1500, 2000)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="powerSensor1.power"
label=varName
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('power [kW]')
plt.title('shaft power output')

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0, 50)
plt.ylim(1, 2)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="powerSensor1.flange_a.tau"
label=varName
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('torque [N*m]')
plt.title(varName)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0, 50)
#plt.ylim(1, 2)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.DieselCycle.fluidState_3.T"
label=varName
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Temperature [K]')
plt.title(label)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0, 50)
#plt.ylim(1, 2)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.DieselCycle.fluidState_2.p"
label=varName
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Pressure [kPa]')
plt.title(label)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0, 50)
plt.ylim(5000, 6000)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.DieselCycle.fluidState_4.T"
label=varName
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Temperature [K]')
plt.title(label)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0, 50)
#plt.ylim(1, 2)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
ylabel='Pressure [kPa]'

fig.append(plt.figure(figsize=(15,8)))
time= df[i_df].loc[:,'time']

varName="PistonCylinder.DieselCycle.fluidState_1.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

varName="PistonCylinder.DieselCycle.fluidState_2.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

varName="PistonCylinder.DieselCycle.fluidState_3.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

varName="PistonCylinder.DieselCycle.fluidState_4.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title('PistonCylinder.DieselCycle. pressures')
plt.legend(loc='center right', fontsize=12)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.port_1.m_flow"
label=varName
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Mass flow rate [kg/s]')
plt.title(label)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0, 50)
plt.ylim(0.0016, 0.0022)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="fuelThrottle.port_1.m_flow"
label=varName
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Mass flow rate [kg/s]')
plt.title(label)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0, 50)
plt.ylim(6e-5, 9e-5)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %%
i_df=1
tgtTime=50
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 1004
# time of extracted = 50.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,15)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

'''or(i==3)or(i==4)or(i==5)or(i==6)or(i==7)'''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------
