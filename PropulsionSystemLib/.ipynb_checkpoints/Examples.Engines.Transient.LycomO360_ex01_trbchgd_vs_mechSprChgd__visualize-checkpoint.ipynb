# %% [markdown]
# <h1>Visualize: LycomO360_ex01_trbchgd_vs_mechSprChgd</h1>
# <h2>notebook: rev004</h2>
# <p>compatability with OpenModelica v1.17</p>
# <h2>memo: </h2>
# <p>compare Lycom O360 engine with turbochaged one</p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01'
nmModel='LycomO360_ex01'
stopTime=90.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/Examples/Engines/Transient/LycomO360_ex01.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#      time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0     0.0         0.000000    -209.439510           -209.439510
# 1     0.1       -22.126547    -230.977595           -230.977595
# 2     0.2       -45.879106    -242.910492           -242.910492
# 3     0.3       -70.533826    -249.539978           -249.539978
# 4     0.4       -95.690211    -253.229456           -253.229456
# ..    ...              ...            ...                   ...
# 901  89.7    -23723.315664    -273.063609           -273.063609
# 902  89.8    -23750.622025    -273.063609           -273.063609
# 903  89.9    -23777.928386    -273.063609           -273.063609
# 904  90.0    -23805.234747    -273.063609           -273.063609
# 905  90.0    -23805.234747    -273.063609           -273.063609
#
#      der(damper1.w_rel)  Flt2Fluid.AltMN2pTh.TambStd  \
# 0         -2.854958e+02                       288.16
# 1         -1.579208e+02                       288.16
# 2         -8.764113e+01                       288.16
# 3         -4.874499e+01                       288.16
# 4         -2.714777e+01                       288.16
# ..                  ...                          ...
# 901        1.227818e-11                       288.16
# 902        1.273293e-11                       288.16
# 903        1.273293e-11                       288.16
# 904        1.341505e-11                       288.16
# 905        1.364242e-11                       288.16
#
#      Flt2Fluid.AltMN2pTh.fluidAmb.MM  Flt2Fluid.AltMN2pTh.fluidAmb.R  \
# 0                           0.028965                      287.051225
# 1                           0.028965                      287.051225
# 2                           0.028965                      287.051225
# 3                           0.028965                      287.051225
# 4                           0.028965                      287.051225
# ..                               ...                             ...
# 901                         0.028965                      287.051225
# 902                         0.028965                      287.051225
# 903                         0.028965                      287.051225
# 904                         0.028965                      287.051225
# 905                         0.028965                      287.051225
#
#      Flt2Fluid.AltMN2pTh.fluidAmb.T_degC  Flt2Fluid.AltMN2pTh.fluidAmb.X[1]  \
# 0                                  15.01                                  1
# 1                                  15.01                                  1
# 2                                  15.01                                  1
# 3                                  15.01                                  1
# 4                                  15.01                                  1
# ..                                   ...                                ...
# 901                                15.01                                  1
# 902                                15.01                                  1
# 903                                15.01                                  1
# 904                                15.01                                  1
# 905                                15.01                                  1
#
#      ...  throttle.port_1.h_outflow  throttle.port_1.m_flow  \
# 0    ...              288574.819851                0.099558
# 1    ...              288574.819851                0.106446
# 2    ...              288574.819851                0.110023
# 3    ...              288574.819851                0.111940
# 4    ...              288574.819851                0.112986
# ..   ...                        ...                     ...
# 901  ...              288574.819851                0.128137
# 902  ...              288574.819851                0.128137
# 903  ...              288574.819851                0.128137
# 904  ...              288574.819851                0.128137
# 905  ...              288574.819851                0.128137
#
#      throttle.port_1.p  throttle.port_2.m_flow  throttle.port_2.p  \
# 0             101323.7               -0.099558       83520.541741
# 1             101323.7               -0.106446       80971.938584
# 2             101323.7               -0.110023       79581.288847
# 3             101323.7               -0.111940       78816.951683
# 4             101323.7               -0.112986       78394.368428
# ..                 ...                     ...                ...
# 901           101323.7               -0.128137       82449.251213
# 902           101323.7               -0.128137       82449.251213
# 903           101323.7               -0.128137       82449.251213
# 904           101323.7               -0.128137       82449.251213
# 905           101323.7               -0.128137       82449.251213
#
#      throttle.u_Cd  throttle.u_kArea  to_rpm_crankshaft.u  torque1.flange.phi  \
# 0              0.6               0.8           209.439510           -0.000000
# 1              0.6               0.8           230.977595           22.126547
# 2              0.6               0.8           242.910492           45.879106
# 3              0.6               0.8           249.539978           70.533826
# 4              0.6               0.8           253.229456           95.690211
# ..             ...               ...                  ...                 ...
# 901            0.6               1.0           273.063609        23723.315664
# 902            0.6               1.0           273.063609        23750.622025
# 903            0.6               1.0           273.063609        23777.928386
# 904            0.6               1.0           273.063609        23805.234747
# 905            0.6               1.0           273.063609        23805.234747
#
#      torque1.tau
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 901            0
# 902            0
# 903            0
# 904            0
# 905            0
#
# [906 rows x 3467 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'damper1.phi_rel',
#  'damper1.w_rel',
#  'der(damper1.phi_rel)',
#  'der(damper1.w_rel)',
#  'Flt2Fluid.AltMN2pTh.TambStd',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.u',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.h',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.u',
#  'Flt2Fluid.AltMN2pTh.fluidTot.MM',
#  'Flt2Fluid.AltMN2pTh.fluidTot.R',
#  'Flt2Fluid.AltMN2pTh.fluidTot.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidTot.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidTot.d',
#  'Flt2Fluid.AltMN2pTh.fluidTot.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidTot.u',
#  'Flt2Fluid.AltMN2pTh.pAmbStd',
#  'Flt2Fluid.AltMN2pTh.u_X[1]',
#  'Flt2Fluid.AltMN2pTh.u_dTamb',
#  'Flt2Fluid.AltMN2pTh.y_Tamb',
#  'Flt2Fluid.AltMN2pTh.y_Ttot',
#  'Flt2Fluid.AltMN2pTh.y_hTot',
#  'Flt2Fluid.AltMN2pTh.y_pAmb',
#  'Flt2Fluid.AltMN2pTh.y_pTot',
#  'Flt2Fluid.limiter2.y',
#  'Flt2Fluid.limiter4.y',
#  'Flt2Fluid.port_amb4sink.m_flow',
#  'Flt2Fluid.port_amb4source.m_flow',
#  'Flt2Fluid.s_fluid_amb4sink',
#  'Flt2Fluid.s_fluid_amb4source',
#  'Flt2Fluid.s_fluid_inlet',
#  'Flt2Fluid.sourceFluid2Inlet.X_in[1]',
#  'Flt2Fluid.sourceFluid2Inlet.medium.MM',
#  'Flt2Fluid.sourceFluid2Inlet.medium.R',
#  'Flt2Fluid.sourceFluid2Inlet.medium.T_degC',
#  'Flt2Fluid.sourceFluid2Inlet.medium.X[1]',
#  'Flt2Fluid.sourceFluid2Inlet.medium.d',
#  'Flt2Fluid.sourceFluid2Inlet.medium.p_bar',
#  'Flt2Fluid.sourceFluid2Inlet.medium.u',
#  'Flt2Fluid.sourceFluid2Inlet.p_in',
#  'Flt2Fluid.sourceFluid2Inlet.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluid2Inlet.ports[1].m_flow',
#  'Flt2Fluid.sourceFluidAmb4sink.X_in[1]',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.R',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.X[1]',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.d',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.u',
#  'Flt2Fluid.sourceFluidAmb4sink.p_in',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidAmb4source.X_in[1]',
#  'Flt2Fluid.sourceFluidAmb4source.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4source.medium.R',
#  'Flt2Fluid.sourceFluidAmb4source.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4source.medium.X[1]',
#  'Flt2Fluid.sourceFluidAmb4source.medium.d',
#  'Flt2Fluid.sourceFluidAmb4source.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4source.medium.u',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].h_outflow',
#  'Flt2Fluid.y_V_inf',
#  'LossRotMech.Qloss',
#  'LossRotMech.eff',
#  'LossRotMech.pwrIn',
#  'LossRotMech.pwrOut_inv',
#  'LossRotMech.trqIn',
#  'LossRotMech.trqMax',
#  'LossRotMech.trqMin',
#  'LossRotMech.trqOut_inv',
#  'Pa2inHg.y',
#  'PistonCylinder.CR',
#  'PistonCylinder.Nmech',
#  'PistonCylinder.OttoCycle.ER',
#  'PistonCylinder.OttoCycle.PR_1_2',
#  'PistonCylinder.OttoCycle.PR_3_4',
#  'PistonCylinder.OttoCycle.W_1_2',
#  'PistonCylinder.OttoCycle.W_3_4',
#  'PistonCylinder.OttoCycle.arr_T[2]',
#  'PistonCylinder.OttoCycle.arr_T[3]',
#  'PistonCylinder.OttoCycle.arr_T[4]',
#  'PistonCylinder.OttoCycle.arr_T[5]',
#  'PistonCylinder.OttoCycle.arr_h[2]',
#  'PistonCylinder.OttoCycle.arr_h[3]',
#  'PistonCylinder.OttoCycle.arr_h[4]',
#  'PistonCylinder.OttoCycle.arr_h[5]',
#  'PistonCylinder.OttoCycle.arr_s[2]',
#  'PistonCylinder.OttoCycle.arr_s[3]',
#  'PistonCylinder.OttoCycle.arr_u[2]',
#  'PistonCylinder.OttoCycle.arr_u[3]',
#  'PistonCylinder.OttoCycle.arr_u[4]',
#  'PistonCylinder.OttoCycle.arr_u[5]',
#  'PistonCylinder.OttoCycle.arr_v[2]',
#  'PistonCylinder.OttoCycle.arr_v[3]',
#  'PistonCylinder.OttoCycle.arr_v[4]',
#  'PistonCylinder.OttoCycle.arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[2].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[3].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[1].ds',
#  'PistonCylinder.OttoCycle.curve_hs[2].ds',
#  'PistonCylinder.OttoCycle.curve_hs[3].ds',
#  'PistonCylinder.OttoCycle.curve_hs[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[2].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[3].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[4].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[1].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[2].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[3].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[4].hUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[2].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[3].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[4].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[1].u_m',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].dp',
#  'PistonCylinder.OttoCycle.curve_pv[2].dp',
#  'PistonCylinder.OttoCycle.curve_pv[3].dp',
#  'PistonCylinder.OttoCycle.curve_pv[4].dp',
#  'PistonCylinder.OttoCycle.curve_pv[1].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[2].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[3].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[4].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[1].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[2].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[3].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[4].vUpper',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].ds',
#  'PistonCylinder.OttoCycle.curve_us[2].ds',
#  'PistonCylinder.OttoCycle.curve_us[3].ds',
#  'PistonCylinder.OttoCycle.curve_us[4].ds',
#  'PistonCylinder.OttoCycle.curve_us[1].uLower',
#  'PistonCylinder.OttoCycle.curve_us[2].uLower',
#  'PistonCylinder.OttoCycle.curve_us[3].uLower',
#  'PistonCylinder.OttoCycle.curve_us[4].uLower',
#  'PistonCylinder.OttoCycle.curve_us[1].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[2].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[3].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[4].uUpper',
#  'PistonCylinder.OttoCycle.effThermal',
#  'PistonCylinder.OttoCycle.fluidState_1.MM',
#  'PistonCylinder.OttoCycle.fluidState_1.R',
#  'PistonCylinder.OttoCycle.fluidState_1.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_1.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_1.d',
#  'PistonCylinder.OttoCycle.fluidState_1.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_2.MM',
#  'PistonCylinder.OttoCycle.fluidState_2.R',
#  'PistonCylinder.OttoCycle.fluidState_2.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_2.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_2.d',
#  'PistonCylinder.OttoCycle.fluidState_2.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_3.MM',
#  'PistonCylinder.OttoCycle.fluidState_3.R',
#  'PistonCylinder.OttoCycle.fluidState_3.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_3.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_3.d',
#  'PistonCylinder.OttoCycle.fluidState_3.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_4.MM',
#  'PistonCylinder.OttoCycle.fluidState_4.R',
#  'PistonCylinder.OttoCycle.fluidState_4.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_4.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_4.d',
#  'PistonCylinder.OttoCycle.fluidState_4.p_bar',
#  'PistonCylinder.OttoCycle.par_CR',
#  'PistonCylinder.OttoCycle.par_LHV_fuel',
#  'PistonCylinder.OttoCycle.u_effComb',
#  'PistonCylinder.OttoCycle.u_fracFuel',
#  'PistonCylinder.OttoCycle.y_Q_2_3',
#  'PistonCylinder.OttoCycle.y_Q_4_1',
#  'PistonCylinder.OttoCycle.y_m_fuel',
#  'PistonCylinder.Q_add',
#  'PistonCylinder.Q_reject',
#  'PistonCylinder.V_flow',
#  'PistonCylinder.VolBDC',
#  'PistonCylinder.VolDisp',
#  'PistonCylinder.VolTDC',
#  'PistonCylinder.WexhCycle',
#  'PistonCylinder.WintkCycle',
#  'PistonCylinder.WoutCycle',
#  'PistonCylinder.arr_V[7]',
#  'PistonCylinder.arr_V[8]',
#  'PistonCylinder.arr_p[2]',
#  'PistonCylinder.arr_p[3]',
#  'PistonCylinder.arr_p[4]',
#  'PistonCylinder.calcEffComb.AFRsat',
#  'PistonCylinder.calcEffComb.AFRstoi',
#  'PistonCylinder.calcEffComb.FAR',
#  'PistonCylinder.calcEffComb.FARsat',
#  'PistonCylinder.calcEffComb.FARstoi',
#  'PistonCylinder.calcEffComb.flagValid',
#  'PistonCylinder.calcEffComb.fracAirStoi',
#  'PistonCylinder.calcEffComb.fracFuelStoi',
#  'PistonCylinder.calcEffComb.fracTot',
#  'PistonCylinder.calcEffComb.y_AFR',
#  'PistonCylinder.calcEffComb.y_lambda',
#  'PistonCylinder.dH_1_2_cycle',
#  'PistonCylinder.dU_1_2_cycle',
#  'PistonCylinder.dh_state4_port2',
#  'PistonCylinder.flange_1.tau',
#  'PistonCylinder.fluid_1.MM',
#  'PistonCylinder.fluid_1.R',
#  'PistonCylinder.fluid_1.T',
#  'PistonCylinder.fluid_1.T_degC',
#  'PistonCylinder.fluid_1.X[1]',
#  'PistonCylinder.fluid_1.d',
#  'PistonCylinder.fluid_1.p_bar',
#  'PistonCylinder.fluid_2.MM',
#  'PistonCylinder.fluid_2.R',
#  'PistonCylinder.fluid_2.T',
#  'PistonCylinder.fluid_2.T_degC',
#  'PistonCylinder.fluid_2.X[1]',
#  'PistonCylinder.fluid_2.d',
#  'PistonCylinder.fluid_2.h',
#  'PistonCylinder.fluid_2.p_bar',
#  'PistonCylinder.fluid_2.u',
#  'PistonCylinder.m_flow',
#  'PistonCylinder.m_flow_max',
#  'PistonCylinder.m_flow_min',
#  'PistonCylinder.port_2.h_outflow',
#  'PistonCylinder.pwrCycle',
#  'PistonCylinder.pwrExh',
#  'PistonCylinder.pwrIntk',
#  'PistonCylinder.pwrOut',
#  'PistonCylinder.pwrPumping',
#  'PistonCylinder.pwrPumpingqPwrCycle',
#  'PistonCylinder.pwr_cmp',
#  'PistonCylinder.pwr_exp',
#  'PistonCylinder.s_fluid_1',
#  'PistonCylinder.s_fluid_2',
#  'PistonCylinder.trqOut',
#  'PistonCylinder.u_fracAir',
#  'PistonCylinder.y_m_flow_fuel',
#  'PistonCylinder1.CR',
#  'PistonCylinder1.Nmech',
#  'PistonCylinder1.OttoCycle.ER',
#  'PistonCylinder1.OttoCycle.PR_1_2',
#  'PistonCylinder1.OttoCycle.PR_3_4',
#  'PistonCylinder1.OttoCycle.W_1_2',
#  'PistonCylinder1.OttoCycle.W_3_4',
#  'PistonCylinder1.OttoCycle.arr_T[2]',
#  'PistonCylinder1.OttoCycle.arr_T[3]',
#  'PistonCylinder1.OttoCycle.arr_T[4]',
#  'PistonCylinder1.OttoCycle.arr_T[5]',
#  'PistonCylinder1.OttoCycle.arr_h[2]',
#  'PistonCylinder1.OttoCycle.arr_h[3]',
#  'PistonCylinder1.OttoCycle.arr_h[4]',
#  'PistonCylinder1.OttoCycle.arr_h[5]',
#  'PistonCylinder1.OttoCycle.arr_s[2]',
#  'PistonCylinder1.OttoCycle.arr_s[3]',
#  'PistonCylinder1.OttoCycle.arr_u[2]',
#  'PistonCylinder1.OttoCycle.arr_u[3]',
#  'PistonCylinder1.OttoCycle.arr_u[4]',
#  'PistonCylinder1.OttoCycle.arr_u[5]',
#  'PistonCylinder1.OttoCycle.arr_v[2]',
#  'PistonCylinder1.OttoCycle.arr_v[3]',
#  'PistonCylinder1.OttoCycle.arr_v[4]',
#  'PistonCylinder1.OttoCycle.arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[2].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[3].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[4].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[1].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[2].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[3].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[4].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[1].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[2].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[3].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[4].hUpper',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].u_m',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_v[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_v[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].dp',
#  'PistonCylinder1.OttoCycle.curve_pv[2].dp',
#  'PistonCylinder1.OttoCycle.curve_pv[3].dp',
#  'PistonCylinder1.OttoCycle.curve_pv[4].dp',
#  'PistonCylinder1.OttoCycle.curve_pv[1].vLower',
#  'PistonCylinder1.OttoCycle.curve_pv[2].vLower',
#  'PistonCylinder1.OttoCycle.curve_pv[3].vLower',
#  'PistonCylinder1.OttoCycle.curve_pv[4].vLower',
#  'PistonCylinder1.OttoCycle.curve_pv[1].vUpper',
#  'PistonCylinder1.OttoCycle.curve_pv[2].vUpper',
#  'PistonCylinder1.OttoCycle.curve_pv[3].vUpper',
#  'PistonCylinder1.OttoCycle.curve_pv[4].vUpper',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_us[3].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_us[4].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[2]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[3]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[4]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[5]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[6]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[7]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[8]',
#  'PistonCylinder1.OttoCycle.curve_us[1].arr_u[9]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_u[2]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_u[3]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_u[4]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_u[5]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_u[6]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_u[7]',
#  'PistonCylinder1.OttoCycle.curve_us[2].arr_u[8]',
#  ...]

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=5


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01_res_2.csv
# i_df=3
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01_res_3.csv
# i_df=4
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01_res_4.csv
# i_df=5
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01_res_5.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360_ex01_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#       time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0      0.0         0.000000    -209.439510           -209.439510
# 1      0.2       -45.879106    -242.910492           -242.910492
# 2      0.4       -95.690211    -253.229456           -253.229456
# 3      0.6      -146.717201    -256.431265           -256.431265
# 4      0.8      -198.121938    -257.426426           -257.426426
# ..     ...              ...            ...                   ...
# 501   99.4    -26372.032671    -273.063609           -273.063609
# 502   99.6    -26426.645393    -273.063609           -273.063609
# 503   99.8    -26481.258115    -273.063609           -273.063609
# 504  100.0    -26535.870837    -273.063609           -273.063609
# 505  100.0    -26535.870837    -273.063609           -273.063609
#
#      der(damper1.w_rel)  Flt2Fluid.AltMN2pTh.TambStd  \
# 0         -2.854958e+02                       288.16
# 1         -8.764113e+01                       288.16
# 2         -2.714777e+01                       288.16
# 3         -8.434960e+00                       288.16
# 4         -2.624533e+00                       288.16
# ..                  ...                          ...
# 501        6.593837e-12                       288.16
# 502        5.684342e-12                       288.16
# 503        8.640200e-12                       288.16
# 504        6.593837e-12                       288.16
# 505        7.048584e-12                       288.16
#
#      Flt2Fluid.AltMN2pTh.fluidAmb.MM  Flt2Fluid.AltMN2pTh.fluidAmb.R  \
# 0                           0.028965                      287.051225
# 1                           0.028965                      287.051225
# 2                           0.028965                      287.051225
# 3                           0.028965                      287.051225
# 4                           0.028965                      287.051225
# ..                               ...                             ...
# 501                         0.028965                      287.051225
# 502                         0.028965                      287.051225
# 503                         0.028965                      287.051225
# 504                         0.028965                      287.051225
# 505                         0.028965                      287.051225
#
#      Flt2Fluid.AltMN2pTh.fluidAmb.T_degC  Flt2Fluid.AltMN2pTh.fluidAmb.X[1]  \
# 0                                  15.01                                  1
# 1                                  15.01                                  1
# 2                                  15.01                                  1
# 3                                  15.01                                  1
# 4                                  15.01                                  1
# ..                                   ...                                ...
# 501                                15.01                                  1
# 502                                15.01                                  1
# 503                                15.01                                  1
# 504                                15.01                                  1
# 505                                15.01                                  1
#
#      ...  throttle.port_1.h_outflow  throttle.port_1.m_flow  \
# 0    ...              288574.819851                0.099558
# 1    ...              288574.819851                0.110023
# 2    ...              288574.819851                0.112986
# 3    ...              288574.819851                0.113882
# 4    ...              288574.819851                0.114158
# ..   ...                        ...                     ...
# 501  ...              288574.819851                0.128137
# 502  ...              288574.819851                0.128137
# 503  ...              288574.819851                0.128137
# 504  ...              288574.819851                0.128137
# 505  ...              288574.819851                0.128137
#
#      throttle.port_1.p  throttle.port_2.m_flow  throttle.port_2.p  \
# 0             101323.7               -0.099558       83520.541741
# 1             101323.7               -0.110023       79581.288847
# 2             101323.7               -0.112986       78394.368428
# 3             101323.7               -0.113882       78029.331455
# 4             101323.7               -0.114158       77916.201037
# ..                 ...                     ...                ...
# 501           101323.7               -0.128137       82449.251213
# 502           101323.7               -0.128137       82449.251213
# 503           101323.7               -0.128137       82449.251213
# 504           101323.7               -0.128137       82449.251213
# 505           101323.7               -0.128137       82449.251213
#
#      throttle.u_Cd  throttle.u_kArea  to_rpm_crankshaft.u  torque1.flange.phi  \
# 0              0.6               0.8           209.439510           -0.000000
# 1              0.6               0.8           242.910492           45.879106
# 2              0.6               0.8           253.229456           95.690211
# 3              0.6               0.8           256.431265          146.717201
# 4              0.6               0.8           257.426426          198.121938
# ..             ...               ...                  ...                 ...
# 501            0.6               1.0           273.063609        26372.032671
# 502            0.6               1.0           273.063609        26426.645393
# 503            0.6               1.0           273.063609        26481.258115
# 504            0.6               1.0           273.063609        26535.870837
# 505            0.6               1.0           273.063609        26535.870837
#
#      torque1.tau
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 501            0
# 502            0
# 503            0
# 504            0
# 505            0
#
# [506 rows x 3467 columns]

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #2</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01'
nmModel='LycomO360turboCharged_ex01'
stopTime=90.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
# for 2nd model and lator
#**************************************************

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')

print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/Examples/Engines/Transient/LycomO360turboCharged_ex01.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=100

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#        time        Trb.phi  damper1.phi_rel  damper1.w_rel   inertia2.w  \
# 0       0.0       1.000000         0.000000    -209.439510  3141.592654
# 1       0.1     312.892980       -28.399922    -333.462950  3106.872077
# 2       0.2     623.540148       -64.116927    -374.307080  3109.150489
# 3       0.3     935.077646      -102.476228    -390.591288  3122.549241
# 4       0.4    1248.154243      -141.946593    -397.936509  3139.215965
# ...     ...            ...              ...            ...          ...
# 1003   99.7  355962.354426    -43616.275156    -452.927395  3766.411142
# 1004   99.8  356338.995540    -43661.567896    -452.927395  3766.411142
# 1005   99.9  356715.636654    -43706.860636    -452.927395  3766.411142
# 1006  100.0  357092.277768    -43752.153375    -452.927395  3766.411142
# 1007  100.0  357092.277768    -43752.153375    -452.927395  3766.411142
#
#       der(Trb.phi)  der(damper1.phi_rel)  der(damper1.w_rel)  der(inertia2.w)  \
# 0      3141.592654           -209.439510       -2.212395e+03    -7.460456e+02
# 1      3106.872077           -333.462950       -6.483699e+02    -8.983239e+01
# 2      3109.150489           -374.307080       -2.439944e+02     9.918883e+01
# 3      3122.549241           -390.591288       -1.043284e+02     1.573718e+02
# 4      3139.215965           -397.936509       -5.073569e+01     1.717954e+02
# ...            ...                   ...                 ...              ...
# 1003   3766.411142           -452.927395        3.497007e-09    -4.148296e-08
# 1004   3766.411142           -452.927395        3.464720e-09    -4.122785e-08
# 1005   3766.411142           -452.927395        3.450168e-09    -4.098410e-08
# 1006   3766.411142           -452.927395        3.423338e-09    -4.077128e-08
# 1007   3766.411142           -452.927395        3.421746e-09    -4.073945e-08
#
#       der(Cmp.phi)  ...  throttle.port_1.m_flow  throttle.port_1.p  \
# 0      3141.592654  ...                0.264000      405294.800000
# 1      3106.872077  ...                0.289941      302779.096323
# 2      3109.150489  ...                0.291888      280600.054693
# 3      3122.549241  ...                0.293967      275026.257589
# 4      3139.215965  ...                0.296210      274378.440191
# ...            ...  ...                     ...                ...
# 1003   3766.411142  ...                0.380757      312361.825076
# 1004   3766.411142  ...                0.380757      312361.825076
# 1005   3766.411142  ...                0.380757      312361.825076
# 1006   3766.411142  ...                0.380757      312361.825076
# 1007   3766.411142  ...                0.380757      312361.825076
#
#       throttle.port_2.m_flow  throttle.port_2.p  throttle.u_Cd  \
# 0                  -0.264000      355113.905922            0.6
# 1                  -0.289941      227523.772950            0.6
# 2                  -0.291888      199956.396376            0.6
# 3                  -0.293967      191998.511241            0.6
# 4                  -0.296210      189883.683468            0.6
# ...                      ...                ...            ...
# 1003               -0.380757      228669.531273            0.6
# 1004               -0.380757      228669.531273            0.6
# 1005               -0.380757      228669.531273            0.6
# 1006               -0.380757      228669.531273            0.6
# 1007               -0.380757      228669.531273            0.6
#
#       throttle.u_kArea  to_rpm_crankshaft.u  to_rpm_turboCharger.u  \
# 0                  0.8           209.439510            3141.592654
# 1                  0.8           333.462950            3106.872077
# 2                  0.8           374.307080            3109.150489
# 3                  0.8           390.591288            3122.549241
# 4                  0.8           397.936509            3139.215965
# ...                ...                  ...                    ...
# 1003               1.0           452.927395            3766.411142
# 1004               1.0           452.927395            3766.411142
# 1005               1.0           452.927395            3766.411142
# 1006               1.0           452.927395            3766.411142
# 1007               1.0           452.927395            3766.411142
#
#       torque1.flange.phi  torque1.tau
# 0              -0.000000            0
# 1              28.399922            0
# 2              64.116927            0
# 3             102.476228            0
# 4             141.946593            0
# ...                  ...          ...
# 1003        43616.275156            0
# 1004        43661.567896            0
# 1005        43706.860636            0
# 1006        43752.153375            0
# 1007        43752.153375            0
#
# [1008 rows x 3871 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=100

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'Trb.phi',
#  'damper1.phi_rel',
#  'damper1.w_rel',
#  'inertia2.w',
#  'der(Trb.phi)',
#  'der(damper1.phi_rel)',
#  'der(damper1.w_rel)',
#  'der(inertia2.w)',
#  'der(Cmp.phi)',
#  'Cmp.CmpTbl_WcPReff_NcRline.u_NcTbl',
#  'Cmp.CmpTbl_WcPReff_NcRline.y_PR',
#  'Cmp.CmpTbl_WcPReff_NcRline.y_Wc',
#  'Cmp.CmpTbl_WcPReff_NcRline.y_eff',
#  'Cmp.Nc_1',
#  'Cmp.NcqNcDes_1',
#  'Cmp.Nmech',
#  'Cmp.NqNdes',
#  'Cmp.PR',
#  'Cmp.Rline',
#  'Cmp.ScalerDesCmp.CmpTbl_WcPReff_NcRline_Des.y_PR',
#  'Cmp.ScalerDesCmp.CmpTbl_WcPReff_NcRline_Des.y_Wc',
#  'Cmp.ScalerDesCmp.CmpTbl_WcPReff_NcRline_Des.y_eff',
#  'Cmp.ScalerDesCmp.const.y',
#  'Cmp.ScalerDesCmp.const1.y',
#  'Cmp.ScalerDesCmp.division3.u1',
#  'Cmp.ScalerDesCmp.division3.u2',
#  'Cmp.ScalerDesCmp.u_NcTblDes',
#  'Cmp.ScalerDesCmp.u_RlineTblDes',
#  'Cmp.ScalerDesCmp.y_s_PRdes',
#  'Cmp.ScalerDesCmp.y_s_WcDes',
#  'Cmp.ScalerDesCmp.y_s_effDes',
#  'Cmp.SclCmp.add1.u1',
#  'Cmp.SclCmp.const.y',
#  'Cmp.SclCmp.const1.y',
#  'Cmp.SclCmp.feedback1.y',
#  'Cmp.SclCmp.y_PRscld',
#  'Cmp.SclCmp.y_WcScld',
#  'Cmp.SclCmp.y_effScld',
#  'Cmp.Wc_1',
#  'Cmp.a_PRaud',
#  'Cmp.a_WcAud',
#  'Cmp.a_effAud',
#  'Cmp.dht',
#  'Cmp.dht_is',
#  'Cmp.eff',
#  'Cmp.flange_1.phi',
#  'Cmp.flange_1.tau',
#  'Cmp.flange_2.phi',
#  'Cmp.flange_2.tau',
#  'Cmp.fluid_1.MM',
#  'Cmp.fluid_1.R',
#  'Cmp.fluid_1.T',
#  'Cmp.fluid_1.T_degC',
#  'Cmp.fluid_1.X[1]',
#  'Cmp.fluid_1.d',
#  'Cmp.fluid_1.h',
#  'Cmp.fluid_1.p',
#  'Cmp.fluid_1.p_bar',
#  'Cmp.fluid_1.u',
#  'Cmp.fluid_2.MM',
#  'Cmp.fluid_2.R',
#  'Cmp.fluid_2.T',
#  'Cmp.fluid_2.T_degC',
#  'Cmp.fluid_2.X[1]',
#  'Cmp.fluid_2.d',
#  'Cmp.fluid_2.h',
#  'Cmp.fluid_2.p',
#  'Cmp.fluid_2.p_bar',
#  'Cmp.fluid_2.u',
#  'Cmp.h_2is',
#  'Cmp.m_flow_max',
#  'Cmp.m_flow_min',
#  'Cmp.omega',
#  'Cmp.phi',
#  'Cmp.port_1.m_flow',
#  'Cmp.port_2.h_outflow',
#  'Cmp.port_2.m_flow',
#  'Cmp.pwr',
#  'Cmp.pwr_inv',
#  'Cmp.s_PRaud',
#  'Cmp.s_WcAud',
#  'Cmp.s_effAud',
#  'Cmp.s_fluid_1',
#  'Cmp.s_fluid_2',
#  'Cmp.trq',
#  'Cmp.trq_inv',
#  'Flt2Fluid.AltMN2pTh.TambStd',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.u',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.h',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.u',
#  'Flt2Fluid.AltMN2pTh.fluidTot.MM',
#  'Flt2Fluid.AltMN2pTh.fluidTot.R',
#  'Flt2Fluid.AltMN2pTh.fluidTot.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidTot.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidTot.d',
#  'Flt2Fluid.AltMN2pTh.fluidTot.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidTot.u',
#  'Flt2Fluid.AltMN2pTh.pAmbStd',
#  'Flt2Fluid.AltMN2pTh.u_X[1]',
#  'Flt2Fluid.AltMN2pTh.u_dTamb',
#  'Flt2Fluid.AltMN2pTh.y_Tamb',
#  'Flt2Fluid.AltMN2pTh.y_Ttot',
#  'Flt2Fluid.AltMN2pTh.y_hTot',
#  'Flt2Fluid.AltMN2pTh.y_pAmb',
#  'Flt2Fluid.AltMN2pTh.y_pTot',
#  'Flt2Fluid.limiter2.y',
#  'Flt2Fluid.limiter4.y',
#  'Flt2Fluid.port_amb4source.m_flow',
#  'Flt2Fluid.s_fluid_amb4sink',
#  'Flt2Fluid.s_fluid_amb4source',
#  'Flt2Fluid.s_fluid_inlet',
#  'Flt2Fluid.sourceFluid2Inlet.X_in[1]',
#  'Flt2Fluid.sourceFluid2Inlet.medium.MM',
#  'Flt2Fluid.sourceFluid2Inlet.medium.R',
#  'Flt2Fluid.sourceFluid2Inlet.medium.T_degC',
#  'Flt2Fluid.sourceFluid2Inlet.medium.X[1]',
#  'Flt2Fluid.sourceFluid2Inlet.medium.d',
#  'Flt2Fluid.sourceFluid2Inlet.medium.p_bar',
#  'Flt2Fluid.sourceFluid2Inlet.medium.u',
#  'Flt2Fluid.sourceFluid2Inlet.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidAmb4sink.X_in[1]',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.R',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.X[1]',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.d',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.u',
#  'Flt2Fluid.sourceFluidAmb4sink.p_in',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidAmb4source.X_in[1]',
#  'Flt2Fluid.sourceFluidAmb4source.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4source.medium.R',
#  'Flt2Fluid.sourceFluidAmb4source.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4source.medium.X[1]',
#  'Flt2Fluid.sourceFluidAmb4source.medium.d',
#  'Flt2Fluid.sourceFluidAmb4source.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4source.medium.u',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].h_outflow',
#  'Flt2Fluid.y_V_inf',
#  'LossRotMech.Qloss',
#  'LossRotMech.eff',
#  'LossRotMech.pwrIn',
#  'LossRotMech.pwrOut_inv',
#  'LossRotMech.trqIn',
#  'LossRotMech.trqMax',
#  'LossRotMech.trqMin',
#  'LossRotMech.trqOut_inv',
#  'Pa2inHg.y',
#  'PistonCylinder.CR',
#  'PistonCylinder.Nmech',
#  'PistonCylinder.OttoCycle.ER',
#  'PistonCylinder.OttoCycle.PR_1_2',
#  'PistonCylinder.OttoCycle.PR_3_4',
#  'PistonCylinder.OttoCycle.W_1_2',
#  'PistonCylinder.OttoCycle.W_3_4',
#  'PistonCylinder.OttoCycle.arr_T[2]',
#  'PistonCylinder.OttoCycle.arr_T[3]',
#  'PistonCylinder.OttoCycle.arr_T[4]',
#  'PistonCylinder.OttoCycle.arr_T[5]',
#  'PistonCylinder.OttoCycle.arr_h[2]',
#  'PistonCylinder.OttoCycle.arr_h[3]',
#  'PistonCylinder.OttoCycle.arr_h[4]',
#  'PistonCylinder.OttoCycle.arr_h[5]',
#  'PistonCylinder.OttoCycle.arr_s[2]',
#  'PistonCylinder.OttoCycle.arr_s[3]',
#  'PistonCylinder.OttoCycle.arr_u[2]',
#  'PistonCylinder.OttoCycle.arr_u[3]',
#  'PistonCylinder.OttoCycle.arr_u[4]',
#  'PistonCylinder.OttoCycle.arr_u[5]',
#  'PistonCylinder.OttoCycle.arr_v[2]',
#  'PistonCylinder.OttoCycle.arr_v[3]',
#  'PistonCylinder.OttoCycle.arr_v[4]',
#  'PistonCylinder.OttoCycle.arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[2].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[3].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[1].ds',
#  'PistonCylinder.OttoCycle.curve_hs[2].ds',
#  'PistonCylinder.OttoCycle.curve_hs[3].ds',
#  'PistonCylinder.OttoCycle.curve_hs[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[2].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[3].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[4].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[1].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[2].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[3].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[4].hUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[2].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[3].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[4].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[1].u_m',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].dp',
#  'PistonCylinder.OttoCycle.curve_pv[2].dp',
#  'PistonCylinder.OttoCycle.curve_pv[3].dp',
#  'PistonCylinder.OttoCycle.curve_pv[4].dp',
#  'PistonCylinder.OttoCycle.curve_pv[1].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[2].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[3].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[4].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[1].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[2].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[3].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[4].vUpper',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].ds',
#  'PistonCylinder.OttoCycle.curve_us[2].ds',
#  'PistonCylinder.OttoCycle.curve_us[3].ds',
#  'PistonCylinder.OttoCycle.curve_us[4].ds',
#  'PistonCylinder.OttoCycle.curve_us[1].uLower',
#  'PistonCylinder.OttoCycle.curve_us[2].uLower',
#  'PistonCylinder.OttoCycle.curve_us[3].uLower',
#  'PistonCylinder.OttoCycle.curve_us[4].uLower',
#  'PistonCylinder.OttoCycle.curve_us[1].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[2].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[3].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[4].uUpper',
#  'PistonCylinder.OttoCycle.effThermal',
#  'PistonCylinder.OttoCycle.fluidState_1.MM',
#  'PistonCylinder.OttoCycle.fluidState_1.R',
#  'PistonCylinder.OttoCycle.fluidState_1.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_1.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_1.d',
#  'PistonCylinder.OttoCycle.fluidState_1.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_2.MM',
#  'PistonCylinder.OttoCycle.fluidState_2.R',
#  'PistonCylinder.OttoCycle.fluidState_2.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_2.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_2.d',
#  'PistonCylinder.OttoCycle.fluidState_2.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_3.MM',
#  'PistonCylinder.OttoCycle.fluidState_3.R',
#  'PistonCylinder.OttoCycle.fluidState_3.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_3.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_3.d',
#  'PistonCylinder.OttoCycle.fluidState_3.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_4.MM',
#  'PistonCylinder.OttoCycle.fluidState_4.R',
#  'PistonCylinder.OttoCycle.fluidState_4.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_4.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_4.d',
#  'PistonCylinder.OttoCycle.fluidState_4.p_bar',
#  'PistonCylinder.OttoCycle.par_CR',
#  'PistonCylinder.OttoCycle.par_LHV_fuel',
#  'PistonCylinder.OttoCycle.u_effComb',
#  'PistonCylinder.OttoCycle.u_fracFuel',
#  'PistonCylinder.OttoCycle.y_Q_2_3',
#  'PistonCylinder.OttoCycle.y_Q_4_1',
#  'PistonCylinder.OttoCycle.y_m_fuel',
#  'PistonCylinder.Q_add',
#  'PistonCylinder.Q_reject',
#  'PistonCylinder.V_flow',
#  'PistonCylinder.VolBDC',
#  'PistonCylinder.VolDisp',
#  'PistonCylinder.VolTDC',
#  'PistonCylinder.WexhCycle',
#  'PistonCylinder.WintkCycle',
#  'PistonCylinder.WoutCycle',
#  'PistonCylinder.arr_V[7]',
#  'PistonCylinder.arr_V[8]',
#  'PistonCylinder.arr_p[2]',
#  'PistonCylinder.arr_p[3]',
#  'PistonCylinder.arr_p[4]',
#  'PistonCylinder.calcEffComb.AFRsat',
#  'PistonCylinder.calcEffComb.AFRstoi',
#  'PistonCylinder.calcEffComb.FAR',
#  'PistonCylinder.calcEffComb.FARsat',
#  'PistonCylinder.calcEffComb.FARstoi',
#  'PistonCylinder.calcEffComb.flagValid',
#  'PistonCylinder.calcEffComb.fracAirStoi',
#  'PistonCylinder.calcEffComb.fracFuelStoi',
#  'PistonCylinder.calcEffComb.fracTot',
#  'PistonCylinder.calcEffComb.y_AFR',
#  'PistonCylinder.calcEffComb.y_lambda',
#  'PistonCylinder.dH_1_2_cycle',
#  'PistonCylinder.dU_1_2_cycle',
#  'PistonCylinder.dh_state4_port2',
#  'PistonCylinder.flange_1.tau',
#  'PistonCylinder.fluid_1.MM',
#  'PistonCylinder.fluid_1.R',
#  'PistonCylinder.fluid_1.T',
#  'PistonCylinder.fluid_1.T_degC',
#  'PistonCylinder.fluid_1.X[1]',
#  'PistonCylinder.fluid_1.d',
#  'PistonCylinder.fluid_1.p_bar',
#  'PistonCylinder.fluid_2.MM',
#  'PistonCylinder.fluid_2.R',
#  'PistonCylinder.fluid_2.T',
#  'PistonCylinder.fluid_2.T_degC',
#  'PistonCylinder.fluid_2.X[1]',
#  'PistonCylinder.fluid_2.d',
#  'PistonCylinder.fluid_2.h',
#  'PistonCylinder.fluid_2.p_bar',
#  'PistonCylinder.fluid_2.u',
#  'PistonCylinder.m_flow',
#  'PistonCylinder.m_flow_max',
#  'PistonCylinder.m_flow_min',
#  'PistonCylinder.port_2.h_outflow',
#  'PistonCylinder.pwrCycle',
#  'PistonCylinder.pwrExh',
#  'PistonCylinder.pwrIntk',
#  'PistonCylinder.pwrOut',
#  'PistonCylinder.pwrPumping',
#  'PistonCylinder.pwrPumpingqPwrCycle',
#  'PistonCylinder.pwr_cmp',
#  'PistonCylinder.pwr_exp',
#  'PistonCylinder.s_fluid_1',
#  'PistonCylinder.s_fluid_2',
#  'PistonCylinder.trqOut',
#  'PistonCylinder.u_fracAir',
#  'PistonCylinder.y_m_flow_fuel',
#  'PistonCylinder1.CR',
#  'PistonCylinder1.Nmech',
#  'PistonCylinder1.OttoCycle.ER',
#  'PistonCylinder1.OttoCycle.PR_1_2',
#  'PistonCylinder1.OttoCycle.PR_3_4',
#  'PistonCylinder1.OttoCycle.W_1_2',
#  'PistonCylinder1.OttoCycle.W_3_4',
#  'PistonCylinder1.OttoCycle.arr_T[2]',
#  'PistonCylinder1.OttoCycle.arr_T[3]',
#  'PistonCylinder1.OttoCycle.arr_T[4]',
#  'PistonCylinder1.OttoCycle.arr_T[5]',
#  'PistonCylinder1.OttoCycle.arr_h[2]',
#  'PistonCylinder1.OttoCycle.arr_h[3]',
#  'PistonCylinder1.OttoCycle.arr_h[4]',
#  'PistonCylinder1.OttoCycle.arr_h[5]',
#  'PistonCylinder1.OttoCycle.arr_s[2]',
#  'PistonCylinder1.OttoCycle.arr_s[3]',
#  'PistonCylinder1.OttoCycle.arr_u[2]',
#  'PistonCylinder1.OttoCycle.arr_u[3]',
#  'PistonCylinder1.OttoCycle.arr_u[4]',
#  'PistonCylinder1.OttoCycle.arr_u[5]',
#  'PistonCylinder1.OttoCycle.arr_v[2]',
#  'PistonCylinder1.OttoCycle.arr_v[3]',
#  'PistonCylinder1.OttoCycle.arr_v[4]',
#  'PistonCylinder1.OttoCycle.arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[2].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[3].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[4].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[1].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[2].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[3].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[4].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[1].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[2].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[3].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[4].hUpper',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].u_m',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[9]',
#  ...]

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=102
i_df_end=105


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=102
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01_res_102.csv
# i_df=103
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01_res_103.csv
# i_df=104
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01_res_104.csv
# i_df=105
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01_res_105.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=101

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360turboCharged_ex01_res_101.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#       time        Trb.phi  damper1.phi_rel  damper1.w_rel   inertia2.w  \
# 0      0.0       1.000000         0.000000    -209.439510  3141.592654
# 1      0.2     623.540148       -64.116927    -374.307080  3109.150489
# 2      0.4    1248.154243      -141.946593    -397.936509  3139.215965
# 3      0.6    1879.413842      -222.253946    -404.160962  3173.043270
# 4      0.8    2517.146352      -303.427097    -407.363448  3203.631631
# ..     ...            ...              ...            ...          ...
# 503   99.4  354832.431083    -43480.396938    -452.927395  3766.411142
# 504   99.6  355585.713312    -43570.982417    -452.927395  3766.411142
# 505   99.8  356338.995540    -43661.567896    -452.927395  3766.411142
# 506  100.0  357092.277768    -43752.153375    -452.927395  3766.411142
# 507  100.0  357092.277768    -43752.153375    -452.927395  3766.411142
#
#      der(Trb.phi)  der(damper1.phi_rel)  der(damper1.w_rel)  der(inertia2.w)  \
# 0     3141.592654           -209.439510       -2.212395e+03    -7.460456e+02
# 1     3109.150489           -374.307080       -2.439944e+02     9.918883e+01
# 2     3139.215965           -397.936509       -5.073569e+01     1.717954e+02
# 3     3173.043270           -404.160962       -1.991911e+01     1.625010e+02
# 4     3203.631631           -407.363448       -1.345568e+01     1.431276e+02
# ..            ...                   ...                 ...              ...
# 503   3766.411142           -452.927395        3.548394e-09    -4.222238e-08
# 504   3766.411142           -452.927395        3.510195e-09    -4.172489e-08
# 505   3766.411142           -452.927395        3.467449e-09    -4.122421e-08
# 506   3766.411142           -452.927395        3.422201e-09    -4.071262e-08
# 507   3766.411142           -452.927395        3.425839e-09    -4.072444e-08
#
#      der(Cmp.phi)  ...  throttle.port_1.m_flow  throttle.port_1.p  \
# 0     3141.592654  ...                0.264000      405294.800000
# 1     3109.150489  ...                0.291888      280600.054693
# 2     3139.215965  ...                0.296210      274378.440191
# 3     3173.043270  ...                0.300598      277040.424332
# 4     3203.631631  ...                0.304541      280549.784994
# ..            ...  ...                     ...                ...
# 503   3766.411142  ...                0.380757      312361.825076
# 504   3766.411142  ...                0.380757      312361.825076
# 505   3766.411142  ...                0.380757      312361.825076
# 506   3766.411142  ...                0.380757      312361.825076
# 507   3766.411142  ...                0.380757      312361.825076
#
#      throttle.port_2.m_flow  throttle.port_2.p  throttle.u_Cd  \
# 0                 -0.264000      355113.905922            0.6
# 1                 -0.291888      199956.396376            0.6
# 2                 -0.296210      189883.683468            0.6
# 3                 -0.300598      190506.457089            0.6
# 4                 -0.304541      192416.500506            0.6
# ..                      ...                ...            ...
# 503               -0.380757      228669.531273            0.6
# 504               -0.380757      228669.531273            0.6
# 505               -0.380757      228669.531273            0.6
# 506               -0.380757      228669.531273            0.6
# 507               -0.380757      228669.531273            0.6
#
#      throttle.u_kArea  to_rpm_crankshaft.u  to_rpm_turboCharger.u  \
# 0                 0.8           209.439510            3141.592654
# 1                 0.8           374.307080            3109.150489
# 2                 0.8           397.936509            3139.215965
# 3                 0.8           404.160962            3173.043270
# 4                 0.8           407.363448            3203.631631
# ..                ...                  ...                    ...
# 503               1.0           452.927395            3766.411142
# 504               1.0           452.927395            3766.411142
# 505               1.0           452.927395            3766.411142
# 506               1.0           452.927395            3766.411142
# 507               1.0           452.927395            3766.411142
#
#      torque1.flange.phi  torque1.tau
# 0             -0.000000            0
# 1             64.116927            0
# 2            141.946593            0
# 3            222.253946            0
# 4            303.427097            0
# ..                  ...          ...
# 503        43480.396938            0
# 504        43570.982417            0
# 505        43661.567896            0
# 506        43752.153375            0
# 507        43752.153375            0
#
# [508 rows x 3871 columns]

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #3</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01'
nmModel='LycomO360superCharged_ex01'
stopTime=90.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
# for 2nd model and lator
#**************************************************

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')

print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/Examples/Engines/Transient/LycomO360superCharged_ex01.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=200

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#        time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0       0.0         0.000000    -448.798951           -448.798951
# 1       0.1       -45.293800    -456.833178           -456.833178
# 2       0.2       -91.321667    -463.516269           -463.516269
# 3       0.3      -137.958918    -469.053736           -469.053736
# 4       0.4      -185.100311    -473.626789           -473.626789
# ...     ...              ...            ...                   ...
# 1003   99.7    -50887.254516    -527.340404           -527.340404
# 1004   99.8    -50939.988557    -527.340404           -527.340404
# 1005   99.9    -50992.722597    -527.340404           -527.340404
# 1006  100.0    -51045.456637    -527.340404           -527.340404
# 1007  100.0    -51045.456637    -527.340404           -527.340404
#
#       der(damper1.w_rel)  der(Cmp.omega)  der(Cmp.phi)  der(inertia2.w)  \
# 0          -8.784189e+01    6.148932e+02   3141.592654     6.148932e+02
# 1          -7.322448e+01    5.125713e+02   3197.832244     5.125713e+02
# 2          -6.078058e+01    4.254641e+02   3244.613884     4.254641e+02
# 3          -5.027057e+01    3.518940e+02   3283.376149     3.518940e+02
# 4          -4.145311e+01    2.901717e+02   3315.387525     2.901717e+02
# ...                  ...             ...           ...              ...
# 1003        1.268745e-10   -8.881216e-10   3691.382831    -8.881216e-10
# 1004        1.396074e-10   -9.772521e-10   3691.382831    -9.772521e-10
# 1005        1.282388e-10   -8.976713e-10   3691.382831    -8.976713e-10
# 1006        1.309672e-10   -9.167707e-10   3691.382831    -9.167707e-10
# 1007        1.450644e-10   -1.015451e-09   3691.382831    -1.015451e-09
#
#       Cmp.CmpTbl_WcPReff_NcRline.u_NcTbl  Cmp.CmpTbl_WcPReff_NcRline.y_PR  \
# 0                               1.000000                        21.970556
# 1                               1.017902                        22.732869
# 2                               1.032793                        23.374677
# 3                               1.045131                        23.911757
# 4                               1.055321                        24.358919
# ...                                  ...                              ...
# 1003                            1.175004                        26.970806
# 1004                            1.175004                        26.970806
# 1005                            1.175004                        26.970806
# 1006                            1.175004                        26.970806
# 1007                            1.175004                        26.970806
#
#       ...  throttle.port_1.m_flow  throttle.port_1.p  throttle.port_2.m_flow  \
# 0     ...                0.431799      405294.800000               -0.431799
# 1     ...                0.444577      416344.629003               -0.444577
# 2     ...                0.455302      425647.724696               -0.455302
# 3     ...                0.464251      433432.781679               -0.464251
# 4     ...                0.471685      439914.446324               -0.471685
# ...   ...                     ...                ...                     ...
# 1003  ...                0.585392      477774.109771               -0.585392
# 1004  ...                0.585392      477774.109771               -0.585392
# 1005  ...                0.585392      477774.109771               -0.585392
# 1006  ...                0.585392      477774.109771               -0.585392
# 1007  ...                0.585392      477774.109771               -0.585392
#
#       throttle.port_2.p  throttle.u_Cd  throttle.u_kArea  to_rpm_crankshaft.u  \
# 0         271051.424671            0.6               0.8           448.798951
# 1         276589.814832            0.6               0.8           456.833178
# 2         281222.536727            0.6               0.8           463.516269
# 3         285079.072033            0.6               0.8           469.053736
# 4         288276.420944            0.6               0.8           473.626789
# ...                 ...            ...               ...                  ...
# 1003      334499.403870            0.6               1.0           527.340404
# 1004      334499.403870            0.6               1.0           527.340404
# 1005      334499.403870            0.6               1.0           527.340404
# 1006      334499.403870            0.6               1.0           527.340404
# 1007      334499.403870            0.6               1.0           527.340404
#
#       to_rpm_superCharger.u  torque1.flange.phi  torque1.tau
# 0               3141.592654           -0.000000            0
# 1               3197.832244           45.293800            0
# 2               3244.613884           91.321667            0
# 3               3283.376149          137.958918            0
# 4               3315.387525          185.100311            0
# ...                     ...                 ...          ...
# 1003            3691.382831        50887.254516            0
# 1004            3691.382831        50939.988557            0
# 1005            3691.382831        50992.722597            0
# 1006            3691.382831        51045.456637            0
# 1007            3691.382831        51045.456637            0
#
# [1008 rows x 3690 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=200

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'damper1.phi_rel',
#  'damper1.w_rel',
#  'der(damper1.phi_rel)',
#  'der(damper1.w_rel)',
#  'der(Cmp.omega)',
#  'der(Cmp.phi)',
#  'der(inertia2.w)',
#  'Cmp.CmpTbl_WcPReff_NcRline.u_NcTbl',
#  'Cmp.CmpTbl_WcPReff_NcRline.y_PR',
#  'Cmp.CmpTbl_WcPReff_NcRline.y_Wc',
#  'Cmp.CmpTbl_WcPReff_NcRline.y_eff',
#  'Cmp.Nc_1',
#  'Cmp.NcqNcDes_1',
#  'Cmp.Nmech',
#  'Cmp.NqNdes',
#  'Cmp.PR',
#  'Cmp.Rline',
#  'Cmp.ScalerDesCmp.CmpTbl_WcPReff_NcRline_Des.y_PR',
#  'Cmp.ScalerDesCmp.CmpTbl_WcPReff_NcRline_Des.y_Wc',
#  'Cmp.ScalerDesCmp.CmpTbl_WcPReff_NcRline_Des.y_eff',
#  'Cmp.ScalerDesCmp.const.y',
#  'Cmp.ScalerDesCmp.const1.y',
#  'Cmp.ScalerDesCmp.division3.u1',
#  'Cmp.ScalerDesCmp.division3.u2',
#  'Cmp.ScalerDesCmp.u_NcTblDes',
#  'Cmp.ScalerDesCmp.u_RlineTblDes',
#  'Cmp.ScalerDesCmp.y_s_PRdes',
#  'Cmp.ScalerDesCmp.y_s_WcDes',
#  'Cmp.ScalerDesCmp.y_s_effDes',
#  'Cmp.SclCmp.add1.u1',
#  'Cmp.SclCmp.const.y',
#  'Cmp.SclCmp.const1.y',
#  'Cmp.SclCmp.feedback1.y',
#  'Cmp.SclCmp.y_PRscld',
#  'Cmp.SclCmp.y_WcScld',
#  'Cmp.SclCmp.y_effScld',
#  'Cmp.Wc_1',
#  'Cmp.a_PRaud',
#  'Cmp.a_WcAud',
#  'Cmp.a_effAud',
#  'Cmp.dht',
#  'Cmp.dht_is',
#  'Cmp.eff',
#  'Cmp.flange_1.phi',
#  'Cmp.flange_1.tau',
#  'Cmp.flange_2.phi',
#  'Cmp.flange_2.tau',
#  'Cmp.fluid_1.MM',
#  'Cmp.fluid_1.R',
#  'Cmp.fluid_1.T',
#  'Cmp.fluid_1.T_degC',
#  'Cmp.fluid_1.X[1]',
#  'Cmp.fluid_1.d',
#  'Cmp.fluid_1.h',
#  'Cmp.fluid_1.p',
#  'Cmp.fluid_1.p_bar',
#  'Cmp.fluid_1.u',
#  'Cmp.fluid_2.MM',
#  'Cmp.fluid_2.R',
#  'Cmp.fluid_2.T',
#  'Cmp.fluid_2.T_degC',
#  'Cmp.fluid_2.X[1]',
#  'Cmp.fluid_2.d',
#  'Cmp.fluid_2.h',
#  'Cmp.fluid_2.p',
#  'Cmp.fluid_2.p_bar',
#  'Cmp.fluid_2.u',
#  'Cmp.h_2is',
#  'Cmp.m_flow_max',
#  'Cmp.m_flow_min',
#  'Cmp.omega',
#  'Cmp.phi',
#  'Cmp.port_1.m_flow',
#  'Cmp.port_2.h_outflow',
#  'Cmp.port_2.m_flow',
#  'Cmp.pwr',
#  'Cmp.pwr_inv',
#  'Cmp.s_PRaud',
#  'Cmp.s_WcAud',
#  'Cmp.s_effAud',
#  'Cmp.s_fluid_1',
#  'Cmp.s_fluid_2',
#  'Cmp.trq',
#  'Cmp.trq_inv',
#  'Flt2Fluid.AltMN2pTh.TambStd',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.u',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.h',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.u',
#  'Flt2Fluid.AltMN2pTh.fluidTot.MM',
#  'Flt2Fluid.AltMN2pTh.fluidTot.R',
#  'Flt2Fluid.AltMN2pTh.fluidTot.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidTot.X[1]',
#  'Flt2Fluid.AltMN2pTh.fluidTot.d',
#  'Flt2Fluid.AltMN2pTh.fluidTot.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidTot.u',
#  'Flt2Fluid.AltMN2pTh.pAmbStd',
#  'Flt2Fluid.AltMN2pTh.u_X[1]',
#  'Flt2Fluid.AltMN2pTh.u_dTamb',
#  'Flt2Fluid.AltMN2pTh.y_Tamb',
#  'Flt2Fluid.AltMN2pTh.y_Ttot',
#  'Flt2Fluid.AltMN2pTh.y_hTot',
#  'Flt2Fluid.AltMN2pTh.y_pAmb',
#  'Flt2Fluid.AltMN2pTh.y_pTot',
#  'Flt2Fluid.limiter2.y',
#  'Flt2Fluid.limiter4.y',
#  'Flt2Fluid.port_amb4sink.m_flow',
#  'Flt2Fluid.port_amb4source.m_flow',
#  'Flt2Fluid.s_fluid_amb4sink',
#  'Flt2Fluid.s_fluid_amb4source',
#  'Flt2Fluid.s_fluid_inlet',
#  'Flt2Fluid.sourceFluid2Inlet.X_in[1]',
#  'Flt2Fluid.sourceFluid2Inlet.medium.MM',
#  'Flt2Fluid.sourceFluid2Inlet.medium.R',
#  'Flt2Fluid.sourceFluid2Inlet.medium.T_degC',
#  'Flt2Fluid.sourceFluid2Inlet.medium.X[1]',
#  'Flt2Fluid.sourceFluid2Inlet.medium.d',
#  'Flt2Fluid.sourceFluid2Inlet.medium.p_bar',
#  'Flt2Fluid.sourceFluid2Inlet.medium.u',
#  'Flt2Fluid.sourceFluid2Inlet.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidAmb4sink.X_in[1]',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.R',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.X[1]',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.d',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.u',
#  'Flt2Fluid.sourceFluidAmb4sink.p_in',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidAmb4source.X_in[1]',
#  'Flt2Fluid.sourceFluidAmb4source.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4source.medium.R',
#  'Flt2Fluid.sourceFluidAmb4source.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4source.medium.X[1]',
#  'Flt2Fluid.sourceFluidAmb4source.medium.d',
#  'Flt2Fluid.sourceFluidAmb4source.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4source.medium.u',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].h_outflow',
#  'Flt2Fluid.y_V_inf',
#  'LossRotMech.Qloss',
#  'LossRotMech.eff',
#  'LossRotMech.pwrIn',
#  'LossRotMech.pwrOut_inv',
#  'LossRotMech.trqIn',
#  'LossRotMech.trqMax',
#  'LossRotMech.trqMin',
#  'LossRotMech.trqOut_inv',
#  'Pa2inHg.y',
#  'PistonCylinder.CR',
#  'PistonCylinder.Nmech',
#  'PistonCylinder.OttoCycle.ER',
#  'PistonCylinder.OttoCycle.PR_1_2',
#  'PistonCylinder.OttoCycle.PR_3_4',
#  'PistonCylinder.OttoCycle.W_1_2',
#  'PistonCylinder.OttoCycle.W_3_4',
#  'PistonCylinder.OttoCycle.arr_T[2]',
#  'PistonCylinder.OttoCycle.arr_T[3]',
#  'PistonCylinder.OttoCycle.arr_T[4]',
#  'PistonCylinder.OttoCycle.arr_T[5]',
#  'PistonCylinder.OttoCycle.arr_h[2]',
#  'PistonCylinder.OttoCycle.arr_h[3]',
#  'PistonCylinder.OttoCycle.arr_h[4]',
#  'PistonCylinder.OttoCycle.arr_h[5]',
#  'PistonCylinder.OttoCycle.arr_s[2]',
#  'PistonCylinder.OttoCycle.arr_s[3]',
#  'PistonCylinder.OttoCycle.arr_u[2]',
#  'PistonCylinder.OttoCycle.arr_u[3]',
#  'PistonCylinder.OttoCycle.arr_u[4]',
#  'PistonCylinder.OttoCycle.arr_u[5]',
#  'PistonCylinder.OttoCycle.arr_v[2]',
#  'PistonCylinder.OttoCycle.arr_v[3]',
#  'PistonCylinder.OttoCycle.arr_v[4]',
#  'PistonCylinder.OttoCycle.arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TLower',
#  'PistonCylinder.OttoCycle.curve_Ts[1].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[2].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[3].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[4].TUpper',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_Ts[1].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[2].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[3].ds',
#  'PistonCylinder.OttoCycle.curve_Ts[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_hs[1].ds',
#  'PistonCylinder.OttoCycle.curve_hs[2].ds',
#  'PistonCylinder.OttoCycle.curve_hs[3].ds',
#  'PistonCylinder.OttoCycle.curve_hs[4].ds',
#  'PistonCylinder.OttoCycle.curve_hs[1].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[2].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[3].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[4].hLower',
#  'PistonCylinder.OttoCycle.curve_hs[1].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[2].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[3].hUpper',
#  'PistonCylinder.OttoCycle.curve_hs[4].hUpper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vlower',
#  'PistonCylinder.OttoCycle.curve_pVol[1].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[2].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[3].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[4].Vupper',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pVol[1].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[2].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[3].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[4].dp',
#  'PistonCylinder.OttoCycle.curve_pVol[1].u_m',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[2].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[3].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[2]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[3]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[4]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[5]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[6]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[7]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[8]',
#  'PistonCylinder.OttoCycle.curve_pv[4].arr_v[9]',
#  'PistonCylinder.OttoCycle.curve_pv[1].dp',
#  'PistonCylinder.OttoCycle.curve_pv[2].dp',
#  'PistonCylinder.OttoCycle.curve_pv[3].dp',
#  'PistonCylinder.OttoCycle.curve_pv[4].dp',
#  'PistonCylinder.OttoCycle.curve_pv[1].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[2].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[3].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[4].vLower',
#  'PistonCylinder.OttoCycle.curve_pv[1].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[2].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[3].vUpper',
#  'PistonCylinder.OttoCycle.curve_pv[4].vUpper',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_s[10]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[1].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[2].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[3].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[2]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[3]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[4]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[5]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[6]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[7]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[8]',
#  'PistonCylinder.OttoCycle.curve_us[4].arr_u[9]',
#  'PistonCylinder.OttoCycle.curve_us[1].ds',
#  'PistonCylinder.OttoCycle.curve_us[2].ds',
#  'PistonCylinder.OttoCycle.curve_us[3].ds',
#  'PistonCylinder.OttoCycle.curve_us[4].ds',
#  'PistonCylinder.OttoCycle.curve_us[1].uLower',
#  'PistonCylinder.OttoCycle.curve_us[2].uLower',
#  'PistonCylinder.OttoCycle.curve_us[3].uLower',
#  'PistonCylinder.OttoCycle.curve_us[4].uLower',
#  'PistonCylinder.OttoCycle.curve_us[1].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[2].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[3].uUpper',
#  'PistonCylinder.OttoCycle.curve_us[4].uUpper',
#  'PistonCylinder.OttoCycle.effThermal',
#  'PistonCylinder.OttoCycle.fluidState_1.MM',
#  'PistonCylinder.OttoCycle.fluidState_1.R',
#  'PistonCylinder.OttoCycle.fluidState_1.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_1.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_1.d',
#  'PistonCylinder.OttoCycle.fluidState_1.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_2.MM',
#  'PistonCylinder.OttoCycle.fluidState_2.R',
#  'PistonCylinder.OttoCycle.fluidState_2.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_2.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_2.d',
#  'PistonCylinder.OttoCycle.fluidState_2.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_3.MM',
#  'PistonCylinder.OttoCycle.fluidState_3.R',
#  'PistonCylinder.OttoCycle.fluidState_3.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_3.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_3.d',
#  'PistonCylinder.OttoCycle.fluidState_3.p_bar',
#  'PistonCylinder.OttoCycle.fluidState_4.MM',
#  'PistonCylinder.OttoCycle.fluidState_4.R',
#  'PistonCylinder.OttoCycle.fluidState_4.T_degC',
#  'PistonCylinder.OttoCycle.fluidState_4.X[1]',
#  'PistonCylinder.OttoCycle.fluidState_4.d',
#  'PistonCylinder.OttoCycle.fluidState_4.p_bar',
#  'PistonCylinder.OttoCycle.par_CR',
#  'PistonCylinder.OttoCycle.par_LHV_fuel',
#  'PistonCylinder.OttoCycle.u_effComb',
#  'PistonCylinder.OttoCycle.u_fracFuel',
#  'PistonCylinder.OttoCycle.y_Q_2_3',
#  'PistonCylinder.OttoCycle.y_Q_4_1',
#  'PistonCylinder.OttoCycle.y_m_fuel',
#  'PistonCylinder.Q_add',
#  'PistonCylinder.Q_reject',
#  'PistonCylinder.V_flow',
#  'PistonCylinder.VolBDC',
#  'PistonCylinder.VolDisp',
#  'PistonCylinder.VolTDC',
#  'PistonCylinder.WexhCycle',
#  'PistonCylinder.WintkCycle',
#  'PistonCylinder.WoutCycle',
#  'PistonCylinder.arr_V[7]',
#  'PistonCylinder.arr_V[8]',
#  'PistonCylinder.arr_p[2]',
#  'PistonCylinder.arr_p[3]',
#  'PistonCylinder.arr_p[4]',
#  'PistonCylinder.calcEffComb.AFRsat',
#  'PistonCylinder.calcEffComb.AFRstoi',
#  'PistonCylinder.calcEffComb.FAR',
#  'PistonCylinder.calcEffComb.FARsat',
#  'PistonCylinder.calcEffComb.FARstoi',
#  'PistonCylinder.calcEffComb.flagValid',
#  'PistonCylinder.calcEffComb.fracAirStoi',
#  'PistonCylinder.calcEffComb.fracFuelStoi',
#  'PistonCylinder.calcEffComb.fracTot',
#  'PistonCylinder.calcEffComb.y_AFR',
#  'PistonCylinder.calcEffComb.y_lambda',
#  'PistonCylinder.dH_1_2_cycle',
#  'PistonCylinder.dU_1_2_cycle',
#  'PistonCylinder.dh_state4_port2',
#  'PistonCylinder.flange_1.tau',
#  'PistonCylinder.flange_2.tau',
#  'PistonCylinder.fluid_1.MM',
#  'PistonCylinder.fluid_1.R',
#  'PistonCylinder.fluid_1.T',
#  'PistonCylinder.fluid_1.T_degC',
#  'PistonCylinder.fluid_1.X[1]',
#  'PistonCylinder.fluid_1.d',
#  'PistonCylinder.fluid_1.p_bar',
#  'PistonCylinder.fluid_2.MM',
#  'PistonCylinder.fluid_2.R',
#  'PistonCylinder.fluid_2.T',
#  'PistonCylinder.fluid_2.T_degC',
#  'PistonCylinder.fluid_2.X[1]',
#  'PistonCylinder.fluid_2.d',
#  'PistonCylinder.fluid_2.h',
#  'PistonCylinder.fluid_2.p_bar',
#  'PistonCylinder.fluid_2.u',
#  'PistonCylinder.m_flow',
#  'PistonCylinder.m_flow_max',
#  'PistonCylinder.m_flow_min',
#  'PistonCylinder.port_2.h_outflow',
#  'PistonCylinder.pwrCycle',
#  'PistonCylinder.pwrExh',
#  'PistonCylinder.pwrIntk',
#  'PistonCylinder.pwrOut',
#  'PistonCylinder.pwrPumping',
#  'PistonCylinder.pwrPumpingqPwrCycle',
#  'PistonCylinder.pwr_cmp',
#  'PistonCylinder.pwr_exp',
#  'PistonCylinder.s_fluid_1',
#  'PistonCylinder.s_fluid_2',
#  'PistonCylinder.trqOut',
#  'PistonCylinder.u_fracAir',
#  'PistonCylinder.y_m_flow_fuel',
#  'PistonCylinder1.CR',
#  'PistonCylinder1.Nmech',
#  'PistonCylinder1.OttoCycle.ER',
#  'PistonCylinder1.OttoCycle.PR_1_2',
#  'PistonCylinder1.OttoCycle.PR_3_4',
#  'PistonCylinder1.OttoCycle.W_1_2',
#  'PistonCylinder1.OttoCycle.W_3_4',
#  'PistonCylinder1.OttoCycle.arr_T[2]',
#  'PistonCylinder1.OttoCycle.arr_T[3]',
#  'PistonCylinder1.OttoCycle.arr_T[4]',
#  'PistonCylinder1.OttoCycle.arr_T[5]',
#  'PistonCylinder1.OttoCycle.arr_h[2]',
#  'PistonCylinder1.OttoCycle.arr_h[3]',
#  'PistonCylinder1.OttoCycle.arr_h[4]',
#  'PistonCylinder1.OttoCycle.arr_h[5]',
#  'PistonCylinder1.OttoCycle.arr_s[2]',
#  'PistonCylinder1.OttoCycle.arr_s[3]',
#  'PistonCylinder1.OttoCycle.arr_u[2]',
#  'PistonCylinder1.OttoCycle.arr_u[3]',
#  'PistonCylinder1.OttoCycle.arr_u[4]',
#  'PistonCylinder1.OttoCycle.arr_u[5]',
#  'PistonCylinder1.OttoCycle.arr_v[2]',
#  'PistonCylinder1.OttoCycle.arr_v[3]',
#  'PistonCylinder1.OttoCycle.arr_v[4]',
#  'PistonCylinder1.OttoCycle.arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].TLower',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].TUpper',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_T[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_Ts[1].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[2].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[3].ds',
#  'PistonCylinder1.OttoCycle.curve_Ts[4].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_h[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[2].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[3].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[2]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[3]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[4]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[5]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[6]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[7]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[8]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[9]',
#  'PistonCylinder1.OttoCycle.curve_hs[4].arr_s[10]',
#  'PistonCylinder1.OttoCycle.curve_hs[1].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[2].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[3].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[4].ds',
#  'PistonCylinder1.OttoCycle.curve_hs[1].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[2].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[3].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[4].hLower',
#  'PistonCylinder1.OttoCycle.curve_hs[1].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[2].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[3].hUpper',
#  'PistonCylinder1.OttoCycle.curve_hs[4].hUpper',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].Vlower',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].Vupper',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_V[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[2].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[3].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[4].dp',
#  'PistonCylinder1.OttoCycle.curve_pVol[1].u_m',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[3].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[4].arr_p[10]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[1].arr_v[9]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[2]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[3]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[4]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[5]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[6]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[7]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[8]',
#  'PistonCylinder1.OttoCycle.curve_pv[2].arr_v[9]',
#  ...]

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=202
i_df_end=205


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=202
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01_res_202.csv
# i_df=203
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01_res_203.csv
# i_df=204
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01_res_204.csv
# i_df=205
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01_res_205.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=201

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/PropulsionSystem.Examples.Engines.Transient.LycomO360superCharged_ex01_res_201.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
#       time  damper1.phi_rel  damper1.w_rel  der(damper1.phi_rel)  \
# 0      0.0         0.000000    -448.798951           -448.798951
# 1      0.2       -91.321667    -463.516269           -463.516269
# 2      0.4      -185.100311    -473.626789           -473.626789
# 3      0.6      -280.556385    -480.487801           -480.487801
# 4      0.8      -377.146079    -485.104197           -485.104197
# ..     ...              ...            ...                   ...
# 503   99.4    -50729.052395    -527.340404           -527.340404
# 504   99.6    -50834.520476    -527.340404           -527.340404
# 505   99.8    -50939.988557    -527.340404           -527.340404
# 506  100.0    -51045.456637    -527.340404           -527.340404
# 507  100.0    -51045.456637    -527.340404           -527.340404
#
#      der(damper1.w_rel)  der(Cmp.omega)  der(Cmp.phi)  der(inertia2.w)  \
# 0         -8.784189e+01    6.148932e+02   3141.592654     6.148932e+02
# 1         -6.078058e+01    4.254641e+02   3244.613884     4.254641e+02
# 2         -4.145311e+01    2.901717e+02   3315.387525     2.901717e+02
# 3         -2.798736e+01    1.959115e+02   3363.414607     1.959115e+02
# 4         -1.876539e+01    1.313577e+02   3395.729377     1.313577e+02
# ..                  ...             ...           ...              ...
# 503        1.373337e-10   -9.613359e-10   3691.382831    -9.613359e-10
# 504        1.300577e-10   -9.104042e-10   3691.382831    -9.104042e-10
# 505        1.437002e-10   -1.005901e-09   3691.382831    -1.005901e-09
# 506        1.355147e-10   -9.486030e-10   3691.382831    -9.486030e-10
# 507        1.359695e-10   -9.517862e-10   3691.382831    -9.517862e-10
#
#      Cmp.CmpTbl_WcPReff_NcRline.u_NcTbl  Cmp.CmpTbl_WcPReff_NcRline.y_PR  ...  \
# 0                              1.000000                        21.970556  ...
# 1                              1.032793                        23.374677  ...
# 2                              1.055321                        24.358919  ...
# 3                              1.070608                        25.035955  ...
# 4                              1.080894                        25.495665  ...
# ..                                  ...                              ...  ...
# 503                            1.175004                        26.970806  ...
# 504                            1.175004                        26.970806  ...
# 505                            1.175004                        26.970806  ...
# 506                            1.175004                        26.970806  ...
# 507                            1.175004                        26.970806  ...
#
#      throttle.port_1.m_flow  throttle.port_1.p  throttle.port_2.m_flow  \
# 0                  0.431799      405294.800000               -0.431799
# 1                  0.455302      425647.724696               -0.455302
# 2                  0.471685      439914.446324               -0.471685
# 3                  0.482907      449728.183866               -0.482907
# 4                  0.490505      456391.740866               -0.490505
# ..                      ...                ...                     ...
# 503                0.585392      477774.109771               -0.585392
# 504                0.585392      477774.109771               -0.585392
# 505                0.585392      477774.109771               -0.585392
# 506                0.585392      477774.109771               -0.585392
# 507                0.585392      477774.109771               -0.585392
#
#      throttle.port_2.p  throttle.u_Cd  throttle.u_kArea  to_rpm_crankshaft.u  \
# 0        271051.424671            0.6               0.8           448.798951
# 1        281222.536727            0.6               0.8           463.516269
# 2        288276.420944            0.6               0.8           473.626789
# 3        293095.040735            0.6               0.8           480.487801
# 4        296352.131655            0.6               0.8           485.104197
# ..                 ...            ...               ...                  ...
# 503      334499.403870            0.6               1.0           527.340404
# 504      334499.403870            0.6               1.0           527.340404
# 505      334499.403870            0.6               1.0           527.340404
# 506      334499.403870            0.6               1.0           527.340404
# 507      334499.403870            0.6               1.0           527.340404
#
#      to_rpm_superCharger.u  torque1.flange.phi  torque1.tau
# 0              3141.592654           -0.000000            0
# 1              3244.613884           91.321667            0
# 2              3315.387525          185.100311            0
# 3              3363.414607          280.556385            0
# 4              3395.729377          377.146079            0
# ..                     ...                 ...          ...
# 503            3691.382831        50729.052395            0
# 504            3691.382831        50834.520476            0
# 505            3691.382831        50939.988557            0
# 506            3691.382831        51045.456637            0
# 507            3691.382831        51045.456637            0
#
# [508 rows x 3690 columns]

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="throttle.u_kArea"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='green')

#----------
i_df=101
varName="throttle.u_kArea"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='red')

#----------
i_df=201
varName="throttle.u_kArea"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('valve opening [nond]')
plt.title(varName)

plt.legend(loc='upper right', fontsize=12)
plt.ylim(0.0, 1.4)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="to_rpm_crankshaft.y"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="to_rpm_crankshaft.y"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="to_rpm_crankshaft.y"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('angular speed [rpm]')
plt.title('crankshaft angular speed')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40,100)
plt.ylim(2000, 5500)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="powerSensor1.power"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="powerSensor1.power"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="powerSensor1.power"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('power [kW]')
plt.title('shaft power output')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(100, 600)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="powerSensor1.flange_a.tau"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="powerSensor1.flange_a.tau"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="powerSensor1.flange_a.tau"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('torque [N*m]')
plt.title('shaft torque output')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(500, 1100)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
xvarName="to_rpm_crankshaft.y"
yvarName="powerSensor1.flange_a.tau"
label="not turbocharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="green")

#----------
i_df=101
xvarName="to_rpm_crankshaft.y"
yvarName="powerSensor1.flange_a.tau"
label="turbocharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="red")

#----------
i_df=201
xvarName="to_rpm_crankshaft.y"
yvarName="powerSensor1.flange_a.tau"
label="mech. supercharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="blue")

#----------
plt.xlabel('angular speed [rpm]')
plt.ylabel('torque [N*m]')
plt.title('tau-N of engine crankshaft')

plt.legend(loc='center right', fontsize=12)
plt.xlim(2000, 5500)
plt.ylim(500, 1100)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.OttoCycle.effThermal"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="PistonCylinder.OttoCycle.effThermal"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="PistonCylinder.OttoCycle.effThermal"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('efficiency [nond]')
plt.title('thermal efficiency of piston-cylinder ')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
#plt.ylim(0.1, 0.6)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="throttle.port_1.m_flow"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="throttle.port_1.m_flow"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="throttle.port_1.m_flow"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('mass flow rate [kg/s]')
plt.title('mass flow of in-taken air')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(0.1, 0.6)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="throttle.port_2.p"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="throttle.port_2.p"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="throttle.port_2.p"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('pressure [kPa]')
plt.title('intake manifold (throttle outlet) pressure')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(50, 350)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="throttle.fluid_2.T"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="throttle.fluid_2.T"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="throttle.fluid_2.T"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('temperature [K]')
plt.title('intake manifold (throttle outlet) temperature')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(250.0, 550.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="throttle.port_1.p"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="throttle.port_1.p"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="throttle.port_1.p"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('pressure [kPa]')
plt.title('throttle inlet pressure')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(50, 500)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.y_m_flow_fuel"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="PistonCylinder.y_m_flow_fuel"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="PistonCylinder.y_m_flow_fuel"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('mass flow rate [kg/s]')
plt.title('mass flow rate of fuel')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(0.0010, 0.009)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="pressure1.p"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="pressure1.p"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="pressure1.p"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('pressure [kPa]')
plt.title('exhaust manifold pressure')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(100, 600)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="temperature.T"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="temperature.T"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="temperature.T"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('temperature [K]')
plt.title('exhaust manifold temperature')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(1700.0, 2100.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Cmp.PR"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="Cmp.PR"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('pressure ratio [nond]')
plt.title('compressor pressure ratio')

plt.legend(loc='lower right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(1.0, 5.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Cmp.Wc_1"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="Cmp.Wc_1"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('corrected mass flow rate [kg/s]')
plt.title('compressor corrected mass flow rate')

plt.legend(loc='lower right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(0.0, 0.7)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Cmp.Nmech"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="Cmp.Nmech"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('rotational speed [rpm]')
plt.title('turbocharger/supercharger mechanical rotational speed')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(30000.0, 38000.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=101
xvarName="Cmp.Wc_1"
yvarName="Cmp.PR"
label="turbocharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="red")

#----------
i_df=201
xvarName="Cmp.Wc_1"
yvarName="Cmp.PR"
label="mech. supercharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="blue")

#----------
plt.xlabel('Corrected mass flow rate [kg/s]')
plt.ylabel('pressure retio [nond]')
plt.title('P-Q of compressor')

plt.legend(loc='center right', fontsize=12)
plt.xlim(0.3, 0.6)
plt.ylim(2.0, 5.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Cmp.Rline"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="Cmp.Rline"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('Rline value [nond]')
plt.title('Compressor Rline')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(0.0, 0.8)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=101
xvarName="Cmp.Nc_1"
yvarName="Cmp.Wc_1"
label="turbocharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="red")

i_df=201
xvarName="Cmp.Nc_1"
yvarName="Cmp.Wc_1"
label="mech. supercharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="blue")

#----------
plt.xlabel('Corrected rotary speed [rpm]')
plt.ylabel('Corrected mass flow rate [kg/s]')
plt.title('Q-N of compressor')

plt.legend(loc='lower right', fontsize=12)
plt.xlim(32000, 36000)
plt.ylim(0.30, 0.60)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=101
xvarName="Cmp.Nc_1"
yvarName="Cmp.PR"
label="turbocharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="red")

i_df=201
xvarName="Cmp.Nc_1"
yvarName="Cmp.PR"
label="mech. supercharged"
xvar= df[i_df].loc[:,xvarName]
yvar= df[i_df].loc[:,yvarName]
plt.plot(xvar, yvar, label=label, color="blue")

#----------
plt.xlabel('Corrected rotary speed [rpm]')
plt.ylabel('Pressure ratio [nond]')
plt.title('P-N of compressor')

plt.legend(loc='center right', fontsize=12)
plt.xlim(32000, 36000)
plt.ylim(2.0, 5.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Cmp.pwr"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="Cmp.pwr"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('power [kW]')
plt.title('compressor power')

plt.legend(loc='center right', fontsize=12)
plt.xlim(40,100)
plt.ylim(40, 130)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Trb.pwr_inv"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('power [kW]')
plt.title('turbine power')

plt.legend(loc='lower right', fontsize=12)
#plt.ylim(1700.0, 1900.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Trb.trq_inv"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('torque [Nm]')
plt.title('turbine torque')

plt.legend(loc='lower right', fontsize=12)
#plt.ylim(1700.0, 1900.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Trb.PR"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('pressure ratio [nond]')
plt.title('turbine pressure ratio')

plt.legend(loc='lower right', fontsize=12)
#plt.ylim(1700.0, 1900.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

#----------
i_df=101
varName="Trb.dht"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('delta enthalpy [kJ/kg]')
plt.title('turbine dht')

plt.legend(loc='lower right', fontsize=12)
#plt.ylim(1700.0, 1900.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="exhLine.fluid_2.T"
label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
i_df=101
varName="exhLine.fluid_2.T"
label="turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
i_df=201
varName="exhLine.fluid_2.T"
label="mech. supercharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('temperature [K]')
plt.title('exhaust temperature')

plt.legend(loc='lower right', fontsize=12)
plt.xlim(40, 100)
plt.ylim(1700.0, 2000.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %% [markdown]
# <p>Naturally aspirated</p>

# %%
i_df=1
tgtTime=45
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 225
# time of extracted = 45.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

'''or(i==3)or(i==4)or(i==5)or(i==6)or(i==7)'''
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
tgtTime=70
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 354
# time of extracted = 70.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <p>Turbocharged</p>

# %%
i_df=101
tgtTime=45
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 227
# time of extracted = 45.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

'''or(i==3)or(i==4)or(i==5)or(i==6)or(i==7)'''
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
tgtTime=70
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 354
# time of extracted = 70.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <p>Mech. supercharged</p>

# %%
i_df=201
tgtTime=45
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 227
# time of extracted = 45.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

'''or(i==3)or(i==4)or(i==5)or(i==6)or(i==7)'''
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
tgtTime=70
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
print('------------------------------')
# Out:
# row extracted = 354
# time of extracted = 70.0
# ------------------------------

# %%
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/PropulsionSystemLib
# ------------------------------
