# %% [markdown]
# <h1>Visualize: AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.Drone4rotor00_ex02</h1>
# <h2>notebook: rev004</h2>
# <p>compatability with OpenModelica v1.17</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import numpy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib
import math

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.Drone4rotor00_ex02'
nmModel='Drone4rotor00_ex02'
stopTime=200.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.Drone4rotor00_ex02
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/RigidBodyFDM/Examples/sampleAircrafts/Drone4rotor00_ex02.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.Drone4rotor00_ex02_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#          time  airplaneDyn.XG  airplaneDyn.YG  airplaneDyn.ZG  airplaneDyn.p  \
# 0        0.00        0.000000        0.000000        0.000000   0.000000e+00
# 1        0.01        0.000000        0.000000        0.000000   0.000000e+00
# 2        0.02        0.000000        0.000000        0.000000   0.000000e+00
# 3        0.03        0.000000        0.000000        0.000000   0.000000e+00
# 4        0.04        0.000000        0.000000        0.000000   0.000000e+00
# ...       ...             ...             ...             ...            ...
# 20053  199.97      223.013913      125.587466      -71.660341  -2.225504e-17
# 20054  199.98      223.020359      125.591862      -71.660238  -2.232683e-17
# 20055  199.99      223.026804      125.596258      -71.660135  -2.239879e-17
# 20056  200.00      223.033249      125.600654      -71.660031  -2.247094e-17
# 20057  200.00      223.033249      125.600654      -71.660031  -2.247094e-17
#
#        airplaneDyn.phi  airplaneDyn.psi  airplaneDyn.q  airplaneDyn.r  \
# 0             0.000000          0.00000   0.000000e+00   0.000000e+00
# 1             0.000000          0.00000   0.000000e+00   0.000000e+00
# 2             0.000000          0.00000   0.000000e+00   0.000000e+00
# 3             0.000000          0.00000   0.000000e+00   0.000000e+00
# 4             0.000000          0.00000   0.000000e+00   0.000000e+00
# ...                ...              ...            ...            ...
# 20053        -0.021652          1.55667   1.501214e-14   3.099573e-11
# 20054        -0.021652          1.55667   1.501266e-14   3.073043e-11
# 20055        -0.021652          1.55667   1.501321e-14   3.046494e-11
# 20056        -0.021652          1.55667   1.501379e-14   3.019925e-11
# 20057        -0.021652          1.55667   1.501379e-14   3.019925e-11
#
#        airplaneDyn.theta  ...  srcGravity.psi  srcGravity.theta  \
# 0               0.000000  ...         0.00000          0.000000
# 1               0.000000  ...         0.00000          0.000000
# 2               0.000000  ...         0.00000          0.000000
# 3               0.000000  ...         0.00000          0.000000
# 4               0.000000  ...         0.00000          0.000000
# ...                  ...  ...             ...               ...
# 20053          -0.015224  ...         1.55667         -0.015224
# 20054          -0.015224  ...         1.55667         -0.015224
# 20055          -0.015224  ...         1.55667         -0.015224
# 20056          -0.015224  ...         1.55667         -0.015224
# 20057          -0.015224  ...         1.55667         -0.015224
#
#        thrustNominal1.u  thrustNominal1.y  thrustNominal2.u  thrustNominal2.y  \
# 0                  0.25        2947.95351              0.25        2947.95351
# 1                  0.25        2947.95351              0.25        2947.95351
# 2                  0.25        2947.95351              0.25        2947.95351
# 3                  0.25        2947.95351              0.25        2947.95351
# 4                  0.25        2947.95351              0.25        2947.95351
# ...                 ...               ...               ...               ...
# 20053              0.25        2947.95351              0.25        2947.95351
# 20054              0.25        2947.95351              0.25        2947.95351
# 20055              0.25        2947.95351              0.25        2947.95351
# 20056              0.25        2947.95351              0.25        2947.95351
# 20057              0.25        2947.95351              0.25        2947.95351
#
#        thrustNominal3.u  thrustNominal3.y  thrustNominal4.u  thrustNominal4.y
# 0                  0.25        2947.95351              0.25        2947.95351
# 1                  0.25        2947.95351              0.25        2947.95351
# 2                  0.25        2947.95351              0.25        2947.95351
# 3                  0.25        2947.95351              0.25        2947.95351
# 4                  0.25        2947.95351              0.25        2947.95351
# ...                 ...               ...               ...               ...
# 20053              0.25        2947.95351              0.25        2947.95351
# 20054              0.25        2947.95351              0.25        2947.95351
# 20055              0.25        2947.95351              0.25        2947.95351
# 20056              0.25        2947.95351              0.25        2947.95351
# 20057              0.25        2947.95351              0.25        2947.95351
#
# [20058 rows x 533 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'airplaneDyn.XG',
#  'airplaneDyn.YG',
#  'airplaneDyn.ZG',
#  'airplaneDyn.p',
#  'airplaneDyn.phi',
#  'airplaneDyn.psi',
#  'airplaneDyn.q',
#  'airplaneDyn.r',
#  'airplaneDyn.theta',
#  'airplaneDyn.u',
#  'airplaneDyn.v',
#  'airplaneDyn.w',
#  'der(airplaneDyn.XG)',
#  'der(airplaneDyn.YG)',
#  'der(airplaneDyn.ZG)',
#  'der(airplaneDyn.p)',
#  'der(airplaneDyn.phi)',
#  'der(airplaneDyn.psi)',
#  'der(airplaneDyn.q)',
#  'der(airplaneDyn.r)',
#  'der(airplaneDyn.theta)',
#  'der(airplaneDyn.u)',
#  'der(airplaneDyn.v)',
#  'der(airplaneDyn.w)',
#  'der(airplaneDyn.dPhi)',
#  'der(airplaneDyn.dPsi)',
#  'der(airplaneDyn.dTheta)',
#  'der(airplaneDyn.dXG)',
#  'der(airplaneDyn.dYG)',
#  'der(airplaneDyn.dZG)',
#  'der(animAircraft.theta[3])',
#  '$cse14',
#  'airplaneDyn.alpha',
#  'airplaneDyn.alpha4disp',
#  'airplaneDyn.alt',
#  'airplaneDyn.beta',
#  'airplaneDyn.beta4disp',
#  'airplaneDyn.d2XG',
#  'airplaneDyn.d2YG',
#  'airplaneDyn.d2ZG',
#  'airplaneDyn.d2phi',
#  'airplaneDyn.d2psi',
#  'airplaneDyn.d2theta',
#  'airplaneDyn.dPhi',
#  'airplaneDyn.dPsi',
#  'airplaneDyn.dTheta',
#  'airplaneDyn.dXG',
#  'airplaneDyn.dYG',
#  'airplaneDyn.dZG',
#  'airplaneDyn.gamma',
#  'airplaneDyn.gamma4disp',
#  'airplaneDyn.phi4disp',
#  'airplaneDyn.psi4disp',
#  'airplaneDyn.sum_u_F[1]',
#  'airplaneDyn.sum_u_F[2]',
#  'airplaneDyn.sum_u_F[3]',
#  'airplaneDyn.sum_u_M[1]',
#  'airplaneDyn.sum_u_M[2]',
#  'airplaneDyn.sum_u_M[3]',
#  'airplaneDyn.theta4disp',
#  'airplaneDyn.xEast',
#  'airplaneDyn.xNorth',
#  'animAircraft.R.T[1,1]',
#  'animAircraft.R.T[1,2]',
#  'animAircraft.R.T[1,3]',
#  'animAircraft.R.T[2,1]',
#  'animAircraft.R.T[2,2]',
#  'animAircraft.R.T[2,3]',
#  'animAircraft.R.T[3,1]',
#  'animAircraft.R.T[3,2]',
#  'animAircraft.R.T[3,3]',
#  'animAircraft.R.w[1]',
#  'animAircraft.R.w[2]',
#  'animAircraft.R.w[3]',
#  'animAircraft.aircraft.color[1]',
#  'animAircraft.aircraft.color[2]',
#  'animAircraft.aircraft.color[3]',
#  'animAircraft.aircraft.extra',
#  'animAircraft.aircraft.height',
#  'animAircraft.aircraft.length',
#  'animAircraft.aircraft.lengthDirection[1]',
#  'animAircraft.aircraft.lengthDirection[2]',
#  'animAircraft.aircraft.lengthDirection[3]',
#  'animAircraft.aircraft.specularCoefficient',
#  'animAircraft.aircraft.width',
#  'animAircraft.aircraft.widthDirection[1]',
#  'animAircraft.aircraft.widthDirection[2]',
#  'animAircraft.aircraft.widthDirection[3]',
#  'animAircraft.r[1]',
#  'animAircraft.r[2]',
#  'animAircraft.r[3]',
#  'animAircraft.theta[3]',
#  'animAircraft.theta4disp[1]',
#  'animAircraft.theta4disp[2]',
#  'animAircraft.theta4disp[3]',
#  'animAircraft.world.frame_b.R.T[1,1]',
#  'animAircraft.world.frame_b.R.T[1,2]',
#  'animAircraft.world.frame_b.R.T[1,3]',
#  'animAircraft.world.frame_b.R.T[2,1]',
#  'animAircraft.world.frame_b.R.T[2,2]',
#  'animAircraft.world.frame_b.R.T[2,3]',
#  'animAircraft.world.frame_b.R.T[3,1]',
#  'animAircraft.world.frame_b.R.T[3,2]',
#  'animAircraft.world.frame_b.R.T[3,3]',
#  'animAircraft.world.frame_b.R.w[1]',
#  'animAircraft.world.frame_b.R.w[2]',
#  'animAircraft.world.frame_b.R.w[3]',
#  'animAircraft.world.frame_b.f[1]',
#  'animAircraft.world.frame_b.f[2]',
#  'animAircraft.world.frame_b.f[3]',
#  'animAircraft.world.frame_b.r_0[1]',
#  'animAircraft.world.frame_b.r_0[2]',
#  'animAircraft.world.frame_b.r_0[3]',
#  'animAircraft.world.frame_b.t[1]',
#  'animAircraft.world.frame_b.t[2]',
#  'animAircraft.world.frame_b.t[3]',
#  'linearResistance.F[1]',
#  'linearResistance.F[2]',
#  'linearResistance.F[3]',
#  'linearResistance.M[1]',
#  'linearResistance.M[2]',
#  'linearResistance.M[3]',
#  'linearResistance.lossPowerRot[1]',
#  'linearResistance.lossPowerRot[2]',
#  'linearResistance.lossPowerRot[3]',
#  'linearResistance.lossPowerTran[1]',
#  'linearResistance.lossPowerTran[2]',
#  'linearResistance.lossPowerTran[3]',
#  'linearResistance.sumLossPower',
#  'linearResistance.sumLossPowerRot',
#  'rotor1.F[1]',
#  'rotor1.F[2]',
#  'rotor1.F[3]',
#  'rotor1.M[1]',
#  'rotor1.M[2]',
#  'rotor1.M[3]',
#  'rotor1.MbyT[1]',
#  'rotor1.MbyT[2]',
#  'rotor1.MbyT[3]',
#  'rotor1.QqT',
#  'rotor1.countTrq',
#  'rotor1.u_thrust',
#  'rotor1.vectArm[1]',
#  'rotor1.vectArm[2]',
#  'rotor1.vectArm[3]',
#  'rotor1.vectCountTrq[1]',
#  'rotor1.vectCountTrq[2]',
#  'rotor1.vectCountTrq[3]',
#  'rotor2.F[1]',
#  'rotor2.F[2]',
#  'rotor2.F[3]',
#  'rotor2.M[1]',
#  'rotor2.M[2]',
#  'rotor2.M[3]',
#  'rotor2.MbyT[1]',
#  'rotor2.MbyT[2]',
#  'rotor2.MbyT[3]',
#  'rotor2.QqT',
#  'rotor2.countTrq',
#  'rotor2.u_thrust',
#  'rotor2.vectArm[1]',
#  'rotor2.vectArm[2]',
#  'rotor2.vectArm[3]',
#  'rotor2.vectCountTrq[1]',
#  'rotor2.vectCountTrq[2]',
#  'rotor2.vectCountTrq[3]',
#  'rotor3.F[1]',
#  'rotor3.F[2]',
#  'rotor3.F[3]',
#  'rotor3.M[1]',
#  'rotor3.M[2]',
#  'rotor3.M[3]',
#  'rotor3.MbyT[1]',
#  'rotor3.MbyT[2]',
#  'rotor3.MbyT[3]',
#  'rotor3.QqT',
#  'rotor3.countTrq',
#  'rotor3.u_thrust',
#  'rotor3.vectArm[1]',
#  'rotor3.vectArm[2]',
#  'rotor3.vectArm[3]',
#  'rotor3.vectCountTrq[1]',
#  'rotor3.vectCountTrq[2]',
#  'rotor3.vectCountTrq[3]',
#  'rotor4.F[1]',
#  'rotor4.F[2]',
#  'rotor4.F[3]',
#  'rotor4.M[1]',
#  'rotor4.M[2]',
#  'rotor4.M[3]',
#  'rotor4.MbyT[1]',
#  'rotor4.MbyT[2]',
#  'rotor4.MbyT[3]',
#  'rotor4.QqT',
#  'rotor4.countTrq',
#  'rotor4.u_thrust',
#  'rotor4.vectArm[1]',
#  'rotor4.vectArm[2]',
#  'rotor4.vectArm[3]',
#  'rotor4.vectCountTrq[1]',
#  'rotor4.vectCountTrq[2]',
#  'rotor4.vectCountTrq[3]',
#  'srcGravity.Fg[1]',
#  'srcGravity.Fg[2]',
#  'srcGravity.Fg[3]',
#  'srcGravity.FgG[1]',
#  'srcGravity.FgG[2]',
#  'srcGravity.FgG[3]',
#  'srcGravity.FgG_rot[1]',
#  'srcGravity.FgG_rot[2]',
#  'srcGravity.FgG_rot[3]',
#  'srcGravity.outCntrSrcForceMoment.M[1]',
#  'srcGravity.outCntrSrcForceMoment.M[2]',
#  'srcGravity.outCntrSrcForceMoment.M[3]',
#  'uSignal_thrustLevel1.y[1]',
#  'uSignal_thrustLevel2.y[1]',
#  'uSignal_thrustLevel3.y[1]',
#  'uSignal_thrustLevel4.y[1]',
#  'animAircraft.world.axisColor_x[1]',
#  'animAircraft.world.axisColor_x[2]',
#  'animAircraft.world.axisColor_x[3]',
#  'animAircraft.world.axisColor_y[1]',
#  'animAircraft.world.axisColor_y[2]',
#  'animAircraft.world.axisColor_y[3]',
#  'animAircraft.world.axisColor_z[1]',
#  'animAircraft.world.axisColor_z[2]',
#  'animAircraft.world.axisColor_z[3]',
#  'animAircraft.world.gravityArrowColor[1]',
#  'animAircraft.world.gravityArrowColor[2]',
#  'animAircraft.world.gravityArrowColor[3]',
#  'animAircraft.world.gravitySphereColor[1]',
#  'animAircraft.world.gravitySphereColor[2]',
#  'animAircraft.world.gravitySphereColor[3]',
#  'animAircraft.world.groundColor[1]',
#  'animAircraft.world.groundColor[2]',
#  'animAircraft.world.groundColor[3]',
#  'airplaneDyn.L',
#  'airplaneDyn.M',
#  'airplaneDyn.N',
#  'airplaneDyn.VisInfoOut.alpha',
#  'airplaneDyn.VisInfoOut.beta',
#  'airplaneDyn.VisInfoOut.r[1]',
#  'airplaneDyn.VisInfoOut.r[2]',
#  'airplaneDyn.VisInfoOut.r[3]',
#  'airplaneDyn.VisInfoOut.theta[1]',
#  'airplaneDyn.VisInfoOut.theta[2]',
#  'airplaneDyn.VisInfoOut.theta[3]',
#  'airplaneDyn.Xf',
#  'airplaneDyn.Yf',
#  'airplaneDyn.Zf',
#  'airplaneDyn.inCntrSrcForceMoment[1].F[1]',
#  'airplaneDyn.inCntrSrcForceMoment[1].F[2]',
#  'airplaneDyn.inCntrSrcForceMoment[1].F[3]',
#  'airplaneDyn.inCntrSrcForceMoment[2].F[1]',
#  'airplaneDyn.inCntrSrcForceMoment[2].F[2]',
#  'airplaneDyn.inCntrSrcForceMoment[2].F[3]',
#  'airplaneDyn.inCntrSrcForceMoment[3].F[1]',
#  'airplaneDyn.inCntrSrcForceMoment[3].F[2]',
#  'airplaneDyn.inCntrSrcForceMoment[3].F[3]',
#  'airplaneDyn.inCntrSrcForceMoment[4].F[1]',
#  'airplaneDyn.inCntrSrcForceMoment[4].F[2]',
#  'airplaneDyn.inCntrSrcForceMoment[4].F[3]',
#  'airplaneDyn.inCntrSrcForceMoment[5].F[1]',
#  'airplaneDyn.inCntrSrcForceMoment[5].F[2]',
#  'airplaneDyn.inCntrSrcForceMoment[5].F[3]',
#  'airplaneDyn.inCntrSrcForceMoment[6].F[1]',
#  'airplaneDyn.inCntrSrcForceMoment[6].F[2]',
#  'airplaneDyn.inCntrSrcForceMoment[6].F[3]',
#  'airplaneDyn.inCntrSrcForceMoment[1].M[1]',
#  'airplaneDyn.inCntrSrcForceMoment[1].M[2]',
#  'airplaneDyn.inCntrSrcForceMoment[1].M[3]',
#  'airplaneDyn.inCntrSrcForceMoment[2].M[1]',
#  'airplaneDyn.inCntrSrcForceMoment[2].M[2]',
#  'airplaneDyn.inCntrSrcForceMoment[2].M[3]',
#  'airplaneDyn.inCntrSrcForceMoment[3].M[1]',
#  'airplaneDyn.inCntrSrcForceMoment[3].M[2]',
#  'airplaneDyn.inCntrSrcForceMoment[3].M[3]',
#  'airplaneDyn.inCntrSrcForceMoment[4].M[1]',
#  'airplaneDyn.inCntrSrcForceMoment[4].M[2]',
#  'airplaneDyn.inCntrSrcForceMoment[4].M[3]',
#  'airplaneDyn.inCntrSrcForceMoment[5].M[1]',
#  'airplaneDyn.inCntrSrcForceMoment[5].M[2]',
#  'airplaneDyn.inCntrSrcForceMoment[5].M[3]',
#  'airplaneDyn.inCntrSrcForceMoment[6].M[1]',
#  'airplaneDyn.inCntrSrcForceMoment[6].M[2]',
#  'airplaneDyn.inCntrSrcForceMoment[6].M[3]',
#  'airplaneDyn.inCntrSrcForceMoment[1].alpha',
#  'airplaneDyn.inCntrSrcForceMoment[2].alpha',
#  'airplaneDyn.inCntrSrcForceMoment[3].alpha',
#  'airplaneDyn.inCntrSrcForceMoment[4].alpha',
#  'airplaneDyn.inCntrSrcForceMoment[5].alpha',
#  'airplaneDyn.inCntrSrcForceMoment[6].alpha',
#  'airplaneDyn.inCntrSrcForceMoment[1].beta',
#  'airplaneDyn.inCntrSrcForceMoment[2].beta',
#  'airplaneDyn.inCntrSrcForceMoment[3].beta',
#  'airplaneDyn.inCntrSrcForceMoment[4].beta',
#  'airplaneDyn.inCntrSrcForceMoment[5].beta',
#  'airplaneDyn.inCntrSrcForceMoment[6].beta',
#  'airplaneDyn.inCntrSrcForceMoment[1].omega[1]',
#  'airplaneDyn.inCntrSrcForceMoment[1].omega[2]',
#  'airplaneDyn.inCntrSrcForceMoment[1].omega[3]',
#  'airplaneDyn.inCntrSrcForceMoment[2].omega[1]',
#  'airplaneDyn.inCntrSrcForceMoment[2].omega[2]',
#  'airplaneDyn.inCntrSrcForceMoment[2].omega[3]',
#  'airplaneDyn.inCntrSrcForceMoment[3].omega[1]',
#  'airplaneDyn.inCntrSrcForceMoment[3].omega[2]',
#  'airplaneDyn.inCntrSrcForceMoment[3].omega[3]',
#  'airplaneDyn.inCntrSrcForceMoment[4].omega[1]',
#  'airplaneDyn.inCntrSrcForceMoment[4].omega[2]',
#  'airplaneDyn.inCntrSrcForceMoment[4].omega[3]',
#  'airplaneDyn.inCntrSrcForceMoment[5].omega[1]',
#  'airplaneDyn.inCntrSrcForceMoment[5].omega[2]',
#  'airplaneDyn.inCntrSrcForceMoment[5].omega[3]',
#  'airplaneDyn.inCntrSrcForceMoment[6].omega[1]',
#  'airplaneDyn.inCntrSrcForceMoment[6].omega[2]',
#  'airplaneDyn.inCntrSrcForceMoment[6].omega[3]',
#  'airplaneDyn.inCntrSrcForceMoment[1].r[1]',
#  'airplaneDyn.inCntrSrcForceMoment[1].r[2]',
#  'airplaneDyn.inCntrSrcForceMoment[1].r[3]',
#  'airplaneDyn.inCntrSrcForceMoment[2].r[1]',
#  'airplaneDyn.inCntrSrcForceMoment[2].r[2]',
#  'airplaneDyn.inCntrSrcForceMoment[2].r[3]',
#  'airplaneDyn.inCntrSrcForceMoment[3].r[1]',
#  'airplaneDyn.inCntrSrcForceMoment[3].r[2]',
#  'airplaneDyn.inCntrSrcForceMoment[3].r[3]',
#  'airplaneDyn.inCntrSrcForceMoment[4].r[1]',
#  'airplaneDyn.inCntrSrcForceMoment[4].r[2]',
#  'airplaneDyn.inCntrSrcForceMoment[4].r[3]',
#  'airplaneDyn.inCntrSrcForceMoment[5].r[1]',
#  'airplaneDyn.inCntrSrcForceMoment[5].r[2]',
#  'airplaneDyn.inCntrSrcForceMoment[5].r[3]',
#  'airplaneDyn.inCntrSrcForceMoment[6].r[1]',
#  'airplaneDyn.inCntrSrcForceMoment[6].r[2]',
#  'airplaneDyn.inCntrSrcForceMoment[6].r[3]',
#  'airplaneDyn.inCntrSrcForceMoment[1].theta[1]',
#  'airplaneDyn.inCntrSrcForceMoment[1].theta[2]',
#  'airplaneDyn.inCntrSrcForceMoment[1].theta[3]',
#  'airplaneDyn.inCntrSrcForceMoment[2].theta[1]',
#  'airplaneDyn.inCntrSrcForceMoment[2].theta[2]',
#  'airplaneDyn.inCntrSrcForceMoment[2].theta[3]',
#  'airplaneDyn.inCntrSrcForceMoment[3].theta[1]',
#  'airplaneDyn.inCntrSrcForceMoment[3].theta[2]',
#  'airplaneDyn.inCntrSrcForceMoment[3].theta[3]',
#  'airplaneDyn.inCntrSrcForceMoment[4].theta[1]',
#  'airplaneDyn.inCntrSrcForceMoment[4].theta[2]',
#  'airplaneDyn.inCntrSrcForceMoment[4].theta[3]',
#  'airplaneDyn.inCntrSrcForceMoment[5].theta[1]',
#  'airplaneDyn.inCntrSrcForceMoment[5].theta[2]',
#  'airplaneDyn.inCntrSrcForceMoment[5].theta[3]',
#  'airplaneDyn.inCntrSrcForceMoment[6].theta[1]',
#  'airplaneDyn.inCntrSrcForceMoment[6].theta[2]',
#  'airplaneDyn.inCntrSrcForceMoment[6].theta[3]',
#  'airplaneDyn.inCntrSrcForceMoment[1].v[1]',
#  'airplaneDyn.inCntrSrcForceMoment[1].v[2]',
#  'airplaneDyn.inCntrSrcForceMoment[1].v[3]',
#  'airplaneDyn.inCntrSrcForceMoment[2].v[1]',
#  'airplaneDyn.inCntrSrcForceMoment[2].v[2]',
#  'airplaneDyn.inCntrSrcForceMoment[2].v[3]',
#  'airplaneDyn.inCntrSrcForceMoment[3].v[1]',
#  'airplaneDyn.inCntrSrcForceMoment[3].v[2]',
#  'airplaneDyn.inCntrSrcForceMoment[3].v[3]',
#  'airplaneDyn.inCntrSrcForceMoment[4].v[1]',
#  'airplaneDyn.inCntrSrcForceMoment[4].v[2]',
#  'airplaneDyn.inCntrSrcForceMoment[4].v[3]',
#  'airplaneDyn.inCntrSrcForceMoment[5].v[1]',
#  'airplaneDyn.inCntrSrcForceMoment[5].v[2]',
#  'airplaneDyn.inCntrSrcForceMoment[5].v[3]',
#  'airplaneDyn.inCntrSrcForceMoment[6].v[1]',
#  'airplaneDyn.inCntrSrcForceMoment[6].v[2]',
#  'airplaneDyn.inCntrSrcForceMoment[6].v[3]',
#  'animAircraft.VisInfoIn.alpha',
#  'animAircraft.VisInfoIn.beta',
#  'animAircraft.VisInfoIn.r[1]',
#  'animAircraft.VisInfoIn.r[2]',
#  'animAircraft.VisInfoIn.r[3]',
#  'animAircraft.VisInfoIn.theta[1]',
#  'animAircraft.VisInfoIn.theta[2]',
#  'animAircraft.VisInfoIn.theta[3]',
#  'animAircraft.aircraft.R.T[1,1]',
#  'animAircraft.aircraft.R.T[1,2]',
#  'animAircraft.aircraft.R.T[1,3]',
#  'animAircraft.aircraft.R.T[2,1]',
#  'animAircraft.aircraft.R.T[2,2]',
#  'animAircraft.aircraft.R.T[2,3]',
#  'animAircraft.aircraft.R.T[3,1]',
#  'animAircraft.aircraft.R.T[3,2]',
#  'animAircraft.aircraft.R.T[3,3]',
#  'animAircraft.aircraft.R.w[1]',
#  'animAircraft.aircraft.R.w[2]',
#  'animAircraft.aircraft.R.w[3]',
#  'animAircraft.aircraft.r[1]',
#  'animAircraft.aircraft.r[2]',
#  'animAircraft.aircraft.r[3]',
#  'animAircraft.theta[1]',
#  'animAircraft.theta[2]',
#  'linearResistance.outCntrSrcForceMoment.F[1]',
#  'linearResistance.outCntrSrcForceMoment.F[2]',
#  'linearResistance.outCntrSrcForceMoment.F[3]',
#  'linearResistance.outCntrSrcForceMoment.M[1]',
#  'linearResistance.outCntrSrcForceMoment.M[2]',
#  'linearResistance.outCntrSrcForceMoment.M[3]',
#  'linearResistance.outCntrSrcForceMoment.alpha',
#  'linearResistance.outCntrSrcForceMoment.beta',
#  'linearResistance.outCntrSrcForceMoment.omega[1]',
#  'linearResistance.outCntrSrcForceMoment.omega[2]',
#  'linearResistance.outCntrSrcForceMoment.omega[3]',
#  'linearResistance.outCntrSrcForceMoment.r[1]',
#  'linearResistance.outCntrSrcForceMoment.r[2]',
#  'linearResistance.outCntrSrcForceMoment.r[3]',
#  'linearResistance.outCntrSrcForceMoment.theta[1]',
#  'linearResistance.outCntrSrcForceMoment.theta[2]',
#  'linearResistance.outCntrSrcForceMoment.theta[3]',
#  'linearResistance.outCntrSrcForceMoment.v[1]',
#  'linearResistance.outCntrSrcForceMoment.v[2]',
#  'linearResistance.outCntrSrcForceMoment.v[3]',
#  'linearResistance.sumLossPowerTran',
#  'rotor1.outCntrSrcForceMoment.F[1]',
#  'rotor1.outCntrSrcForceMoment.F[2]',
#  'rotor1.outCntrSrcForceMoment.F[3]',
#  'rotor1.outCntrSrcForceMoment.M[1]',
#  'rotor1.outCntrSrcForceMoment.M[2]',
#  'rotor1.outCntrSrcForceMoment.M[3]',
#  'rotor1.outCntrSrcForceMoment.alpha',
#  'rotor1.outCntrSrcForceMoment.beta',
#  'rotor1.outCntrSrcForceMoment.omega[1]',
#  'rotor1.outCntrSrcForceMoment.omega[2]',
#  'rotor1.outCntrSrcForceMoment.omega[3]',
#  'rotor1.outCntrSrcForceMoment.r[1]',
#  'rotor1.outCntrSrcForceMoment.r[2]',
#  'rotor1.outCntrSrcForceMoment.r[3]',
#  'rotor1.outCntrSrcForceMoment.theta[1]',
#  'rotor1.outCntrSrcForceMoment.theta[2]',
#  'rotor1.outCntrSrcForceMoment.theta[3]',
#  'rotor1.outCntrSrcForceMoment.v[1]',
#  'rotor1.outCntrSrcForceMoment.v[2]',
#  'rotor1.outCntrSrcForceMoment.v[3]',
#  'rotor1.thrust',
#  'rotor1.trq',
#  'rotor2.outCntrSrcForceMoment.F[1]',
#  'rotor2.outCntrSrcForceMoment.F[2]',
#  'rotor2.outCntrSrcForceMoment.F[3]',
#  'rotor2.outCntrSrcForceMoment.M[1]',
#  'rotor2.outCntrSrcForceMoment.M[2]',
#  'rotor2.outCntrSrcForceMoment.M[3]',
#  'rotor2.outCntrSrcForceMoment.alpha',
#  'rotor2.outCntrSrcForceMoment.beta',
#  'rotor2.outCntrSrcForceMoment.omega[1]',
#  'rotor2.outCntrSrcForceMoment.omega[2]',
#  'rotor2.outCntrSrcForceMoment.omega[3]',
#  'rotor2.outCntrSrcForceMoment.r[1]',
#  'rotor2.outCntrSrcForceMoment.r[2]',
#  'rotor2.outCntrSrcForceMoment.r[3]',
#  'rotor2.outCntrSrcForceMoment.theta[1]',
#  'rotor2.outCntrSrcForceMoment.theta[2]',
#  'rotor2.outCntrSrcForceMoment.theta[3]',
#  'rotor2.outCntrSrcForceMoment.v[1]',
#  'rotor2.outCntrSrcForceMoment.v[2]',
#  'rotor2.outCntrSrcForceMoment.v[3]',
#  'rotor2.thrust',
#  'rotor2.trq',
#  'rotor3.outCntrSrcForceMoment.F[1]',
#  'rotor3.outCntrSrcForceMoment.F[2]',
#  'rotor3.outCntrSrcForceMoment.F[3]',
#  'rotor3.outCntrSrcForceMoment.M[1]',
#  'rotor3.outCntrSrcForceMoment.M[2]',
#  'rotor3.outCntrSrcForceMoment.M[3]',
#  'rotor3.outCntrSrcForceMoment.alpha',
#  'rotor3.outCntrSrcForceMoment.beta',
#  'rotor3.outCntrSrcForceMoment.omega[1]',
#  'rotor3.outCntrSrcForceMoment.omega[2]',
#  'rotor3.outCntrSrcForceMoment.omega[3]',
#  'rotor3.outCntrSrcForceMoment.r[1]',
#  'rotor3.outCntrSrcForceMoment.r[2]',
#  'rotor3.outCntrSrcForceMoment.r[3]',
#  'rotor3.outCntrSrcForceMoment.theta[1]',
#  'rotor3.outCntrSrcForceMoment.theta[2]',
#  'rotor3.outCntrSrcForceMoment.theta[3]',
#  'rotor3.outCntrSrcForceMoment.v[1]',
#  'rotor3.outCntrSrcForceMoment.v[2]',
#  'rotor3.outCntrSrcForceMoment.v[3]',
#  'rotor3.thrust',
#  'rotor3.trq',
#  'rotor4.outCntrSrcForceMoment.F[1]',
#  'rotor4.outCntrSrcForceMoment.F[2]',
#  'rotor4.outCntrSrcForceMoment.F[3]',
#  'rotor4.outCntrSrcForceMoment.M[1]',
#  'rotor4.outCntrSrcForceMoment.M[2]',
#  'rotor4.outCntrSrcForceMoment.M[3]',
#  'rotor4.outCntrSrcForceMoment.alpha',
#  'rotor4.outCntrSrcForceMoment.beta',
#  'rotor4.outCntrSrcForceMoment.omega[1]',
#  'rotor4.outCntrSrcForceMoment.omega[2]',
#  'rotor4.outCntrSrcForceMoment.omega[3]',
#  'rotor4.outCntrSrcForceMoment.r[1]',
#  'rotor4.outCntrSrcForceMoment.r[2]',
#  'rotor4.outCntrSrcForceMoment.r[3]',
#  'rotor4.outCntrSrcForceMoment.theta[1]',
#  'rotor4.outCntrSrcForceMoment.theta[2]',
#  'rotor4.outCntrSrcForceMoment.theta[3]',
#  'rotor4.outCntrSrcForceMoment.v[1]',
#  'rotor4.outCntrSrcForceMoment.v[2]',
#  'rotor4.outCntrSrcForceMoment.v[3]',
#  'rotor4.thrust',
#  'rotor4.trq',
#  'srcGravity.outCntrSrcForceMoment.F[1]',
#  'srcGravity.outCntrSrcForceMoment.F[2]',
#  'srcGravity.outCntrSrcForceMoment.F[3]',
#  'srcGravity.outCntrSrcForceMoment.alpha',
#  'srcGravity.outCntrSrcForceMoment.beta',
#  'srcGravity.outCntrSrcForceMoment.omega[1]',
#  'srcGravity.outCntrSrcForceMoment.omega[2]',
#  'srcGravity.outCntrSrcForceMoment.omega[3]',
#  'srcGravity.outCntrSrcForceMoment.r[1]',
#  'srcGravity.outCntrSrcForceMoment.r[2]',
#  'srcGravity.outCntrSrcForceMoment.r[3]',
#  'srcGravity.outCntrSrcForceMoment.theta[1]',
#  'srcGravity.outCntrSrcForceMoment.theta[2]',
#  'srcGravity.outCntrSrcForceMoment.theta[3]',
#  'srcGravity.outCntrSrcForceMoment.v[1]',
#  'srcGravity.outCntrSrcForceMoment.v[2]',
#  'srcGravity.outCntrSrcForceMoment.v[3]',
#  'srcGravity.phi',
#  'srcGravity.psi',
#  'srcGravity.theta',
#  'thrustNominal1.u',
#  'thrustNominal1.y',
#  'thrustNominal2.u',
#  'thrustNominal2.y',
#  'thrustNominal3.u',
#  'thrustNominal3.y',
#  'thrustNominal4.u',
#  'thrustNominal4.y']

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=2


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.Drone4rotor00_ex02_res_2.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.Drone4rotor00_ex02_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#          time  airplaneDyn.XG  airplaneDyn.YG  airplaneDyn.ZG  airplaneDyn.p  \
# 0        0.00        0.000000        0.000000        0.000000   0.000000e+00
# 1        0.01        0.000000        0.000000        0.000000   0.000000e+00
# 2        0.02        0.000000        0.000000        0.000000   0.000000e+00
# 3        0.03        0.000000        0.000000        0.000000   0.000000e+00
# 4        0.04        0.000000        0.000000        0.000000   0.000000e+00
# ...       ...             ...             ...             ...            ...
# 20053  199.97      223.013913      125.587466      -71.660341  -2.225504e-17
# 20054  199.98      223.020359      125.591862      -71.660238  -2.232683e-17
# 20055  199.99      223.026804      125.596258      -71.660135  -2.239879e-17
# 20056  200.00      223.033249      125.600654      -71.660031  -2.247094e-17
# 20057  200.00      223.033249      125.600654      -71.660031  -2.247094e-17
#
#        airplaneDyn.phi  airplaneDyn.psi  airplaneDyn.q  airplaneDyn.r  \
# 0             0.000000          0.00000   0.000000e+00   0.000000e+00
# 1             0.000000          0.00000   0.000000e+00   0.000000e+00
# 2             0.000000          0.00000   0.000000e+00   0.000000e+00
# 3             0.000000          0.00000   0.000000e+00   0.000000e+00
# 4             0.000000          0.00000   0.000000e+00   0.000000e+00
# ...                ...              ...            ...            ...
# 20053        -0.021652          1.55667   1.501214e-14   3.099573e-11
# 20054        -0.021652          1.55667   1.501266e-14   3.073043e-11
# 20055        -0.021652          1.55667   1.501321e-14   3.046494e-11
# 20056        -0.021652          1.55667   1.501379e-14   3.019925e-11
# 20057        -0.021652          1.55667   1.501379e-14   3.019925e-11
#
#        airplaneDyn.theta  ...  srcGravity.psi  srcGravity.theta  \
# 0               0.000000  ...         0.00000          0.000000
# 1               0.000000  ...         0.00000          0.000000
# 2               0.000000  ...         0.00000          0.000000
# 3               0.000000  ...         0.00000          0.000000
# 4               0.000000  ...         0.00000          0.000000
# ...                  ...  ...             ...               ...
# 20053          -0.015224  ...         1.55667         -0.015224
# 20054          -0.015224  ...         1.55667         -0.015224
# 20055          -0.015224  ...         1.55667         -0.015224
# 20056          -0.015224  ...         1.55667         -0.015224
# 20057          -0.015224  ...         1.55667         -0.015224
#
#        thrustNominal1.u  thrustNominal1.y  thrustNominal2.u  thrustNominal2.y  \
# 0                  0.25        2947.95351              0.25        2947.95351
# 1                  0.25        2947.95351              0.25        2947.95351
# 2                  0.25        2947.95351              0.25        2947.95351
# 3                  0.25        2947.95351              0.25        2947.95351
# 4                  0.25        2947.95351              0.25        2947.95351
# ...                 ...               ...               ...               ...
# 20053              0.25        2947.95351              0.25        2947.95351
# 20054              0.25        2947.95351              0.25        2947.95351
# 20055              0.25        2947.95351              0.25        2947.95351
# 20056              0.25        2947.95351              0.25        2947.95351
# 20057              0.25        2947.95351              0.25        2947.95351
#
#        thrustNominal3.u  thrustNominal3.y  thrustNominal4.u  thrustNominal4.y
# 0                  0.25        2947.95351              0.25        2947.95351
# 1                  0.25        2947.95351              0.25        2947.95351
# 2                  0.25        2947.95351              0.25        2947.95351
# 3                  0.25        2947.95351              0.25        2947.95351
# 4                  0.25        2947.95351              0.25        2947.95351
# ...                 ...               ...               ...               ...
# 20053              0.25        2947.95351              0.25        2947.95351
# 20054              0.25        2947.95351              0.25        2947.95351
# 20055              0.25        2947.95351              0.25        2947.95351
# 20056              0.25        2947.95351              0.25        2947.95351
# 20057              0.25        2947.95351              0.25        2947.95351
#
# [20058 rows x 533 columns]

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="uSignal_thrustLevel1.y[1]"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('fraction against weight [nond]')
plt.title('thrust of rotor 1')

#plt.legend(loc='upper right', fontsize=12)
plt.ylim(0.2, 0.4)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="uSignal_thrustLevel2.y[1]"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('fraction against weight[nond]')
plt.title('Thrust level of rotor 2')

#plt.legend(loc='upper right', fontsize=12)
plt.ylim(0.2, 0.4)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="uSignal_thrustLevel3.y[1]"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('fraction against weight[nond]')
plt.title('Thrust level of rotor 3')

#plt.legend(loc='upper right', fontsize=12)
plt.ylim(0.2, 0.4)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="uSignal_thrustLevel4.y[1]"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('fraction against weight[nond]')
plt.title('Thrust level of rotor 4')

#plt.legend(loc='upper right', fontsize=12)
plt.ylim(0.2, 0.4)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=0

varName="airplaneDyn.theta"
label="Pitch angle"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label)

#----------
'''
varName="airplaneDyn.gamma"
label="Flight path angle"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label)
'''

#----------
'''
varName="airplaneDyn.alpha"
label="Angle of Attack"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label)
'''

#----------
varName="airplaneDyn.phi"
label="Roll(bank) angle"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label)

#----------
'''
varName="airplaneDyn.beta"
label="Sideslip angle"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label)
'''

#----------
plt.xlabel('time [s]')
plt.ylabel('Angle [deg]')
plt.title('Flight state angles')

plt.legend(loc='upper right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(-50, 50)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=0

varName="airplaneDyn.psi"
label="Pitch angle"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Angle [deg]')
plt.title('Heading angle')

#plt.legend(loc='upper right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(0, 100)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=0
varName="airplaneDyn.alt"
label="alt"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Altitude [m]')
plt.title('Altitude')

#plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(0, 100)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=0
title="planner trajectory"
xVarName="airplaneDyn.xEast"
yVarName="airplaneDyn.xNorth"
xlabel='x-east [m]'
ylabel='x-north [m]'

xVar= df[i_df].loc[:, xVarName]
yVar= df[i_df].loc[:, yVarName]
fig.append(plt.figure(figsize=(12,14)))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(xVar, yVar, color='red', linewidth=1.0)
plt.grid()

plt.xticks(numpy.arange(0, 240, 20))
plt.yticks(numpy.arange(0, 240, 20))

print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=0
title="flight trajectory"
xVarName="airplaneDyn.xEast"
yVarName="airplaneDyn.xNorth"
zVarName="airplaneDyn.alt"
xlabel='x-east [m]'
ylabel='x-north [m]'
zlabel="alt [m]"

xVar= df[i_df].loc[:, xVarName]
yVar= df[i_df].loc[:, yVarName]
zVar= df[i_df].loc[:, zVarName]
figure = plt.figure(figsize = (18, 18))
ax = figure.add_subplot(111, projection='3d')

ax.set_title(title, size=20)
ax.set_xlabel(xlabel, size=12)
ax.set_ylabel(ylabel, size=12)
ax.set_zlabel(zlabel, size=12)

ax.plot(xVar, yVar, zVar, color='red', linewidth=1.0)

plt.grid()
ax.set_xlim(0, 240)
ax.set_ylim(0, 240)
ax.set_zlim(0, 100+10)
ax.set_xticks( numpy.arange(0, 240, 20) )
ax.set_yticks( numpy.arange(0, 240, 20) )
ax.set_zticks( numpy.arange(0, 100, 10) )

ax.view_init( elev=25, azim=-60 )
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %% [markdown]
# <p>-</p>

# %%
'''
i_df=1
tgtTime=45
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
'''
print('------------------------------')

# %%
'''
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

'''
print('------------------------------')

# %%
'''
i_df=1
tgtTime=70
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
'''
print('------------------------------')

# %%
'''
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)
'''
print('------------------------------')

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
