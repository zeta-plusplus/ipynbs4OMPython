# %% [markdown]
# <h1>Visualize: PtMassFDM.DoF2.Examples.ExampleAircrafts.AGM84_ex02</h1>
# <h2>notebook: rev004</h2>
# <p>compatability with OpenModelica v1.17</p>
# <h2>memo: </h2>
# <p>compare Lycom O360 engine with turbochaged one</p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib
import math

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF2.Examples.ExampleAircrafts.AGM84_ex02'
nmModel='AGM84_ex02'
stopTime=600.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF2.Examples.ExampleAircrafts.AGM84_ex02
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF2/Examples/ExampleAircrafts/AGM84_ex02.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF2.Examples.ExampleAircrafts.AGM84_ex02_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#          time  aircraftMassCenter1.fltStates.V  \
# 0        0.00                       608.345175
# 1        0.05                       607.600543
# 2        0.10                       606.856975
# 3        0.15                       606.114585
# 4        0.20                       605.373477
# ...       ...                              ...
# 12005  599.85                       291.758757
# 12006  599.90                       291.758757
# 12007  599.95                       291.758757
# 12008  600.00                       291.758757
# 12009  600.00                       291.758757
#
#        aircraftMassCenter1.fltStates.XG  aircraftMassCenter1.fltStates.ZG  \
# 0                              0.000000                        -50.000000
# 1                             30.398639                        -50.000783
# 2                             60.760072                        -50.002965
# 3                             91.084355                        -50.007644
# 4                            121.371550                        -50.015649
# ...                                 ...                               ...
# 12005                     175694.520131                        -45.000000
# 12006                     175709.108068                        -45.000000
# 12007                     175723.696006                        -45.000000
# 12008                     175738.283944                        -45.000000
# 12009                     175738.283944                        -45.000000
#
#        aircraftMassCenter1.fltStates.gamma  delay_thrust.y  delay_thrust.yd  \
# 0                             1.745330e-05        0.000000     0.000000e+00
# 1                             4.191946e-05       -0.005893    -3.506402e-01
# 2                             1.078096e-04       -0.045982    -1.354540e+00
# 3                             2.053779e-04       -0.147027    -2.705550e+00
# 4                             3.266264e-04       -0.317849    -4.138765e+00
# ...                                    ...             ...              ...
# 12005                        -2.926119e-13     2007.488936     2.865393e-07
# 12006                        -2.925086e-13     2007.488936     2.859163e-07
# 12007                        -2.924052e-13     2007.488936     2.852934e-07
# 12008                        -2.923019e-13     2007.488936     2.846705e-07
# 12009                        -2.923019e-13     2007.488936     2.846705e-07
#
#        derivative1.x  integGain_fltPath.y  integGain_pitch.y  ...  \
# 0           0.000000         0.000000e+00           0.000000  ...
# 1          -5.795924         3.749753e-03           0.001749  ...
# 2          -5.836510         7.498473e-03           0.003507  ...
# 3          -5.838303         1.124468e-02           0.005255  ...
# 4          -5.839824         1.498617e-02           0.006978  ...
# ...              ...                  ...                ...  ...
# 12005      -5.134509         3.672013e-11           0.160614  ...
# 12006      -5.134509         3.656379e-11           0.160614  ...
# 12007      -5.134509         3.640745e-11           0.160614  ...
# 12008      -5.134509         3.625111e-11           0.160614  ...
# 12009      -5.134509         3.625111e-11           0.160614  ...
#
#        wing.port_amb.h_outflow  wing.port_amb.p    wing.y_Fx    wing.y_Fz  \
# 0                293586.685237           101325  1380.289178  7269.991974
# 1                293586.685237           101325  1362.985981  7692.965961
# 2                293586.685237           101325  1348.152234  8018.370157
# 3                293586.685237           101325  1335.607027  8263.745074
# 4                293586.685237           101325  1325.105253  8443.660922
# ...                        ...              ...          ...          ...
# 12005            293586.685237           101325  -208.828301  6783.909045
# 12006            293586.685237           101325  -208.828301  6783.909045
# 12007            293586.685237           101325  -208.828301  6783.909045
# 12008            293586.685237           101325  -208.828301  6783.909045
# 12009            293586.685237           101325  -208.828301  6783.909045
#
#        world.axisColor_y[1]  world.axisColor_y[2]  world.axisColor_y[3]  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 12005                     0                     0                     0
# 12006                     0                     0                     0
# 12007                     0                     0                     0
# 12008                     0                     0                     0
# 12009                     0                     0                     0
#
#        world.axisColor_z[1]  world.axisColor_z[2]  world.axisColor_z[3]
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 12005                     0                     0                     0
# 12006                     0                     0                     0
# 12007                     0                     0                     0
# 12008                     0                     0                     0
# 12009                     0                     0                     0
#
# [12010 rows x 496 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'aircraftMassCenter1.fltStates.V',
#  'aircraftMassCenter1.fltStates.XG',
#  'aircraftMassCenter1.fltStates.ZG',
#  'aircraftMassCenter1.fltStates.gamma',
#  'delay_thrust.y',
#  'delay_thrust.yd',
#  'derivative1.x',
#  'integGain_fltPath.y',
#  'integGain_pitch.y',
#  'integGain_thrust.y',
#  'integrator1.y',
#  'der(delay_thrust.y)',
#  'der(delay_thrust.yd)',
#  'der(derivative1.x)',
#  'der(integGain_fltPath.y)',
#  'der(integGain_pitch.y)',
#  'der(integGain_thrust.y)',
#  'der(integrator1.y)',
#  'aircraftMassCenter1.EKinetic',
#  'aircraftMassCenter1.EMechanical',
#  'aircraftMassCenter1.EPotential',
#  'aircraftMassCenter1.FltStatesBus1.fltAng4disp.alpha',
#  'aircraftMassCenter1.FltStatesBus1.fltAng4disp.theta',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.Fcentr',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.Ftan',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.X',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.XGdot',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.Z',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.ZGdot',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.u',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.w',
#  'aircraftMassCenter1.LqD',
#  'aircraftMassCenter1.drag',
#  'aircraftMassCenter1.fltAng4disp.beta',
#  'aircraftMassCenter1.fltAng4disp.phi',
#  'aircraftMassCenter1.fltAng4disp.psi',
#  'aircraftMassCenter1.fltStates.Fturn',
#  'aircraftMassCenter1.fltStates.L',
#  'aircraftMassCenter1.fltStates.M',
#  'aircraftMassCenter1.fltStates.N',
#  'aircraftMassCenter1.fltStates.Y',
#  'aircraftMassCenter1.fltStates.YG',
#  'aircraftMassCenter1.fltStates.YGdot',
#  'aircraftMassCenter1.fltStates.beta',
#  'aircraftMassCenter1.fltStates.p',
#  'aircraftMassCenter1.fltStates.phi',
#  'aircraftMassCenter1.fltStates.psi',
#  'aircraftMassCenter1.fltStates.q',
#  'aircraftMassCenter1.fltStates.r',
#  'aircraftMassCenter1.fltStates.v',
#  'aircraftMassCenter1.lift',
#  'aircraftMassCenter1.massTotal',
#  'aircraftMassCenter1.radiPerpend',
#  'aircraftMassCenter1.sum_u_FxBackward',
#  'aircraftMassCenter1.sum_u_Fz',
#  'aircraftMassCenter1.sum_u_mass',
#  'aircraftMassCenter1.u_FxBackward[1]',
#  'aircraftMassCenter1.u_FxBackward[2]',
#  'aircraftMassCenter1.u_Fz[1]',
#  'aircraftMassCenter1.u_Fz[2]',
#  'aircraftMassCenter1.weight',
#  'boundary.T_in_internal',
#  'boundary.medium.MM',
#  'boundary.medium.R',
#  'boundary.medium.T_degC',
#  'boundary.medium.X[1]',
#  'boundary.medium.d',
#  'boundary.medium.p_bar',
#  'boundary.medium.u',
#  'boundary.p_in_internal',
#  'boundary.ports[3].h_outflow',
#  'boundary.ports[1].m_flow',
#  'boundary.ports[2].m_flow',
#  'boundary.ports[3].m_flow',
#  'delay_thrust.u',
#  'derivative1.u',
#  'derivative1.y',
#  'dragObjSimple001.CD',
#  'dragObjSimple001.Sref',
#  'dragObjSimple001.Vflow',
#  'dragObjSimple001.fluid_amb.MM',
#  'dragObjSimple001.fluid_amb.R',
#  'dragObjSimple001.fluid_amb.T',
#  'dragObjSimple001.fluid_amb.T_degC',
#  'dragObjSimple001.fluid_amb.X[1]',
#  'dragObjSimple001.fluid_amb.d',
#  'dragObjSimple001.fluid_amb.h',
#  'dragObjSimple001.fluid_amb.p_bar',
#  'dragObjSimple001.fluid_amb.u',
#  'dragObjSimple001.port_amb.m_flow',
#  'dragObjSimple001.y_Df',
#  'feedback1.u1',
#  'feedback1.y',
#  'feedback_ctrl_pitch.u1',
#  'feedback_ctrl_pitch.u2',
#  'feedback_ctrl_pitch.y',
#  'feedback_ctrl_thrust.u1',
#  'feedback_ctrl_thrust.u2',
#  'feedback_ctrl_thrust.y',
#  'from_deg1.u',
#  'gain3.u',
#  'integrator1.u',
#  'limiter_fltPath.u',
#  'limiter_pitch.u',
#  'limiter_pitch.y',
#  'limiter_thrustLevel.y',
#  'sum1.u[1]',
#  'sum_ctrl_pitch.u[1]',
#  'sum_ctrl_thrust.u[1]',
#  'wing.AR',
#  'wing.CD',
#  'wing.CD0',
#  'wing.CDi',
#  'wing.CDp',
#  'wing.CL',
#  'wing.ChRoot',
#  'wing.Df0',
#  'wing.DfFric',
#  'wing.DfInduced',
#  'wing.DfPress',
#  'wing.LqD',
#  'wing.S',
#  'wing.Vsound',
#  'wing.airfoil2WingSimple001.CL0',
#  'wing.airfoil2WingSimple001.CL_alpha',
#  'wing.airfoil2WingSimple001.ChTip',
#  'wing.airfoil2WingSimple001.Cl0',
#  'wing.airfoil2WingSimple001.Cl_alpha',
#  'wing.airfoil2WingSimple001.MAC',
#  'wing.airfoil2WingSimple001.alphaEff',
#  'wing.airfoil2WingSimple001.alphaInd',
#  'wing.airfoil2WingSimple001.b',
#  'wing.airfoilSimple001.Cd',
#  'wing.airfoilSimple001.Cdf',
#  'wing.airfoilSimple001.CdpStall',
#  'wing.airfoilSimple001.Cl',
#  'wing.airfoilSimple001.Clmax',
#  'wing.airfoilSimple001.alpha4Cl0',
#  'wing.airfoilSimple001.alpha4Clmax',
#  'wing.airfoilSimple001.alpha4Clmin',
#  'wing.airfoilSimple001.alpha_CdpMin',
#  'wing.airfoilSimple001.intcptCdp_1',
#  'wing.airfoilSimple001.kCdp',
#  'wing.airfoilSimple001.kCdp_1',
#  'wing.airfoilSimple001.pwrCdp',
#  'wing.airfoilSimple001.pwrCdp_1',
#  'wing.alpha',
#  'wing.effOs',
#  'wing.fluid_amb.MM',
#  'wing.fluid_amb.R',
#  'wing.fluid_amb.T',
#  'wing.fluid_amb.T_degC',
#  'wing.fluid_amb.X[1]',
#  'wing.fluid_amb.d',
#  'wing.fluid_amb.h',
#  'wing.fluid_amb.p_bar',
#  'wing.fluid_amb.u',
#  'wing.inciAng',
#  'wing.port_amb.m_flow',
#  'wing.rambda',
#  'wing.sweep',
#  'wing.y_Df',
#  'wing.y_Lf',
#  'world.frame_b.R.T[1,1]',
#  'world.frame_b.R.T[1,2]',
#  'world.frame_b.R.T[1,3]',
#  'world.frame_b.R.T[2,1]',
#  'world.frame_b.R.T[2,2]',
#  'world.frame_b.R.T[2,3]',
#  'world.frame_b.R.T[3,1]',
#  'world.frame_b.R.T[3,2]',
#  'world.frame_b.R.T[3,3]',
#  'world.frame_b.R.w[1]',
#  'world.frame_b.R.w[2]',
#  'world.frame_b.R.w[3]',
#  'world.frame_b.f[1]',
#  'world.frame_b.f[2]',
#  'world.frame_b.f[3]',
#  'world.frame_b.r_0[1]',
#  'world.frame_b.r_0[2]',
#  'world.frame_b.r_0[3]',
#  'world.frame_b.t[1]',
#  'world.frame_b.t[2]',
#  'world.frame_b.t[3]',
#  'world.axisColor_x[1]',
#  'world.axisColor_x[2]',
#  'world.axisColor_x[3]',
#  'world.gravityArrowColor[1]',
#  'world.gravityArrowColor[2]',
#  'world.gravityArrowColor[3]',
#  'world.gravitySphereColor[1]',
#  'world.gravitySphereColor[2]',
#  'world.gravitySphereColor[3]',
#  'world.groundColor[1]',
#  'world.groundColor[2]',
#  'world.groundColor[3]',
#  'aircraftMassCenter1.FltStatesBus1.fltAng4disp.beta',
#  'aircraftMassCenter1.FltStatesBus1.fltAng4disp.gamma',
#  'aircraftMassCenter1.FltStatesBus1.fltAng4disp.phi',
#  'aircraftMassCenter1.FltStatesBus1.fltAng4disp.psi',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.Fturn',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.L',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.M',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.Mn',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.N',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.V',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.XG',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.Y',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.YG',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.YGdot',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.ZG',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.alpha',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.alt',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.beta',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.gamma',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.p',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.phi',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.psi',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.q',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.r',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.theta',
#  'aircraftMassCenter1.FltStatesBus1.fltStates.v',
#  'aircraftMassCenter1.InfoBus1.Mn',
#  'aircraftMassCenter1.InfoBus1.Vflow',
#  'aircraftMassCenter1.InfoBus1.Vsound',
#  'aircraftMassCenter1.InfoBus1.alpha',
#  'aircraftMassCenter1.InfoBus1.gamma',
#  'aircraftMassCenter1.InfoBus1.thetaCmd',
#  'aircraftMassCenter1.alt',
#  'aircraftMassCenter1.sum_u_FxForward',
#  'aircraftMassCenter1.thrust',
#  'aircraftMassCenter1.u_FxForward[1]',
#  'aircraftMassCenter1.xWorld',
#  'boundary.medium.T',
#  'boundary.medium.h',
#  'boundary.medium.p',
#  'boundary.medium.state.T',
#  'boundary.medium.state.p',
#  'boundary.ports[1].h_outflow',
#  'boundary.ports[2].h_outflow',
#  'boundary.ports[1].p',
#  'boundary.ports[2].p',
#  'boundary.ports[3].p',
#  'dragObjSimple001.Df',
#  'dragObjSimple001.Fx',
#  'dragObjSimple001.Fz',
#  'dragObjSimple001.Mn',
#  'dragObjSimple001.alpha',
#  'dragObjSimple001.busFltStates1.Mn',
#  'dragObjSimple001.busFltStates1.Vflow',
#  'dragObjSimple001.busFltStates1.Vsound',
#  'dragObjSimple001.busFltStates1.alpha',
#  'dragObjSimple001.busFltStates1.gamma',
#  'dragObjSimple001.busFltStates1.thetaCmd',
#  'dragObjSimple001.fluid_amb.p',
#  'dragObjSimple001.fluid_amb.state.T',
#  'dragObjSimple001.fluid_amb.state.p',
#  'dragObjSimple001.port_amb.h_outflow',
#  'dragObjSimple001.port_amb.p',
#  'dragObjSimple001.y_Fx',
#  'dragObjSimple001.y_Fz',
#  'feedback1.u2',
#  'from_deg1.y',
#  'gain3.y',
#  'integGain_fltPath.u',
#  'integGain_pitch.u',
#  'integGain_thrust.u',
#  'limiter1.u',
#  'limiter1.y',
#  'limiter_fltPath.y',
#  'limiter_thrustLevel.u',
#  'propGain_fltPath.u',
#  'propGain_fltPath.y',
#  'propGain_pitch.u',
#  'propGain_pitch.y',
#  'propGain_thrust.u',
#  'propGain_thrust.y',
#  'r_Mn.y',
#  'r_alt.y',
#  'sensorAltitude.FltStatesBus1.fltAng4disp.alpha',
#  'sensorAltitude.FltStatesBus1.fltAng4disp.beta',
#  'sensorAltitude.FltStatesBus1.fltAng4disp.gamma',
#  'sensorAltitude.FltStatesBus1.fltAng4disp.phi',
#  'sensorAltitude.FltStatesBus1.fltAng4disp.psi',
#  'sensorAltitude.FltStatesBus1.fltAng4disp.theta',
#  'sensorAltitude.FltStatesBus1.fltStates.Fcentr',
#  'sensorAltitude.FltStatesBus1.fltStates.Ftan',
#  'sensorAltitude.FltStatesBus1.fltStates.Fturn',
#  'sensorAltitude.FltStatesBus1.fltStates.L',
#  'sensorAltitude.FltStatesBus1.fltStates.M',
#  'sensorAltitude.FltStatesBus1.fltStates.Mn',
#  'sensorAltitude.FltStatesBus1.fltStates.N',
#  'sensorAltitude.FltStatesBus1.fltStates.V',
#  'sensorAltitude.FltStatesBus1.fltStates.X',
#  'sensorAltitude.FltStatesBus1.fltStates.XG',
#  'sensorAltitude.FltStatesBus1.fltStates.XGdot',
#  'sensorAltitude.FltStatesBus1.fltStates.Y',
#  'sensorAltitude.FltStatesBus1.fltStates.YG',
#  'sensorAltitude.FltStatesBus1.fltStates.YGdot',
#  'sensorAltitude.FltStatesBus1.fltStates.Z',
#  'sensorAltitude.FltStatesBus1.fltStates.ZG',
#  'sensorAltitude.FltStatesBus1.fltStates.ZGdot',
#  'sensorAltitude.FltStatesBus1.fltStates.alpha',
#  'sensorAltitude.FltStatesBus1.fltStates.alt',
#  'sensorAltitude.FltStatesBus1.fltStates.beta',
#  'sensorAltitude.FltStatesBus1.fltStates.gamma',
#  'sensorAltitude.FltStatesBus1.fltStates.p',
#  'sensorAltitude.FltStatesBus1.fltStates.phi',
#  'sensorAltitude.FltStatesBus1.fltStates.psi',
#  'sensorAltitude.FltStatesBus1.fltStates.q',
#  'sensorAltitude.FltStatesBus1.fltStates.r',
#  'sensorAltitude.FltStatesBus1.fltStates.theta',
#  'sensorAltitude.FltStatesBus1.fltStates.u',
#  'sensorAltitude.FltStatesBus1.fltStates.v',
#  'sensorAltitude.FltStatesBus1.fltStates.w',
#  'sensorAltitude.y_alt',
#  'sensorGamma.FltStatesBus1.fltAng4disp.alpha',
#  'sensorGamma.FltStatesBus1.fltAng4disp.beta',
#  'sensorGamma.FltStatesBus1.fltAng4disp.gamma',
#  'sensorGamma.FltStatesBus1.fltAng4disp.phi',
#  'sensorGamma.FltStatesBus1.fltAng4disp.psi',
#  'sensorGamma.FltStatesBus1.fltAng4disp.theta',
#  'sensorGamma.FltStatesBus1.fltStates.Fcentr',
#  'sensorGamma.FltStatesBus1.fltStates.Ftan',
#  'sensorGamma.FltStatesBus1.fltStates.Fturn',
#  'sensorGamma.FltStatesBus1.fltStates.L',
#  'sensorGamma.FltStatesBus1.fltStates.M',
#  'sensorGamma.FltStatesBus1.fltStates.Mn',
#  'sensorGamma.FltStatesBus1.fltStates.N',
#  'sensorGamma.FltStatesBus1.fltStates.V',
#  'sensorGamma.FltStatesBus1.fltStates.X',
#  'sensorGamma.FltStatesBus1.fltStates.XG',
#  'sensorGamma.FltStatesBus1.fltStates.XGdot',
#  'sensorGamma.FltStatesBus1.fltStates.Y',
#  'sensorGamma.FltStatesBus1.fltStates.YG',
#  'sensorGamma.FltStatesBus1.fltStates.YGdot',
#  'sensorGamma.FltStatesBus1.fltStates.Z',
#  'sensorGamma.FltStatesBus1.fltStates.ZG',
#  'sensorGamma.FltStatesBus1.fltStates.ZGdot',
#  'sensorGamma.FltStatesBus1.fltStates.alpha',
#  'sensorGamma.FltStatesBus1.fltStates.alt',
#  'sensorGamma.FltStatesBus1.fltStates.beta',
#  'sensorGamma.FltStatesBus1.fltStates.gamma',
#  'sensorGamma.FltStatesBus1.fltStates.p',
#  'sensorGamma.FltStatesBus1.fltStates.phi',
#  'sensorGamma.FltStatesBus1.fltStates.psi',
#  'sensorGamma.FltStatesBus1.fltStates.q',
#  'sensorGamma.FltStatesBus1.fltStates.r',
#  'sensorGamma.FltStatesBus1.fltStates.theta',
#  'sensorGamma.FltStatesBus1.fltStates.u',
#  'sensorGamma.FltStatesBus1.fltStates.v',
#  'sensorGamma.FltStatesBus1.fltStates.w',
#  'sensorGamma.y_gamma',
#  'sensorMach.FltStatesBus1.fltAng4disp.alpha',
#  'sensorMach.FltStatesBus1.fltAng4disp.beta',
#  'sensorMach.FltStatesBus1.fltAng4disp.gamma',
#  'sensorMach.FltStatesBus1.fltAng4disp.phi',
#  'sensorMach.FltStatesBus1.fltAng4disp.psi',
#  'sensorMach.FltStatesBus1.fltAng4disp.theta',
#  'sensorMach.FltStatesBus1.fltStates.Fcentr',
#  'sensorMach.FltStatesBus1.fltStates.Ftan',
#  'sensorMach.FltStatesBus1.fltStates.Fturn',
#  'sensorMach.FltStatesBus1.fltStates.L',
#  'sensorMach.FltStatesBus1.fltStates.M',
#  'sensorMach.FltStatesBus1.fltStates.Mn',
#  'sensorMach.FltStatesBus1.fltStates.N',
#  'sensorMach.FltStatesBus1.fltStates.V',
#  'sensorMach.FltStatesBus1.fltStates.X',
#  'sensorMach.FltStatesBus1.fltStates.XG',
#  'sensorMach.FltStatesBus1.fltStates.XGdot',
#  'sensorMach.FltStatesBus1.fltStates.Y',
#  'sensorMach.FltStatesBus1.fltStates.YG',
#  'sensorMach.FltStatesBus1.fltStates.YGdot',
#  'sensorMach.FltStatesBus1.fltStates.Z',
#  'sensorMach.FltStatesBus1.fltStates.ZG',
#  'sensorMach.FltStatesBus1.fltStates.ZGdot',
#  'sensorMach.FltStatesBus1.fltStates.alpha',
#  'sensorMach.FltStatesBus1.fltStates.alt',
#  'sensorMach.FltStatesBus1.fltStates.beta',
#  'sensorMach.FltStatesBus1.fltStates.gamma',
#  'sensorMach.FltStatesBus1.fltStates.p',
#  'sensorMach.FltStatesBus1.fltStates.phi',
#  'sensorMach.FltStatesBus1.fltStates.psi',
#  'sensorMach.FltStatesBus1.fltStates.q',
#  'sensorMach.FltStatesBus1.fltStates.r',
#  'sensorMach.FltStatesBus1.fltStates.theta',
#  'sensorMach.FltStatesBus1.fltStates.u',
#  'sensorMach.FltStatesBus1.fltStates.v',
#  'sensorMach.FltStatesBus1.fltStates.w',
#  'sensorMach.y_Mn',
#  'sum1.u[2]',
#  'sum1.y',
#  'sum_ctrl_pitch.u[2]',
#  'sum_ctrl_pitch.y',
#  'sum_ctrl_thrust.u[2]',
#  'sum_ctrl_thrust.y',
#  'thrust_nominal.u',
#  'thrust_nominal.y',
#  'wing.CDf',
#  'wing.Df',
#  'wing.Fx',
#  'wing.Fz',
#  'wing.Lf',
#  'wing.Mn',
#  'wing.Vflow',
#  'wing.airfoil2WingSimple001.AR',
#  'wing.airfoil2WingSimple001.CD',
#  'wing.airfoil2WingSimple001.CD0',
#  'wing.airfoil2WingSimple001.CDf',
#  'wing.airfoil2WingSimple001.CDi',
#  'wing.airfoil2WingSimple001.CDp',
#  'wing.airfoil2WingSimple001.CL',
#  'wing.airfoil2WingSimple001.Cdf',
#  'wing.airfoil2WingSimple001.Cdp',
#  'wing.airfoil2WingSimple001.ChRoot',
#  'wing.airfoil2WingSimple001.Mn',
#  'wing.airfoil2WingSimple001.S',
#  'wing.airfoil2WingSimple001.alpha',
#  'wing.airfoil2WingSimple001.alpha4CL0',
#  'wing.airfoil2WingSimple001.alpha4CLmax',
#  'wing.airfoil2WingSimple001.alpha4CLmin',
#  'wing.airfoil2WingSimple001.alpha4Cl0',
#  'wing.airfoil2WingSimple001.alpha4Clmax',
#  'wing.airfoil2WingSimple001.alpha4Clmin',
#  'wing.airfoil2WingSimple001.effOs',
#  'wing.airfoil2WingSimple001.rambda',
#  'wing.airfoil2WingSimple001.signalBus1.AR',
#  'wing.airfoil2WingSimple001.signalBus1.Cd',
#  'wing.airfoil2WingSimple001.signalBus1.Cdf',
#  'wing.airfoil2WingSimple001.signalBus1.Cdp',
#  'wing.airfoil2WingSimple001.signalBus1.ChRoot',
#  'wing.airfoil2WingSimple001.signalBus1.Cl',
#  'wing.airfoil2WingSimple001.signalBus1.Cl0',
#  'wing.airfoil2WingSimple001.signalBus1.Cl_alpha',
#  'wing.airfoil2WingSimple001.signalBus1.Mn',
#  'wing.airfoil2WingSimple001.signalBus1.S',
#  'wing.airfoil2WingSimple001.signalBus1.alpha',
#  'wing.airfoil2WingSimple001.signalBus1.alpha4Cl0',
#  'wing.airfoil2WingSimple001.signalBus1.alpha4Clmax',
#  'wing.airfoil2WingSimple001.signalBus1.alpha4Clmin',
#  'wing.airfoil2WingSimple001.signalBus1.effOs',
#  'wing.airfoil2WingSimple001.signalBus1.rambda',
#  'wing.airfoil2WingSimple001.signalBus1.sweep',
#  'wing.airfoil2WingSimple001.signalBus2.CD',
#  'wing.airfoil2WingSimple001.signalBus2.CD0',
#  'wing.airfoil2WingSimple001.signalBus2.CDf',
#  'wing.airfoil2WingSimple001.signalBus2.CDi',
#  'wing.airfoil2WingSimple001.signalBus2.CDp',
#  'wing.airfoil2WingSimple001.signalBus2.CL',
#  'wing.airfoil2WingSimple001.signalBus2.CL0',
#  'wing.airfoil2WingSimple001.signalBus2.CL_alpha',
#  'wing.airfoil2WingSimple001.signalBus2.S',
#  'wing.airfoil2WingSimple001.sweep',
#  'wing.airfoilSimple001.Cdp',
#  'wing.airfoilSimple001.Cl0',
#  'wing.airfoilSimple001.Cl_alpha',
#  'wing.airfoilSimple001.alpha',
#  'wing.airfoilSimple001.signalBus1.alpha',
#  'wing.airfoilSimple001.signalBus2.AR',
#  'wing.airfoilSimple001.signalBus2.Cd',
#  'wing.airfoilSimple001.signalBus2.Cdf',
#  'wing.airfoilSimple001.signalBus2.Cdp',
#  'wing.airfoilSimple001.signalBus2.ChRoot',
#  'wing.airfoilSimple001.signalBus2.Cl',
#  'wing.airfoilSimple001.signalBus2.Cl0',
#  'wing.airfoilSimple001.signalBus2.Cl_alpha',
#  'wing.airfoilSimple001.signalBus2.Mn',
#  'wing.airfoilSimple001.signalBus2.S',
#  'wing.airfoilSimple001.signalBus2.alpha',
#  'wing.airfoilSimple001.signalBus2.alpha4Cl0',
#  'wing.airfoilSimple001.signalBus2.alpha4Clmax',
#  'wing.airfoilSimple001.signalBus2.alpha4Clmin',
#  'wing.airfoilSimple001.signalBus2.effOs',
#  'wing.airfoilSimple001.signalBus2.rambda',
#  'wing.airfoilSimple001.signalBus2.sweep',
#  'wing.alphaFlt',
#  'wing.busFltStates1.Mn',
#  'wing.busFltStates1.Vflow',
#  'wing.busFltStates1.Vsound',
#  'wing.busFltStates1.alpha',
#  'wing.busFltStates1.gamma',
#  'wing.busFltStates1.thetaCmd',
#  'wing.fluid_amb.p',
#  'wing.fluid_amb.state.T',
#  'wing.fluid_amb.state.p',
#  'wing.port_amb.h_outflow',
#  'wing.port_amb.p',
#  'wing.y_Fx',
#  'wing.y_Fz',
#  'world.axisColor_y[1]',
#  'world.axisColor_y[2]',
#  'world.axisColor_y[3]',
#  'world.axisColor_z[1]',
#  'world.axisColor_z[2]',
#  'world.axisColor_z[3]']

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=2


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF2.Examples.ExampleAircrafts.AGM84_ex02_res_2.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF2.Examples.ExampleAircrafts.AGM84_ex02_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#          time  aircraftMassCenter1.fltStates.V  \
# 0        0.00                       608.345175
# 1        0.05                       607.600543
# 2        0.10                       606.856975
# 3        0.15                       606.114585
# 4        0.20                       605.373477
# ...       ...                              ...
# 12005  599.85                       291.758757
# 12006  599.90                       291.758757
# 12007  599.95                       291.758757
# 12008  600.00                       291.758757
# 12009  600.00                       291.758757
#
#        aircraftMassCenter1.fltStates.XG  aircraftMassCenter1.fltStates.ZG  \
# 0                              0.000000                        -50.000000
# 1                             30.398639                        -50.000783
# 2                             60.760072                        -50.002965
# 3                             91.084355                        -50.007644
# 4                            121.371550                        -50.015649
# ...                                 ...                               ...
# 12005                     175694.520131                        -45.000000
# 12006                     175709.108068                        -45.000000
# 12007                     175723.696006                        -45.000000
# 12008                     175738.283944                        -45.000000
# 12009                     175738.283944                        -45.000000
#
#        aircraftMassCenter1.fltStates.gamma  delay_thrust.y  delay_thrust.yd  \
# 0                             1.745330e-05        0.000000     0.000000e+00
# 1                             4.191946e-05       -0.005893    -3.506402e-01
# 2                             1.078096e-04       -0.045982    -1.354540e+00
# 3                             2.053779e-04       -0.147027    -2.705550e+00
# 4                             3.266264e-04       -0.317849    -4.138765e+00
# ...                                    ...             ...              ...
# 12005                        -2.926119e-13     2007.488936     2.865393e-07
# 12006                        -2.925086e-13     2007.488936     2.859163e-07
# 12007                        -2.924052e-13     2007.488936     2.852934e-07
# 12008                        -2.923019e-13     2007.488936     2.846705e-07
# 12009                        -2.923019e-13     2007.488936     2.846705e-07
#
#        derivative1.x  integGain_fltPath.y  integGain_pitch.y  ...  \
# 0           0.000000         0.000000e+00           0.000000  ...
# 1          -5.795924         3.749753e-03           0.001749  ...
# 2          -5.836510         7.498473e-03           0.003507  ...
# 3          -5.838303         1.124468e-02           0.005255  ...
# 4          -5.839824         1.498617e-02           0.006978  ...
# ...              ...                  ...                ...  ...
# 12005      -5.134509         3.672013e-11           0.160614  ...
# 12006      -5.134509         3.656379e-11           0.160614  ...
# 12007      -5.134509         3.640745e-11           0.160614  ...
# 12008      -5.134509         3.625111e-11           0.160614  ...
# 12009      -5.134509         3.625111e-11           0.160614  ...
#
#        wing.port_amb.h_outflow  wing.port_amb.p    wing.y_Fx    wing.y_Fz  \
# 0                293586.685237           101325  1380.289178  7269.991974
# 1                293586.685237           101325  1362.985981  7692.965961
# 2                293586.685237           101325  1348.152234  8018.370157
# 3                293586.685237           101325  1335.607027  8263.745074
# 4                293586.685237           101325  1325.105253  8443.660922
# ...                        ...              ...          ...          ...
# 12005            293586.685237           101325  -208.828301  6783.909045
# 12006            293586.685237           101325  -208.828301  6783.909045
# 12007            293586.685237           101325  -208.828301  6783.909045
# 12008            293586.685237           101325  -208.828301  6783.909045
# 12009            293586.685237           101325  -208.828301  6783.909045
#
#        world.axisColor_y[1]  world.axisColor_y[2]  world.axisColor_y[3]  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 12005                     0                     0                     0
# 12006                     0                     0                     0
# 12007                     0                     0                     0
# 12008                     0                     0                     0
# 12009                     0                     0                     0
#
#        world.axisColor_z[1]  world.axisColor_z[2]  world.axisColor_z[3]
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 12005                     0                     0                     0
# 12006                     0                     0                     0
# 12007                     0                     0                     0
# 12008                     0                     0                     0
# 12009                     0                     0                     0
#
# [12010 rows x 496 columns]

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="r_alt.y"
#label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
#plt.plot(time, var, label=label, color='green')
plt.plot(time, var, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('altitude [m]')
plt.title('altitude command')

#plt.legend(loc='upper right', fontsize=12)
plt.ylim(40, 60)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="r_Mn.y"
#label="not turbocharged"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
#plt.plot(time, var, label=label, color='green')
plt.plot(time, var, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('Mach [nond]')
plt.title('Flight mach number command')

#plt.legend(loc='upper right', fontsize=12)
plt.ylim(0.75, 0.9)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="aircraftMassCenter1.FltStatesBus1.fltStates.alt"
label="aircraft response"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
varName="r_alt.y"
label="command signal"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('Altitude [m]')
plt.title('Altitude')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(40, 60)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="aircraftMassCenter1.FltStatesBus1.fltStates.Mn"
label="aircraft response"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
varName="r_Mn.y"
label="command signal"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('Mach [nond]')
plt.title('Flight mach number')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(0.75, 1.1)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="aircraftMassCenter1.FltStatesBus1.fltStates.theta"
label="Pitch angle"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label, color="red")

#----------
varName="aircraftMassCenter1.FltStatesBus1.fltStates.gamma"
label="Flight path angle"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label, color="blue")

#----------
varName="aircraftMassCenter1.FltStatesBus1.fltStates.alpha"
label="Angle of Attack"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
plt.plot(time, var, label=label, color="green")
 
#----------
plt.xlabel('time [s]')
plt.ylabel('Angle [deg]')
plt.title('Flight state angles')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(-2, 12)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="wing.CL"
label="CL, wing (3D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
varName="wing.airfoilSimple001.Cl"
label="Cl, airfoil (2D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('Coefficient [nond]')
plt.title('Lift coefficient')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(0, 1.2)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="aircraftMassCenter1.drag"
label="aircraft"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
varName="wing.Df"
label="wing"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
varName="dragObjSimple001.Df"
label="fulselage"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="green")

#----------
plt.xlabel('time [s]')
plt.ylabel('Force [N]')
plt.title('Drag')

plt.legend(loc='lower right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(0, 3000)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="wing.Df"
label="overall wing drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.Df0"
label="total of zero-lift drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.DfFric"
label="friction drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.DfInduced"
label="induced drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.DfPress"
label="pressure drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
plt.xlabel('time [s]')
plt.ylabel('Force [N]')
plt.title('Drags of wing')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(0, 1200)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="wing.CD"
label="overall wing drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.CD0"
label="total of zero-lift drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.CDf"
label="friction drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.CDi"
label="induced drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.CDp"
label="pressure drag"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
plt.xlabel('time [s]')
plt.ylabel('Drag coefficient [nond]')
plt.title('Drag coefficient of wing')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
#plt.ylim(0, 1200)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="aircraftMassCenter1.LqD"
label="L/D, aircraft (3D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
varName="wing.LqD"
label="L/D, wing (3D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="blue")

#----------
plt.xlabel('time [s]')
plt.ylabel('Coefficient/Coefficient [nond]')
plt.title('Lift/Drag')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
#plt.ylim(2000, 5500)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="aircraftMassCenter1.LqD"
label="L/D, aircraft (3D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName="wing.LqD"
label="L/D, wing (3D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label)

#----------
varName1= "wing.airfoilSimple001.Cl"
varName2= "wing.airfoilSimple001.Cd"
label= "L/D, airfoil (2D)"
time= df[i_df].loc[:,'time']
var1= df[i_df].loc[:,varName1]
var2= df[i_df].loc[:,varName2]
var= var1/var2
plt.plot(time, var, label=label)

#----------
plt.xlabel('time [s]')
plt.ylabel('Coefficient/Coefficient [nond]')
plt.title('Lift/Drag')

plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
#plt.ylim(2000, 5500)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="aircraftMassCenter1.thrust"
#label="L/D, aircraft (3D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Force [N]')
plt.title('Engine thrust')

#plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(-500, 3000)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
fig.append(plt.figure( figsize=(15,8)))

i_df=1

varName="thrust_nominal.u"
#label="L/D, aircraft (3D)"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('Fraction [nond]')
plt.title('Engine thrust level')

#plt.legend(loc='center right', fontsize=12)
#plt.xlim(40,100)
plt.ylim(-0.25, 1.25)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %% [markdown]
# <p>-</p>

# %%
'''
i_df=1
tgtTime=45
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)

'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
i_df=1
tgtTime=70
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(20,20)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------
