# %% [markdown]
# <h1>AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02</h1>
# <p>rev001</p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib
import math

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Use settings</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02'
nmModel='LongitudinalLTISS00_ex02'
stopTime=70.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Windows (nt)
# -. Home directory of current environment is: C:\Users\grabacr
# -. Temporary Working directory is: C:\Users\grabacr/OMPythonWork
#
# -. Directory of This notebook: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# -. Directory of library which contains this notebook is: C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02
# -. Full path of Model file to be ran is: C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/RigidBodyFDM/Examples/sampleAircrafts/LongitudinalLTISS00_ex02.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- load Modelica Standard Library
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# 2021-06-03 22:10:54,854 - OMPython - INFO - OMC Server is up and running at file:///C:/Users/grabacr/AppData/Local/Temp/openmodelica.port.ed3d94b1e8114f948db9981654ad21e7 pid=7652
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
# send: cd("C:\Users\grabacr/OMPythonWork")
# OMShell: C:/Users/grabacr/OMPythonWork
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("C:/Users/grabacr/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Building Model</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
print(''); print('...moving OMshell to temporary working directry')
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- build the model
print(''); print('...building the model, wait...')
strcmd= 'buildModel(' + fullpathModel + ', stopTime='+str(stopTime) + ', outputFormat="csv"' + ')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...model build finished.')

#-- save original parameter setting file
print(''); print('...Saving original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (fullpathModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
#
# ...moving OMshell to temporary working directry
# send: cd("C:\Users\grabacr/OMPythonWork")
# OMShell: C:/Users/grabacr/OMPythonWork
#
# ...building the model, wait...
# send: buildModel(AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02, stopTime=70.0, outputFormat="csv")
# OMShell: ('C:/Users/grabacr/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02', 'AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml')
# ...model build finished.
#
# ...Saving original parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_org.xml")
# OMShell: 0
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Print source code of model built</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

strcmd= 'list('+fullpathModel+')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print('source code of model build:')
print('')
print(str(msgOMShell)); 

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
# send: list(AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02)
# source code of model build:
#
# model LongitudinalLTISS00_ex02
#   extends Modelica.Icons.Example;
#   //-----
#   //package surrFluid = Modelica.Media.Air.DryAirNasa;
#   package surrFluid = AircraftDynamics.Media.DryAirMethaneMixture00;
#   //redeclare package Medium = surrFluid
#   //-----
#   Modelica.Blocks.Math.UnitConversions.From_deg from_deg1 annotation(
#     Placement(visible = true, transformation(origin = {-50, 20}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Constant const_S(k = 16.165129) annotation(
#     Placement(visible = true, transformation(origin = {10, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Blocks.Sources.Constant const_m(k = 1202.01978) annotation(
#     Placement(visible = true, transformation(origin = {40, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Blocks.Sources.Constant const_Iyy(k = 1824.9309607) annotation(
#     Placement(visible = true, transformation(origin = {70, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Blocks.Sources.Constant const_cBar(k = 1.49352) annotation(
#     Placement(visible = true, transformation(origin = {100, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   AircraftDynamics.Sources.FlightCondition2Fluid00 Flt2Fluid(redeclare package Medium = surrFluid, MN_paramInput = 0.201, alt_paramInput = 1524) annotation(
#     Placement(visible = true, transformation(origin = {-70, 60}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   inner AircraftDynamics.SimEnvironment environmentAircraftDynSim annotation(
#     Placement(visible = true, transformation(origin = {-90, 90}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   AircraftDynamics.RigidBodyFDM.Components.LongitudinalLTISS00 FltDynLongiSS(use_u_Iyy = true, use_u_S = true, use_u_U1 = true, use_u_cBar = true, use_u_m = true, use_u_q1bar = true) annotation(
#     Placement(visible = true, transformation(origin = {32.0548, 19.8733}, extent = {{-32.2028, -20.1267}, {28.1774, 20.1267}}, rotation = 0)));
#   Modelica.Blocks.Math.Gain gain_Tsteady(k = 50) annotation(
#     Placement(visible = true, transformation(origin = {-50, -20}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Math.UnitConversions.To_deg to_deg1 annotation(
#     Placement(visible = true, transformation(origin = {90, 16}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Continuous.Integrator integrator1 annotation(
#     Placement(visible = true, transformation(origin = {90, -20}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.RealExpression uSignal_deltaE(y = if time <= 2 then 0 elseif 2 <= time and time <= 3 then -3
#    elseif 7 <= time and time <= 8 then 3
#    elseif 31 <= time then 0 else 0) annotation(
#     Placement(visible = true, transformation(origin = {-90, 20}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.RealExpression uSignal_deltaFracT(y = if time <= 2 then 0 elseif 2 <= time and time <= 3 then 0
#    elseif 30 <= time and time <= 31 then 0
#    elseif 31 <= time then 0 else 0) annotation(
#     Placement(visible = true, transformation(origin = {-90, -20}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
# equation
#   connect(Flt2Fluid.y_qBar, FltDynLongiSS.u_q1bar) annotation(
#     Line(points = {{-58, 52}, {4, 52}, {4, 42}}, color = {0, 0, 127}));
#   connect(FltDynLongiSS.u_U1, Flt2Fluid.y_V_inf) annotation(
#     Line(points = {{12, 42}, {12, 56}, {-58, 56}}, color = {0, 0, 127}));
#   connect(const_S.y, FltDynLongiSS.u_S) annotation(
#     Line(points = {{10, 100}, {10, 90}, {32, 90}, {32, 42}}, color = {0, 0, 127}));
#   connect(const_m.y, FltDynLongiSS.u_m) annotation(
#     Line(points = {{40, 100}, {40, 42}}, color = {0, 0, 127}));
#   connect(const_Iyy.y, FltDynLongiSS.u_Iyy) annotation(
#     Line(points = {{70, 100}, {70, 88}, {48, 88}, {48, 42}}, color = {0, 0, 127}));
#   connect(const_cBar.y, FltDynLongiSS.u_cBar) annotation(
#     Line(points = {{100, 100}, {100, 68}, {56, 68}, {56, 42}}, color = {0, 0, 127}));
#   connect(gain_Tsteady.y, FltDynLongiSS.u_deltaT) annotation(
#     Line(points = {{-39, -20}, {-8, -20}, {-8, 8}, {-2, 8}}, color = {0, 0, 127}));
#   connect(FltDynLongiSS.y_q, to_deg1.u) annotation(
#     Line(points = {{62, 26}, {70, 26}, {70, 16}, {78, 16}}, color = {0, 0, 127}));
#   connect(FltDynLongiSS.y_q, integrator1.u) annotation(
#     Line(points = {{62, 26}, {70, 26}, {70, -20}, {78, -20}}, color = {0, 0, 127}));
#   connect(from_deg1.y, FltDynLongiSS.u_deltaE) annotation(
#     Line(points = {{-39, 20}, {-30, 20}, {-30, 32}, {-2, 32}}, color = {0, 0, 127}));
#   connect(uSignal_deltaE.y, from_deg1.u) annotation(
#     Line(points = {{-78, 20}, {-62, 20}}, color = {0, 0, 127}));
#   connect(uSignal_deltaFracT.y, gain_Tsteady.u) annotation(
#     Line(points = {{-78, -20}, {-62, -20}, {-62, -20}, {-62, -20}}, color = {0, 0, 127}));
#   annotation(
#     Diagram(coordinateSystem(extent = {{-100, -100}, {120, 120}})),
#     __OpenModelica_commandLineOptions = "",
#     experiment(StartTime = 0, StopTime = 120, Tolerance = 1e-06, Interval = 0.01),
#     __OpenModelica_simulationFlags(lv = "LOG_STATS", outputFormat = "mat", s = "dassl"));
# end LongitudinalLTISS00_ex02;
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation, default setting</h1>

# %%
stopTime=70

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- reset _init.xml
print('...calling original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#-- run simulation with default parameter setting
print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
##### end if #####
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
# ...calling original parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_org.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02.exe -override stopTime=70 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>parameter sweep, 1 parameter </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
''''''
iRunBegin=2
iRunEnd=4
param2change="Flt2Fluid.MN_paramInput"
valBegin=0.1
deltaVal=0.1
stopTime=150.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    iRun=i
    value2set=valBegin+(i-1)*deltaVal
    filenameXmlOrg=fullpathModel+'_init_org.xml'
    filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
    
    print(''); print('-----')
    print('iRun= '+ str(iRun))
    
    #-- overwrite parameter setting xml file
    print('...Overwriting parameter setting file...')
    strcmd= 'setInitXmlStartValue("' + filenameXmlOrg+'", '+ '"'+param2change+'", ' + '"'+str(value2set)+'", '+ '"'+fullpathModel+'_init.xml"' +')'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- save parameter setting file after overwriting
    print(''); print('...Saving parameter setting file...')
    strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- run simulation with default parameter setting
    print(''); print("...running simulation, wait...")
    if(os.name=='nt'):
        strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    elif(os.name=='posix'):
        strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    ##### end if #####

    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
    print('...simulation run finished.')
##### end for #####

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
#
# -----
# iRun= 2
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_org.xml", "Flt2Fluid.MN_paramInput", "0.2", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_2.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02.exe -override stopTime=150.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res_2.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 3
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_org.xml", "Flt2Fluid.MN_paramInput", "0.30000000000000004", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_3.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02.exe -override stopTime=150.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res_3.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 4
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_org.xml", "Flt2Fluid.MN_paramInput", "0.4", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_4.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02.exe -override stopTime=150.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res_4.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Change multiple parameters </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRun=1
param2change=[
    'Flt2Fluid.MN_paramInput', 'Flt2Fluid.alt_paramInput',
    'uSignal_deltaE.y'
]

value2set=[
    0.201, 1524,
    'if time <= 2 then 0 elseif 2 <= time and time <= 3 then -3 elseif 7 <= time and time <= 8 then 3 elseif 31 <= time then 0 else 0' ,
]
stopTime=150.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2change)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(fullpathModel+'_init.xml')+'", '+ '"'+param2change[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(fullpathModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
# iRun=1
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_org.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml", "Flt2Fluid.MN_paramInput", "0.201", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml", "Flt2Fluid.alt_paramInput", "1524", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml", "uSignal_deltaE.y", "if time <= 2 then 0 elseif 2 <= time and time <= 3 then -3 elseif 7 <= time and time <= 8 then 3 elseif 31 <= time then 0 else 0", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml")
# OMShell: False
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_init_1.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02.exe -override stopTime=150.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res_1.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process</h1>

# %%
n_df=100
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
# data read: C:\Users\grabacr\OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
#             time  FltDynLongiSS.x[1]  FltDynLongiSS.x[2]  FltDynLongiSS.x[3]  \
# 0       0.000000            0.000000            0.000000            0.000000
# 1       0.005833            0.000000            0.000000            0.000000
# 2       0.011667            0.000000            0.000000            0.000000
# 3       0.017500            0.000000            0.000000            0.000000
# 4       0.023333            0.000000            0.000000            0.000000
# ...          ...                 ...                 ...                 ...
# 12005  69.982500           -0.070317           -0.000040            0.000280
# 12006  69.988333           -0.072269           -0.000039            0.000274
# 12007  69.994167           -0.074221           -0.000038            0.000268
# 12008  70.000000           -0.076172           -0.000037            0.000262
# 12009  70.000000           -0.076172           -0.000037            0.000262
#
#        FltDynLongiSS.x[4]  integrator1.y  der(FltDynLongiSS.x[1])  \
# 0                0.000000       0.000000                 0.000000
# 1                0.000000       0.000000                 0.000000
# 2                0.000000       0.000000                 0.000000
# 3                0.000000       0.000000                 0.000000
# 4                0.000000       0.000000                 0.000000
# ...                   ...            ...                      ...
# 12005            0.034549       0.034549                -0.334665
# 12006            0.034551       0.034551                -0.334584
# 12007            0.034552       0.034552                -0.334503
# 12008            0.034554       0.034554                -0.334421
# 12009            0.034554       0.034554                -0.334421
#
#        der(FltDynLongiSS.x[2])  der(FltDynLongiSS.x[3])  \
# 0                     0.000000                 0.000000
# 1                     0.000000                 0.000000
# 2                     0.000000                 0.000000
# 3                     0.000000                 0.000000
# 4                     0.000000                 0.000000
# ...                        ...                      ...
# 12005                 0.000224                -0.001003
# 12006                 0.000224                -0.001003
# 12007                 0.000224                -0.001003
# 12008                 0.000224                -0.001002
# 12009                 0.000224                -0.001002
#
#        der(FltDynLongiSS.x[4])  ...  FltDynLongiSS.u_deltaE  \
# 0                     0.000000  ...                     0.0
# 1                     0.000000  ...                     0.0
# 2                     0.000000  ...                     0.0
# 3                     0.000000  ...                     0.0
# 4                     0.000000  ...                     0.0
# ...                        ...  ...                     ...
# 12005                 0.000280  ...                     0.0
# 12006                 0.000274  ...                     0.0
# 12007                 0.000268  ...                     0.0
# 12008                 0.000262  ...                     0.0
# 12009                 0.000262  ...                     0.0
#
#        FltDynLongiSS.u_deltaT  FltDynLongiSS.y_aX  FltDynLongiSS.y_aZ  \
# 0                           0            0.000000           -0.000000
# 1                           0            0.000000           -0.000000
# 2                           0            0.000000           -0.000000
# 3                           0            0.000000           -0.000000
# 4                           0            0.000000           -0.000000
# ...                       ...                 ...                 ...
# 12005                       0           -0.333023           -0.003743
# 12006                       0           -0.332976           -0.003352
# 12007                       0           -0.332928           -0.002961
# 12008                       0           -0.332881           -0.002570
# 12009                       0           -0.332881           -0.002570
#
#        from_deg1.y  gain_Tsteady.u  gain_Tsteady.y  integrator1.u  to_deg1.u  \
# 0              0.0               0               0       0.000000   0.000000
# 1              0.0               0               0       0.000000   0.000000
# 2              0.0               0               0       0.000000   0.000000
# 3              0.0               0               0       0.000000   0.000000
# 4              0.0               0               0       0.000000   0.000000
# ...            ...             ...             ...            ...        ...
# 12005          0.0               0               0       0.000280   0.000280
# 12006          0.0               0               0       0.000274   0.000274
# 12007          0.0               0               0       0.000268   0.000268
# 12008          0.0               0               0       0.000262   0.000262
# 12009          0.0               0               0       0.000262   0.000262
#
#        uSignal_deltaE.y
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 12005                 0
# 12006                 0
# 12007                 0
# 12008                 0
# 12009                 0
#
# [12010 rows x 306 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'FltDynLongiSS.x[1]',
#  'FltDynLongiSS.x[2]',
#  'FltDynLongiSS.x[3]',
#  'FltDynLongiSS.x[4]',
#  'integrator1.y',
#  'der(FltDynLongiSS.x[1])',
#  'der(FltDynLongiSS.x[2])',
#  'der(FltDynLongiSS.x[3])',
#  'der(FltDynLongiSS.x[4])',
#  'der(integrator1.y)',
#  'Flt2Fluid.AltMN2pTh.TambStd',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.u',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.h',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.u',
#  'Flt2Fluid.AltMN2pTh.fluidTot.MM',
#  'Flt2Fluid.AltMN2pTh.fluidTot.R',
#  'Flt2Fluid.AltMN2pTh.fluidTot.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidTot.d',
#  'Flt2Fluid.AltMN2pTh.fluidTot.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidTot.u',
#  'Flt2Fluid.AltMN2pTh.pAmbStd',
#  'Flt2Fluid.AltMN2pTh.y_Tamb',
#  'Flt2Fluid.AltMN2pTh.y_Ttot',
#  'Flt2Fluid.AltMN2pTh.y_hAmb',
#  'Flt2Fluid.AltMN2pTh.y_hTot',
#  'Flt2Fluid.AltMN2pTh.y_pAmb',
#  'Flt2Fluid.AltMN2pTh.y_pTot',
#  'Flt2Fluid.Vsound',
#  'Flt2Fluid.limiter2.y',
#  'Flt2Fluid.limiter4.y',
#  'Flt2Fluid.port_amb4sink.m_flow',
#  'Flt2Fluid.port_amb4source.m_flow',
#  'Flt2Fluid.port_total.m_flow',
#  'Flt2Fluid.s_fluid_amb4sink',
#  'Flt2Fluid.s_fluid_amb4source',
#  'Flt2Fluid.s_fluid_inlet',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.R',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.d',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.u',
#  'Flt2Fluid.sourceFluidAmb4sink.p_in',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidAmb4source.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4source.medium.R',
#  'Flt2Fluid.sourceFluidAmb4source.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4source.medium.d',
#  'Flt2Fluid.sourceFluidAmb4source.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4source.medium.u',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidTotal.medium.MM',
#  'Flt2Fluid.sourceFluidTotal.medium.R',
#  'Flt2Fluid.sourceFluidTotal.medium.T_degC',
#  'Flt2Fluid.sourceFluidTotal.medium.d',
#  'Flt2Fluid.sourceFluidTotal.medium.p_bar',
#  'Flt2Fluid.sourceFluidTotal.medium.u',
#  'Flt2Fluid.sourceFluidTotal.p_in',
#  'Flt2Fluid.sourceFluidTotal.ports[1].h_outflow',
#  'FltDynLongiSS.u[1]',
#  'FltDynLongiSS.u[2]',
#  'FltDynLongiSS.u_Iyy',
#  'FltDynLongiSS.u_S',
#  'FltDynLongiSS.u_U1',
#  'FltDynLongiSS.u_cBar',
#  'FltDynLongiSS.u_m',
#  'FltDynLongiSS.u_q1bar',
#  'FltDynLongiSS.y[1]',
#  'FltDynLongiSS.y[2]',
#  'FltDynLongiSS.y[3]',
#  'FltDynLongiSS.y[4]',
#  'FltDynLongiSS.y[5]',
#  'FltDynLongiSS.y[6]',
#  'FltDynLongiSS.y_alpha',
#  'FltDynLongiSS.y_q',
#  'FltDynLongiSS.y_theta',
#  'FltDynLongiSS.y_u',
#  'from_deg1.u',
#  'to_deg1.y',
#  'uSignal_deltaFracT.y',
#  'FltDynLongiSS.DerLongi.CTu',
#  'FltDynLongiSS.DerLongi.MTalpha',
#  'FltDynLongiSS.DerLongi.MTu',
#  'FltDynLongiSS.DerLongi.Malpha',
#  'FltDynLongiSS.DerLongi.Malpha_dot',
#  'FltDynLongiSS.DerLongi.MdeltaE',
#  'FltDynLongiSS.DerLongi.Mq',
#  'FltDynLongiSS.DerLongi.Mu',
#  'FltDynLongiSS.DerLongi.XTu',
#  'FltDynLongiSS.DerLongi.Xq_pri',
#  'FltDynLongiSS.DerLongi.Xu',
#  'FltDynLongiSS.DerLongi.Zalpha',
#  'FltDynLongiSS.DerLongi.Zalpha_dot',
#  'FltDynLongiSS.DerLongi.ZdeltaE',
#  'FltDynLongiSS.DerLongi.Zq',
#  'FltDynLongiSS.DerLongi.Zu',
#  'FltDynLongiSS.DerLongi.infoBusAircraft.Iyy',
#  'FltDynLongiSS.DerLongi.infoBusAircraft.S',
#  'FltDynLongiSS.DerLongi.infoBusAircraft.cBar',
#  'FltDynLongiSS.DerLongi.infoBusAircraft.m',
#  'FltDynLongiSS.DerLongi.infoBusDim.Malpha_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.MdeltaE_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Mq_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Mtheta_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Mu_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xalpha_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xalpha_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.XdeltaE_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.XdeltaE_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xq_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xq_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xtheta_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xtheta_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xu_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xu_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zalpha_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zalpha_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.ZdeltaE_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.ZdeltaE_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zq_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zq_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Ztheta_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Ztheta_pri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zu_ppri',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zu_pri',
#  'FltDynLongiSS.DerLongi.infoBusFlt.U1',
#  'FltDynLongiSS.DerLongi.infoBusFlt.alpha1',
#  'FltDynLongiSS.DerLongi.infoBusFlt.g',
#  'FltDynLongiSS.DerLongi.infoBusFlt.q1bar',
#  'FltDynLongiSS.DerLongi.infoBusFlt.theta1',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CD1',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CDalpha',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CDdeltaE',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CDu',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CL1',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CLalpha',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CLalpha_dot',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CLdeltaE',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CLq',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CLu',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CTX1',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CTXu',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.Cm1',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CmAlpha',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CmAlpha_dot',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CmDeltaE',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CmT1',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CmTalpha',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.CmTu',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.Cmq',
#  'FltDynLongiSS.DerLongi.infoBusNonDim.Cmu',
#  'Flt2Fluid.AltMN2pTh.Tamb',
#  'Flt2Fluid.AltMN2pTh.V_inf',
#  'Flt2Fluid.AltMN2pTh.Vsound',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.h',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.p',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.state.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.state.p',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.p',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.state.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.state.p',
#  'Flt2Fluid.AltMN2pTh.fluidTot.T',
#  'Flt2Fluid.AltMN2pTh.fluidTot.h',
#  'Flt2Fluid.AltMN2pTh.fluidTot.p',
#  'Flt2Fluid.AltMN2pTh.fluidTot.state.T',
#  'Flt2Fluid.AltMN2pTh.fluidTot.state.p',
#  'Flt2Fluid.AltMN2pTh.infoBus1.Vsound',
#  'Flt2Fluid.AltMN2pTh.pAmb',
#  'Flt2Fluid.AltMN2pTh.y_V_inf',
#  'Flt2Fluid.dynP',
#  'Flt2Fluid.infoBus1.Vsound',
#  'Flt2Fluid.limiter1.u',
#  'Flt2Fluid.limiter1.y',
#  'Flt2Fluid.limiter2.u',
#  'Flt2Fluid.limiter3.u',
#  'Flt2Fluid.limiter3.y',
#  'Flt2Fluid.limiter4.u',
#  'Flt2Fluid.port_amb4sink.h_outflow',
#  'Flt2Fluid.port_amb4sink.p',
#  'Flt2Fluid.port_amb4source.h_outflow',
#  'Flt2Fluid.port_amb4source.p',
#  'Flt2Fluid.port_total.h_outflow',
#  'Flt2Fluid.port_total.p',
#  'Flt2Fluid.sourceFluidAmb4sink.T_in',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.T',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.h',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.p',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.state.T',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.state.p',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].m_flow',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].p',
#  'Flt2Fluid.sourceFluidAmb4source.T_in',
#  'Flt2Fluid.sourceFluidAmb4source.medium.T',
#  'Flt2Fluid.sourceFluidAmb4source.medium.h',
#  'Flt2Fluid.sourceFluidAmb4source.medium.p',
#  'Flt2Fluid.sourceFluidAmb4source.medium.state.T',
#  'Flt2Fluid.sourceFluidAmb4source.medium.state.p',
#  'Flt2Fluid.sourceFluidAmb4source.p_in',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].m_flow',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].p',
#  'Flt2Fluid.sourceFluidTotal.T_in',
#  'Flt2Fluid.sourceFluidTotal.medium.T',
#  'Flt2Fluid.sourceFluidTotal.medium.h',
#  'Flt2Fluid.sourceFluidTotal.medium.p',
#  'Flt2Fluid.sourceFluidTotal.medium.state.T',
#  'Flt2Fluid.sourceFluidTotal.medium.state.p',
#  'Flt2Fluid.sourceFluidTotal.ports[1].m_flow',
#  'Flt2Fluid.sourceFluidTotal.ports[1].p',
#  'Flt2Fluid.y_V_inf',
#  'Flt2Fluid.y_qBar',
#  'FltDynLongiSS.DerLongi.CD1',
#  'FltDynLongiSS.DerLongi.CDalpha',
#  'FltDynLongiSS.DerLongi.CDdeltaE',
#  'FltDynLongiSS.DerLongi.CDu',
#  'FltDynLongiSS.DerLongi.CL1',
#  'FltDynLongiSS.DerLongi.CLalpha',
#  'FltDynLongiSS.DerLongi.CLalpha_dot',
#  'FltDynLongiSS.DerLongi.CLdeltaE',
#  'FltDynLongiSS.DerLongi.CLq',
#  'FltDynLongiSS.DerLongi.CLu',
#  'FltDynLongiSS.DerLongi.CTX1',
#  'FltDynLongiSS.DerLongi.CTXu',
#  'FltDynLongiSS.DerLongi.Cm1',
#  'FltDynLongiSS.DerLongi.CmAlpha',
#  'FltDynLongiSS.DerLongi.CmAlpha_dot',
#  'FltDynLongiSS.DerLongi.CmDeltaE',
#  'FltDynLongiSS.DerLongi.CmT1',
#  'FltDynLongiSS.DerLongi.CmTalpha',
#  'FltDynLongiSS.DerLongi.CmTu',
#  'FltDynLongiSS.DerLongi.Cmq',
#  'FltDynLongiSS.DerLongi.Cmu',
#  'FltDynLongiSS.DerLongi.Iyy',
#  'FltDynLongiSS.DerLongi.Malpha_pri',
#  'FltDynLongiSS.DerLongi.MdeltaE_pri',
#  'FltDynLongiSS.DerLongi.Mq_pri',
#  'FltDynLongiSS.DerLongi.Mtheta_pri',
#  'FltDynLongiSS.DerLongi.Mu_pri',
#  'FltDynLongiSS.DerLongi.S',
#  'FltDynLongiSS.DerLongi.U1',
#  'FltDynLongiSS.DerLongi.Xalpha',
#  'FltDynLongiSS.DerLongi.Xalpha_ppri',
#  'FltDynLongiSS.DerLongi.Xalpha_pri',
#  'FltDynLongiSS.DerLongi.XdeltaE',
#  'FltDynLongiSS.DerLongi.XdeltaE_ppri',
#  'FltDynLongiSS.DerLongi.XdeltaE_pri',
#  'FltDynLongiSS.DerLongi.Xq_ppri',
#  'FltDynLongiSS.DerLongi.Xtheta_ppri',
#  'FltDynLongiSS.DerLongi.Xtheta_pri',
#  'FltDynLongiSS.DerLongi.Xu_ppri',
#  'FltDynLongiSS.DerLongi.Xu_pri',
#  'FltDynLongiSS.DerLongi.Zalpha_dot_pri',
#  'FltDynLongiSS.DerLongi.Zalpha_ppri',
#  'FltDynLongiSS.DerLongi.Zalpha_pri',
#  'FltDynLongiSS.DerLongi.ZdeltaE_ppri',
#  'FltDynLongiSS.DerLongi.ZdeltaE_pri',
#  'FltDynLongiSS.DerLongi.Zq_ppri',
#  'FltDynLongiSS.DerLongi.Zq_pri',
#  'FltDynLongiSS.DerLongi.Ztheta_ppri',
#  'FltDynLongiSS.DerLongi.Ztheta_pri',
#  'FltDynLongiSS.DerLongi.Zu_ppri',
#  'FltDynLongiSS.DerLongi.Zu_pri',
#  'FltDynLongiSS.DerLongi.alpha1',
#  'FltDynLongiSS.DerLongi.cBar',
#  'FltDynLongiSS.DerLongi.g',
#  'FltDynLongiSS.DerLongi.infoBusDim.MTalpha',
#  'FltDynLongiSS.DerLongi.infoBusDim.MTu',
#  'FltDynLongiSS.DerLongi.infoBusDim.Malpha',
#  'FltDynLongiSS.DerLongi.infoBusDim.Malpha_dot',
#  'FltDynLongiSS.DerLongi.infoBusDim.MdeltaE',
#  'FltDynLongiSS.DerLongi.infoBusDim.Mq',
#  'FltDynLongiSS.DerLongi.infoBusDim.Mu',
#  'FltDynLongiSS.DerLongi.infoBusDim.XTu',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xalpha',
#  'FltDynLongiSS.DerLongi.infoBusDim.XdeltaE',
#  'FltDynLongiSS.DerLongi.infoBusDim.Xu',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zalpha',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zalpha_dot',
#  'FltDynLongiSS.DerLongi.infoBusDim.ZdeltaE',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zq',
#  'FltDynLongiSS.DerLongi.infoBusDim.Zu',
#  'FltDynLongiSS.DerLongi.m',
#  'FltDynLongiSS.DerLongi.q1bar',
#  'FltDynLongiSS.DerLongi.theta1',
#  'FltDynLongiSS.u_deltaE',
#  'FltDynLongiSS.u_deltaT',
#  'FltDynLongiSS.y_aX',
#  'FltDynLongiSS.y_aZ',
#  'from_deg1.y',
#  'gain_Tsteady.u',
#  'gain_Tsteady.y',
#  'integrator1.u',
#  'to_deg1.u',
#  'uSignal_deltaE.y']

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=3


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
# i_df=2
# data read: C:\Users\grabacr\OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res_2.csv
# i_df=3
# data read: C:\Users\grabacr\OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res_3.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: C:\Users\grabacr\OMPythonWork
# ------------------------------
#
# data read: C:\Users\grabacr\OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LongitudinalLTISS00_ex02_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
#              time  FltDynLongiSS.x[1]  FltDynLongiSS.x[2]  FltDynLongiSS.x[3]  \
# 0        0.000000            0.000000            0.000000            0.000000
# 1        0.005833            0.000000            0.000000            0.000000
# 2        0.011667            0.000000            0.000000            0.000000
# 3        0.017500            0.000000            0.000000            0.000000
# 4        0.023334            0.000000            0.000000            0.000000
# ...           ...                 ...                 ...                 ...
# 25719  149.982500           -0.393254            0.000249           -0.001096
# 25720  149.988333           -0.393487            0.000249           -0.001097
# 25721  149.994167           -0.393719            0.000249           -0.001098
# 25722  150.000000           -0.393951            0.000249           -0.001099
# 25723  150.000000           -0.393951            0.000249           -0.001099
#
#        FltDynLongiSS.x[4]  integrator1.y  der(FltDynLongiSS.x[1])  \
# 0                0.000000       0.000000                 0.000000
# 1                0.000000       0.000000                 0.000000
# 2                0.000000       0.000000                 0.000000
# 3                0.000000       0.000000                 0.000000
# 4                0.000000       0.000000                 0.000000
# ...                   ...            ...                      ...
# 25719            0.006079       0.006079                -0.039950
# 25720            0.006073       0.006073                -0.039875
# 25721            0.006067       0.006067                -0.039801
# 25722            0.006060       0.006060                -0.039727
# 25723            0.006060       0.006060                -0.039727
#
#        der(FltDynLongiSS.x[2])  der(FltDynLongiSS.x[3])  \
# 0                      0.00000                 0.000000
# 1                      0.00000                 0.000000
# 2                      0.00000                 0.000000
# 3                      0.00000                 0.000000
# 4                      0.00000                 0.000000
# ...                        ...                      ...
# 25719                  0.00003                -0.000133
# 25720                  0.00003                -0.000132
# 25721                  0.00003                -0.000132
# 25722                  0.00003                -0.000132
# 25723                  0.00003                -0.000132
#
#        der(FltDynLongiSS.x[4])  ...  FltDynLongiSS.u_deltaE  \
# 0                     0.000000  ...                     0.0
# 1                     0.000000  ...                     0.0
# 2                     0.000000  ...                     0.0
# 3                     0.000000  ...                     0.0
# 4                     0.000000  ...                     0.0
# ...                        ...  ...                     ...
# 25719                -0.001096  ...                     0.0
# 25720                -0.001097  ...                     0.0
# 25721                -0.001098  ...                     0.0
# 25722                -0.001099  ...                     0.0
# 25723                -0.001099  ...                     0.0
#
#        FltDynLongiSS.u_deltaT  FltDynLongiSS.y_aX  FltDynLongiSS.y_aZ  \
# 0                           0            0.000000           -0.000000
# 1                           0            0.000000           -0.000000
# 2                           0            0.000000           -0.000000
# 3                           0            0.000000           -0.000000
# 4                           0            0.000000           -0.000000
# ...                       ...                 ...                 ...
# 25719                       0           -0.046383            0.075854
# 25720                       0           -0.046313            0.075904
# 25721                       0           -0.046243            0.075954
# 25722                       0           -0.046174            0.076004
# 25723                       0           -0.046174            0.076004
#
#        from_deg1.y  gain_Tsteady.u  gain_Tsteady.y  integrator1.u  to_deg1.u  \
# 0              0.0               0               0       0.000000   0.000000
# 1              0.0               0               0       0.000000   0.000000
# 2              0.0               0               0       0.000000   0.000000
# 3              0.0               0               0       0.000000   0.000000
# 4              0.0               0               0       0.000000   0.000000
# ...            ...             ...             ...            ...        ...
# 25719          0.0               0               0      -0.001096  -0.001096
# 25720          0.0               0               0      -0.001097  -0.001097
# 25721          0.0               0               0      -0.001098  -0.001098
# 25722          0.0               0               0      -0.001099  -0.001099
# 25723          0.0               0               0      -0.001099  -0.001099
#
#        uSignal_deltaE.y
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 25719                 0
# 25720                 0
# 25721                 0
# 25722                 0
# 25723                 0
#
# [25724 rows x 306 columns]

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
i_df=1
varName="FltDynLongiSS.u_deltaE"
ylabel='delta Elevator angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=1
varName="FltDynLongiSS.y_u"
ylabel='Velocity [m/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(50, 80)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLongiSS.x[1])"
ylabel='Acceleration [m/s2]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(u)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-1.5, 1.5)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLongiSS.y_theta"
ylabel='Angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(-2.0, 16.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLongiSS.y_q"
ylabel='Anguler Velocity [deg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(-15.0, 15.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLongiSS.x[3])"
ylabel='Anguler Acceleration [deg/s2]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(q)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-150.0, 150.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLongiSS.y_alpha"
ylabel='Angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(0.0, 10.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLongiSS.x[2])"
ylabel='Anguler Velocity [deg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(alpha)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-15.0, 15.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: C:\Users\grabacr\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------
