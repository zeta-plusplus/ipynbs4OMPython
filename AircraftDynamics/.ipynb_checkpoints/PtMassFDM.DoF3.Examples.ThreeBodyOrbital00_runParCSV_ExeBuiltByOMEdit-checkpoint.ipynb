# %% [markdown]
# <h1>Run ExeBuiltByOMEdit, multi case, multiple parameter defined by CSV Table file: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00</h1>
# <h2>notebook: rev 001</h2>
# <p>compatability with OpenModelica v1.21.0</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML

backslash= '\\'
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'
swWorkSubDir= 'fullpathModel'
'''
'None': 
'fullPathModel': work in sub dir named with fullaPathModel
'''

libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00'
nmModel='ThreeBodyOrbital00'
stopTime=3600.0
outputFormat='csv'

#****************************************
#    User must NOT edit code below 
#****************************************
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
if(swWorkSubDir=='fullpathModel'):
    dirWorkRelToHome= dirWorkRelToHome + '/' + fullpathModel
##### end if #####

print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirHome= dirHome.replace(backslash, '/')
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')

print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF3/Examples/ThreeBodyOrbital00.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...copy parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (nmModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00")
# OMShell: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...copy parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_org.xml")
# OMShell: 0
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Multiple parameter sweep, Org case </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunOrg=0

startTime=0
stopTime=800000
stepSize=50.0

#********** parameters to set fixed for parameter sweep run **********
param2set=[
    'r3_init[1]',
    'r3_init[2]',
    'r3_init[3]',
    'v3_init[1]',
    'v3_init[2]',
    'v3_init[3]',
    'phi_r2_deg_init',
]

value2set=[
    (-1.0)*(6378.137+400.0)*10.0**3.0,
    0.0,
    0.0,
    0.0,
    -10780,
    0.0,
    -43.0,
]

#****************************************
#    User must NOT edit code below 
#****************************************
iRun=iRunOrg
#----------
numberOfIntervals=int((stopTime-startTime)/stepSize)
print('numberOfIntervals of simulation='+str(numberOfIntervals))
print('')

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=nmModel+'_init_parSweepOrg'+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init_org.xml') +' '+ (nmModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2set)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+param2set[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(nmModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
print("***** Org case of multiple parameter sweep *****")
if(os.name=='nt'):
    strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv'  +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# numberOfIntervals of simulation=16000
#
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# iRun=0
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init_org.xml ThreeBodyOrbital00_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10780", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_parSweepOrg.xml")
# OMShell: 0
#
# ...running simulation, wait...
# ***** Org case of multiple parameter sweep *****
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_0.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h2>Read Parameters CSV Table</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
nameParameterTableCSV="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_2.csv"
swDir="ipynbs"
'''
'ipynbs': csv is in the save directory as this ipynbs
'workDir': csv is in the same directory as working dir
'''
if(swDir=='workDir'):
    fullPathCSV= nameParameterTableCSV
elif(swDir=='ipynbs'):
    fullPathCSV= pathNotebook+'/'+nameParameterTableCSV
#***** end if *****


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')
#----------

print("Reading CSV...")
print(fullPathCSV)
df_parameter = pd.read_csv(fullPathCSV, index_col=0, header=0)

print(''); 
print("Parameter Table read:")
print(df_parameter)
print('------------------------------')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# Reading CSV...
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_2.csv
#
# Parameter Table read:
#                      1024      1025      1026      1027      1028      1029  \
# swExec                Not       Not       Not       Not       Not       Not
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10783    -10783    -10783    -10783    -10783    -10783
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -35     -35.5       -36     -36.5       -37     -37.5
#
#                      1030      1031      1032      1033  ...      1262  \
# swExec                Not       Not       Not       Not  ...      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  ...  -6778137
# r3_init[2]              0         0         0         0  ...         0
# r3_init[3]              0         0         0         0  ...         0
# v3_init[1]              0         0         0         0  ...         0
# v3_init[2]         -10783    -10783    -10783    -10783  ...    -10790
# v3_init[3]              0         0         0         0  ...         0
# phi_r2_deg_init       -38     -38.5       -39     -39.5  ...     -45.5
#
#                      1263      1264      1265      1266      1267      1268  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10790    -10790    -10790    -10790    -10790    -10790
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -46     -46.5       -47     -47.5       -48     -48.5
#
#                      1269      1270      1271
# swExec               Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137
# r3_init[2]              0         0         0
# r3_init[3]              0         0         0
# v3_init[1]              0         0         0
# v3_init[2]         -10790    -10790    -10790
# v3_init[3]              0         0         0
# phi_r2_deg_init       -49     -49.5       -50
#
# [8 rows x 248 columns]
# ------------------------------
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Sweep cases defined by CSV</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
startTime=0
stopTime=800000
stepSize=50.0


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

print('...multi-case calculation: generating parameter setting xml fils...')
print('    Cases: '+ str(len(df_parameter.columns)))
print('    Parameters set: '+ str(len(df_parameter.index)-1))
print('')
for j in range(len(df_parameter.columns)):
    print('case='+str(df_parameter.columns[j])+', '+'swExec='+str(df_parameter.iloc[0,j]))
    if(df_parameter.iloc[0,j]=='Exec'):
        print('generating parameter setting xml fils...')
        #-- copy _init_org file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_parSweepOrg.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        for i in range(1, len(df_parameter.index)):
            #----------
            #-- overwrite parameter setting xml file
            print('i='+str(i))
            strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+df_parameter.index[i]+'", ' + '"'+str(df_parameter.iloc[i,j])+'", '+ '"'+(nmModel+'_init.xml')+'")'
            print('send: '+strcmd)
            msgOMShell=omc.sendExpression(strcmd)
            print("OMShell: "+ str(msgOMShell))
        ##### end for #####

        #-- save parameter setting file after overwriting
        print(''); print('...Saving parameter setting file...')
        filenameXmlNew=nmModel+'_init_'+str(df_parameter.columns[j])+'.xml'
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
        
        print(''); print('---- run simulation ----')
        #-- call _init.xml file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_'+str(df_parameter.columns[j])+'.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        
        #-- run
        if(os.name=='nt'):
            strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv' +'")'
        elif(os.name=='posix'):
            strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv'  +'")'
        ##### end if #####
        
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
    #***** end if *****
    
    print('-----');
    print('');
    print('');
##### end for #####
print('---------------------------------------------------------------------------')
print('...simulation run completed.')
print('');

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# ...multi-case calculation: generating parameter setting xml fils...
#     Cases: 248
#     Parameters set: 7
#
# case=1024, swExec=Not
# -----
#
#
# case=1025, swExec=Not
# -----
#
#
# case=1026, swExec=Not
# -----
#
#
# case=1027, swExec=Not
# -----
#
#
# case=1028, swExec=Not
# -----
#
#
# case=1029, swExec=Not
# -----
#
#
# case=1030, swExec=Not
# -----
#
#
# case=1031, swExec=Not
# -----
#
#
# case=1032, swExec=Not
# -----
#
#
# case=1033, swExec=Not
# -----
#
#
# case=1034, swExec=Not
# -----
#
#
# case=1035, swExec=Not
# -----
#
#
# case=1036, swExec=Not
# -----
#
#
# case=1037, swExec=Not
# -----
#
#
# case=1038, swExec=Not
# -----
#
#
# case=1039, swExec=Not
# -----
#
#
# case=1040, swExec=Not
# -----
#
#
# case=1041, swExec=Not
# -----
#
#
# case=1042, swExec=Not
# -----
#
#
# case=1043, swExec=Not
# -----
#
#
# case=1044, swExec=Not
# -----
#
#
# case=1045, swExec=Not
# -----
#
#
# case=1046, swExec=Not
# -----
#
#
# case=1047, swExec=Not
# -----
#
#
# case=1048, swExec=Not
# -----
#
#
# case=1049, swExec=Not
# -----
#
#
# case=1050, swExec=Not
# -----
#
#
# case=1051, swExec=Not
# -----
#
#
# case=1052, swExec=Not
# -----
#
#
# case=1053, swExec=Not
# -----
#
#
# case=1054, swExec=Not
# -----
#
#
# case=1055, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1055.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1055.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1055.csv")
# OMShell: 0
# -----
#
#
# case=1056, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1056.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1056.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1056.csv")
# OMShell: 0
# -----
#
#
# case=1057, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1057.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1057.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1057.csv")
# OMShell: 0
# -----
#
#
# case=1058, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1058.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1058.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1058.csv")
# OMShell: 0
# -----
#
#
# case=1059, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1059.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1059.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1059.csv")
# OMShell: 0
# -----
#
#
# case=1060, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1060.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1060.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1060.csv")
# OMShell: 0
# -----
#
#
# case=1061, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1061.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1061.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1061.csv")
# OMShell: 0
# -----
#
#
# case=1062, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1062.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1062.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1062.csv")
# OMShell: 0
# -----
#
#
# case=1063, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1063.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1063.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1063.csv")
# OMShell: 0
# -----
#
#
# case=1064, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1064.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1064.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1064.csv")
# OMShell: 0
# -----
#
#
# case=1065, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1065.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1065.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1065.csv")
# OMShell: 0
# -----
#
#
# case=1066, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1066.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1066.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1066.csv")
# OMShell: 0
# -----
#
#
# case=1067, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1067.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1067.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1067.csv")
# OMShell: 0
# -----
#
#
# case=1068, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1068.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1068.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1068.csv")
# OMShell: 0
# -----
#
#
# case=1069, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1069.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1069.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1069.csv")
# OMShell: 0
# -----
#
#
# case=1070, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1070.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1070.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1070.csv")
# OMShell: 0
# -----
#
#
# case=1071, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1071.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1071.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1071.csv")
# OMShell: 0
# -----
#
#
# case=1072, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1072.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1072.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1072.csv")
# OMShell: 0
# -----
#
#
# case=1073, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1073.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1073.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1073.csv")
# OMShell: 0
# -----
#
#
# case=1074, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1074.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1074.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1074.csv")
# OMShell: 0
# -----
#
#
# case=1075, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1075.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1075.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1075.csv")
# OMShell: 249
# -----
#
#
# case=1076, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1076.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1076.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1076.csv")
# OMShell: 0
# -----
#
#
# case=1077, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1077.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1077.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1077.csv")
# OMShell: 0
# -----
#
#
# case=1078, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1078.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1078.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1078.csv")
# OMShell: 0
# -----
#
#
# case=1079, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1079.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1079.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1079.csv")
# OMShell: 0
# -----
#
#
# case=1080, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1080.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1080.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1080.csv")
# OMShell: 0
# -----
#
#
# case=1081, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-48", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1081.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1081.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1081.csv")
# OMShell: 0
# -----
#
#
# case=1082, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-48.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1082.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1082.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1082.csv")
# OMShell: 0
# -----
#
#
# case=1083, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-49", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1083.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1083.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1083.csv")
# OMShell: 0
# -----
#
#
# case=1084, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-49.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1084.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1084.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1084.csv")
# OMShell: 0
# -----
#
#
# case=1085, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10784", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-50", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1085.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1085.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1085.csv")
# OMShell: 0
# -----
#
#
# case=1086, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10785", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1086.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1086.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1086.csv")
# OMShell: 0
# -----
#
#
# case=1087, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10785", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# ...
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1261.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1261.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1261.csv")
# OMShell: 0
# -----
#
#
# case=1262, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1262.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1262.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1262.csv")
# OMShell: 0
# -----
#
#
# case=1263, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1263.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1263.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1263.csv")
# OMShell: 0
# -----
#
#
# case=1264, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1264.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1264.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1264.csv")
# OMShell: 0
# -----
#
#
# case=1265, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1265.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1265.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1265.csv")
# OMShell: 0
# -----
#
#
# case=1266, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1266.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1266.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1266.csv")
# OMShell: 0
# -----
#
#
# case=1267, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-48", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1267.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1267.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1267.csv")
# OMShell: 0
# -----
#
#
# case=1268, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-48.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1268.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1268.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1268.csv")
# OMShell: 0
# -----
#
#
# case=1269, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-49", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1269.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1269.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1269.csv")
# OMShell: 0
# -----
#
#
# case=1270, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-49.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1270.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1270.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1270.csv")
# OMShell: 0
# -----
#
#
# case=1271, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10790", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-50", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_1271.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_1271.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_1271.csv")
# OMShell: 0
# -----
#
#
# ---------------------------------------------------------------------------
# ...simulation run completed.
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
