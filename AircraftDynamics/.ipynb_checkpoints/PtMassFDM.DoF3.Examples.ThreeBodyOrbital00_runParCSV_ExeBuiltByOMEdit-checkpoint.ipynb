# %% [markdown]
# <h1>Run ExeBuiltByOMEdit, multi case, multiple parameter defined by CSV Table file: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00</h1>
# <h2>notebook: rev 001</h2>
# <p>compatability with OpenModelica v1.21.0</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML

backslash= '\\'
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'
swWorkSubDir= 'fullpathModel'
'''
'None': 
'fullPathModel': work in sub dir named with fullaPathModel
'''

libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00'
nmModel='ThreeBodyOrbital00'
stopTime=3600.0
outputFormat='csv'

#****************************************
#    User must NOT edit code below 
#****************************************
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
if(swWorkSubDir=='fullpathModel'):
    dirWorkRelToHome= dirWorkRelToHome + '/' + fullpathModel
##### end if #####

print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirHome= dirHome.replace(backslash, '/')
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')

print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF3/Examples/ThreeBodyOrbital00.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...copy parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (nmModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00")
# OMShell: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...copy parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_org.xml")
# OMShell: 0
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Multiple parameter sweep, Org case </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunOrg=0

startTime=0
stopTime=800000
stepSize=50.0

#********** parameters to set fixed for parameter sweep run **********
param2set=[
    'r3_init[1]',
    'r3_init[2]',
    'r3_init[3]',
    'v3_init[1]',
    'v3_init[2]',
    'v3_init[3]',
    'phi_r2_deg_init',
]

value2set=[
    (-1.0)*(6378.137+400.0)*10.0**3.0,
    0.0,
    0.0,
    0.0,
    -10780,
    0.0,
    -43.0,
]

#****************************************
#    User must NOT edit code below 
#****************************************
iRun=iRunOrg
#----------
numberOfIntervals=int((stopTime-startTime)/stepSize)
print('numberOfIntervals of simulation='+str(numberOfIntervals))
print('')

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=nmModel+'_init_parSweepOrg'+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init_org.xml') +' '+ (nmModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2set)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+param2set[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(nmModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
print("***** Org case of multiple parameter sweep *****")
if(os.name=='nt'):
    strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv'  +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# numberOfIntervals of simulation=16000
#
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# iRun=0
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init_org.xml ThreeBodyOrbital00_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10780", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_parSweepOrg.xml")
# OMShell: 0
#
# ...running simulation, wait...
# ***** Org case of multiple parameter sweep *****
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_0.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h2>Read Parameters CSV Table</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
nameParameterTableCSV="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_5.csv"
swDir="ipynbs"
'''
'ipynbs': csv is in the save directory as this ipynbs
'workDir': csv is in the same directory as working dir
'''
if(swDir=='workDir'):
    fullPathCSV= nameParameterTableCSV
elif(swDir=='ipynbs'):
    fullPathCSV= pathNotebook+'/'+nameParameterTableCSV
#***** end if *****


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')
#----------

print("Reading CSV...")
print(fullPathCSV)
df_parameter = pd.read_csv(fullPathCSV, index_col=0, header=0)

print(''); 
print("Parameter Table read:")
print(df_parameter)
print('------------------------------')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# Reading CSV...
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_5.csv
#
# Parameter Table read:
#                      3253      3254      3255      3256      3257      3258  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10739    -10739    -10739    -10739    -10739    -10739
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -35     -35.5       -36     -36.5       -37     -37.5
#
#                      3259      3260      3261      3262  ...      3953  \
# swExec               Exec      Exec      Exec      Exec  ...      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  ...  -6778137
# r3_init[2]              0         0         0         0  ...         0
# r3_init[3]              0         0         0         0  ...         0
# v3_init[1]              0         0         0         0  ...         0
# v3_init[2]         -10739    -10739    -10739    -10739  ...    -10730
# v3_init[3]              0         0         0         0  ...         0
# phi_r2_deg_init       -38     -38.5       -39     -39.5  ...     -65.5
#
#                      3954      3955      3956      3957      3958      3959  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10730    -10730    -10730    -10730    -10730    -10730
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -66     -66.5       -67     -67.5       -68     -68.5
#
#                      3960      3961      3962
# swExec               Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137
# r3_init[2]              0         0         0
# r3_init[3]              0         0         0
# v3_init[1]              0         0         0
# v3_init[2]         -10730    -10730    -10730
# v3_init[3]              0         0         0
# phi_r2_deg_init       -69     -69.5       -70
#
# [8 rows x 710 columns]
# ------------------------------
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Sweep cases defined by CSV</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
startTime=0
stopTime=800000
stepSize=50.0


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

print('...multi-case calculation: generating parameter setting xml fils...')
print('    Cases: '+ str(len(df_parameter.columns)))
print('    Parameters set: '+ str(len(df_parameter.index)-1))
print('')
for j in range(len(df_parameter.columns)):
    print('case='+str(df_parameter.columns[j])+', '+'swExec='+str(df_parameter.iloc[0,j]))
    if(df_parameter.iloc[0,j]=='Exec'):
        print('generating parameter setting xml fils...')
        #-- copy _init_org file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_parSweepOrg.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        for i in range(1, len(df_parameter.index)):
            #----------
            #-- overwrite parameter setting xml file
            print('i='+str(i))
            strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+df_parameter.index[i]+'", ' + '"'+str(df_parameter.iloc[i,j])+'", '+ '"'+(nmModel+'_init.xml')+'")'
            print('send: '+strcmd)
            msgOMShell=omc.sendExpression(strcmd)
            print("OMShell: "+ str(msgOMShell))
        ##### end for #####

        #-- save parameter setting file after overwriting
        print(''); print('...Saving parameter setting file...')
        filenameXmlNew=nmModel+'_init_'+str(df_parameter.columns[j])+'.xml'
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
        
        print(''); print('---- run simulation ----')
        #-- call _init.xml file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_'+str(df_parameter.columns[j])+'.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        
        #-- run
        if(os.name=='nt'):
            strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv' +'")'
        elif(os.name=='posix'):
            strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv'  +'")'
        ##### end if #####
        
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
    #***** end if *****
    
    print('-----');
    print('');
    print('');
##### end for #####
print('---------------------------------------------------------------------------')
print('...simulation run completed.')
print('');

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# ...multi-case calculation: generating parameter setting xml fils...
#     Cases: 710
#     Parameters set: 7
#
# case=2543, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2543.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2543.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2543.csv")
# OMShell: 0
# -----
#
#
# case=2544, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2544.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2544.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2544.csv")
# OMShell: 0
# -----
#
#
# case=2545, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2545.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2545.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2545.csv")
# OMShell: 0
# -----
#
#
# case=2546, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2546.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2546.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2546.csv")
# OMShell: 0
# -----
#
#
# case=2547, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2547.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2547.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2547.csv")
# OMShell: 0
# -----
#
#
# case=2548, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2548.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2548.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2548.csv")
# OMShell: 0
# -----
#
#
# case=2549, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2549.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2549.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2549.csv")
# OMShell: 0
# -----
#
#
# case=2550, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2550.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2550.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2550.csv")
# OMShell: 0
# -----
#
#
# case=2551, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2551.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2551.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2551.csv")
# OMShell: 0
# -----
#
#
# case=2552, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2552.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2552.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2552.csv")
# OMShell: 0
# -----
#
#
# case=2553, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2553.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2553.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2553.csv")
# OMShell: 0
# -----
#
#
# case=2554, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2554.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2554.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2554.csv")
# OMShell: 0
# -----
#
#
# case=2555, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2555.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2555.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2555.csv")
# OMShell: 0
# -----
#
#
# case=2556, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2556.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2556.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2556.csv")
# OMShell: 0
# -----
#
#
# case=2557, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2557.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2557.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2557.csv")
# OMShell: 0
# -----
#
#
# case=2558, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2558.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2558.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2558.csv")
# OMShell: 0
# -----
#
#
# case=2559, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2559.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2559.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2559.csv")
# OMShell: 0
# -----
#
#
# case=2560, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2560.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2560.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2560.csv")
# OMShell: 0
# -----
#
#
# case=2561, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2561.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2561.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2561.csv")
# OMShell: 0
# -----
#
#
# case=2562, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2562.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2562.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2562.csv")
# OMShell: 0
# -----
#
#
# case=2563, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2563.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2563.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2563.csv")
# OMShell: 0
# -----
#
#
# case=2564, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2564.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2564.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2564.csv")
# OMShell: 0
# -----
#
#
# case=2565, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2565.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2565.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2565.csv")
# OMShell: 0
# -----
#
#
# case=2566, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2566.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2566.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2566.csv")
# OMShell: 0
# -----
#
#
# case=2567, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2567.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2567.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2567.csv")
# OMShell: 0
# -----
#
#
# case=2568, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2568.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2568.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2568.csv")
# OMShell: 0
# -----
#
#
# case=2569, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-48", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2569.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2569.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2569.csv")
# OMShell: 0
# -----
#
#
# case=2570, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-48.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2570.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2570.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2570.csv")
# OMShell: 0
# -----
#
#
# case=2571, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-49", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2571.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2571.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2571.csv")
# OMShell: 0
# -----
#
#
# case=2572, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-49.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2572.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2572.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2572.csv")
# OMShell: 0
# -----
#
#
# case=2573, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-50", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2573.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2573.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2573.csv")
# OMShell: 0
# -----
#
#
# case=2574, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-50.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2574.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2574.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2574.csv")
# OMShell: 0
# -----
#
#
# case=2575, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10749", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-51", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_2575.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_2575.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_2575.csv")
# OMShell: 0
# -----
#
#
# case=2576, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# ...
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-65", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3242.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3242.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3242.csv")
# OMShell: 0
# -----
#
#
# case=3243, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-65.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3243.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3243.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3243.csv")
# OMShell: 0
# -----
#
#
# case=3244, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-66", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3244.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3244.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3244.csv")
# OMShell: 0
# -----
#
#
# case=3245, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-66.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3245.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3245.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3245.csv")
# OMShell: 0
# -----
#
#
# case=3246, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-67", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3246.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3246.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3246.csv")
# OMShell: 0
# -----
#
#
# case=3247, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-67.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3247.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3247.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3247.csv")
# OMShell: 0
# -----
#
#
# case=3248, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-68", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3248.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3248.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3248.csv")
# OMShell: 0
# -----
#
#
# case=3249, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-68.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3249.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3249.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3249.csv")
# OMShell: 0
# -----
#
#
# case=3250, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-69", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3250.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3250.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3250.csv")
# OMShell: 0
# -----
#
#
# case=3251, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-69.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3251.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3251.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3251.csv")
# OMShell: 0
# -----
#
#
# case=3252, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10740", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-70", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3252.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3252.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3252.csv")
# OMShell: 0
# -----
#
#
# ---------------------------------------------------------------------------
# ...simulation run completed.
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
