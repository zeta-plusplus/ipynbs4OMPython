# %% [markdown]
# <h1>AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02</h1>
# <p>rev001</p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib
import math

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Use settings</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02'
nmModel='LateralLTISS00_ex02'
stopTime=70.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/RigidBodyFDM/Examples/sampleAircrafts/LateralLTISS00_ex02.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- load Modelica Standard Library
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Building Model</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
print(''); print('...moving OMshell to temporary working directry')
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#-- build the model
print(''); print('...building the model, wait...')
strcmd= 'buildModel(' + fullpathModel + ', stopTime='+str(stopTime) + ', outputFormat="csv"' + ')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

errMsg= omc.sendExpression('getErrorString(True)')
print('')
print('OMShell error message: ')
print(str(errMsg))

print('...model build finished.')

#-- save original parameter setting file
print(''); print('...Saving original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (fullpathModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# ...moving OMshell to temporary working directry
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Examples/Output/dispVarPyConsole02_00_ex01.mo:17:104-17:108:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Examples/Output/dispVarPyConsole02_00_ex01.mo:17:104-17:122:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Output/dispVarPyConsole02_00.mo:18:37-18:41:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Output/dispVarPyConsole02_00.mo:18:37-18:55:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
#
#
#
# ...building the model, wait...
# send: buildModel(AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02, stopTime=70.0, outputFormat="csv")
# OMShell: ('/home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02', 'AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml')
#
# OMShell error message:
# Warning: The model contains alias variables with redundant start and/or conflicting nominal values. It is recommended to resolve the conflicts, because otherwise the system could be hard to solve. To print the conflicting alias sets and the chosen candidates please use -d=aliasConflicts.
#
# ...model build finished.
#
# ...Saving original parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_org.xml")
# OMShell: 0
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Print source code of model built</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

strcmd= 'list('+fullpathModel+')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print('source code of model build:')
print('')
print(str(msgOMShell)); 

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: list(AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02)
# source code of model build:
#
# model LateralLTISS00_ex02
#   extends Modelica.Icons.Example;
#   //-----
#   //package surrFluid = Modelica.Media.Air.DryAirNasa;
#   package surrFluid = AircraftDynamics.Media.DryAirMethaneMixture00;
#   //redeclare package Medium = surrFluid
#   //-----
#   Modelica.Blocks.Math.UnitConversions.From_deg from_deg1 annotation(
#     Placement(visible = true, transformation(origin = {-50, 0}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Constant const_S(k = 16.165129) annotation(
#     Placement(visible = true, transformation(origin = {-50, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Blocks.Sources.Constant const_m(k = 1202.01978) annotation(
#     Placement(visible = true, transformation(origin = {-20, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Blocks.Sources.Constant const_Ixx(k = 1285.3154166) annotation(
#     Placement(visible = true, transformation(origin = {40, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Blocks.Sources.Constant const_b(k = 10.9728) annotation(
#     Placement(visible = true, transformation(origin = {10, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   AircraftDynamics.Sources.FlightCondition2Fluid00 Flt2Fluid(redeclare package Medium = surrFluid, MN_paramInput = 0.201, alt_paramInput = 1524) annotation(
#     Placement(visible = true, transformation(origin = {-70, 60}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   inner AircraftDynamics.SimEnvironment environmentAircraftDynSim annotation(
#     Placement(visible = true, transformation(origin = {-90, 90}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Math.UnitConversions.To_deg to_deg_p annotation(
#     Placement(visible = true, transformation(origin = {90, 10}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.RealExpression uSignal_deltaA(y = if time <= 2 then 0 elseif 2 <= time and time <= 3 then 0
#    elseif 22 <= time and time <= 23 then 0
#    elseif 31 <= time then 0 else 0) annotation(
#     Placement(visible = true, transformation(origin = {-90, 0}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.RealExpression uSignal_deltaR(y = if time <= 2 then 0 elseif 2 <= time and time <= 3 then -6
#    elseif 22 <= time and time <= 23 then 6
#    elseif 31 <= time then 0 else 0) annotation(
#     Placement(visible = true, transformation(origin = {-90, -40}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Math.UnitConversions.From_deg from_deg2 annotation(
#     Placement(visible = true, transformation(origin = {-50, -40}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   AircraftDynamics.RigidBodyFDM.Components.LateralLTISS00 FltDynLateralSS(use_u_Ixx = true, use_u_Ixz = true, use_u_Izz = true, use_u_S = true, use_u_U1 = true, use_u_b = true, use_u_m = true, use_u_q1bar = true) annotation(
#     Placement(visible = true, transformation(origin = {29.5714, -2.99996}, extent = {{-29.5714, -23}, {29.5714, 23}}, rotation = 0)));
#   Modelica.Blocks.Math.UnitConversions.To_deg to_deg_r annotation(
#     Placement(visible = true, transformation(origin = {90, -20}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Constant const_Izz(k = 2666.89390765) annotation(
#     Placement(visible = true, transformation(origin = {70, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Blocks.Sources.Constant const_Ixz(k = 0) annotation(
#     Placement(visible = true, transformation(origin = {100, 110}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
# equation
#   connect(Flt2Fluid.y_qBar, FltDynLateralSS.u_q1bar) annotation(
#     Line(points = {{-58, 52}, {-30, 52}, {-30, 7}, {-2, 7}}, color = {0, 0, 127}));
#   connect(Flt2Fluid.y_V_inf, FltDynLateralSS.u_U1) annotation(
#     Line(points = {{-58, 56}, {-14, 56}, {-14, 15}, {-2, 15}}, color = {0, 0, 127}));
#   connect(from_deg2.y, FltDynLateralSS.u_deltaR) annotation(
#     Line(points = {{-39, -40}, {-15, -40}, {-15, -15}, {-2, -15}}, color = {0, 0, 127}));
#   connect(const_S.y, FltDynLateralSS.u_S) annotation(
#     Line(points = {{-50, 99}, {-50, 68}, {6, 68}, {6, 22}}, color = {0, 0, 127}));
#   connect(const_m.y, FltDynLateralSS.u_m) annotation(
#     Line(points = {{-20, 99}, {-20, 72}, {14, 72}, {14, 22}}, color = {0, 0, 127}));
#   connect(const_b.y, FltDynLateralSS.u_b) annotation(
#     Line(points = {{10, 99}, {10, 76}, {22, 76}, {22, 22}}, color = {0, 0, 127}));
#   connect(const_Ixx.y, FltDynLateralSS.u_Ixx) annotation(
#     Line(points = {{40, 100}, {40, 76}, {30, 76}, {30, 22}}, color = {0, 0, 127}));
#   connect(const_Izz.y, FltDynLateralSS.u_Izz) annotation(
#     Line(points = {{70, 100}, {70, 70}, {37, 70}, {37, 22}}, color = {0, 0, 127}));
#   connect(const_Ixz.y, FltDynLateralSS.u_Ixz) annotation(
#     Line(points = {{100, 100}, {100, 50}, {45, 50}, {45, 22}}, color = {0, 0, 127}));
#   connect(FltDynLateralSS.y_r, to_deg_r.u) annotation(
#     Line(points = {{61, 3}, {69.6667, 3}, {69.6667, -19.9996}, {77.6667, -19.9996}}, color = {0, 0, 127}));
#   connect(from_deg1.y, FltDynLateralSS.u_deltaA) annotation(
#     Line(points = {{-39, 0}, {-20.5, 0}, {-20.5, -6}, {-2, -6}}, color = {0, 0, 127}));
#   connect(FltDynLateralSS.y_p, to_deg_p.u) annotation(
#     Line(points = {{61, 9}, {69.6667, 9}, {69.6667, 10.6667}, {77.6667, 10.6667}}, color = {0, 0, 127}));
#   connect(uSignal_deltaA.y, from_deg1.u) annotation(
#     Line(points = {{-79, 0}, {-63, 0}}, color = {0, 0, 127}));
#   connect(uSignal_deltaR.y, from_deg2.u) annotation(
#     Line(points = {{-79, -40}, {-63, -40}, {-63, -40}, {-63, -40}}, color = {0, 0, 127}));
#   annotation(
#     Diagram(coordinateSystem(extent = {{-100, -100}, {120, 120}})),
#     __OpenModelica_commandLineOptions = "",
#     experiment(StartTime = 0, StopTime = 60, Tolerance = 1e-06, Interval = 0.01),
#     __OpenModelica_simulationFlags(lv = "LOG_STATS", outputFormat = "mat", s = "dassl"));
# end LateralLTISS00_ex02;
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation, default setting</h1>

# %%
stopTime=70

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- reset _init.xml
print('...calling original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#-- run simulation with default parameter setting
print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
##### end if #####
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# ...calling original parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_org.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02 -override stopTime=70 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>parameter sweep, 1 parameter </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
''''''
iRunBegin=2
iRunEnd=4
param2change="Flt2Fluid.MN_paramInput"
valBegin=0.1
deltaVal=0.1
stopTime=70.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    iRun=i
    value2set=valBegin+(i-1)*deltaVal
    filenameXmlOrg=fullpathModel+'_init_org.xml'
    filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
    
    print(''); print('-----')
    print('iRun= '+ str(iRun))
    
    #-- overwrite parameter setting xml file
    print('...Overwriting parameter setting file...')
    strcmd= 'setInitXmlStartValue("' + filenameXmlOrg+'", '+ '"'+param2change+'", ' + '"'+str(value2set)+'", '+ '"'+fullpathModel+'_init.xml"' +')'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- save parameter setting file after overwriting
    print(''); print('...Saving parameter setting file...')
    strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- run simulation with default parameter setting
    print(''); print("...running simulation, wait...")
    if(os.name=='nt'):
        strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    elif(os.name=='posix'):
        strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    ##### end if #####

    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
    print('...simulation run finished.')
##### end for #####

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# -----
# iRun= 2
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_org.xml", "Flt2Fluid.MN_paramInput", "0.2", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_2.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02 -override stopTime=70.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res_2.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 3
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_org.xml", "Flt2Fluid.MN_paramInput", "0.30000000000000004", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_3.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02 -override stopTime=70.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res_3.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 4
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_org.xml", "Flt2Fluid.MN_paramInput", "0.4", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_4.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02 -override stopTime=70.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res_4.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Change multiple parameters </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRun=1
param2change=[
    'Flt2Fluid.MN_paramInput', 'Flt2Fluid.alt_paramInput',
    'uSignal_deltaA.y',
    'uSignal_deltaR.y',
]

value2set=[
    0.201, 1524,
    'if time <= 62 then 0 elseif 62 <= time and time <= 63 then -5 elseif 82 <= time and time <= 83 then 5 elseif 91 <= time then 0 else 0' ,
    'if time <= 2 then 0 elseif 2 <= time and time <= 3 then -6 elseif 22 <= time and time <= 23 then 6 elseif 31 <= time then 0 else 0',
]
stopTime=80.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2change)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(fullpathModel+'_init.xml')+'", '+ '"'+param2change[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(fullpathModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# iRun=1
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_org.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml", "Flt2Fluid.MN_paramInput", "0.201", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml", "Flt2Fluid.alt_paramInput", "1524", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml", "uSignal_deltaA.y", "if time <= 62 then 0 elseif 62 <= time and time <= 63 then -5 elseif 82 <= time and time <= 83 then 5 elseif 91 <= time then 0 else 0", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: False
# i=3
# send: setInitXmlStartValue("AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml", "uSignal_deltaR.y", "if time <= 2 then 0 elseif 2 <= time and time <= 3 then -6 elseif 22 <= time and time <= 23 then 6 elseif 31 <= time then 0 else 0", "AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml")
# OMShell: False
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init.xml AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_init_1.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02 -override stopTime=80.0 -r=AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res_1.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process</h1>

# %%
n_df=100
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#            time  FltDynLateralSS.x[1]  FltDynLateralSS.x[2]  \
# 0      0.000000              0.000000              0.000000
# 1      0.011667              0.000000              0.000000
# 2      0.023333              0.000000              0.000000
# 3      0.035000              0.000000              0.000000
# 4      0.046667              0.000000              0.000000
# ...         ...                   ...                   ...
# 6005  69.965000             -0.000465              0.000468
# 6006  69.976667             -0.000465              0.000468
# 6007  69.988333             -0.000465              0.000468
# 6008  70.000000             -0.000465              0.000468
# 6009  70.000000             -0.000465              0.000468
#
#       FltDynLateralSS.x[3]  FltDynLateralSS.x[4]  FltDynLateralSS.x[5]  \
# 0                 0.000000              0.000000              0.000000
# 1                 0.000000              0.000000              0.000000
# 2                 0.000000              0.000000              0.000000
# 3                 0.000000              0.000000              0.000000
# 4                 0.000000              0.000000              0.000000
# ...                    ...                   ...                   ...
# 6005             -0.003761             -0.026140              0.240282
# 6006             -0.003760             -0.026135              0.240238
# 6007             -0.003760             -0.026131              0.240194
# 6008             -0.003759             -0.026126              0.240150
# 6009             -0.003759             -0.026126              0.240150
#
#       der(FltDynLateralSS.x[1])  der(FltDynLateralSS.x[2])  \
# 0                      0.000000                   0.000000
# 1                      0.000000                   0.000000
# 2                      0.000000                   0.000000
# 3                      0.000000                   0.000000
# 4                      0.000000                   0.000000
# ...                         ...                        ...
# 6005                   0.000007                  -0.000007
# 6006                   0.000007                  -0.000007
# 6007                   0.000007                  -0.000007
# 6008                   0.000007                  -0.000007
# 6009                   0.000007                  -0.000007
#
#       der(FltDynLateralSS.x[3])  der(FltDynLateralSS.x[4])  ...  \
# 0                      0.000000                   0.000000  ...
# 1                      0.000000                   0.000000  ...
# 2                      0.000000                   0.000000  ...
# 3                      0.000000                   0.000000  ...
# 4                      0.000000                   0.000000  ...
# ...                         ...                        ...  ...
# 6005                   0.000059                   0.000409  ...
# 6006                   0.000059                   0.000409  ...
# 6007                   0.000059                   0.000409  ...
# 6008                   0.000059                   0.000409  ...
# 6009                   0.000059                   0.000409  ...
#
#       FltDynLateralSS.DerLateral.theta1  FltDynLateralSS.u_deltaA  \
# 0                              0.015699                         0
# 1                              0.015699                         0
# 2                              0.015699                         0
# 3                              0.015699                         0
# 4                              0.015699                         0
# ...                                 ...                       ...
# 6005                           0.015699                         0
# 6006                           0.015699                         0
# 6007                           0.015699                         0
# 6008                           0.015699                         0
# 6009                           0.015699                         0
#
#       FltDynLateralSS.u_deltaR  FltDynLateralSS.y_aY  from_deg1.u  \
# 0                          0.0              0.000000            0
# 1                          0.0              0.000000            0
# 2                          0.0              0.000000            0
# 3                          0.0              0.000000            0
# 4                          0.0              0.000000            0
# ...                        ...                   ...          ...
# 6005                       0.0             -0.252741            0
# 6006                       0.0             -0.252695            0
# 6007                       0.0             -0.252648            0
# 6008                       0.0             -0.252602            0
# 6009                       0.0             -0.252602            0
#
#       from_deg1.y  from_deg2.y  to_deg_p.u  to_deg_r.u  uSignal_deltaR.y
# 0               0          0.0    0.000000    0.000000                 0
# 1               0          0.0    0.000000    0.000000                 0
# 2               0          0.0    0.000000    0.000000                 0
# 3               0          0.0    0.000000    0.000000                 0
# 4               0          0.0    0.000000    0.000000                 0
# ...           ...          ...         ...         ...               ...
# 6005            0          0.0    0.000468   -0.003761                 0
# 6006            0          0.0    0.000468   -0.003760                 0
# 6007            0          0.0    0.000468   -0.003760                 0
# 6008            0          0.0    0.000468   -0.003759                 0
# 6009            0          0.0    0.000468   -0.003759                 0
#
# [6010 rows x 331 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'FltDynLateralSS.x[1]',
#  'FltDynLateralSS.x[2]',
#  'FltDynLateralSS.x[3]',
#  'FltDynLateralSS.x[4]',
#  'FltDynLateralSS.x[5]',
#  'der(FltDynLateralSS.x[1])',
#  'der(FltDynLateralSS.x[2])',
#  'der(FltDynLateralSS.x[3])',
#  'der(FltDynLateralSS.x[4])',
#  'der(FltDynLateralSS.x[5])',
#  'Flt2Fluid.AltMN2pTh.TambStd',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.u',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.MM',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.R',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.d',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.h',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.u',
#  'Flt2Fluid.AltMN2pTh.fluidTot.MM',
#  'Flt2Fluid.AltMN2pTh.fluidTot.R',
#  'Flt2Fluid.AltMN2pTh.fluidTot.T_degC',
#  'Flt2Fluid.AltMN2pTh.fluidTot.d',
#  'Flt2Fluid.AltMN2pTh.fluidTot.p_bar',
#  'Flt2Fluid.AltMN2pTh.fluidTot.u',
#  'Flt2Fluid.AltMN2pTh.pAmbStd',
#  'Flt2Fluid.AltMN2pTh.y_Tamb',
#  'Flt2Fluid.AltMN2pTh.y_Ttot',
#  'Flt2Fluid.AltMN2pTh.y_hAmb',
#  'Flt2Fluid.AltMN2pTh.y_hTot',
#  'Flt2Fluid.AltMN2pTh.y_pAmb',
#  'Flt2Fluid.AltMN2pTh.y_pTot',
#  'Flt2Fluid.Vsound',
#  'Flt2Fluid.limiter2.y',
#  'Flt2Fluid.limiter4.y',
#  'Flt2Fluid.port_amb4sink.m_flow',
#  'Flt2Fluid.port_amb4source.m_flow',
#  'Flt2Fluid.port_total.m_flow',
#  'Flt2Fluid.s_fluid_amb4sink',
#  'Flt2Fluid.s_fluid_amb4source',
#  'Flt2Fluid.s_fluid_inlet',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.R',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.d',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.u',
#  'Flt2Fluid.sourceFluidAmb4sink.p_in',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidAmb4source.medium.MM',
#  'Flt2Fluid.sourceFluidAmb4source.medium.R',
#  'Flt2Fluid.sourceFluidAmb4source.medium.T_degC',
#  'Flt2Fluid.sourceFluidAmb4source.medium.d',
#  'Flt2Fluid.sourceFluidAmb4source.medium.p_bar',
#  'Flt2Fluid.sourceFluidAmb4source.medium.u',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].h_outflow',
#  'Flt2Fluid.sourceFluidTotal.medium.MM',
#  'Flt2Fluid.sourceFluidTotal.medium.R',
#  'Flt2Fluid.sourceFluidTotal.medium.T_degC',
#  'Flt2Fluid.sourceFluidTotal.medium.d',
#  'Flt2Fluid.sourceFluidTotal.medium.p_bar',
#  'Flt2Fluid.sourceFluidTotal.medium.u',
#  'Flt2Fluid.sourceFluidTotal.p_in',
#  'Flt2Fluid.sourceFluidTotal.ports[1].h_outflow',
#  'FltDynLateralSS.u[1]',
#  'FltDynLateralSS.u[2]',
#  'FltDynLateralSS.u_Ixx',
#  'FltDynLateralSS.u_Ixz',
#  'FltDynLateralSS.u_Izz',
#  'FltDynLateralSS.u_S',
#  'FltDynLateralSS.u_U1',
#  'FltDynLateralSS.u_b',
#  'FltDynLateralSS.u_m',
#  'FltDynLateralSS.u_q1bar',
#  'FltDynLateralSS.y[1]',
#  'FltDynLateralSS.y[2]',
#  'FltDynLateralSS.y[3]',
#  'FltDynLateralSS.y[4]',
#  'FltDynLateralSS.y[5]',
#  'FltDynLateralSS.y[6]',
#  'FltDynLateralSS.y_beta',
#  'FltDynLateralSS.y_p',
#  'FltDynLateralSS.y_phi',
#  'FltDynLateralSS.y_psi',
#  'FltDynLateralSS.y_r',
#  'from_deg2.u',
#  'to_deg_p.y',
#  'to_deg_r.y',
#  'uSignal_deltaA.y',
#  'FltDynLateralSS.DerLateral.I1',
#  'FltDynLateralSS.DerLateral.I2',
#  'FltDynLateralSS.DerLateral.Lbeta',
#  'FltDynLateralSS.DerLateral.LdeltaA',
#  'FltDynLateralSS.DerLateral.LdeltaF',
#  'FltDynLateralSS.DerLateral.LdeltaF_pri',
#  'FltDynLateralSS.DerLateral.LdeltaR',
#  'FltDynLateralSS.DerLateral.LdeltaS_pri',
#  'FltDynLateralSS.DerLateral.Lp',
#  'FltDynLateralSS.DerLateral.Lr_pri',
#  'FltDynLateralSS.DerLateral.Nbeta',
#  'FltDynLateralSS.DerLateral.NdeltaA',
#  'FltDynLateralSS.DerLateral.NdeltaF',
#  'FltDynLateralSS.DerLateral.NdeltaF_pri',
#  'FltDynLateralSS.DerLateral.NdeltaR',
#  'FltDynLateralSS.DerLateral.NdeltaS',
#  'FltDynLateralSS.DerLateral.NdeltaS_pri',
#  'FltDynLateralSS.DerLateral.Np',
#  'FltDynLateralSS.DerLateral.Nr_pri',
#  'FltDynLateralSS.DerLateral.Ybeta',
#  'FltDynLateralSS.DerLateral.YdeltaA',
#  'FltDynLateralSS.DerLateral.YdeltaF',
#  'FltDynLateralSS.DerLateral.YdeltaF_ppri',
#  'FltDynLateralSS.DerLateral.YdeltaF_pri',
#  'FltDynLateralSS.DerLateral.YdeltaR',
#  'FltDynLateralSS.DerLateral.YdeltaS',
#  'FltDynLateralSS.DerLateral.YdeltaS_ppri',
#  'FltDynLateralSS.DerLateral.YdeltaS_pri',
#  'FltDynLateralSS.DerLateral.Yp',
#  'FltDynLateralSS.DerLateral.Yr',
#  'FltDynLateralSS.DerLateral.infoBusAircraft.Ixx',
#  'FltDynLateralSS.DerLateral.infoBusAircraft.Ixz',
#  'FltDynLateralSS.DerLateral.infoBusAircraft.Izz',
#  'FltDynLateralSS.DerLateral.infoBusAircraft.S',
#  'FltDynLateralSS.DerLateral.infoBusAircraft.b',
#  'FltDynLateralSS.DerLateral.infoBusAircraft.m',
#  'FltDynLateralSS.DerLateral.infoBusDim.Lbeta_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaA_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaR_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Lp_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Lr_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Nbeta_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaA_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaR_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Np_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Nr_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Ybeta_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Ybeta_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaA_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaA_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaR_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaR_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yp_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yp_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yphi_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yphi_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yr_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yr_pri',
#  'FltDynLateralSS.DerLateral.infoBusFlt.U1',
#  'FltDynLateralSS.DerLateral.infoBusFlt.g',
#  'FltDynLateralSS.DerLateral.infoBusFlt.q1bar',
#  'FltDynLateralSS.DerLateral.infoBusFlt.theta1',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CYbeta',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CYdeltaA',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CYdeltaF',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CYdeltaR',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CYdeltaS',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CYp',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CYr',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.Clbeta',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CldeltaA',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CldeltaF',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CldeltaR',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CldeltaS',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.Clp',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.Clr',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.Cnbeta',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CndeltaA',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CndeltaF',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CndeltaR',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.CndeltaS',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.Cnp',
#  'FltDynLateralSS.DerLateral.infoBusNonDim.Cnr',
#  'Flt2Fluid.AltMN2pTh.Tamb',
#  'Flt2Fluid.AltMN2pTh.V_inf',
#  'Flt2Fluid.AltMN2pTh.Vsound',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.h',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.p',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.state.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmb.state.p',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.p',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.state.T',
#  'Flt2Fluid.AltMN2pTh.fluidAmbStd.state.p',
#  'Flt2Fluid.AltMN2pTh.fluidTot.T',
#  'Flt2Fluid.AltMN2pTh.fluidTot.h',
#  'Flt2Fluid.AltMN2pTh.fluidTot.p',
#  'Flt2Fluid.AltMN2pTh.fluidTot.state.T',
#  'Flt2Fluid.AltMN2pTh.fluidTot.state.p',
#  'Flt2Fluid.AltMN2pTh.infoBus1.Vsound',
#  'Flt2Fluid.AltMN2pTh.pAmb',
#  'Flt2Fluid.AltMN2pTh.y_V_inf',
#  'Flt2Fluid.dynP',
#  'Flt2Fluid.infoBus1.Vsound',
#  'Flt2Fluid.limiter1.u',
#  'Flt2Fluid.limiter1.y',
#  'Flt2Fluid.limiter2.u',
#  'Flt2Fluid.limiter3.u',
#  'Flt2Fluid.limiter3.y',
#  'Flt2Fluid.limiter4.u',
#  'Flt2Fluid.port_amb4sink.h_outflow',
#  'Flt2Fluid.port_amb4sink.p',
#  'Flt2Fluid.port_amb4source.h_outflow',
#  'Flt2Fluid.port_amb4source.p',
#  'Flt2Fluid.port_total.h_outflow',
#  'Flt2Fluid.port_total.p',
#  'Flt2Fluid.sourceFluidAmb4sink.T_in',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.T',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.h',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.p',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.state.T',
#  'Flt2Fluid.sourceFluidAmb4sink.medium.state.p',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].m_flow',
#  'Flt2Fluid.sourceFluidAmb4sink.ports[1].p',
#  'Flt2Fluid.sourceFluidAmb4source.T_in',
#  'Flt2Fluid.sourceFluidAmb4source.medium.T',
#  'Flt2Fluid.sourceFluidAmb4source.medium.h',
#  'Flt2Fluid.sourceFluidAmb4source.medium.p',
#  'Flt2Fluid.sourceFluidAmb4source.medium.state.T',
#  'Flt2Fluid.sourceFluidAmb4source.medium.state.p',
#  'Flt2Fluid.sourceFluidAmb4source.p_in',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].m_flow',
#  'Flt2Fluid.sourceFluidAmb4source.ports[1].p',
#  'Flt2Fluid.sourceFluidTotal.T_in',
#  'Flt2Fluid.sourceFluidTotal.medium.T',
#  'Flt2Fluid.sourceFluidTotal.medium.h',
#  'Flt2Fluid.sourceFluidTotal.medium.p',
#  'Flt2Fluid.sourceFluidTotal.medium.state.T',
#  'Flt2Fluid.sourceFluidTotal.medium.state.p',
#  'Flt2Fluid.sourceFluidTotal.ports[1].m_flow',
#  'Flt2Fluid.sourceFluidTotal.ports[1].p',
#  'Flt2Fluid.y_V_inf',
#  'Flt2Fluid.y_qBar',
#  'FltDynLateralSS.DerLateral.CYbeta',
#  'FltDynLateralSS.DerLateral.CYdeltaA',
#  'FltDynLateralSS.DerLateral.CYdeltaF',
#  'FltDynLateralSS.DerLateral.CYdeltaR',
#  'FltDynLateralSS.DerLateral.CYdeltaS',
#  'FltDynLateralSS.DerLateral.CYp',
#  'FltDynLateralSS.DerLateral.CYr',
#  'FltDynLateralSS.DerLateral.Clbeta',
#  'FltDynLateralSS.DerLateral.CldeltaA',
#  'FltDynLateralSS.DerLateral.CldeltaF',
#  'FltDynLateralSS.DerLateral.CldeltaR',
#  'FltDynLateralSS.DerLateral.CldeltaS',
#  'FltDynLateralSS.DerLateral.Clp',
#  'FltDynLateralSS.DerLateral.Clr',
#  'FltDynLateralSS.DerLateral.Cnbeta',
#  'FltDynLateralSS.DerLateral.CndeltaA',
#  'FltDynLateralSS.DerLateral.CndeltaF',
#  'FltDynLateralSS.DerLateral.CndeltaR',
#  'FltDynLateralSS.DerLateral.CndeltaS',
#  'FltDynLateralSS.DerLateral.Cnp',
#  'FltDynLateralSS.DerLateral.Cnr',
#  'FltDynLateralSS.DerLateral.Ixx',
#  'FltDynLateralSS.DerLateral.Ixz',
#  'FltDynLateralSS.DerLateral.Izz',
#  'FltDynLateralSS.DerLateral.Lbeta_pri',
#  'FltDynLateralSS.DerLateral.LdeltaA_pri',
#  'FltDynLateralSS.DerLateral.LdeltaR_pri',
#  'FltDynLateralSS.DerLateral.LdeltaS',
#  'FltDynLateralSS.DerLateral.Lp_pri',
#  'FltDynLateralSS.DerLateral.Lr',
#  'FltDynLateralSS.DerLateral.Nbeta_pri',
#  'FltDynLateralSS.DerLateral.NdeltaA_pri',
#  'FltDynLateralSS.DerLateral.NdeltaR_pri',
#  'FltDynLateralSS.DerLateral.Np_pri',
#  'FltDynLateralSS.DerLateral.Nr',
#  'FltDynLateralSS.DerLateral.S',
#  'FltDynLateralSS.DerLateral.U1',
#  'FltDynLateralSS.DerLateral.Ybeta_ppri',
#  'FltDynLateralSS.DerLateral.Ybeta_pri',
#  'FltDynLateralSS.DerLateral.YdeltaA_ppri',
#  'FltDynLateralSS.DerLateral.YdeltaA_pri',
#  'FltDynLateralSS.DerLateral.YdeltaR_ppri',
#  'FltDynLateralSS.DerLateral.YdeltaR_pri',
#  'FltDynLateralSS.DerLateral.Yp_ppri',
#  'FltDynLateralSS.DerLateral.Yp_pri',
#  'FltDynLateralSS.DerLateral.Yphi_ppri',
#  'FltDynLateralSS.DerLateral.Yphi_pri',
#  'FltDynLateralSS.DerLateral.Yr_ppri',
#  'FltDynLateralSS.DerLateral.Yr_pri',
#  'FltDynLateralSS.DerLateral.b',
#  'FltDynLateralSS.DerLateral.g',
#  'FltDynLateralSS.DerLateral.infoBusDim.Lbeta',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaA',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaF',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaF_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaR',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaS',
#  'FltDynLateralSS.DerLateral.infoBusDim.LdeltaS_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Lp',
#  'FltDynLateralSS.DerLateral.infoBusDim.Lr',
#  'FltDynLateralSS.DerLateral.infoBusDim.Nbeta',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaA',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaF',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaF_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaR',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaS',
#  'FltDynLateralSS.DerLateral.infoBusDim.NdeltaS_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Np',
#  'FltDynLateralSS.DerLateral.infoBusDim.Nr',
#  'FltDynLateralSS.DerLateral.infoBusDim.Ybeta',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaA',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaF',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaF_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaF_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaR',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaS',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaS_ppri',
#  'FltDynLateralSS.DerLateral.infoBusDim.YdeltaS_pri',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yp',
#  'FltDynLateralSS.DerLateral.infoBusDim.Yr',
#  'FltDynLateralSS.DerLateral.m',
#  'FltDynLateralSS.DerLateral.q1bar',
#  'FltDynLateralSS.DerLateral.theta1',
#  'FltDynLateralSS.u_deltaA',
#  'FltDynLateralSS.u_deltaR',
#  'FltDynLateralSS.y_aY',
#  'from_deg1.u',
#  'from_deg1.y',
#  'from_deg2.y',
#  'to_deg_p.u',
#  'to_deg_r.u',
#  'uSignal_deltaR.y']

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=3


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res_2.csv
# i_df=3
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res_3.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.RigidBodyFDM.Examples.sampleAircrafts.LateralLTISS00_ex02_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#            time  FltDynLateralSS.x[1]  FltDynLateralSS.x[2]  \
# 0      0.000000              0.000000                0.0000
# 1      0.011667              0.000000                0.0000
# 2      0.023334              0.000000                0.0000
# 3      0.035001              0.000000                0.0000
# 4      0.046668              0.000000                0.0000
# ...         ...                   ...                   ...
# 6862  79.964999             -0.000397                0.0004
# 6863  79.976666             -0.000397                0.0004
# 6864  79.988333             -0.000397                0.0004
# 6865  80.000000             -0.000397                0.0004
# 6866  80.000000             -0.000397                0.0004
#
#       FltDynLateralSS.x[3]  FltDynLateralSS.x[4]  FltDynLateralSS.x[5]  \
# 0                 0.000000              0.000000              0.000000
# 1                 0.000000              0.000000              0.000000
# 2                 0.000000              0.000000              0.000000
# 3                 0.000000              0.000000              0.000000
# 4                 0.000000              0.000000              0.000000
# ...                    ...                   ...                   ...
# 6862             -0.003216             -0.022352              0.205464
# 6863             -0.003216             -0.022348              0.205427
# 6864             -0.003215             -0.022344              0.205389
# 6865             -0.003214             -0.022340              0.205352
# 6866             -0.003214             -0.022340              0.205352
#
#       der(FltDynLateralSS.x[1])  der(FltDynLateralSS.x[2])  \
# 0                      0.000000                   0.000000
# 1                      0.000000                   0.000000
# 2                      0.000000                   0.000000
# 3                      0.000000                   0.000000
# 4                      0.000000                   0.000000
# ...                         ...                        ...
# 6862                   0.000006                  -0.000006
# 6863                   0.000006                  -0.000006
# 6864                   0.000006                  -0.000006
# 6865                   0.000006                  -0.000006
# 6866                   0.000006                  -0.000006
#
#       der(FltDynLateralSS.x[3])  der(FltDynLateralSS.x[4])  ...  \
# 0                       0.00000                    0.00000  ...
# 1                       0.00000                    0.00000  ...
# 2                       0.00000                    0.00000  ...
# 3                       0.00000                    0.00000  ...
# 4                       0.00000                    0.00000  ...
# ...                         ...                        ...  ...
# 6862                    0.00005                    0.00035  ...
# 6863                    0.00005                    0.00035  ...
# 6864                    0.00005                    0.00035  ...
# 6865                    0.00005                    0.00035  ...
# 6866                    0.00005                    0.00035  ...
#
#       FltDynLateralSS.DerLateral.theta1  FltDynLateralSS.u_deltaA  \
# 0                              0.015699                         0
# 1                              0.015699                         0
# 2                              0.015699                         0
# 3                              0.015699                         0
# 4                              0.015699                         0
# ...                                 ...                       ...
# 6862                           0.015699                         0
# 6863                           0.015699                         0
# 6864                           0.015699                         0
# 6865                           0.015699                         0
# 6866                           0.015699                         0
#
#       FltDynLateralSS.u_deltaR  FltDynLateralSS.y_aY  from_deg1.u  \
# 0                          0.0              0.000000            0
# 1                          0.0              0.000000            0
# 2                          0.0              0.000000            0
# 3                          0.0              0.000000            0
# 4                          0.0              0.000000            0
# ...                        ...                   ...          ...
# 6862                       0.0             -0.216118            0
# 6863                       0.0             -0.216078            0
# 6864                       0.0             -0.216039            0
# 6865                       0.0             -0.215999            0
# 6866                       0.0             -0.215999            0
#
#       from_deg1.y  from_deg2.y  to_deg_p.u  to_deg_r.u  uSignal_deltaR.y
# 0               0          0.0      0.0000    0.000000                 0
# 1               0          0.0      0.0000    0.000000                 0
# 2               0          0.0      0.0000    0.000000                 0
# 3               0          0.0      0.0000    0.000000                 0
# 4               0          0.0      0.0000    0.000000                 0
# ...           ...          ...         ...         ...               ...
# 6862            0          0.0      0.0004   -0.003216                 0
# 6863            0          0.0      0.0004   -0.003216                 0
# 6864            0          0.0      0.0004   -0.003215                 0
# 6865            0          0.0      0.0004   -0.003214                 0
# 6866            0          0.0      0.0004   -0.003214                 0
#
# [6867 rows x 331 columns]

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
i_df=1
varName="FltDynLateralSS.u_deltaA"
ylabel='delta aileron angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLateralSS.u_deltaR"
ylabel='delta rudder angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.ylim(-10.0, 10.0)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=1
varName="FltDynLateralSS.y_beta"
ylabel='Angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(-10, 10)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLateralSS.x[1])"
ylabel='Angular Velocity [deg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(beta)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-25, 25)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLateralSS.y_p"
ylabel='Angular Velocity [deg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(-25.0, 25.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLateralSS.x[2])"
ylabel='Angular Acceleration [deg/s2]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(p)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-60.0, 60.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLateralSS.y_r"
ylabel='Anguler Velocity [deg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(-25.0, 25.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLateralSS.x[3])"
ylabel='Anguler Acceleration [deg/s2]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(r)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-100.0, 100.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLateralSS.y_phi"
ylabel='Angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(-10.0, 20.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLateralSS.x[4])"
ylabel='Anguler Velocity [deg/s2]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(phi)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-25.0, 25.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="FltDynLateralSS.y_psi"
ylabel='Angle [deg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(-10.0, 40.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="der(FltDynLateralSS.x[5])"
ylabel='Anguler Velocity [deg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*180.0/math.pi
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName+' ( d(psi)/dt )')
plt.plot(time, var, color='red')
plt.ylim(-30.0, 30.0)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------
