# %% [markdown]
# <h1>Visualize ExeBuiltByOMEdit: AircraftDynamics.PtMassFDM.DoF3.Examples.TwoBodyOrbital00</h1>
# <h2>notebook: rev001</h2>
# <p>compatability with OpenModelica v1.21.0</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import numpy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib
import math

from IPython.display import display, HTML

backslash= '\\'
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=100000
df=[[]]*n_df
i_df= -10
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'
swWorkSubDir= 'fullpathModel'
'''
'None': 
'fullPathModel': work in sub dir named with fullaPathModel
'''

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00'
nmModel='ThreeBodyOrbital00'
outputFormat='csv'

#****************************************
#    User must NOT edit code below 
#****************************************
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
if(swWorkSubDir=='fullpathModel'):
    dirWorkRelToHome= dirWorkRelToHome + '/' + fullpathModel
##### end if #####

print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirHome= dirHome.replace(backslash, '/')
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF3/Examples/ThreeBodyOrbital00.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization, evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00")
# OMShell: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization, evaluateAllParameters,NLSanalyticJacobian")
# OMShell: False
#
# OMShell error message:
#
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#nmcsv= fullpathModel + '_res.csv'
nmcsv= nmModel + '_res.csv'
fullpathFile= os.getcwd()+"/"+nmcsv
fullpathFile= fullpathFile.replace(backslash, "/")
print("data read: "+ fullpathFile)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#         time  r1[1]  r1[2]  r1[3]         r2[1]         r2[2]  r2[3]  \
# 0          0      0      0      0  3.328993e+08 -1.921995e+08      0
# 1         30      0      0      0  3.329146e+08 -1.921729e+08      0
# 2         60      0      0      0  3.329300e+08 -1.921464e+08      0
# 3         90      0      0      0  3.329453e+08 -1.921198e+08      0
# 4        120      0      0      0  3.329606e+08 -1.920933e+08      0
# ...      ...    ...    ...    ...           ...           ...    ...
# 5757  172710      0      0      0  3.838839e+08 -2.485144e+07      0
# 5758  172740      0      0      0  3.838860e+08 -2.482087e+07      0
# 5759  172770      0      0      0  3.838881e+08 -2.479030e+07      0
# 5760  172800      0      0      0  3.838901e+08 -2.475974e+07      0
# 5761  172800      0      0      0  3.838901e+08 -2.475974e+07      0
#
#              r3[1]         r3[2]  r3[3]  ...       v2_3[2]  v2_3[3]  \
# 0    -6.778137e+06  0.000000e+00      0  ... -10885.077963        0
# 1    -6.774234e+06 -2.999424e+05      0  ... -10879.362330        0
# 2    -6.762540e+06 -5.995401e+05      0  ... -10862.185347        0
# 3    -6.743096e+06 -8.984510e+05      0  ... -10833.689497        0
# 4    -6.715969e+06 -1.196339e+06      0  ... -10794.108611        0
# ...            ...           ...    ...  ...           ...      ...
# 5757  9.445119e+06 -1.552959e+07      0  ...  -2079.639319        0
# 5758  9.595210e+06 -1.556095e+07      0  ...  -2048.956638        0
# 5759  9.744739e+06 -1.559139e+07      0  ...  -2018.737901        0
# 5760  9.893704e+06 -1.562094e+07      0  ...  -1988.973064        0
# 5761  9.893704e+06 -1.562094e+07      0  ...  -1988.973064        0
#
#            v2_3Abs         v3Abs     a2[1]     a2[2]  a2[3]     a3[1]  \
# 0     10897.065809  10000.000000 -0.002336  0.001349      0  8.675678
# 1     10882.253103   9997.628285 -0.002336  0.001349      0  8.660198
# 2     10862.188629   9990.532248 -0.002336  0.001348      0  8.613986
# 3     10836.951253   9978.759930 -0.002336  0.001348      0  8.537720
# 4     10806.653668   9962.390257 -0.002337  0.001348      0  8.432505
# ...            ...           ...       ...       ...    ...       ...
# 5757   5362.840663   5123.451352 -0.002688  0.000174      0 -0.626960
# 5758   5333.733240   5098.776374 -0.002688  0.000174      0 -0.625998
# 5759   5304.914091   5074.357659 -0.002688  0.000174      0 -0.624951
# 5760   5276.378236   5050.190846 -0.002688  0.000173      0 -0.623824
# 5761   5276.378236   5050.190846 -0.002688  0.000173      0 -0.623824
#
#          a3[2]  a3[3]
# 0     0.000016      0
# 1     0.383464      0
# 2     0.763700      0
# 3     1.137587      0
# 4     1.502132      0
# ...        ...    ...
# 5757  1.030786      0
# 5758  1.015151      0
# 5759  0.999854      0
# 5760  0.984886      0
# 5761  0.984886      0
#
# [5762 rows x 110 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'r1[1]',
#  'r1[2]',
#  'r1[3]',
#  'r2[1]',
#  'r2[2]',
#  'r2[3]',
#  'r3[1]',
#  'r3[2]',
#  'r3[3]',
#  'v1[1]',
#  'v1[2]',
#  'v1[3]',
#  'v2[1]',
#  'v2[2]',
#  'v2[3]',
#  'v3[1]',
#  'v3[2]',
#  'v3[3]',
#  'der(r1[1])',
#  'der(r1[2])',
#  'der(r1[3])',
#  'der(r2[1])',
#  'der(r2[2])',
#  'der(r2[3])',
#  'der(r3[1])',
#  'der(r3[2])',
#  'der(r3[3])',
#  'der(v1[1])',
#  'der(v1[2])',
#  'der(v1[3])',
#  'der(v2[1])',
#  'der(v2[2])',
#  'der(v2[3])',
#  'der(v3[1])',
#  'der(v3[2])',
#  'der(v3[3])',
#  'Alt',
#  'Fg1_2[1]',
#  'Fg1_2[2]',
#  'Fg1_2[3]',
#  'Fg1_3[1]',
#  'Fg1_3[2]',
#  'Fg1_3[3]',
#  'Fg2_1[1]',
#  'Fg2_1[2]',
#  'Fg2_1[3]',
#  'Fg2_3[1]',
#  'Fg2_3[2]',
#  'Fg2_3[3]',
#  'Fg3_1[1]',
#  'Fg3_1[2]',
#  'Fg3_1[3]',
#  'Fg3_2[1]',
#  'Fg3_2[2]',
#  'Fg3_2[3]',
#  'a1[1]',
#  'a1[2]',
#  'a1[3]',
#  'a1Abs',
#  'a1_2[1]',
#  'a1_2[2]',
#  'a1_2[3]',
#  'a1_2Abs',
#  'a1_3[1]',
#  'a1_3[2]',
#  'a1_3[3]',
#  'a1_3Abs',
#  'a2Abs',
#  'a2_3[1]',
#  'a2_3[2]',
#  'a2_3[3]',
#  'a2_3Abs',
#  'a3Abs',
#  'mag_r1',
#  'mag_r1_2',
#  'mag_r1_3',
#  'mag_r2',
#  'mag_r2_3',
#  'mag_r3',
#  'r1_2[1]',
#  'r1_2[2]',
#  'r1_2[3]',
#  'r1_3[1]',
#  'r1_3[2]',
#  'r1_3[3]',
#  'r2_3[1]',
#  'r2_3[2]',
#  'r2_3[3]',
#  'v1Abs',
#  'v1_2[1]',
#  'v1_2[2]',
#  'v1_2[3]',
#  'v1_2Abs',
#  'v1_3[1]',
#  'v1_3[2]',
#  'v1_3[3]',
#  'v1_3Abs',
#  'v2Abs',
#  'v2_3[1]',
#  'v2_3[2]',
#  'v2_3[3]',
#  'v2_3Abs',
#  'v3Abs',
#  'a2[1]',
#  'a2[2]',
#  'a2[3]',
#  'a3[1]',
#  'a3[2]',
#  'a3[3]']

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
fullpathFile= os.getcwd()+"/"+nmcsv
fullpathFile= fullpathFile.replace(backslash, "/")
print("data read: "+ fullpathFile)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_0.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#          time  r1[1]  r1[2]  r1[3]         r2[1]         r2[2]  r2[3]  \
# 0           0      0      0      0  2.811316e+08 -2.621595e+08      0
# 1          50      0      0      0  2.811665e+08 -2.621221e+08      0
# 2         100      0      0      0  2.812013e+08 -2.620847e+08      0
# 3         150      0      0      0  2.812362e+08 -2.620474e+08      0
# 4         200      0      0      0  2.812710e+08 -2.620100e+08      0
# ...       ...    ...    ...    ...           ...           ...    ...
# 15997  799850      0      0      0  8.217088e+07  3.798715e+08      0
# 15998  799900      0      0      0  8.212155e+07  3.798825e+08      0
# 15999  799950      0      0      0  8.207221e+07  3.798935e+08      0
# 16000  800000      0      0      0  8.202288e+07  3.799045e+08      0
# 16001  800000      0      0      0  8.202288e+07  3.799045e+08      0
#
#               r3[1]         r3[2]  r3[3]  ...       v2_3[2]  v2_3[3]  \
# 0     -6.778137e+06  0.000000e+00      0  ... -11527.443483        0
# 1     -6.767290e+06 -5.387118e+05      0  ... -11510.310246        0
# 2     -6.734926e+06 -1.075713e+06      0  ... -11459.328465        0
# 3     -6.681427e+06 -1.609343e+06      0  ... -11376.021165        0
# 4     -6.607435e+06 -2.138045e+06      0  ... -11262.833369        0
# ...             ...           ...    ...  ...           ...      ...
# 15997  1.109777e+08 -4.270982e+07      0  ...    237.693208        0
# 15998  1.108717e+08 -4.268693e+07      0  ...    238.327609        0
# 15999  1.107656e+08 -4.266401e+07      0  ...    238.963115        0
# 16000  1.106595e+08 -4.264106e+07      0  ...    239.599728        0
# 16001  1.106595e+08 -4.264106e+07      0  ...    239.599728        0
#
#             v2_3Abs         v3Abs     a2[1]     a2[2]  a2[3]     a3[1]  \
# 0      11548.496244  10780.000000 -0.001973  0.001840      0  8.675682
# 1      11513.337952  10771.476483 -0.001973  0.001839      0  8.621436
# 2      11460.495884  10746.199062 -0.001973  0.001839      0  8.461517
# 3      11390.832985  10704.792346 -0.001974  0.001839      0  8.204394
# 4      11305.632719  10648.292482 -0.001974  0.001839      0  7.863011
# ...             ...           ...       ...       ...    ...       ...
# 15997   1157.750572   2168.530868 -0.000558 -0.002579      0 -0.026306
# 15998   1159.142029   2169.924386 -0.000558 -0.002579      0 -0.026352
# 15999   1160.536096   2171.320412 -0.000557 -0.002579      0 -0.026398
# 16000   1161.932781   2172.718955 -0.000557 -0.002579      0 -0.026444
# 16001   1161.932781   2172.718955 -0.000557 -0.002579      0 -0.026444
#
#           a3[2]  a3[3]
# 0      0.000022      0
# 1      0.686335      0
# 2      1.351512      0
# 3      1.976205      0
# 4      2.544356      0
# ...         ...    ...
# 15997  0.010097      0
# 15998  0.010119      0
# 15999  0.010141      0
# 16000  0.010163      0
# 16001  0.010163      0
#
# [16002 rows x 110 columns]

# %% [markdown]
# <h2>Read Parameters CSV Table</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
nameParameterTableCSV="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_4.csv"
swDir="ipynbs"
'''
'ipynbs': csv is in the save directory as this ipynbs
'workDir': csv is in the same directory as working dir
'''
if(swDir=='workDir'):
    fullPathCSV= nameParameterTableCSV
elif(swDir=='ipynbs'):
    fullPathCSV= pathNotebook+'/'+nameParameterTableCSV
#***** end if *****


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')
#----------

print("Reading CSV...")
print(fullPathCSV)
df_parameter = pd.read_csv(fullPathCSV, index_col=0, header=0)

print(''); 
print("Parameter Table read:")
print(df_parameter)
print('------------------------------')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# Reading CSV...
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_4.csv
#
# Parameter Table read:
#                      2543      2544      2545      2546      2547      2548  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10749    -10749    -10749    -10749    -10749    -10749
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -35     -35.5       -36     -36.5       -37     -37.5
#
#                      2549      2550      2551      2552  ...      3243  \
# swExec               Exec      Exec      Exec      Exec  ...      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  ...  -6778137
# r3_init[2]              0         0         0         0  ...         0
# r3_init[3]              0         0         0         0  ...         0
# v3_init[1]              0         0         0         0  ...         0
# v3_init[2]         -10749    -10749    -10749    -10749  ...    -10740
# v3_init[3]              0         0         0         0  ...         0
# phi_r2_deg_init       -38     -38.5       -39     -39.5  ...     -65.5
#
#                      3244      3245      3246      3247      3248      3249  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10740    -10740    -10740    -10740    -10740    -10740
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -66     -66.5       -67     -67.5       -68     -68.5
#
#                      3250      3251      3252
# swExec               Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137
# r3_init[2]              0         0         0
# r3_init[3]              0         0         0
# v3_init[1]              0         0         0
# v3_init[2]         -10740    -10740    -10740
# v3_init[3]              0         0         0
# phi_r2_deg_init       -69     -69.5       -70
#
# [8 rows x 710 columns]
# ------------------------------
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Read csv, multi-cases</h1>

# %%
iRunBegin= 1
iRunEnd= 2

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    i_df=i
    nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
    fullpathFile= os.getcwd()+"/"+nmcsv
    fullpathFile= fullpathFile.replace(backslash, "/")
    print("data read: "+ fullpathFile)
    df.insert(i_df, pd.read_csv(nmcsv))
    
    print('')
#***** end for *****

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1.csv
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_2.csv
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=0
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')
# Out:
# i_df= 0
# v3_init[2]=-10740
# phi_r2_deg_init=-70
# ------------------------------

# %%
i_df=0
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')
# Out:
# i_df= 0
# v3_init[2]=-10740
# phi_r2_deg_init=-70
# ------------------------------

# %%
print(str(len(df)))
# Out:
# 100004

# %% [markdown]
# <h1>===========================================================================</h1>

# %%
i_df_begin= 3142
i_df_end= 3300

subDir="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat"
swDir="ipynbs"
'''
'ipynbs': csv is in the save directory as this ipynbs
'workDir': csv is in the same directory as working dir
'''

#*** get directory of this notebook
sys.path.append('..')
pathNotebook=''
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#***
if(swDir=='workDir'):
    fullPathDir= dirWork+'/'+subDir
elif(swDir=='ipynbs'):
    fullPathDir= pathNotebook+'/'+subDir
#***** end if *****
print('Dir to save figs is...')
print(fullPathDir)
print('')

#************************************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()

print('colBegin='+str(df_parameter.columns.get_loc(str(i_df_begin))))
print('colEnd='+str(df_parameter.columns.get_loc(str(i_df_end))))
print('')

i_df=i_df_begin
for i in range(df_parameter.columns.get_loc(str(i_df_begin)), df_parameter.columns.get_loc(str(i_df_end))+1):
    print('i='+str(i))
    print('i_df='+str(i_df))
    
    nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
    fullpathFile= os.getcwd()+"/"+nmcsv
    fullpathFile= fullpathFile.replace(backslash, "/")
    print("data read: "+ fullpathFile)
    df.insert(i_df, pd.read_csv(nmcsv))
    
    fullPathFigName= fullPathDir+'/'+'case_'+str(i_df)+'_'+df_parameter.index[5]+'='+str(df_parameter.loc['v3_init[2]', str(i_df)])+'_'+df_parameter.index[7]+'='+str(df_parameter.loc['phi_r2_deg_init', str(i_df)])+'_Trajectory-XY.jpg'
    print(fullPathFigName)
    
    fig.append(plt.figure(figsize=[20, 20]))
    ax = plt.axes()

    title="planner trajectory"

    x1VarName="r3[1]"
    y1VarName="r3[2]"
    x2VarName="r2[1]"
    y2VarName="r2[2]"

    xlabel='x [km]'
    ylabel='y [km]'

    x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
    y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
    x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
    y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
    plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
    plt.grid()

    # --- drow planet
    planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
    ax.add_patch(planet)

    plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
    plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))
    
    plt.savefig(fullPathFigName)
    
    i_df=i_df+1
    print('')
#***** end for *****
print('------------------------------')
# Out:
# ------------------------------
#
# Dir to save figs is...
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat
#
# colBegin=458
# colEnd=657
#
# i=458
# i_df=3001
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3001.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3001_v3_init[2]=-10743_phi_r2_deg_init=-51_Trajectory-XY.jpg
#
# i=459
# i_df=3002
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3002.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3002_v3_init[2]=-10743_phi_r2_deg_init=-51.5_Trajectory-XY.jpg
#
# i=460
# i_df=3003
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3003.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3003_v3_init[2]=-10743_phi_r2_deg_init=-52_Trajectory-XY.jpg
#
# i=461
# i_df=3004
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3004.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3004_v3_init[2]=-10743_phi_r2_deg_init=-52.5_Trajectory-XY.jpg
#
# i=462
# i_df=3005
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3005.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3005_v3_init[2]=-10743_phi_r2_deg_init=-53_Trajectory-XY.jpg
#
# i=463
# i_df=3006
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3006.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3006_v3_init[2]=-10743_phi_r2_deg_init=-53.5_Trajectory-XY.jpg
#
# i=464
# i_df=3007
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3007.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3007_v3_init[2]=-10743_phi_r2_deg_init=-54_Trajectory-XY.jpg
#
# i=465
# i_df=3008
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3008.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3008_v3_init[2]=-10743_phi_r2_deg_init=-54.5_Trajectory-XY.jpg
#
# i=466
# i_df=3009
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3009.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3009_v3_init[2]=-10743_phi_r2_deg_init=-55_Trajectory-XY.jpg
#
# i=467
# i_df=3010
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3010.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3010_v3_init[2]=-10743_phi_r2_deg_init=-55.5_Trajectory-XY.jpg
#
# i=468
# i_df=3011
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3011.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3011_v3_init[2]=-10743_phi_r2_deg_init=-56_Trajectory-XY.jpg
#
# i=469
# i_df=3012
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3012.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3012_v3_init[2]=-10743_phi_r2_deg_init=-56.5_Trajectory-XY.jpg
#
# i=470
# i_df=3013
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3013.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3013_v3_init[2]=-10743_phi_r2_deg_init=-57_Trajectory-XY.jpg
#
# i=471
# i_df=3014
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3014.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3014_v3_init[2]=-10743_phi_r2_deg_init=-57.5_Trajectory-XY.jpg
#
# i=472
# i_df=3015
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3015.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3015_v3_init[2]=-10743_phi_r2_deg_init=-58_Trajectory-XY.jpg
#
# i=473
# i_df=3016
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3016.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3016_v3_init[2]=-10743_phi_r2_deg_init=-58.5_Trajectory-XY.jpg
#
# i=474
# i_df=3017
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3017.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3017_v3_init[2]=-10743_phi_r2_deg_init=-59_Trajectory-XY.jpg
#
# i=475
# i_df=3018
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3018.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3018_v3_init[2]=-10743_phi_r2_deg_init=-59.5_Trajectory-XY.jpg
#
# i=476
# i_df=3019
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3019.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3019_v3_init[2]=-10743_phi_r2_deg_init=-60_Trajectory-XY.jpg
#
# i=477
# i_df=3020
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3020.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3020_v3_init[2]=-10743_phi_r2_deg_init=-60.5_Trajectory-XY.jpg
#
# i=478
# i_df=3021
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3021.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3021_v3_init[2]=-10743_phi_r2_deg_init=-61_Trajectory-XY.jpg
#
# i=479
# i_df=3022
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3022.csv
# <ipython-input-16-b0c897749729>:51: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig.append(plt.figure(figsize=[20, 20]))
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3022_v3_init[2]=-10743_phi_r2_deg_init=-61.5_Trajectory-XY.jpg
#
# i=480
# i_df=3023
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3023.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3023_v3_init[2]=-10743_phi_r2_deg_init=-62_Trajectory-XY.jpg
#
# i=481
# i_df=3024
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3024.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3024_v3_init[2]=-10743_phi_r2_deg_init=-62.5_Trajectory-XY.jpg
#
# i=482
# i_df=3025
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3025.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3025_v3_init[2]=-10743_phi_r2_deg_init=-63_Trajectory-XY.jpg
#
# i=483
# i_df=3026
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3026.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3026_v3_init[2]=-10743_phi_r2_deg_init=-63.5_Trajectory-XY.jpg
#
# i=484
# i_df=3027
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3027.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3027_v3_init[2]=-10743_phi_r2_deg_init=-64_Trajectory-XY.jpg
#
# i=485
# i_df=3028
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3028.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3028_v3_init[2]=-10743_phi_r2_deg_init=-64.5_Trajectory-XY.jpg
#
# i=486
# i_df=3029
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3029.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3029_v3_init[2]=-10743_phi_r2_deg_init=-65_Trajectory-XY.jpg
#
# i=487
# i_df=3030
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3030.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3030_v3_init[2]=-10743_phi_r2_deg_init=-65.5_Trajectory-XY.jpg
#
# i=488
# i_df=3031
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3031.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3031_v3_init[2]=-10743_phi_r2_deg_init=-66_Trajectory-XY.jpg
#
# i=489
# i_df=3032
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3032.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3032_v3_init[2]=-10743_phi_r2_deg_init=-66.5_Trajectory-XY.jpg
#
# i=490
# i_df=3033
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3033.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3033_v3_init[2]=-10743_phi_r2_deg_init=-67_Trajectory-XY.jpg
#
# i=491
# i_df=3034
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3034.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3034_v3_init[2]=-10743_phi_r2_deg_init=-67.5_Trajectory-XY.jpg
#
# i=492
# i_df=3035
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3035.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3035_v3_init[2]=-10743_phi_r2_deg_init=-68_Trajectory-XY.jpg
#
# i=493
# i_df=3036
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3036.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3036_v3_init[2]=-10743_phi_r2_deg_init=-68.5_Trajectory-XY.jpg
#
# i=494
# i_df=3037
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3037.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3037_v3_init[2]=-10743_phi_r2_deg_init=-69_Trajectory-XY.jpg
#
# i=495
# i_df=3038
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3038.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3038_v3_init[2]=-10743_phi_r2_deg_init=-69.5_Trajectory-XY.jpg
#
# i=496
# i_df=3039
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3039.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3039_v3_init[2]=-10743_phi_r2_deg_init=-70_Trajectory-XY.jpg
#
# i=497
# i_df=3040
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3040.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3040_v3_init[2]=-10742_phi_r2_deg_init=-35_Trajectory-XY.jpg
#
# i=498
# i_df=3041
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3041.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3041_v3_init[2]=-10742_phi_r2_deg_init=-35.5_Trajectory-XY.jpg
#
# i=499
# i_df=3042
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3042.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3042_v3_init[2]=-10742_phi_r2_deg_init=-36_Trajectory-XY.jpg
#
# i=500
# i_df=3043
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3043.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3043_v3_init[2]=-10742_phi_r2_deg_init=-36.5_Trajectory-XY.jpg
#
# i=501
# i_df=3044
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3044.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3044_v3_init[2]=-10742_phi_r2_deg_init=-37_Trajectory-XY.jpg
#
# i=502
# i_df=3045
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3045.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3045_v3_init[2]=-10742_phi_r2_deg_init=-37.5_Trajectory-XY.jpg
#
# i=503
# i_df=3046
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3046.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3046_v3_init[2]=-10742_phi_r2_deg_init=-38_Trajectory-XY.jpg
#
# i=504
# i_df=3047
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3047.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3047_v3_init[2]=-10742_phi_r2_deg_init=-38.5_Trajectory-XY.jpg
#
# i=505
# i_df=3048
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3048.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3048_v3_init[2]=-10742_phi_r2_deg_init=-39_Trajectory-XY.jpg
#
# i=506
# i_df=3049
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3049.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3049_v3_init[2]=-10742_phi_r2_deg_init=-39.5_Trajectory-XY.jpg
#
# i=507
# i_df=3050
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3050.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3050_v3_init[2]=-10742_phi_r2_deg_init=-40_Trajectory-XY.jpg
#
# i=508
# i_df=3051
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3051.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3051_v3_init[2]=-10742_phi_r2_deg_init=-40.5_Trajectory-XY.jpg
#
# i=509
# i_df=3052
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3052.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3052_v3_init[2]=-10742_phi_r2_deg_init=-41_Trajectory-XY.jpg
#
# i=510
# i_df=3053
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3053.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3053_v3_init[2]=-10742_phi_r2_deg_init=-41.5_Trajectory-XY.jpg
#
# i=511
# i_df=3054
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3054.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3054_v3_init[2]=-10742_phi_r2_deg_init=-42_Trajectory-XY.jpg
#
# i=512
# i_df=3055
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3055.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3055_v3_init[2]=-10742_phi_r2_deg_init=-42.5_Trajectory-XY.jpg
#
# i=513
# i_df=3056
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3056.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3056_v3_init[2]=-10742_phi_r2_deg_init=-43_Trajectory-XY.jpg
#
# i=514
# i_df=3057
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3057.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3057_v3_init[2]=-10742_phi_r2_deg_init=-43.5_Trajectory-XY.jpg
#
# i=515
# i_df=3058
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3058.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3058_v3_init[2]=-10742_phi_r2_deg_init=-44_Trajectory-XY.jpg
#
# i=516
# i_df=3059
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3059.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3059_v3_init[2]=-10742_phi_r2_deg_init=-44.5_Trajectory-XY.jpg
#
# i=517
# i_df=3060
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3060.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3060_v3_init[2]=-10742_phi_r2_deg_init=-45_Trajectory-XY.jpg
#
# i=518
# i_df=3061
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3061.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3061_v3_init[2]=-10742_phi_r2_deg_init=-45.5_Trajectory-XY.jpg
#
# i=519
# i_df=3062
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3062.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3062_v3_init[2]=-10742_phi_r2_deg_init=-46_Trajectory-XY.jpg
#
# i=520
# i_df=3063
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3063.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3063_v3_init[2]=-10742_phi_r2_deg_init=-46.5_Trajectory-XY.jpg
#
# i=521
# i_df=3064
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3064.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3064_v3_init[2]=-10742_phi_r2_deg_init=-47_Trajectory-XY.jpg
#
# i=522
# i_df=3065
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3065.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3065_v3_init[2]=-10742_phi_r2_deg_init=-47.5_Trajectory-XY.jpg
#
# i=523
# i_df=3066
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3066.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3066_v3_init[2]=-10742_phi_r2_deg_init=-48_Trajectory-XY.jpg
#
# i=524
# i_df=3067
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3067.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3067_v3_init[2]=-10742_phi_r2_deg_init=-48.5_Trajectory-XY.jpg
#
# i=525
# i_df=3068
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3068.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3068_v3_init[2]=-10742_phi_r2_deg_init=-49_Trajectory-XY.jpg
#
# i=526
# i_df=3069
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3069.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3069_v3_init[2]=-10742_phi_r2_deg_init=-49.5_Trajectory-XY.jpg
#
# i=527
# i_df=3070
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3070.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3070_v3_init[2]=-10742_phi_r2_deg_init=-50_Trajectory-XY.jpg
#
# i=528
# i_df=3071
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3071.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3071_v3_init[2]=-10742_phi_r2_deg_init=-50.5_Trajectory-XY.jpg
#
# i=529
# i_df=3072
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3072.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3072_v3_init[2]=-10742_phi_r2_deg_init=-51_Trajectory-XY.jpg
#
# i=530
# i_df=3073
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3073.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3073_v3_init[2]=-10742_phi_r2_deg_init=-51.5_Trajectory-XY.jpg
#
# i=531
# i_df=3074
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3074.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3074_v3_init[2]=-10742_phi_r2_deg_init=-52_Trajectory-XY.jpg
#
# i=532
# i_df=3075
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3075.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3075_v3_init[2]=-10742_phi_r2_deg_init=-52.5_Trajectory-XY.jpg
#
# i=533
# i_df=3076
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3076.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3076_v3_init[2]=-10742_phi_r2_deg_init=-53_Trajectory-XY.jpg
#
# i=534
# i_df=3077
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3077.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3077_v3_init[2]=-10742_phi_r2_deg_init=-53.5_Trajectory-XY.jpg
#
# i=535
# i_df=3078
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3078.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3078_v3_init[2]=-10742_phi_r2_deg_init=-54_Trajectory-XY.jpg
#
# i=536
# i_df=3079
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3079.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3079_v3_init[2]=-10742_phi_r2_deg_init=-54.5_Trajectory-XY.jpg
#
# i=537
# i_df=3080
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3080.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3080_v3_init[2]=-10742_phi_r2_deg_init=-55_Trajectory-XY.jpg
#
# i=538
# i_df=3081
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3081.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3081_v3_init[2]=-10742_phi_r2_deg_init=-55.5_Trajectory-XY.jpg
#
# i=539
# i_df=3082
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3082.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3082_v3_init[2]=-10742_phi_r2_deg_init=-56_Trajectory-XY.jpg
#
# i=540
# i_df=3083
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3083.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3083_v3_init[2]=-10742_phi_r2_deg_init=-56.5_Trajectory-XY.jpg
#
# i=541
# i_df=3084
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3084.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3084_v3_init[2]=-10742_phi_r2_deg_init=-57_Trajectory-XY.jpg
#
# i=542
# i_df=3085
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3085.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3085_v3_init[2]=-10742_phi_r2_deg_init=-57.5_Trajectory-XY.jpg
#
# i=543
# i_df=3086
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3086.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3086_v3_init[2]=-10742_phi_r2_deg_init=-58_Trajectory-XY.jpg
#
# i=544
# i_df=3087
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3087.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3087_v3_init[2]=-10742_phi_r2_deg_init=-58.5_Trajectory-XY.jpg
#
# i=545
# i_df=3088
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3088.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3088_v3_init[2]=-10742_phi_r2_deg_init=-59_Trajectory-XY.jpg
#
# i=546
# i_df=3089
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3089.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3089_v3_init[2]=-10742_phi_r2_deg_init=-59.5_Trajectory-XY.jpg
#
# i=547
# i_df=3090
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3090.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3090_v3_init[2]=-10742_phi_r2_deg_init=-60_Trajectory-XY.jpg
#
# i=548
# i_df=3091
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3091.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3091_v3_init[2]=-10742_phi_r2_deg_init=-60.5_Trajectory-XY.jpg
#
# i=549
# i_df=3092
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3092.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3092_v3_init[2]=-10742_phi_r2_deg_init=-61_Trajectory-XY.jpg
#
# i=550
# i_df=3093
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3093.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3093_v3_init[2]=-10742_phi_r2_deg_init=-61.5_Trajectory-XY.jpg
#
# i=551
# i_df=3094
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3094.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3094_v3_init[2]=-10742_phi_r2_deg_init=-62_Trajectory-XY.jpg
#
# i=552
# i_df=3095
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3095.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3095_v3_init[2]=-10742_phi_r2_deg_init=-62.5_Trajectory-XY.jpg
#
# i=553
# i_df=3096
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3096.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3096_v3_init[2]=-10742_phi_r2_deg_init=-63_Trajectory-XY.jpg
#
# i=554
# i_df=3097
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3097.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3097_v3_init[2]=-10742_phi_r2_deg_init=-63.5_Trajectory-XY.jpg
#
# i=555
# i_df=3098
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3098.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3098_v3_init[2]=-10742_phi_r2_deg_init=-64_Trajectory-XY.jpg
#
# i=556
# i_df=3099
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3099.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3099_v3_init[2]=-10742_phi_r2_deg_init=-64.5_Trajectory-XY.jpg
#
# i=557
# i_df=3100
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3100.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3100_v3_init[2]=-10742_phi_r2_deg_init=-65_Trajectory-XY.jpg
#
# i=558
# i_df=3101
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3101.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3101_v3_init[2]=-10742_phi_r2_deg_init=-65.5_Trajectory-XY.jpg
#
# i=559
# i_df=3102
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3102.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3102_v3_init[2]=-10742_phi_r2_deg_init=-66_Trajectory-XY.jpg
#
# i=560
# i_df=3103
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3103.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3103_v3_init[2]=-10742_phi_r2_deg_init=-66.5_Trajectory-XY.jpg
#
# i=561
# i_df=3104
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3104.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3104_v3_init[2]=-10742_phi_r2_deg_init=-67_Trajectory-XY.jpg
#
# i=562
# i_df=3105
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3105.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3105_v3_init[2]=-10742_phi_r2_deg_init=-67.5_Trajectory-XY.jpg
#
# i=563
# i_df=3106
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3106.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3106_v3_init[2]=-10742_phi_r2_deg_init=-68_Trajectory-XY.jpg
#
# i=564
# i_df=3107
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3107.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3107_v3_init[2]=-10742_phi_r2_deg_init=-68.5_Trajectory-XY.jpg
#
# i=565
# i_df=3108
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3108.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3108_v3_init[2]=-10742_phi_r2_deg_init=-69_Trajectory-XY.jpg
#
# i=566
# i_df=3109
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3109.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3109_v3_init[2]=-10742_phi_r2_deg_init=-69.5_Trajectory-XY.jpg
#
# i=567
# i_df=3110
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3110.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3110_v3_init[2]=-10742_phi_r2_deg_init=-70_Trajectory-XY.jpg
#
# i=568
# i_df=3111
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3111.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3111_v3_init[2]=-10741_phi_r2_deg_init=-35_Trajectory-XY.jpg
#
# i=569
# i_df=3112
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3112.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3112_v3_init[2]=-10741_phi_r2_deg_init=-35.5_Trajectory-XY.jpg
#
# i=570
# i_df=3113
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3113.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3113_v3_init[2]=-10741_phi_r2_deg_init=-36_Trajectory-XY.jpg
#
# i=571
# i_df=3114
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3114.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3114_v3_init[2]=-10741_phi_r2_deg_init=-36.5_Trajectory-XY.jpg
#
# i=572
# i_df=3115
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3115.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3115_v3_init[2]=-10741_phi_r2_deg_init=-37_Trajectory-XY.jpg
#
# i=573
# i_df=3116
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3116.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3116_v3_init[2]=-10741_phi_r2_deg_init=-37.5_Trajectory-XY.jpg
#
# i=574
# i_df=3117
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3117.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3117_v3_init[2]=-10741_phi_r2_deg_init=-38_Trajectory-XY.jpg
#
# i=575
# i_df=3118
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3118.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3118_v3_init[2]=-10741_phi_r2_deg_init=-38.5_Trajectory-XY.jpg
#
# i=576
# i_df=3119
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3119.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3119_v3_init[2]=-10741_phi_r2_deg_init=-39_Trajectory-XY.jpg
#
# i=577
# i_df=3120
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3120.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3120_v3_init[2]=-10741_phi_r2_deg_init=-39.5_Trajectory-XY.jpg
#
# i=578
# i_df=3121
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3121.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3121_v3_init[2]=-10741_phi_r2_deg_init=-40_Trajectory-XY.jpg
#
# i=579
# i_df=3122
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3122.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3122_v3_init[2]=-10741_phi_r2_deg_init=-40.5_Trajectory-XY.jpg
#
# i=580
# i_df=3123
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3123.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3123_v3_init[2]=-10741_phi_r2_deg_init=-41_Trajectory-XY.jpg
#
# i=581
# i_df=3124
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3124.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3124_v3_init[2]=-10741_phi_r2_deg_init=-41.5_Trajectory-XY.jpg
#
# i=582
# i_df=3125
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3125.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3125_v3_init[2]=-10741_phi_r2_deg_init=-42_Trajectory-XY.jpg
#
# i=583
# i_df=3126
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3126.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3126_v3_init[2]=-10741_phi_r2_deg_init=-42.5_Trajectory-XY.jpg
#
# i=584
# i_df=3127
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3127.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3127_v3_init[2]=-10741_phi_r2_deg_init=-43_Trajectory-XY.jpg
#
# i=585
# i_df=3128
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3128.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3128_v3_init[2]=-10741_phi_r2_deg_init=-43.5_Trajectory-XY.jpg
#
# i=586
# i_df=3129
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3129.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3129_v3_init[2]=-10741_phi_r2_deg_init=-44_Trajectory-XY.jpg
#
# i=587
# i_df=3130
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3130.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3130_v3_init[2]=-10741_phi_r2_deg_init=-44.5_Trajectory-XY.jpg
#
# i=588
# i_df=3131
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3131.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3131_v3_init[2]=-10741_phi_r2_deg_init=-45_Trajectory-XY.jpg
#
# i=589
# i_df=3132
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3132.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3132_v3_init[2]=-10741_phi_r2_deg_init=-45.5_Trajectory-XY.jpg
#
# i=590
# i_df=3133
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3133.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3133_v3_init[2]=-10741_phi_r2_deg_init=-46_Trajectory-XY.jpg
#
# i=591
# i_df=3134
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3134.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3134_v3_init[2]=-10741_phi_r2_deg_init=-46.5_Trajectory-XY.jpg
#
# i=592
# i_df=3135
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3135.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3135_v3_init[2]=-10741_phi_r2_deg_init=-47_Trajectory-XY.jpg
#
# i=593
# i_df=3136
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3136.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3136_v3_init[2]=-10741_phi_r2_deg_init=-47.5_Trajectory-XY.jpg
#
# i=594
# i_df=3137
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3137.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3137_v3_init[2]=-10741_phi_r2_deg_init=-48_Trajectory-XY.jpg
#
# i=595
# i_df=3138
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3138.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3138_v3_init[2]=-10741_phi_r2_deg_init=-48.5_Trajectory-XY.jpg
#
# i=596
# i_df=3139
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3139.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3139_v3_init[2]=-10741_phi_r2_deg_init=-49_Trajectory-XY.jpg
#
# i=597
# i_df=3140
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3140.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3140_v3_init[2]=-10741_phi_r2_deg_init=-49.5_Trajectory-XY.jpg
#
# i=598
# i_df=3141
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3141.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_3141_v3_init[2]=-10741_phi_r2_deg_init=-50_Trajectory-XY.jpg
#
# i=599
# i_df=3142
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_3142.csv

# %% [markdown]
# <h1>===========================================================================</h1>

# %%
i_df=249
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
'''
i_df=1
fig.append(plt.figure(figsize = (18, 18)))
ax = fig[-1].add_subplot(111, projection="3d")

# ***** Make data for sphere *****
u = numpy.linspace(0, 2 * numpy.pi, 50)
v = numpy.linspace(0, numpy.pi, 50)
radius= 6378.137
xShpere = radius * numpy.outer(numpy.cos(u), numpy.sin(v))
yShpere = radius * numpy.outer(numpy.sin(u), numpy.sin(v))
zShpere = radius * numpy.outer(numpy.ones(numpy.size(u)), numpy.cos(v))

ax.plot_surface(xShpere, yShpere, zShpere, zorder=-1, color='green')

# ***** plot trajectry *****
title="flight trajectory"
xVarName="r2[1]"
yVarName="r2[2]"
zVarName="r2[3]"
xlabel='x [km]'
ylabel='y [km]'
zlabel="z [km]"

xVar= df[i_df].loc[:, xVarName]*1.0/1000.0
yVar= df[i_df].loc[:, yVarName]*1.0/1000.0
zVar= df[i_df].loc[:, zVarName]*1.0/1000.0

ax.set_title(title, size=20)
ax.set_xlabel(xlabel, size=12)
ax.set_ylabel(ylabel, size=12)
ax.set_zlabel(zlabel, size=12)

ax.plot(xVar, yVar, zVar, zorder=2, color='red', linewidth=1.0)

plt.grid()
ax.set_xlim(0, 240)
ax.set_ylim(0, 240)
ax.set_zlim(0, 100+10)
ax.set_xticks( numpy.arange(-10000, 12000, 2000) )
ax.set_yticks( numpy.arange(-10000, 12000, 2000) )
ax.set_zticks( numpy.arange(-10000, 12000, 2000) )

ax.view_init( elev=70, azim=-60 )

print('------------------------------')
'''

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
