# %% [markdown]
# <h1>Visualize ExeBuiltByOMEdit: AircraftDynamics.PtMassFDM.DoF3.Examples.TwoBodyOrbital00</h1>
# <h2>notebook: rev001</h2>
# <p>compatability with OpenModelica v1.21.0</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import numpy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib
import math

from IPython.display import display, HTML

backslash= '\\'
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'
swWorkSubDir= 'fullpathModel'
'''
'None': 
'fullPathModel': work in sub dir named with fullaPathModel
'''

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00'
nmModel='ThreeBodyOrbital00'
outputFormat='csv'

#****************************************
#    User must NOT edit code below 
#****************************************
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
if(swWorkSubDir=='fullpathModel'):
    dirWorkRelToHome= dirWorkRelToHome + '/' + fullpathModel
##### end if #####

print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirHome= dirHome.replace(backslash, '/')
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF3/Examples/ThreeBodyOrbital00.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization, evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00")
# OMShell: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization, evaluateAllParameters,NLSanalyticJacobian")
# OMShell: False
#
# OMShell error message:
#
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#nmcsv= fullpathModel + '_res.csv'
nmcsv= nmModel + '_res.csv'
fullpathFile= os.getcwd()+"/"+nmcsv
fullpathFile= fullpathFile.replace(backslash, "/")
print("data read: "+ fullpathFile)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#         time  r1[1]  r1[2]  r1[3]         r2[1]         r2[2]  r2[3]  \
# 0          0      0      0      0  3.328993e+08 -1.921995e+08      0
# 1         30      0      0      0  3.329146e+08 -1.921729e+08      0
# 2         60      0      0      0  3.329300e+08 -1.921464e+08      0
# 3         90      0      0      0  3.329453e+08 -1.921198e+08      0
# 4        120      0      0      0  3.329606e+08 -1.920933e+08      0
# ...      ...    ...    ...    ...           ...           ...    ...
# 5757  172710      0      0      0  3.838839e+08 -2.485144e+07      0
# 5758  172740      0      0      0  3.838860e+08 -2.482087e+07      0
# 5759  172770      0      0      0  3.838881e+08 -2.479030e+07      0
# 5760  172800      0      0      0  3.838901e+08 -2.475974e+07      0
# 5761  172800      0      0      0  3.838901e+08 -2.475974e+07      0
#
#              r3[1]         r3[2]  r3[3]  ...       v2_3[2]  v2_3[3]  \
# 0    -6.778137e+06  0.000000e+00      0  ... -10885.077963        0
# 1    -6.774234e+06 -2.999424e+05      0  ... -10879.362330        0
# 2    -6.762540e+06 -5.995401e+05      0  ... -10862.185347        0
# 3    -6.743096e+06 -8.984510e+05      0  ... -10833.689497        0
# 4    -6.715969e+06 -1.196339e+06      0  ... -10794.108611        0
# ...            ...           ...    ...  ...           ...      ...
# 5757  9.445119e+06 -1.552959e+07      0  ...  -2079.639319        0
# 5758  9.595210e+06 -1.556095e+07      0  ...  -2048.956638        0
# 5759  9.744739e+06 -1.559139e+07      0  ...  -2018.737901        0
# 5760  9.893704e+06 -1.562094e+07      0  ...  -1988.973064        0
# 5761  9.893704e+06 -1.562094e+07      0  ...  -1988.973064        0
#
#            v2_3Abs         v3Abs     a2[1]     a2[2]  a2[3]     a3[1]  \
# 0     10897.065809  10000.000000 -0.002336  0.001349      0  8.675678
# 1     10882.253103   9997.628285 -0.002336  0.001349      0  8.660198
# 2     10862.188629   9990.532248 -0.002336  0.001348      0  8.613986
# 3     10836.951253   9978.759930 -0.002336  0.001348      0  8.537720
# 4     10806.653668   9962.390257 -0.002337  0.001348      0  8.432505
# ...            ...           ...       ...       ...    ...       ...
# 5757   5362.840663   5123.451352 -0.002688  0.000174      0 -0.626960
# 5758   5333.733240   5098.776374 -0.002688  0.000174      0 -0.625998
# 5759   5304.914091   5074.357659 -0.002688  0.000174      0 -0.624951
# 5760   5276.378236   5050.190846 -0.002688  0.000173      0 -0.623824
# 5761   5276.378236   5050.190846 -0.002688  0.000173      0 -0.623824
#
#          a3[2]  a3[3]
# 0     0.000016      0
# 1     0.383464      0
# 2     0.763700      0
# 3     1.137587      0
# 4     1.502132      0
# ...        ...    ...
# 5757  1.030786      0
# 5758  1.015151      0
# 5759  0.999854      0
# 5760  0.984886      0
# 5761  0.984886      0
#
# [5762 rows x 110 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'r1[1]',
#  'r1[2]',
#  'r1[3]',
#  'r2[1]',
#  'r2[2]',
#  'r2[3]',
#  'r3[1]',
#  'r3[2]',
#  'r3[3]',
#  'v1[1]',
#  'v1[2]',
#  'v1[3]',
#  'v2[1]',
#  'v2[2]',
#  'v2[3]',
#  'v3[1]',
#  'v3[2]',
#  'v3[3]',
#  'der(r1[1])',
#  'der(r1[2])',
#  'der(r1[3])',
#  'der(r2[1])',
#  'der(r2[2])',
#  'der(r2[3])',
#  'der(r3[1])',
#  'der(r3[2])',
#  'der(r3[3])',
#  'der(v1[1])',
#  'der(v1[2])',
#  'der(v1[3])',
#  'der(v2[1])',
#  'der(v2[2])',
#  'der(v2[3])',
#  'der(v3[1])',
#  'der(v3[2])',
#  'der(v3[3])',
#  'Alt',
#  'Fg1_2[1]',
#  'Fg1_2[2]',
#  'Fg1_2[3]',
#  'Fg1_3[1]',
#  'Fg1_3[2]',
#  'Fg1_3[3]',
#  'Fg2_1[1]',
#  'Fg2_1[2]',
#  'Fg2_1[3]',
#  'Fg2_3[1]',
#  'Fg2_3[2]',
#  'Fg2_3[3]',
#  'Fg3_1[1]',
#  'Fg3_1[2]',
#  'Fg3_1[3]',
#  'Fg3_2[1]',
#  'Fg3_2[2]',
#  'Fg3_2[3]',
#  'a1[1]',
#  'a1[2]',
#  'a1[3]',
#  'a1Abs',
#  'a1_2[1]',
#  'a1_2[2]',
#  'a1_2[3]',
#  'a1_2Abs',
#  'a1_3[1]',
#  'a1_3[2]',
#  'a1_3[3]',
#  'a1_3Abs',
#  'a2Abs',
#  'a2_3[1]',
#  'a2_3[2]',
#  'a2_3[3]',
#  'a2_3Abs',
#  'a3Abs',
#  'mag_r1',
#  'mag_r1_2',
#  'mag_r1_3',
#  'mag_r2',
#  'mag_r2_3',
#  'mag_r3',
#  'r1_2[1]',
#  'r1_2[2]',
#  'r1_2[3]',
#  'r1_3[1]',
#  'r1_3[2]',
#  'r1_3[3]',
#  'r2_3[1]',
#  'r2_3[2]',
#  'r2_3[3]',
#  'v1Abs',
#  'v1_2[1]',
#  'v1_2[2]',
#  'v1_2[3]',
#  'v1_2Abs',
#  'v1_3[1]',
#  'v1_3[2]',
#  'v1_3[3]',
#  'v1_3Abs',
#  'v2Abs',
#  'v2_3[1]',
#  'v2_3[2]',
#  'v2_3[3]',
#  'v2_3Abs',
#  'v3Abs',
#  'a2[1]',
#  'a2[2]',
#  'a2[3]',
#  'a3[1]',
#  'a3[2]',
#  'a3[3]']

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
fullpathFile= os.getcwd()+"/"+nmcsv
fullpathFile= fullpathFile.replace(backslash, "/")
print("data read: "+ fullpathFile)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
#          time  r1[1]  r1[2]  r1[3]         r2[1]         r2[2]  r2[3]  \
# 0           0      0      0      0  3.148812e+08 -2.204822e+08      0
# 1          50      0      0      0  3.149105e+08 -2.204403e+08      0
# 2         100      0      0      0  3.149398e+08 -2.203985e+08      0
# 3         150      0      0      0  3.149691e+08 -2.203566e+08      0
# 4         200      0      0      0  3.149984e+08 -2.203147e+08      0
# ...       ...    ...    ...    ...           ...           ...    ...
# 15997  799850      0      0      0  2.850330e+07  3.876106e+08      0
# 15998  799900      0      0      0  2.845292e+07  3.876146e+08      0
# 15999  799950      0      0      0  2.840254e+07  3.876186e+08      0
# 16000  800000      0      0      0  2.835215e+07  3.876227e+08      0
# 16001  800000      0      0      0  2.835215e+07  3.876227e+08      0
#
#               r3[1]         r3[2]  r3[3]  ...       v2_3[2]  v2_3[3]  \
# 0     -6.778137e+06  0.000000e+00      0  ... -11587.173389        0
# 1     -6.767304e+06 -5.372138e+05      0  ... -11570.096191        0
# 2     -6.734939e+06 -1.072721e+06      0  ... -11519.237681        0
# 3     -6.681435e+06 -1.604867e+06      0  ... -11436.121683        0
# 4     -6.607427e+06 -2.132096e+06      0  ... -11323.163420        0
# ...             ...           ...    ...  ...           ...      ...
# 15997  1.479364e+08 -3.003289e+07      0  ...   -173.200757        0
# 15998  1.480237e+08 -3.003752e+07      0  ...   -172.896558        0
# 15999  1.481110e+08 -3.004214e+07      0  ...   -172.592630        0
# 16000  1.481983e+08 -3.004676e+07      0  ...   -172.288971        0
# 16001  1.481983e+08 -3.004676e+07      0  ...   -172.288971        0
#
#             v2_3Abs         v3Abs     a2[1]     a2[2]  a2[3]     a3[1]  \
# 0      11601.991720  10750.000000 -0.002210  0.001547      0  8.675680
# 1      11571.110399  10741.571635 -0.002210  0.001547      0  8.621850
# 2      11522.506967  10716.508065 -0.002210  0.001547      0  8.463235
# 3      11457.023146  10675.441458 -0.002210  0.001546      0  8.208124
# 4      11375.899391  10619.388393 -0.002210  0.001546      0  7.869240
# ...             ...           ...       ...       ...    ...       ...
# 15997   2759.930149   1749.335141 -0.000194 -0.002632      0 -0.017135
# 15998   2759.066140   1748.470934 -0.000193 -0.002632      0 -0.017116
# 15999   2758.203118   1747.607714 -0.000193 -0.002632      0 -0.017096
# 16000   2757.341080   1746.745480 -0.000192 -0.002632      0 -0.017077
# 16001   2757.341080   1746.745480 -0.000192 -0.002632      0 -0.017077
#
#           a3[2]  a3[3]
# 0      0.000018      0
# 1      0.684455      0
# 2      1.348022      0
# 3      1.971599      0
# 4      2.539286      0
# ...         ...    ...
# 15997  0.003455      0
# 15998  0.003450      0
# 15999  0.003444      0
# 16000  0.003439      0
# 16001  0.003439      0
#
# [16002 rows x 110 columns]

# %% [markdown]
# <h2>Read Parameters CSV Table</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
nameParameterTableCSV="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_2.csv"
swDir="ipynbs"
'''
'ipynbs': csv is in the save directory as this ipynbs
'workDir': csv is in the same directory as working dir
'''
if(swDir=='workDir'):
    fullPathCSV= nameParameterTableCSV
elif(swDir=='ipynbs'):
    fullPathCSV= pathNotebook+'/'+nameParameterTableCSV
#***** end if *****


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')
#----------

print("Reading CSV...")
print(fullPathCSV)
df_parameter = pd.read_csv(fullPathCSV, index_col=0, header=0)

print(''); 
print("Parameter Table read:")
print(df_parameter)
print('------------------------------')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# Reading CSV...
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_2.csv
#
# Parameter Table read:
#                      1024      1025      1026      1027      1028      1029  \
# swExec                Not       Not       Not       Not       Not       Not
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10783    -10783    -10783    -10783    -10783    -10783
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -35     -35.5       -36     -36.5       -37     -37.5
#
#                      1030      1031      1032      1033  ...      1262  \
# swExec                Not       Not       Not       Not  ...      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  ...  -6778137
# r3_init[2]              0         0         0         0  ...         0
# r3_init[3]              0         0         0         0  ...         0
# v3_init[1]              0         0         0         0  ...         0
# v3_init[2]         -10783    -10783    -10783    -10783  ...    -10790
# v3_init[3]              0         0         0         0  ...         0
# phi_r2_deg_init       -38     -38.5       -39     -39.5  ...     -45.5
#
#                      1263      1264      1265      1266      1267      1268  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10790    -10790    -10790    -10790    -10790    -10790
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -46     -46.5       -47     -47.5       -48     -48.5
#
#                      1269      1270      1271
# swExec               Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137
# r3_init[2]              0         0         0
# r3_init[3]              0         0         0
# v3_init[1]              0         0         0
# v3_init[2]         -10790    -10790    -10790
# v3_init[3]              0         0         0
# phi_r2_deg_init       -49     -49.5       -50
#
# [8 rows x 248 columns]
# ------------------------------
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Read csv, multi-cases</h1>

# %%
iRunBegin= 1
iRunEnd= 2

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    i_df=i
    nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
    fullpathFile= os.getcwd()+"/"+nmcsv
    fullpathFile= fullpathFile.replace(backslash, "/")
    print("data read: "+ fullpathFile)
    df.insert(i_df, pd.read_csv(nmcsv))
    
    print('')
#***** end for *****

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_501.csv
#
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_502.csv
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=0
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')
# Out:
# i_df= 0
# v3_init[2]=-10782
# phi_r2_deg_init=-50
# ------------------------------

# %%
i_df=0
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')
# Out:
# i_df= 0
# v3_init[2]=-10782
# phi_r2_deg_init=-50
# ------------------------------

# %% [markdown]
# <h1>===========================================================================</h1>

# %%
i_df_begin= 1024
i_df_end= 1054

subDir="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat"
swDir="ipynbs"
'''
'ipynbs': csv is in the save directory as this ipynbs
'workDir': csv is in the same directory as working dir
'''

if(swDir=='workDir'):
    fullPathDir= dirWork+'/'+subDir
elif(swDir=='ipynbs'):
    fullPathDir= pathNotebook+'/'+subDir
#***** end if *****
print('Dir to save figs is...')
print(fullPathDir)
print('')

#************************************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()

print('colBegin='+str(df_parameter.columns.get_loc(str(i_df_begin))))
print('colEnd='+str(df_parameter.columns.get_loc(str(i_df_end))))
print('')

for i in range(df_parameter.columns.get_loc(str(i_df_begin)), df_parameter.columns.get_loc(str(i_df_end))+1):
    i_df=i_df_begin+i
    print('i='+str(i))
    print('i_df='+str(i_df))
    
    nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
    fullpathFile= os.getcwd()+"/"+nmcsv
    fullpathFile= fullpathFile.replace(backslash, "/")
    print("data read: "+ fullpathFile)
    df.insert(i_df, pd.read_csv(nmcsv))
    
    fullPathFigName= fullPathDir+'/'+'case_'+str(i_df)+'_'+df_parameter.index[5]+'='+str(df_parameter.loc['v3_init[2]', str(i_df)])+'_'+df_parameter.index[7]+'='+str(df_parameter.loc['phi_r2_deg_init', str(i_df)])+'_Trajectory-XY.jpg'
    print(fullPathFigName)
    
    fig.append(plt.figure(figsize=[20, 20]))
    ax = plt.axes()

    title="planner trajectory"

    x1VarName="r3[1]"
    y1VarName="r3[2]"
    x2VarName="r2[1]"
    y2VarName="r2[2]"

    xlabel='x [km]'
    ylabel='y [km]'

    x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
    y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
    x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
    y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
    plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
    plt.grid()

    # --- drow planet
    planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
    ax.add_patch(planet)

    plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
    plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))
    
    plt.savefig(fullPathFigName)
    
    print('')
#***** end for *****
print('------------------------------')
# Out:
# Dir to save figs is...
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat
#
# colBegin=0
# colEnd=30
#
# i=0
# i_df=1024
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1024.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1024_v3_init[2]=-10783_phi_r2_deg_init=-35_Trajectory-XY.jpg
#
# i=1
# i_df=1025
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1025.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1025_v3_init[2]=-10783_phi_r2_deg_init=-35.5_Trajectory-XY.jpg
#
# i=2
# i_df=1026
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1026.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1026_v3_init[2]=-10783_phi_r2_deg_init=-36_Trajectory-XY.jpg
#
# i=3
# i_df=1027
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1027.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1027_v3_init[2]=-10783_phi_r2_deg_init=-36.5_Trajectory-XY.jpg
#
# i=4
# i_df=1028
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1028.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1028_v3_init[2]=-10783_phi_r2_deg_init=-37_Trajectory-XY.jpg
#
# i=5
# i_df=1029
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1029.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1029_v3_init[2]=-10783_phi_r2_deg_init=-37.5_Trajectory-XY.jpg
#
# i=6
# i_df=1030
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1030.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1030_v3_init[2]=-10783_phi_r2_deg_init=-38_Trajectory-XY.jpg
#
# i=7
# i_df=1031
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1031.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1031_v3_init[2]=-10783_phi_r2_deg_init=-38.5_Trajectory-XY.jpg
#
# i=8
# i_df=1032
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1032.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1032_v3_init[2]=-10783_phi_r2_deg_init=-39_Trajectory-XY.jpg
#
# i=9
# i_df=1033
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1033.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1033_v3_init[2]=-10783_phi_r2_deg_init=-39.5_Trajectory-XY.jpg
#
# i=10
# i_df=1034
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1034.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1034_v3_init[2]=-10783_phi_r2_deg_init=-40_Trajectory-XY.jpg
#
# i=11
# i_df=1035
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1035.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1035_v3_init[2]=-10783_phi_r2_deg_init=-40.5_Trajectory-XY.jpg
#
# i=12
# i_df=1036
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1036.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1036_v3_init[2]=-10783_phi_r2_deg_init=-41_Trajectory-XY.jpg
#
# i=13
# i_df=1037
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1037.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1037_v3_init[2]=-10783_phi_r2_deg_init=-41.5_Trajectory-XY.jpg
#
# i=14
# i_df=1038
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1038.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1038_v3_init[2]=-10783_phi_r2_deg_init=-42_Trajectory-XY.jpg
#
# i=15
# i_df=1039
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1039.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1039_v3_init[2]=-10783_phi_r2_deg_init=-42.5_Trajectory-XY.jpg
#
# i=16
# i_df=1040
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1040.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1040_v3_init[2]=-10783_phi_r2_deg_init=-43_Trajectory-XY.jpg
#
# i=17
# i_df=1041
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1041.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1041_v3_init[2]=-10783_phi_r2_deg_init=-43.5_Trajectory-XY.jpg
#
# i=18
# i_df=1042
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1042.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1042_v3_init[2]=-10783_phi_r2_deg_init=-44_Trajectory-XY.jpg
#
# i=19
# i_df=1043
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1043.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1043_v3_init[2]=-10783_phi_r2_deg_init=-44.5_Trajectory-XY.jpg
#
# i=20
# i_df=1044
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1044.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1044_v3_init[2]=-10783_phi_r2_deg_init=-45_Trajectory-XY.jpg
# <ipython-input-56-53e672b49f2c>:43: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig.append(plt.figure(figsize=[20, 20]))
# i=21
# i_df=1045
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1045.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1045_v3_init[2]=-10783_phi_r2_deg_init=-45.5_Trajectory-XY.jpg
#
# i=22
# i_df=1046
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1046.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1046_v3_init[2]=-10783_phi_r2_deg_init=-46_Trajectory-XY.jpg
#
# i=23
# i_df=1047
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1047.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1047_v3_init[2]=-10783_phi_r2_deg_init=-46.5_Trajectory-XY.jpg
#
# i=24
# i_df=1048
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1048.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1048_v3_init[2]=-10783_phi_r2_deg_init=-47_Trajectory-XY.jpg
#
# i=25
# i_df=1049
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1049.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1049_v3_init[2]=-10783_phi_r2_deg_init=-47.5_Trajectory-XY.jpg
#
# i=26
# i_df=1050
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1050.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1050_v3_init[2]=-10783_phi_r2_deg_init=-48_Trajectory-XY.jpg
#
# i=27
# i_df=1051
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1051.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1051_v3_init[2]=-10783_phi_r2_deg_init=-48.5_Trajectory-XY.jpg
#
# i=28
# i_df=1052
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1052.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1052_v3_init[2]=-10783_phi_r2_deg_init=-49_Trajectory-XY.jpg
#
# i=29
# i_df=1053
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1053.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1053_v3_init[2]=-10783_phi_r2_deg_init=-49.5_Trajectory-XY.jpg
#
# i=30
# i_df=1054
# data read: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1054.csv
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_visualizeDat/case_1054_v3_init[2]=-10783_phi_r2_deg_init=-50_Trajectory-XY.jpg
#
# ------------------------------

# %% [markdown]
# <h1>===========================================================================</h1>

# %%
i_df=249
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
i_df=i_df+1
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[10, 10]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xlim(-500000, 500000) #plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.ylim(-500000, 500000) #plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')

# %%
'''
i_df=1
fig.append(plt.figure(figsize = (18, 18)))
ax = fig[-1].add_subplot(111, projection="3d")

# ***** Make data for sphere *****
u = numpy.linspace(0, 2 * numpy.pi, 50)
v = numpy.linspace(0, numpy.pi, 50)
radius= 6378.137
xShpere = radius * numpy.outer(numpy.cos(u), numpy.sin(v))
yShpere = radius * numpy.outer(numpy.sin(u), numpy.sin(v))
zShpere = radius * numpy.outer(numpy.ones(numpy.size(u)), numpy.cos(v))

ax.plot_surface(xShpere, yShpere, zShpere, zorder=-1, color='green')

# ***** plot trajectry *****
title="flight trajectory"
xVarName="r2[1]"
yVarName="r2[2]"
zVarName="r2[3]"
xlabel='x [km]'
ylabel='y [km]'
zlabel="z [km]"

xVar= df[i_df].loc[:, xVarName]*1.0/1000.0
yVar= df[i_df].loc[:, yVarName]*1.0/1000.0
zVar= df[i_df].loc[:, zVarName]*1.0/1000.0

ax.set_title(title, size=20)
ax.set_xlabel(xlabel, size=12)
ax.set_ylabel(ylabel, size=12)
ax.set_zlabel(zlabel, size=12)

ax.plot(xVar, yVar, zVar, zorder=2, color='red', linewidth=1.0)

plt.grid()
ax.set_xlim(0, 240)
ax.set_ylim(0, 240)
ax.set_zlim(0, 100+10)
ax.set_xticks( numpy.arange(-10000, 12000, 2000) )
ax.set_yticks( numpy.arange(-10000, 12000, 2000) )
ax.set_zticks( numpy.arange(-10000, 12000, 2000) )

ax.view_init( elev=70, azim=-60 )

print('------------------------------')
'''

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
