# %% [markdown]
# <h1>Visualize ExeBuiltByOMEdit: AircraftDynamics.PtMassFDM.DoF3.Examples.TwoBodyOrbital00</h1>
# <h2>notebook: rev001</h2>
# <p>compatability with OpenModelica v1.21.0</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import numpy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib
import math

from IPython.display import display, HTML

backslash= '\\'
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'
swWorkSubDir= 'fullpathModel'
'''
'None': 
'fullPathModel': work in sub dir named with fullaPathModel
'''

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00'
nmModel='ThreeBodyOrbital00'
outputFormat='csv'

#****************************************
#    User must NOT edit code below 
#****************************************
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
if(swWorkSubDir=='fullpathModel'):
    dirWorkRelToHome= dirWorkRelToHome + '/' + fullpathModel
##### end if #####

print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirHome= dirHome.replace(backslash, '/')
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Windows (nt)
# -. Home directory of current environment is: C:/Users/berku
# -. Temporary Working directory is: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# -. Directory of This notebook: D:/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: D:/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# -. Full path of Model file to be ran is: D:/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF3/Examples/ThreeBodyOrbital00.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization, evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# send: cd("C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00")
# OMShell: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization, evaluateAllParameters,NLSanalyticJacobian")
# OMShell: False
#
# OMShell error message:
#
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#nmcsv= fullpathModel + '_res.csv'
nmcsv= nmModel + '_res.csv'
fullpathFile= os.getcwd()+"/"+nmcsv
fullpathFile= fullpathFile.replace(backslash, "/")
print("data read: "+ fullpathFile)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
#         time  r1[1]  r1[2]  r1[3]         r2[1]         r2[2]  r2[3]  \
# 0          0      0      0      0  3.328993e+08 -1.921995e+08      0
# 1         30      0      0      0  3.329146e+08 -1.921729e+08      0
# 2         60      0      0      0  3.329300e+08 -1.921464e+08      0
# 3         90      0      0      0  3.329453e+08 -1.921198e+08      0
# 4        120      0      0      0  3.329606e+08 -1.920933e+08      0
# ...      ...    ...    ...    ...           ...           ...    ...
# 5757  172710      0      0      0  3.838839e+08 -2.485144e+07      0
# 5758  172740      0      0      0  3.838860e+08 -2.482087e+07      0
# 5759  172770      0      0      0  3.838881e+08 -2.479030e+07      0
# 5760  172800      0      0      0  3.838901e+08 -2.475974e+07      0
# 5761  172800      0      0      0  3.838901e+08 -2.475974e+07      0
#
#              r3[1]         r3[2]  r3[3]  ...       v2_3[2]  v2_3[3]  \
# 0    -6.778137e+06  0.000000e+00      0  ... -10885.077963        0
# 1    -6.774234e+06 -2.999424e+05      0  ... -10879.362330        0
# 2    -6.762540e+06 -5.995401e+05      0  ... -10862.185347        0
# 3    -6.743096e+06 -8.984510e+05      0  ... -10833.689497        0
# 4    -6.715969e+06 -1.196339e+06      0  ... -10794.108611        0
# ...            ...           ...    ...  ...           ...      ...
# 5757  9.445119e+06 -1.552959e+07      0  ...  -2079.639319        0
# 5758  9.595210e+06 -1.556095e+07      0  ...  -2048.956638        0
# 5759  9.744739e+06 -1.559139e+07      0  ...  -2018.737901        0
# 5760  9.893704e+06 -1.562094e+07      0  ...  -1988.973064        0
# 5761  9.893704e+06 -1.562094e+07      0  ...  -1988.973064        0
#
#            v2_3Abs         v3Abs     a2[1]     a2[2]  a2[3]     a3[1]  \
# 0     10897.065809  10000.000000 -0.002336  0.001349      0  8.675678
# 1     10882.253103   9997.628285 -0.002336  0.001349      0  8.660198
# 2     10862.188629   9990.532248 -0.002336  0.001348      0  8.613986
# 3     10836.951253   9978.759930 -0.002336  0.001348      0  8.537720
# 4     10806.653668   9962.390257 -0.002337  0.001348      0  8.432505
# ...            ...           ...       ...       ...    ...       ...
# 5757   5362.840663   5123.451352 -0.002688  0.000174      0 -0.626960
# 5758   5333.733240   5098.776374 -0.002688  0.000174      0 -0.625998
# 5759   5304.914091   5074.357659 -0.002688  0.000174      0 -0.624951
# 5760   5276.378236   5050.190846 -0.002688  0.000173      0 -0.623824
# 5761   5276.378236   5050.190846 -0.002688  0.000173      0 -0.623824
#
#          a3[2]  a3[3]
# 0     0.000016      0
# 1     0.383464      0
# 2     0.763700      0
# 3     1.137587      0
# 4     1.502132      0
# ...        ...    ...
# 5757  1.030786      0
# 5758  1.015151      0
# 5759  0.999854      0
# 5760  0.984886      0
# 5761  0.984886      0
#
# [5762 rows x 110 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'r1[1]',
#  'r1[2]',
#  'r1[3]',
#  'r2[1]',
#  'r2[2]',
#  'r2[3]',
#  'r3[1]',
#  'r3[2]',
#  'r3[3]',
#  'v1[1]',
#  'v1[2]',
#  'v1[3]',
#  'v2[1]',
#  'v2[2]',
#  'v2[3]',
#  'v3[1]',
#  'v3[2]',
#  'v3[3]',
#  'der(r1[1])',
#  'der(r1[2])',
#  'der(r1[3])',
#  'der(r2[1])',
#  'der(r2[2])',
#  'der(r2[3])',
#  'der(r3[1])',
#  'der(r3[2])',
#  'der(r3[3])',
#  'der(v1[1])',
#  'der(v1[2])',
#  'der(v1[3])',
#  'der(v2[1])',
#  'der(v2[2])',
#  'der(v2[3])',
#  'der(v3[1])',
#  'der(v3[2])',
#  'der(v3[3])',
#  'Alt',
#  'Fg1_2[1]',
#  'Fg1_2[2]',
#  'Fg1_2[3]',
#  'Fg1_3[1]',
#  'Fg1_3[2]',
#  'Fg1_3[3]',
#  'Fg2_1[1]',
#  'Fg2_1[2]',
#  'Fg2_1[3]',
#  'Fg2_3[1]',
#  'Fg2_3[2]',
#  'Fg2_3[3]',
#  'Fg3_1[1]',
#  'Fg3_1[2]',
#  'Fg3_1[3]',
#  'Fg3_2[1]',
#  'Fg3_2[2]',
#  'Fg3_2[3]',
#  'a1[1]',
#  'a1[2]',
#  'a1[3]',
#  'a1Abs',
#  'a1_2[1]',
#  'a1_2[2]',
#  'a1_2[3]',
#  'a1_2Abs',
#  'a1_3[1]',
#  'a1_3[2]',
#  'a1_3[3]',
#  'a1_3Abs',
#  'a2Abs',
#  'a2_3[1]',
#  'a2_3[2]',
#  'a2_3[3]',
#  'a2_3Abs',
#  'a3Abs',
#  'mag_r1',
#  'mag_r1_2',
#  'mag_r1_3',
#  'mag_r2',
#  'mag_r2_3',
#  'mag_r3',
#  'r1_2[1]',
#  'r1_2[2]',
#  'r1_2[3]',
#  'r1_3[1]',
#  'r1_3[2]',
#  'r1_3[3]',
#  'r2_3[1]',
#  'r2_3[2]',
#  'r2_3[3]',
#  'v1Abs',
#  'v1_2[1]',
#  'v1_2[2]',
#  'v1_2[3]',
#  'v1_2Abs',
#  'v1_3[1]',
#  'v1_3[2]',
#  'v1_3[3]',
#  'v1_3Abs',
#  'v2Abs',
#  'v2_3[1]',
#  'v2_3[2]',
#  'v2_3[3]',
#  'v2_3Abs',
#  'v3Abs',
#  'a2[1]',
#  'a2[2]',
#  'a2[3]',
#  'a3[1]',
#  'a3[2]',
#  'a3[3]']

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
fullpathFile= os.getcwd()+"/"+nmcsv
fullpathFile= fullpathFile.replace(backslash, "/")
print("data read: "+ fullpathFile)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
#          time  r1[1]  r1[2]  r1[3]         r2[1]         r2[2]  r2[3]  \
# 0           0      0      0      0  3.148812e+08 -2.204822e+08      0
# 1          50      0      0      0  3.149105e+08 -2.204403e+08      0
# 2         100      0      0      0  3.149398e+08 -2.203985e+08      0
# 3         150      0      0      0  3.149691e+08 -2.203566e+08      0
# 4         200      0      0      0  3.149984e+08 -2.203147e+08      0
# ...       ...    ...    ...    ...           ...           ...    ...
# 13997  699850      0      0      0  1.271618e+08  3.665483e+08      0
# 13998  699900      0      0      0  1.271141e+08  3.665653e+08      0
# 13999  699950      0      0      0  1.270663e+08  3.665822e+08      0
# 14000  700000      0      0      0  1.270186e+08  3.665991e+08      0
# 14001  700000      0      0      0  1.270186e+08  3.665991e+08      0
#
#               r3[1]         r3[2]  r3[3]  ...       v2_3[2]  v2_3[3]  \
# 0     -6.778137e+06  0.000000e+00      0  ... -11437.173389        0
# 1     -6.767304e+06 -5.297178e+05      0  ... -11420.333267        0
# 2     -6.734932e+06 -1.057752e+06      0  ... -11370.153065        0
# 3     -6.681398e+06 -1.582468e+06      0  ... -11288.062003        0
# 4     -6.607314e+06 -2.102324e+06      0  ... -11176.332107        0
# ...             ...           ...    ...  ...           ...      ...
# 13997  1.385683e+08 -1.352273e+07      0  ...    123.230695        0
# 13998  1.385936e+08 -1.349964e+07      0  ...    123.453836        0
# 13999  1.386188e+08 -1.347654e+07      0  ...    123.676764        0
# 14000  1.386439e+08 -1.345344e+07      0  ...    123.899477        0
# 14001  1.386439e+08 -1.345344e+07      0  ...    123.899477        0
#
#             v2_3Abs         v3Abs     a2[1]     a2[2]  a2[3]     a3[1]  \
# 0      11452.185811  10600.000000 -0.002210  0.001547      0  8.675680
# 1      11421.360270  10591.933630 -0.002210  0.001547      0  8.624096
# 2      11373.472339  10567.935610 -0.002210  0.001547      0  8.471965
# 3      11309.296446  10528.578485 -0.002210  0.001546      0  8.226859
# 4      11229.973172  10474.786241 -0.002210  0.001546      0  7.900446
# ...             ...           ...       ...       ...    ...       ...
# 13997   1465.106626    684.787805 -0.000868 -0.002502      0 -0.020465
# 13998   1464.149217    684.098982 -0.000868 -0.002502      0 -0.020458
# 13999   1463.192155    683.411096 -0.000867 -0.002502      0 -0.020452
# 14000   1462.235439    682.724148 -0.000867 -0.002502      0 -0.020445
# 14001   1462.235439    682.724148 -0.000867 -0.002502      0 -0.020445
#
#           a3[2]  a3[3]
# 0      0.000018      0
# 1      0.675080      0
# 2      1.330584      0
# 3      1.948531      0
# 4      2.513801      0
# ...         ...    ...
# 13997  0.001963      0
# 13998  0.001959      0
# 13999  0.001955      0
# 14000  0.001950      0
# 14001  0.001950      0
#
# [14002 rows x 110 columns]

# %% [markdown]
# <h2>Read Parameters CSV Table</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
nameParameterTableCSV="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable.csv"


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')
#----------

print("Reading CSV...")
df_parameter = pd.read_csv(nameParameterTableCSV, index_col=0, header=0)

print(''); 
print("Parameter Table read:")
print(df_parameter)
print('------------------------------')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# Reading CSV...
#
# Parameter Table read:
#                         1         2         3         4         5         6  \
# swExec                Not       Not       Not       Not       Not       Not
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10600    -10600    -10600    -10700    -10750    -10750
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -35     -35.1     -35.2       -35       -35     -35.1
#
#                         7         8         9        10  ...       161  \
# swExec                Not       Not       Not       Not  ...      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  ...  -6778137
# r3_init[2]              0         0         0         0  ...         0
# r3_init[3]              0         0         0         0  ...         0
# v3_init[1]              0         0         0         0  ...         0
# v3_init[2]         -10750    -10750    -10750    -10750  ...    -10790
# v3_init[3]              0         0         0         0  ...         0
# phi_r2_deg_init     -35.2     -35.3     -35.4     -35.5  ...     -40.5
#
#                       162       163       164       165       166       167  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10790    -10790    -10790    -10790    -10790    -10790
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -41     -41.5       -42     -42.5       -43     -43.5
#
#                       168       169       170
# swExec               Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137
# r3_init[2]              0         0         0
# r3_init[3]              0         0         0
# v3_init[1]              0         0         0
# v3_init[2]         -10790    -10790    -10790
# v3_init[3]              0         0         0
# phi_r2_deg_init       -44     -44.5       -45
#
# [8 rows x 170 columns]
# ------------------------------
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Read csv, multi-cases</h1>

# %%
iRunBegin= 87
iRunEnd= 170

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    i_df=i
    nmcsv= nmModel + '_res_' + str(i_df) + '.csv'
    fullpathFile= os.getcwd()+"/"+nmcsv
    fullpathFile= fullpathFile.replace(backslash, "/")
    print("data read: "+ fullpathFile)
    df.insert(i_df, pd.read_csv(nmcsv))
    
    print('')
#***** end for *****

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_87.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_88.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_89.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_90.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_91.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_92.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_93.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_94.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_95.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_96.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_97.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_98.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_99.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_100.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_101.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_102.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_103.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_104.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_105.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_106.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_107.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_108.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_109.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_110.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_111.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_112.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_113.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_114.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_115.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_116.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_117.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_118.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_119.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_120.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_121.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_122.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_123.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_124.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_125.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_126.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_127.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_128.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_129.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_130.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_131.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_132.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_133.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_134.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_135.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_136.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_137.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_138.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_139.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_140.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_141.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_142.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_143.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_144.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_145.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_146.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_147.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_148.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_149.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_150.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_151.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_152.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_153.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_154.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_155.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_156.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_157.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_158.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_159.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_160.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_161.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_162.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_163.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_164.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_165.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_166.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_167.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_168.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_169.csv
#
# data read: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00/ThreeBodyOrbital00_res_170.csv
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=171
print('i_df= '+str(i_df))
print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))

fig.append(plt.figure(figsize=[12, 12]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"
x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'

x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0
x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xticks(numpy.arange(-500000, 600000, 100000))
plt.yticks(numpy.arange(-500000, 600000, 100000))

print('------------------------------')
# Out:
# i_df= 171
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[131], line 3
#       1 i_df=171
#       2 print('i_df= '+str(i_df))
# ----> 3 print(df_parameter.index[5]+'='+str(df_parameter.iloc[5, i_df-1]))
#       4 print(df_parameter.index[7]+'='+str(df_parameter.iloc[7, i_df-1]))
#       6 fig.append(plt.figure(figsize=[12, 12]))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3867, in DataFrame._get_value(self, index, col, takeable)
#    3848 """
#    3849 Quickly retrieve single value at passed column and index.
#    3850
#    (...)
#    3864 `self.columns._index_as_unique`; Caller is responsible for checking.
#    3865 """
#    3866 if takeable:
# -> 3867     series = self._ixs(col, axis=1)
#    3868     return series._values[index]
#    3870 series = self._get_item_cache(col)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3664, in DataFrame._ixs(self, i, axis)
#    3660     return result
#    3662 # icol
#    3663 else:
# -> 3664     label = self.columns[i]
#    3666     col_mgr = self._mgr.iget(i)
#    3667     result = self._box_col_values(col_mgr, i)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:5174, in Index.__getitem__(self, key)
#    5171 if is_integer(key) or is_float(key):
#    5172     # GH#44051 exclude bool, which would return a 2d ndarray
#    5173     key = com.cast_scalar_indexer(key)
# -> 5174     return getitem(key)
#    5176 if isinstance(key, slice):
#    5177     # This case is separated from the conditional above to avoid
#    5178     # pessimization com.is_bool_indexer and ndim checks.
#    5179     result = getitem(key)
#
# IndexError: index 170 is out of bounds for axis 0 with size 170

# %%
i_df=1

print('i_df= '+str(i_df))
fig.append(plt.figure(figsize=[12, 12]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"

x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'


x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0

x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xticks(numpy.arange(-400000, 500000, 100000))
plt.yticks(numpy.arange(-400000, 500000, 100000))

print('------------------------------')
# Out:
# i_df= 1
# ------------------------------

# %%
i_df=2

print('i_df= '+str(i_df))
fig.append(plt.figure(figsize=[12, 12]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"

x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'


x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0

x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xticks(numpy.arange(-400000, 500000, 100000))
plt.yticks(numpy.arange(-400000, 500000, 100000))

print('------------------------------')
# Out:
# i_df= 2
# ------------------------------

# %%
i_df=3

print('i_df= '+str(i_df))
fig.append(plt.figure(figsize=[12, 12]))
ax = plt.axes()

title="planner trajectory"

x1VarName="r3[1]"
y1VarName="r3[2]"

x2VarName="r2[1]"
y2VarName="r2[2]"

xlabel='x [km]'
ylabel='y [km]'


x1Var= df[i_df].loc[:, x1VarName]*1.0/1000.0
y1Var= df[i_df].loc[:, y1VarName]*1.0/1000.0

x2Var= df[i_df].loc[:, x2VarName]*1.0/1000.0
y2Var= df[i_df].loc[:, y2VarName]*1.0/1000.0

plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x1Var, y1Var, color='red', linewidth=1.0)
plt.plot(x2Var, y2Var, color='blue', linewidth=1.0)
plt.grid()

# --- drow planet
planet = mpl.patches.Circle(xy=(0, 0), radius=6378.137, fc='green', ec='green')
ax.add_patch(planet)

plt.xticks(numpy.arange(-400000, 500000, 100000))
plt.yticks(numpy.arange(-400000, 500000, 100000))

print('------------------------------')
# Out:
# i_df= 3
# ------------------------------

# %%
'''
i_df=1
fig.append(plt.figure(figsize = (18, 18)))
ax = fig[-1].add_subplot(111, projection="3d")

# ***** Make data for sphere *****
u = numpy.linspace(0, 2 * numpy.pi, 50)
v = numpy.linspace(0, numpy.pi, 50)
radius= 6378.137
xShpere = radius * numpy.outer(numpy.cos(u), numpy.sin(v))
yShpere = radius * numpy.outer(numpy.sin(u), numpy.sin(v))
zShpere = radius * numpy.outer(numpy.ones(numpy.size(u)), numpy.cos(v))

ax.plot_surface(xShpere, yShpere, zShpere, zorder=-1, color='green')

# ***** plot trajectry *****
title="flight trajectory"
xVarName="r2[1]"
yVarName="r2[2]"
zVarName="r2[3]"
xlabel='x [km]'
ylabel='y [km]'
zlabel="z [km]"

xVar= df[i_df].loc[:, xVarName]*1.0/1000.0
yVar= df[i_df].loc[:, yVarName]*1.0/1000.0
zVar= df[i_df].loc[:, zVarName]*1.0/1000.0

ax.set_title(title, size=20)
ax.set_xlabel(xlabel, size=12)
ax.set_ylabel(ylabel, size=12)
ax.set_zlabel(zlabel, size=12)

ax.plot(xVar, yVar, zVar, zorder=2, color='red', linewidth=1.0)

plt.grid()
ax.set_xlim(0, 240)
ax.set_ylim(0, 240)
ax.set_zlim(0, 100+10)
ax.set_xticks( numpy.arange(-10000, 12000, 2000) )
ax.set_yticks( numpy.arange(-10000, 12000, 2000) )
ax.set_zticks( numpy.arange(-10000, 12000, 2000) )

ax.view_init( elev=70, azim=-60 )

print('------------------------------')
'''

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
