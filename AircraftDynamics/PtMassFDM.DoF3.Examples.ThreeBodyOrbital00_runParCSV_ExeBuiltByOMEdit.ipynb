# %% [markdown]
# <h1>Run ExeBuiltByOMEdit, multi case, multiple parameter defined by CSV Table file: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00</h1>
# <h2>notebook: rev 001</h2>
# <p>compatability with OpenModelica v1.21.0</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML

backslash= '\\'
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'
swWorkSubDir= 'fullpathModel'
'''
'None': 
'fullPathModel': work in sub dir named with fullaPathModel
'''

libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00'
nmModel='ThreeBodyOrbital00'
stopTime=3600.0
outputFormat='csv'

#****************************************
#    User must NOT edit code below 
#****************************************
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
if(swWorkSubDir=='fullpathModel'):
    dirWorkRelToHome= dirWorkRelToHome + '/' + fullpathModel
##### end if #####

print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirHome= dirHome.replace(backslash, '/')
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')

print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Windows (nt)
# -. Home directory of current environment is: C:/Users/berku
# -. Temporary Working directory is: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# -. Directory of This notebook: D:/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: D:/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# -. Full path of Model file to be ran is: D:/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF3/Examples/ThreeBodyOrbital00.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...copy parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (nmModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# send: cd("C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00")
# OMShell: C:/Users/berku/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...copy parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_org.xml")
# OMShell: 0
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Multiple parameter sweep, Org case </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunOrg=0

startTime=0
stopTime=700000
stepSize=50.0

#********** parameters to set fixed for parameter sweep run **********
param2set=[
    'r3_init[1]',
    'r3_init[2]',
    'r3_init[3]',
    'v3_init[1]',
    'v3_init[3]',
]

value2set=[
    (-1.0)*(6378.137+400.0)*10.0**3.0,
    0.0,
    0.0,
    0.0,
    0.0,
]

#****************************************
#    User must NOT edit code below 
#****************************************
iRun=iRunOrg
#----------
numberOfIntervals=int((stopTime-startTime)/stepSize)
print('numberOfIntervals of simulation='+str(numberOfIntervals))
print('')

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=nmModel+'_init_parSweepOrg'+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init_org.xml') +' '+ (nmModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2set)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+param2set[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(nmModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
print("***** Org case of multiple parameter sweep *****")
if(os.name=='nt'):
    strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv'  +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# numberOfIntervals of simulation=14000
#
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# iRun=0
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init_org.xml ThreeBodyOrbital00_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_parSweepOrg.xml")
# OMShell: 0
#
# ...running simulation, wait...
# ***** Org case of multiple parameter sweep *****
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_0.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h2>Read Parameters CSV Table</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
nameParameterTableCSV="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable.csv"


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')
#----------

print("Reading CSV...")
df_parameter = pd.read_csv(nameParameterTableCSV, index_col=0, header=0)

print(''); 
print("Parameter Table read:")
print(df_parameter)
print('------------------------------')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# Reading CSV...
#
# Parameter Table read:
#                         1         2         3         4         5         6  \
# swExec                Not       Not       Not       Not       Not       Not
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10600    -10600    -10600    -10700    -10750    -10750
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -35     -35.1     -35.2       -35       -35     -35.1
#
#                         7         8         9        10  ...       161  \
# swExec                Not       Not       Not       Not  ...      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  ...  -6778137
# r3_init[2]              0         0         0         0  ...         0
# r3_init[3]              0         0         0         0  ...         0
# v3_init[1]              0         0         0         0  ...         0
# v3_init[2]         -10750    -10750    -10750    -10750  ...    -10790
# v3_init[3]              0         0         0         0  ...         0
# phi_r2_deg_init     -35.2     -35.3     -35.4     -35.5  ...     -40.5
#
#                       162       163       164       165       166       167  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10790    -10790    -10790    -10790    -10790    -10790
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -41     -41.5       -42     -42.5       -43     -43.5
#
#                       168       169       170
# swExec               Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137
# r3_init[2]              0         0         0
# r3_init[3]              0         0         0
# v3_init[1]              0         0         0
# v3_init[2]         -10790    -10790    -10790
# v3_init[3]              0         0         0
# phi_r2_deg_init       -44     -44.5       -45
#
# [8 rows x 170 columns]
# ------------------------------
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Sweep cases defined by CSV</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
startTime=0
stopTime=700000
stepSize=50.0


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

print('...multi-case calculation: generating parameter setting xml fils...')
print('    Cases: '+ str(len(df_parameter.columns)))
print('    Parameters set: '+ str(len(df_parameter.index)-1))
print('')
for j in range(len(df_parameter.columns)):
    print('case='+str(df_parameter.columns[j])+', '+'swExec='+str(df_parameter.iloc[0,j]))
    if(df_parameter.iloc[0,j]=='Exec'):
        #-- copy _init_org file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_parSweepOrg.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        for i in range(1, len(df_parameter.index)):
            #----------
            #-- overwrite parameter setting xml file
            print('i='+str(i))
            strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+df_parameter.index[i]+'", ' + '"'+str(df_parameter.iloc[i,j])+'", '+ '"'+(nmModel+'_init.xml')+'")'
            print('send: '+strcmd)
            msgOMShell=omc.sendExpression(strcmd)
            print("OMShell: "+ str(msgOMShell))
        ##### end for #####

        #-- save parameter setting file after overwriting
        print(''); print('...Saving parameter setting file...')
        filenameXmlNew=nmModel+'_init_'+str(df_parameter.columns[j])+'.xml'
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
    #***** end if *****
    
    print('-----');
    print('');
    print('');
##### end for #####
print('---------------------------------------------------------------------------')
print('...edit of parameter setting file is completed.')
print('');
print('');

print('...multi-case calculation: run with generated xml fils...')
print('    Cases: '+ str(len(df_parameter.columns)))
print('')
for j in range(len(df_parameter.columns)):
    print('case=' + str(df_parameter.columns[j])+', '+'swExec='+str(df_parameter.iloc[0,j]))
    if(df_parameter.iloc[0,j]=='Exec'):
        #-- call _init.xml file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_'+str(df_parameter.columns[j])+'.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        
        #-- run
        if(os.name=='nt'):
            strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv' +'")'
        elif(os.name=='posix'):
            strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv'  +'")'
        ##### end if #####
        
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
    #***** end if *****
    
    print('')
##### end for #####
print('---------------------------------------------------------------------------')
print('...simulation run completed.')
print('');

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: C:\Users\berku\OMPythonWork\AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# ...multi-case calculation: generating parameter setting xml fils...
#     Cases: 170
#     Parameters set: 7
#
# case=1, swExec=Not
# -----
#
#
# case=2, swExec=Not
# -----
#
#
# case=3, swExec=Not
# -----
#
#
# case=4, swExec=Not
# -----
#
#
# case=5, swExec=Not
# -----
#
#
# case=6, swExec=Not
# -----
#
#
# case=7, swExec=Not
# -----
#
#
# case=8, swExec=Not
# -----
#
#
# case=9, swExec=Not
# -----
#
#
# case=10, swExec=Not
# -----
#
#
# case=11, swExec=Not
# -----
#
#
# case=12, swExec=Not
# -----
#
#
# case=13, swExec=Not
# -----
#
#
# case=14, swExec=Not
# -----
#
#
# case=15, swExec=Not
# -----
#
#
# case=16, swExec=Not
# -----
#
#
# case=17, swExec=Not
# -----
#
#
# case=18, swExec=Not
# -----
#
#
# case=19, swExec=Not
# -----
#
#
# case=20, swExec=Not
# -----
#
#
# case=21, swExec=Not
# -----
#
#
# case=22, swExec=Not
# -----
#
#
# case=23, swExec=Not
# -----
#
#
# case=24, swExec=Not
# -----
#
#
# case=25, swExec=Not
# -----
#
#
# case=26, swExec=Not
# -----
#
#
# case=27, swExec=Not
# -----
#
#
# case=28, swExec=Not
# -----
#
#
# case=29, swExec=Not
# -----
#
#
# case=30, swExec=Not
# -----
#
#
# case=31, swExec=Not
# -----
#
#
# case=32, swExec=Not
# -----
#
#
# case=33, swExec=Not
# -----
#
#
# case=34, swExec=Not
# -----
#
#
# case=35, swExec=Not
# -----
#
#
# case=36, swExec=Not
# -----
#
#
# case=37, swExec=Not
# -----
#
#
# case=38, swExec=Not
# -----
#
#
# case=39, swExec=Not
# -----
#
#
# case=40, swExec=Not
# -----
#
#
# case=41, swExec=Not
# -----
#
#
# case=42, swExec=Not
# -----
#
#
# case=43, swExec=Not
# -----
#
#
# case=44, swExec=Not
# -----
#
#
# case=45, swExec=Not
# -----
#
#
# case=46, swExec=Not
# -----
#
#
# case=47, swExec=Not
# -----
#
#
# case=48, swExec=Not
# -----
#
#
# case=49, swExec=Not
# -----
#
#
# case=50, swExec=Not
# -----
#
#
# case=51, swExec=Not
# -----
#
#
# case=52, swExec=Not
# -----
#
#
# case=53, swExec=Not
# -----
#
#
# case=54, swExec=Not
# -----
#
#
# case=55, swExec=Not
# -----
#
#
# case=56, swExec=Not
# -----
#
#
# case=57, swExec=Not
# -----
#
#
# case=58, swExec=Not
# -----
#
#
# case=59, swExec=Not
# -----
#
#
# case=60, swExec=Not
# -----
#
#
# case=61, swExec=Not
# -----
#
#
# case=62, swExec=Not
# -----
#
#
# case=63, swExec=Not
# -----
#
#
# case=64, swExec=Not
# -----
#
#
# case=65, swExec=Not
# -----
#
#
# case=66, swExec=Not
# -----
#
#
# case=67, swExec=Not
# -----
#
#
# case=68, swExec=Not
# -----
#
#
# case=69, swExec=Not
# -----
#
#
# case=70, swExec=Not
# -----
#
#
# case=71, swExec=Not
# -----
#
#
# case=72, swExec=Not
# -----
#
#
# case=73, swExec=Not
# -----
#
#
# case=74, swExec=Not
# -----
#
#
# case=75, swExec=Not
# -----
#
#
# case=76, swExec=Not
# -----
#
#
# case=77, swExec=Not
# -----
#
#
# case=78, swExec=Not
# -----
#
#
# case=79, swExec=Not
# -----
#
#
# case=80, swExec=Not
# -----
#
#
# case=81, swExec=Not
# -----
#
#
# case=82, swExec=Not
# -----
#
#
# case=83, swExec=Not
# -----
#
#
# case=84, swExec=Not
# -----
#
#
# case=85, swExec=Not
# -----
#
#
# case=86, swExec=Not
# -----
#
#
# case=87, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_87.xml")
# OMShell: 0
# -----
#
#
# case=88, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_88.xml")
# OMShell: 0
# -----
#
#
# case=89, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_89.xml")
# OMShell: 0
# -----
#
#
# case=90, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_90.xml")
# OMShell: 0
# -----
#
#
# case=91, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_91.xml")
# OMShell: 0
# -----
#
#
# case=92, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_92.xml")
# OMShell: 0
# -----
#
#
# case=93, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_93.xml")
# OMShell: 0
# -----
#
#
# case=94, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_94.xml")
# OMShell: 0
# -----
#
#
# case=95, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_95.xml")
# OMShell: 0
# -----
#
#
# case=96, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_96.xml")
# OMShell: 0
# -----
#
#
# case=97, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_97.xml")
# OMShell: 0
# -----
#
#
# case=98, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_98.xml")
# OMShell: 0
# -----
#
#
# case=99, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_99.xml")
# OMShell: 0
# -----
#
#
# case=100, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_100.xml")
# OMShell: 0
# -----
#
#
# case=101, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_101.xml")
# OMShell: 0
# -----
#
#
# case=102, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_102.xml")
# OMShell: 0
# -----
#
#
# case=103, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_103.xml")
# OMShell: 0
# -----
#
#
# case=104, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_104.xml")
# OMShell: 0
# -----
#
#
# case=105, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_105.xml")
# OMShell: 0
# -----
#
#
# case=106, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_106.xml")
# OMShell: 0
# -----
#
#
# case=107, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10760", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_107.xml")
# OMShell: 0
# -----
#
#
# case=108, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_108.xml")
# OMShell: 0
# -----
#
#
# case=109, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-35.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_109.xml")
# OMShell: 0
# -----
#
#
# case=110, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_110.xml")
# OMShell: 0
# -----
#
#
# case=111, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-36.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_111.xml")
# OMShell: 0
# -----
#
#
# case=112, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_112.xml")
# OMShell: 0
# -----
#
#
# case=113, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-37.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_113.xml")
# OMShell: 0
# -----
#
#
# case=114, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_114.xml")
# OMShell: 0
# -----
#
#
# case=115, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-38.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_115.xml")
# OMShell: 0
# -----
#
#
# case=116, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_116.xml")
# OMShell: 0
# -----
#
#
# case=117, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_117.xml")
# OMShell: 0
# -----
#
#
# case=118, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_118.xml")
# OMShell: 0
# -----
#
#
# case=119, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_119.xml")
# OMShell: 0
# -----
#
#
# case=120, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_120.xml")
# OMShell: 0
# -----
#
#
# case=121, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_121.xml")
# OMShell: 0
# -----
#
#
# case=122, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_122.xml")
# OMShell: 0
# -----
#
#
# case=123, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_123.xml")
# OMShell: 0
# -----
#
#
# case=124, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_124.xml")
# OMShell: 0
# -----
#
#
# case=125, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10770", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_125.xml")
# OMShell: 0
# -----
#
#
# case=126, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# ...
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_105.csv")
# OMShell: 0
#
# case=106, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_106.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_106.csv")
# OMShell: 0
#
# case=107, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_107.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_107.csv")
# OMShell: 0
#
# case=108, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_108.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_108.csv")
# OMShell: 0
#
# case=109, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_109.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_109.csv")
# OMShell: 0
#
# case=110, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_110.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_110.csv")
# OMShell: 0
#
# case=111, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_111.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_111.csv")
# OMShell: 0
#
# case=112, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_112.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_112.csv")
# OMShell: 0
#
# case=113, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_113.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_113.csv")
# OMShell: 0
#
# case=114, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_114.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_114.csv")
# OMShell: 0
#
# case=115, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_115.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_115.csv")
# OMShell: 0
#
# case=116, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_116.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_116.csv")
# OMShell: 0
#
# case=117, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_117.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_117.csv")
# OMShell: 0
#
# case=118, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_118.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_118.csv")
# OMShell: 0
#
# case=119, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_119.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_119.csv")
# OMShell: 0
#
# case=120, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_120.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_120.csv")
# OMShell: 0
#
# case=121, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_121.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_121.csv")
# OMShell: 0
#
# case=122, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_122.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_122.csv")
# OMShell: 0
#
# case=123, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_123.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_123.csv")
# OMShell: 0
#
# case=124, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_124.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_124.csv")
# OMShell: 0
#
# case=125, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_125.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_125.csv")
# OMShell: 0
#
# case=126, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_126.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_126.csv")
# OMShell: 0
#
# case=127, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_127.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_127.csv")
# OMShell: 0
#
# case=128, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_128.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_128.csv")
# OMShell: 0
#
# case=129, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_129.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_129.csv")
# OMShell: 0
#
# case=130, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_130.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_130.csv")
# OMShell: 0
#
# case=131, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_131.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_131.csv")
# OMShell: 0
#
# case=132, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_132.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_132.csv")
# OMShell: 0
#
# case=133, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_133.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_133.csv")
# OMShell: 0
#
# case=134, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_134.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_134.csv")
# OMShell: 0
#
# case=135, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_135.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_135.csv")
# OMShell: 0
#
# case=136, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_136.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_136.csv")
# OMShell: 0
#
# case=137, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_137.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_137.csv")
# OMShell: 0
#
# case=138, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_138.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_138.csv")
# OMShell: 0
#
# case=139, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_139.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_139.csv")
# OMShell: 0
#
# case=140, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_140.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_140.csv")
# OMShell: 0
#
# case=141, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_141.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_141.csv")
# OMShell: 0
#
# case=142, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_142.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_142.csv")
# OMShell: 0
#
# case=143, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_143.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_143.csv")
# OMShell: 0
#
# case=144, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_144.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_144.csv")
# OMShell: 0
#
# case=145, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_145.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_145.csv")
# OMShell: 0
#
# case=146, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_146.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_146.csv")
# OMShell: 0
#
# case=147, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_147.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_147.csv")
# OMShell: 0
#
# case=148, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_148.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_148.csv")
# OMShell: 0
#
# case=149, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_149.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_149.csv")
# OMShell: 0
#
# case=150, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_150.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_150.csv")
# OMShell: 0
#
# case=151, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_151.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_151.csv")
# OMShell: 0
#
# case=152, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_152.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_152.csv")
# OMShell: 0
#
# case=153, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_153.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_153.csv")
# OMShell: 0
#
# case=154, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_154.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_154.csv")
# OMShell: 0
#
# case=155, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_155.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_155.csv")
# OMShell: 0
#
# case=156, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_156.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_156.csv")
# OMShell: 0
#
# case=157, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_157.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_157.csv")
# OMShell: 0
#
# case=158, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_158.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_158.csv")
# OMShell: 0
#
# case=159, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_159.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_159.csv")
# OMShell: 0
#
# case=160, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_160.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_160.csv")
# OMShell: 0
#
# case=161, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_161.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_161.csv")
# OMShell: 0
#
# case=162, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_162.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_162.csv")
# OMShell: 0
#
# case=163, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_163.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_163.csv")
# OMShell: 0
#
# case=164, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_164.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_164.csv")
# OMShell: 0
#
# case=165, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_165.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_165.csv")
# OMShell: 0
#
# case=166, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_166.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_166.csv")
# OMShell: 0
#
# case=167, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_167.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_167.csv")
# OMShell: 0
#
# case=168, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_168.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_168.csv")
# OMShell: 0
#
# case=169, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_169.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_169.csv")
# OMShell: 0
#
# case=170, swExec=Exec
# send: system("cp ThreeBodyOrbital00_init_170.xml ThreeBodyOrbital00_init.xml")
#
# send: system("ThreeBodyOrbital00.bat -override=startTime=0,stopTime=700000,stepSize=50.0 -r=ThreeBodyOrbital00_res_170.csv")
# OMShell: 0
#
# ---------------------------------------------------------------------------
# ...simulation run completed.
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: D:\Dropbox\01-sharedspace\modelica-shared\CustomLib\ipynbs4OMPython\AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
