# %% [markdown]
# <h1>Run ExeBuiltByOMEdit, multi case, multiple parameter defined by CSV Table file: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00</h1>
# <h2>notebook: rev 001</h2>
# <p>compatability with OpenModelica v1.21.0</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML

backslash= '\\'
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'
swWorkSubDir= 'fullpathModel'
'''
'None': 
'fullPathModel': work in sub dir named with fullaPathModel
'''

libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00'
nmModel='ThreeBodyOrbital00'
stopTime=3600.0
outputFormat='csv'

#****************************************
#    User must NOT edit code below 
#****************************************
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
if(swWorkSubDir=='fullpathModel'):
    dirWorkRelToHome= dirWorkRelToHome + '/' + fullpathModel
##### end if #####

print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
pathNotebook= pathNotebook.replace(backslash, '/')
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirHome= dirHome.replace(backslash, '/')
dirWorkRelToHome= dirWorkRelToHome.replace(backslash, '/')
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')

print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/PtMassFDM/DoF3/Examples/ThreeBodyOrbital00.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...copy parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (nmModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00")
# OMShell: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...copy parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_org.xml")
# OMShell: 0
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Multiple parameter sweep, Org case </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunOrg=0

startTime=0
stopTime=800000
stepSize=50.0

#********** parameters to set fixed for parameter sweep run **********
param2set=[
    'r3_init[1]',
    'r3_init[2]',
    'r3_init[3]',
    'v3_init[1]',
    'v3_init[2]',
    'v3_init[3]',
    'phi_r2_deg_init',
]

value2set=[
    (-1.0)*(6378.137+400.0)*10.0**3.0,
    0.0,
    0.0,
    0.0,
    -10780,
    0.0,
    -43.0,
]

#****************************************
#    User must NOT edit code below 
#****************************************
iRun=iRunOrg
#----------
numberOfIntervals=int((stopTime-startTime)/stepSize)
print('numberOfIntervals of simulation='+str(numberOfIntervals))
print('')

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=nmModel+'_init_parSweepOrg'+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init_org.xml') +' '+ (nmModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2set)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+param2set[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(nmModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
print("***** Org case of multiple parameter sweep *****")
if(os.name=='nt'):
    strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(iRun) +'.csv'  +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# numberOfIntervals of simulation=16000
#
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# iRun=0
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init_org.xml ThreeBodyOrbital00_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10780", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_parSweepOrg.xml")
# OMShell: 0
#
# ...running simulation, wait...
# ***** Org case of multiple parameter sweep *****
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_0.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h2>Read Parameters CSV Table</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
nameParameterTableCSV="PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_5.csv"
swDir="ipynbs"
'''
'ipynbs': csv is in the save directory as this ipynbs
'workDir': csv is in the same directory as working dir
'''
if(swDir=='workDir'):
    fullPathCSV= nameParameterTableCSV
elif(swDir=='ipynbs'):
    fullPathCSV= pathNotebook+'/'+nameParameterTableCSV
#***** end if *****


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')
#----------

print("Reading CSV...")
print(fullPathCSV)
df_parameter = pd.read_csv(fullPathCSV, index_col=0, header=0)

print(''); 
print("Parameter Table read:")
print(df_parameter)
print('------------------------------')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# Reading CSV...
# /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics/PtMassFDM.DoF3.Examples.ThreeBodyOrbital00_ParTable_5.csv
#
# Parameter Table read:
#                      3253      3254      3255      3256      3257      3258  \
# swExec                Not       Not       Not       Not       Not       Not
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10739    -10739    -10739    -10739    -10739    -10739
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -35     -35.5       -36     -36.5       -37     -37.5
#
#                      3259      3260      3261      3262  ...      3953  \
# swExec                Not       Not       Not       Not  ...      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  ...  -6778137
# r3_init[2]              0         0         0         0  ...         0
# r3_init[3]              0         0         0         0  ...         0
# v3_init[1]              0         0         0         0  ...         0
# v3_init[2]         -10739    -10739    -10739    -10739  ...    -10730
# v3_init[3]              0         0         0         0  ...         0
# phi_r2_deg_init       -38     -38.5       -39     -39.5  ...     -65.5
#
#                      3954      3955      3956      3957      3958      3959  \
# swExec               Exec      Exec      Exec      Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137  -6778137  -6778137  -6778137
# r3_init[2]              0         0         0         0         0         0
# r3_init[3]              0         0         0         0         0         0
# v3_init[1]              0         0         0         0         0         0
# v3_init[2]         -10730    -10730    -10730    -10730    -10730    -10730
# v3_init[3]              0         0         0         0         0         0
# phi_r2_deg_init       -66     -66.5       -67     -67.5       -68     -68.5
#
#                      3960      3961      3962
# swExec               Exec      Exec      Exec
# r3_init[1]       -6778137  -6778137  -6778137
# r3_init[2]              0         0         0
# r3_init[3]              0         0         0
# v3_init[1]              0         0         0
# v3_init[2]         -10730    -10730    -10730
# v3_init[3]              0         0         0
# phi_r2_deg_init       -69     -69.5       -70
#
# [8 rows x 710 columns]
# ------------------------------
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Sweep cases defined by CSV</h2>

# %%
#****************************************
#    User Setting section 
#****************************************
startTime=0
stopTime=800000
stepSize=50.0


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

print('...multi-case calculation: generating parameter setting xml fils...')
print('    Cases: '+ str(len(df_parameter.columns)))
print('    Parameters set: '+ str(len(df_parameter.index)-1))
print('')
for j in range(len(df_parameter.columns)):
    print('case='+str(df_parameter.columns[j])+', '+'swExec='+str(df_parameter.iloc[0,j]))
    if(df_parameter.iloc[0,j]=='Exec'):
        print('generating parameter setting xml fils...')
        #-- copy _init_org file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_parSweepOrg.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        for i in range(1, len(df_parameter.index)):
            #----------
            #-- overwrite parameter setting xml file
            print('i='+str(i))
            strcmd= 'setInitXmlStartValue("' +(nmModel+'_init.xml')+'", '+ '"'+df_parameter.index[i]+'", ' + '"'+str(df_parameter.iloc[i,j])+'", '+ '"'+(nmModel+'_init.xml')+'")'
            print('send: '+strcmd)
            msgOMShell=omc.sendExpression(strcmd)
            print("OMShell: "+ str(msgOMShell))
        ##### end for #####

        #-- save parameter setting file after overwriting
        print(''); print('...Saving parameter setting file...')
        filenameXmlNew=nmModel+'_init_'+str(df_parameter.columns[j])+'.xml'
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
        
        print(''); print('---- run simulation ----')
        #-- call _init.xml file
        strcmd= 'system("'+ 'cp '+ (nmModel+'_init_'+str(df_parameter.columns[j])+'.xml') +' '+ (nmModel+'_init.xml') +'")'
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print('')
        
        #-- run
        if(os.name=='nt'):
            strcmd= 'system("' + nmModel + '.bat' + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize) + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv' +'")'
        elif(os.name=='posix'):
            strcmd= 'system("' + './'+ nmModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + nmModel + '_res_'+ str(df_parameter.columns[j]) +'.csv'  +'")'
        ##### end if #####
        
        print('send: '+strcmd)
        msgOMShell=omc.sendExpression(strcmd)
        print("OMShell: "+ str(msgOMShell))
    #***** end if *****
    
    print('-----');
    print('');
    print('');
##### end for #####
print('---------------------------------------------------------------------------')
print('...simulation run completed.')
print('');

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork/AircraftDynamics.PtMassFDM.DoF3.Examples.ThreeBodyOrbital00
# ------------------------------
#
# ...multi-case calculation: generating parameter setting xml fils...
#     Cases: 710
#     Parameters set: 7
#
# case=3253, swExec=Not
# -----
#
#
# case=3254, swExec=Not
# -----
#
#
# case=3255, swExec=Not
# -----
#
#
# case=3256, swExec=Not
# -----
#
#
# case=3257, swExec=Not
# -----
#
#
# case=3258, swExec=Not
# -----
#
#
# case=3259, swExec=Not
# -----
#
#
# case=3260, swExec=Not
# -----
#
#
# case=3261, swExec=Not
# -----
#
#
# case=3262, swExec=Not
# -----
#
#
# case=3263, swExec=Not
# -----
#
#
# case=3264, swExec=Not
# -----
#
#
# case=3265, swExec=Not
# -----
#
#
# case=3266, swExec=Not
# -----
#
#
# case=3267, swExec=Not
# -----
#
#
# case=3268, swExec=Not
# -----
#
#
# case=3269, swExec=Not
# -----
#
#
# case=3270, swExec=Not
# -----
#
#
# case=3271, swExec=Not
# -----
#
#
# case=3272, swExec=Not
# -----
#
#
# case=3273, swExec=Not
# -----
#
#
# case=3274, swExec=Not
# -----
#
#
# case=3275, swExec=Not
# -----
#
#
# case=3276, swExec=Not
# -----
#
#
# case=3277, swExec=Not
# -----
#
#
# case=3278, swExec=Not
# -----
#
#
# case=3279, swExec=Not
# -----
#
#
# case=3280, swExec=Not
# -----
#
#
# case=3281, swExec=Not
# -----
#
#
# case=3282, swExec=Not
# -----
#
#
# case=3283, swExec=Not
# -----
#
#
# case=3284, swExec=Not
# -----
#
#
# case=3285, swExec=Not
# -----
#
#
# case=3286, swExec=Not
# -----
#
#
# case=3287, swExec=Not
# -----
#
#
# case=3288, swExec=Not
# -----
#
#
# case=3289, swExec=Not
# -----
#
#
# case=3290, swExec=Not
# -----
#
#
# case=3291, swExec=Not
# -----
#
#
# case=3292, swExec=Not
# -----
#
#
# case=3293, swExec=Not
# -----
#
#
# case=3294, swExec=Not
# -----
#
#
# case=3295, swExec=Not
# -----
#
#
# case=3296, swExec=Not
# -----
#
#
# case=3297, swExec=Not
# -----
#
#
# case=3298, swExec=Not
# -----
#
#
# case=3299, swExec=Not
# -----
#
#
# case=3300, swExec=Not
# -----
#
#
# case=3301, swExec=Not
# -----
#
#
# case=3302, swExec=Not
# -----
#
#
# case=3303, swExec=Not
# -----
#
#
# case=3304, swExec=Not
# -----
#
#
# case=3305, swExec=Not
# -----
#
#
# case=3306, swExec=Not
# -----
#
#
# case=3307, swExec=Not
# -----
#
#
# case=3308, swExec=Not
# -----
#
#
# case=3309, swExec=Not
# -----
#
#
# case=3310, swExec=Not
# -----
#
#
# case=3311, swExec=Not
# -----
#
#
# case=3312, swExec=Not
# -----
#
#
# case=3313, swExec=Not
# -----
#
#
# case=3314, swExec=Not
# -----
#
#
# case=3315, swExec=Not
# -----
#
#
# case=3316, swExec=Not
# -----
#
#
# case=3317, swExec=Not
# -----
#
#
# case=3318, swExec=Not
# -----
#
#
# case=3319, swExec=Not
# -----
#
#
# case=3320, swExec=Not
# -----
#
#
# case=3321, swExec=Not
# -----
#
#
# case=3322, swExec=Not
# -----
#
#
# case=3323, swExec=Not
# -----
#
#
# case=3324, swExec=Not
# -----
#
#
# case=3325, swExec=Not
# -----
#
#
# case=3326, swExec=Not
# -----
#
#
# case=3327, swExec=Not
# -----
#
#
# case=3328, swExec=Not
# -----
#
#
# case=3329, swExec=Not
# -----
#
#
# case=3330, swExec=Not
# -----
#
#
# case=3331, swExec=Not
# -----
#
#
# case=3332, swExec=Not
# -----
#
#
# case=3333, swExec=Not
# -----
#
#
# case=3334, swExec=Not
# -----
#
#
# case=3335, swExec=Not
# -----
#
#
# case=3336, swExec=Not
# -----
#
#
# case=3337, swExec=Not
# -----
#
#
# case=3338, swExec=Not
# -----
#
#
# case=3339, swExec=Not
# -----
#
#
# case=3340, swExec=Not
# -----
#
#
# case=3341, swExec=Not
# -----
#
#
# case=3342, swExec=Not
# -----
#
#
# case=3343, swExec=Not
# -----
#
#
# case=3344, swExec=Not
# -----
#
#
# case=3345, swExec=Not
# -----
#
#
# case=3346, swExec=Not
# -----
#
#
# case=3347, swExec=Not
# -----
#
#
# case=3348, swExec=Not
# -----
#
#
# case=3349, swExec=Not
# -----
#
#
# case=3350, swExec=Not
# -----
#
#
# case=3351, swExec=Not
# -----
#
#
# case=3352, swExec=Not
# -----
#
#
# case=3353, swExec=Not
# -----
#
#
# case=3354, swExec=Not
# -----
#
#
# case=3355, swExec=Not
# -----
#
#
# case=3356, swExec=Not
# -----
#
#
# case=3357, swExec=Not
# -----
#
#
# case=3358, swExec=Not
# -----
#
#
# case=3359, swExec=Not
# -----
#
#
# case=3360, swExec=Not
# -----
#
#
# case=3361, swExec=Not
# -----
#
#
# case=3362, swExec=Not
# -----
#
#
# case=3363, swExec=Not
# -----
#
#
# case=3364, swExec=Not
# -----
#
#
# case=3365, swExec=Not
# -----
#
#
# case=3366, swExec=Not
# -----
#
#
# case=3367, swExec=Not
# -----
#
#
# case=3368, swExec=Not
# -----
#
#
# case=3369, swExec=Not
# -----
#
#
# case=3370, swExec=Not
# -----
#
#
# case=3371, swExec=Not
# -----
#
#
# case=3372, swExec=Not
# -----
#
#
# case=3373, swExec=Not
# -----
#
#
# case=3374, swExec=Not
# -----
#
#
# case=3375, swExec=Not
# -----
#
#
# case=3376, swExec=Not
# -----
#
#
# case=3377, swExec=Not
# -----
#
#
# case=3378, swExec=Not
# -----
#
#
# case=3379, swExec=Not
# -----
#
#
# case=3380, swExec=Not
# -----
#
#
# case=3381, swExec=Not
# -----
#
#
# case=3382, swExec=Not
# -----
#
#
# case=3383, swExec=Not
# -----
#
#
# case=3384, swExec=Not
# -----
#
#
# case=3385, swExec=Not
# -----
#
#
# case=3386, swExec=Not
# -----
#
#
# case=3387, swExec=Not
# -----
#
#
# case=3388, swExec=Not
# -----
#
#
# case=3389, swExec=Not
# -----
#
#
# case=3390, swExec=Not
# -----
#
#
# case=3391, swExec=Not
# -----
#
#
# case=3392, swExec=Not
# -----
#
#
# case=3393, swExec=Not
# -----
#
#
# case=3394, swExec=Not
# -----
#
#
# case=3395, swExec=Not
# -----
#
#
# case=3396, swExec=Not
# -----
#
#
# case=3397, swExec=Not
# -----
#
#
# case=3398, swExec=Not
# -----
#
#
# case=3399, swExec=Not
# -----
#
#
# case=3400, swExec=Not
# -----
#
#
# case=3401, swExec=Not
# -----
#
#
# case=3402, swExec=Not
# -----
#
#
# case=3403, swExec=Not
# -----
#
#
# case=3404, swExec=Not
# -----
#
#
# case=3405, swExec=Not
# -----
#
#
# case=3406, swExec=Not
# -----
#
#
# case=3407, swExec=Not
# -----
#
#
# case=3408, swExec=Not
# -----
#
#
# case=3409, swExec=Not
# -----
#
#
# case=3410, swExec=Not
# -----
#
#
# case=3411, swExec=Not
# -----
#
#
# case=3412, swExec=Not
# -----
#
#
# case=3413, swExec=Not
# -----
#
#
# case=3414, swExec=Not
# -----
#
#
# case=3415, swExec=Not
# -----
#
#
# case=3416, swExec=Not
# -----
#
#
# case=3417, swExec=Not
# -----
#
#
# case=3418, swExec=Not
# -----
#
#
# case=3419, swExec=Not
# -----
#
#
# case=3420, swExec=Not
# -----
#
#
# case=3421, swExec=Not
# -----
#
#
# case=3422, swExec=Not
# -----
#
#
# case=3423, swExec=Not
# -----
#
#
# case=3424, swExec=Not
# -----
#
#
# case=3425, swExec=Not
# -----
#
#
# case=3426, swExec=Not
# -----
#
#
# case=3427, swExec=Not
# -----
#
#
# case=3428, swExec=Not
# -----
#
#
# case=3429, swExec=Not
# -----
#
#
# case=3430, swExec=Not
# -----
#
#
# case=3431, swExec=Not
# -----
#
#
# case=3432, swExec=Not
# -----
#
#
# case=3433, swExec=Not
# -----
#
#
# case=3434, swExec=Not
# -----
#
#
# case=3435, swExec=Not
# -----
#
#
# case=3436, swExec=Not
# -----
#
#
# case=3437, swExec=Not
# -----
#
#
# case=3438, swExec=Not
# -----
#
#
# case=3439, swExec=Not
# -----
#
#
# case=3440, swExec=Not
# -----
#
#
# case=3441, swExec=Not
# -----
#
#
# case=3442, swExec=Not
# -----
#
#
# case=3443, swExec=Not
# -----
#
#
# case=3444, swExec=Not
# -----
#
#
# case=3445, swExec=Not
# -----
#
#
# case=3446, swExec=Not
# -----
#
#
# case=3447, swExec=Not
# -----
#
#
# case=3448, swExec=Not
# -----
#
#
# case=3449, swExec=Not
# -----
#
#
# case=3450, swExec=Not
# -----
#
#
# case=3451, swExec=Not
# -----
#
#
# case=3452, swExec=Not
# -----
#
#
# case=3453, swExec=Not
# -----
#
#
# case=3454, swExec=Not
# -----
#
#
# case=3455, swExec=Not
# -----
#
#
# case=3456, swExec=Not
# -----
#
#
# case=3457, swExec=Not
# -----
#
#
# case=3458, swExec=Not
# -----
#
#
# case=3459, swExec=Not
# -----
#
#
# case=3460, swExec=Not
# -----
#
#
# case=3461, swExec=Not
# -----
#
#
# case=3462, swExec=Not
# -----
#
#
# case=3463, swExec=Not
# -----
#
#
# case=3464, swExec=Not
# -----
#
#
# case=3465, swExec=Not
# -----
#
#
# case=3466, swExec=Not
# -----
#
#
# case=3467, swExec=Not
# -----
#
#
# case=3468, swExec=Not
# -----
#
#
# case=3469, swExec=Not
# -----
#
#
# case=3470, swExec=Not
# -----
#
#
# case=3471, swExec=Not
# -----
#
#
# case=3472, swExec=Not
# -----
#
#
# case=3473, swExec=Not
# -----
#
#
# case=3474, swExec=Not
# -----
#
#
# case=3475, swExec=Not
# -----
#
#
# case=3476, swExec=Not
# -----
#
#
# case=3477, swExec=Not
# -----
#
#
# case=3478, swExec=Not
# -----
#
#
# case=3479, swExec=Not
# -----
#
#
# case=3480, swExec=Not
# -----
#
#
# case=3481, swExec=Not
# -----
#
#
# case=3482, swExec=Not
# -----
#
#
# case=3483, swExec=Not
# -----
#
#
# case=3484, swExec=Not
# -----
#
#
# case=3485, swExec=Not
# -----
#
#
# case=3486, swExec=Not
# -----
#
#
# case=3487, swExec=Not
# -----
#
#
# case=3488, swExec=Not
# -----
#
#
# case=3489, swExec=Not
# -----
#
#
# case=3490, swExec=Not
# -----
#
#
# case=3491, swExec=Not
# -----
#
#
# case=3492, swExec=Not
# -----
#
#
# case=3493, swExec=Not
# -----
#
#
# case=3494, swExec=Not
# -----
#
#
# case=3495, swExec=Not
# -----
#
#
# case=3496, swExec=Not
# -----
#
#
# case=3497, swExec=Not
# -----
#
#
# case=3498, swExec=Not
# -----
#
#
# case=3499, swExec=Not
# -----
#
#
# case=3500, swExec=Not
# -----
#
#
# case=3501, swExec=Not
# -----
#
#
# case=3502, swExec=Not
# -----
#
#
# case=3503, swExec=Not
# -----
#
#
# case=3504, swExec=Not
# -----
#
#
# case=3505, swExec=Not
# -----
#
#
# case=3506, swExec=Not
# -----
#
#
# case=3507, swExec=Not
# -----
#
#
# case=3508, swExec=Not
# -----
#
#
# case=3509, swExec=Not
# -----
#
#
# case=3510, swExec=Not
# -----
#
#
# case=3511, swExec=Not
# -----
#
#
# case=3512, swExec=Not
# -----
#
#
# case=3513, swExec=Not
# -----
#
#
# case=3514, swExec=Not
# -----
#
#
# case=3515, swExec=Not
# -----
#
#
# case=3516, swExec=Not
# -----
#
#
# case=3517, swExec=Not
# -----
#
#
# case=3518, swExec=Not
# -----
#
#
# case=3519, swExec=Not
# -----
#
#
# case=3520, swExec=Not
# -----
#
#
# case=3521, swExec=Not
# -----
#
#
# case=3522, swExec=Not
# -----
#
#
# case=3523, swExec=Not
# -----
#
#
# case=3524, swExec=Not
# -----
#
#
# case=3525, swExec=Not
# -----
#
#
# case=3526, swExec=Not
# -----
#
#
# case=3527, swExec=Not
# -----
#
#
# case=3528, swExec=Not
# -----
#
#
# case=3529, swExec=Not
# -----
#
#
# case=3530, swExec=Not
# -----
#
#
# case=3531, swExec=Not
# -----
#
#
# case=3532, swExec=Not
# -----
#
#
# case=3533, swExec=Not
# -----
#
#
# case=3534, swExec=Not
# -----
#
#
# case=3535, swExec=Not
# -----
#
#
# case=3536, swExec=Not
# -----
#
#
# case=3537, swExec=Not
# -----
#
#
# case=3538, swExec=Not
# -----
#
#
# case=3539, swExec=Not
# -----
#
#
# case=3540, swExec=Not
# -----
#
#
# case=3541, swExec=Not
# -----
#
#
# case=3542, swExec=Not
# -----
#
#
# case=3543, swExec=Not
# -----
#
#
# case=3544, swExec=Not
# -----
#
#
# case=3545, swExec=Not
# -----
#
#
# case=3546, swExec=Not
# -----
#
#
# case=3547, swExec=Not
# -----
#
#
# case=3548, swExec=Not
# -----
#
#
# case=3549, swExec=Not
# -----
#
#
# case=3550, swExec=Not
# -----
#
#
# case=3551, swExec=Not
# -----
#
#
# case=3552, swExec=Not
# -----
#
#
# case=3553, swExec=Not
# -----
#
#
# case=3554, swExec=Not
# -----
#
#
# case=3555, swExec=Not
# -----
#
#
# case=3556, swExec=Not
# -----
#
#
# case=3557, swExec=Not
# -----
#
#
# case=3558, swExec=Not
# -----
#
#
# case=3559, swExec=Not
# -----
#
#
# case=3560, swExec=Not
# -----
#
#
# case=3561, swExec=Not
# -----
#
#
# case=3562, swExec=Not
# -----
#
#
# case=3563, swExec=Not
# -----
#
#
# case=3564, swExec=Not
# -----
#
#
# case=3565, swExec=Not
# -----
#
#
# case=3566, swExec=Not
# -----
#
#
# case=3567, swExec=Not
# -----
#
#
# case=3568, swExec=Not
# -----
#
#
# case=3569, swExec=Not
# -----
#
#
# case=3570, swExec=Not
# -----
#
#
# case=3571, swExec=Not
# -----
#
#
# case=3572, swExec=Not
# -----
#
#
# case=3573, swExec=Not
# -----
#
#
# case=3574, swExec=Not
# -----
#
#
# case=3575, swExec=Not
# -----
#
#
# case=3576, swExec=Not
# -----
#
#
# case=3577, swExec=Not
# -----
#
#
# case=3578, swExec=Not
# -----
#
#
# case=3579, swExec=Not
# -----
#
#
# case=3580, swExec=Not
# -----
#
#
# case=3581, swExec=Not
# -----
#
#
# case=3582, swExec=Not
# -----
#
#
# case=3583, swExec=Not
# -----
#
#
# case=3584, swExec=Not
# -----
#
#
# case=3585, swExec=Not
# -----
#
#
# case=3586, swExec=Not
# -----
#
#
# case=3587, swExec=Not
# -----
#
#
# case=3588, swExec=Not
# -----
#
#
# case=3589, swExec=Not
# -----
#
#
# case=3590, swExec=Not
# -----
#
#
# case=3591, swExec=Not
# -----
#
#
# case=3592, swExec=Not
# -----
#
#
# case=3593, swExec=Not
# -----
#
#
# case=3594, swExec=Not
# -----
#
#
# case=3595, swExec=Not
# -----
#
#
# case=3596, swExec=Not
# -----
#
#
# case=3597, swExec=Not
# -----
#
#
# case=3598, swExec=Not
# -----
#
#
# case=3599, swExec=Not
# -----
#
#
# case=3600, swExec=Not
# -----
#
#
# case=3601, swExec=Not
# -----
#
#
# case=3602, swExec=Not
# -----
#
#
# case=3603, swExec=Not
# -----
#
#
# case=3604, swExec=Not
# -----
#
#
# case=3605, swExec=Not
# -----
#
#
# case=3606, swExec=Not
# -----
#
#
# case=3607, swExec=Not
# -----
#
#
# case=3608, swExec=Not
# -----
#
#
# case=3609, swExec=Not
# -----
#
#
# case=3610, swExec=Not
# -----
#
#
# case=3611, swExec=Not
# -----
#
#
# case=3612, swExec=Not
# -----
#
#
# case=3613, swExec=Not
# -----
#
#
# case=3614, swExec=Not
# -----
#
#
# case=3615, swExec=Not
# -----
#
#
# case=3616, swExec=Not
# -----
#
#
# case=3617, swExec=Not
# -----
#
#
# case=3618, swExec=Not
# -----
#
#
# case=3619, swExec=Not
# -----
#
#
# case=3620, swExec=Not
# -----
#
#
# case=3621, swExec=Not
# -----
#
#
# case=3622, swExec=Not
# -----
#
#
# case=3623, swExec=Not
# -----
#
#
# case=3624, swExec=Not
# -----
#
#
# case=3625, swExec=Not
# -----
#
#
# case=3626, swExec=Not
# -----
#
#
# case=3627, swExec=Not
# -----
#
#
# case=3628, swExec=Not
# -----
#
#
# case=3629, swExec=Not
# -----
#
#
# case=3630, swExec=Not
# -----
#
#
# case=3631, swExec=Not
# -----
#
#
# case=3632, swExec=Not
# -----
#
#
# case=3633, swExec=Not
# -----
#
#
# case=3634, swExec=Not
# -----
#
#
# case=3635, swExec=Not
# -----
#
#
# case=3636, swExec=Not
# -----
#
#
# case=3637, swExec=Not
# -----
#
#
# case=3638, swExec=Not
# -----
#
#
# case=3639, swExec=Not
# -----
#
#
# case=3640, swExec=Not
# -----
#
#
# case=3641, swExec=Not
# -----
#
#
# case=3642, swExec=Not
# -----
#
#
# case=3643, swExec=Not
# -----
#
#
# case=3644, swExec=Not
# -----
#
#
# case=3645, swExec=Not
# -----
#
#
# case=3646, swExec=Not
# -----
#
#
# case=3647, swExec=Not
# -----
#
#
# case=3648, swExec=Not
# -----
#
#
# case=3649, swExec=Not
# -----
#
#
# case=3650, swExec=Not
# -----
#
#
# case=3651, swExec=Not
# -----
#
#
# case=3652, swExec=Not
# -----
#
#
# case=3653, swExec=Not
# -----
#
#
# case=3654, swExec=Not
# -----
#
#
# case=3655, swExec=Not
# -----
#
#
# case=3656, swExec=Not
# -----
#
#
# case=3657, swExec=Not
# -----
#
#
# case=3658, swExec=Not
# -----
#
#
# case=3659, swExec=Not
# -----
#
#
# case=3660, swExec=Not
# -----
#
#
# case=3661, swExec=Not
# -----
#
#
# case=3662, swExec=Not
# -----
#
#
# case=3663, swExec=Not
# -----
#
#
# case=3664, swExec=Not
# -----
#
#
# case=3665, swExec=Not
# -----
#
#
# case=3666, swExec=Not
# -----
#
#
# case=3667, swExec=Not
# -----
#
#
# case=3668, swExec=Not
# -----
#
#
# case=3669, swExec=Not
# -----
#
#
# case=3670, swExec=Not
# -----
#
#
# case=3671, swExec=Not
# -----
#
#
# case=3672, swExec=Not
# -----
#
#
# case=3673, swExec=Not
# -----
#
#
# case=3674, swExec=Not
# -----
#
#
# case=3675, swExec=Not
# -----
#
#
# case=3676, swExec=Not
# -----
#
#
# case=3677, swExec=Not
# -----
#
#
# case=3678, swExec=Not
# -----
#
#
# case=3679, swExec=Not
# -----
#
#
# case=3680, swExec=Not
# -----
#
#
# case=3681, swExec=Not
# -----
#
#
# case=3682, swExec=Not
# -----
#
#
# case=3683, swExec=Not
# -----
#
#
# case=3684, swExec=Not
# -----
#
#
# case=3685, swExec=Not
# -----
#
#
# case=3686, swExec=Not
# -----
#
#
# case=3687, swExec=Not
# -----
#
#
# case=3688, swExec=Not
# -----
#
#
# case=3689, swExec=Not
# -----
#
#
# case=3690, swExec=Not
# -----
#
#
# case=3691, swExec=Not
# -----
#
#
# case=3692, swExec=Not
# -----
#
#
# case=3693, swExec=Not
# -----
#
#
# case=3694, swExec=Not
# -----
#
#
# case=3695, swExec=Not
# -----
#
#
# case=3696, swExec=Not
# -----
#
#
# case=3697, swExec=Not
# -----
#
#
# case=3698, swExec=Not
# -----
#
#
# case=3699, swExec=Not
# -----
#
#
# case=3700, swExec=Not
# -----
#
#
# case=3701, swExec=Not
# -----
#
#
# case=3702, swExec=Not
# -----
#
#
# case=3703, swExec=Not
# -----
#
#
# case=3704, swExec=Not
# -----
#
#
# case=3705, swExec=Not
# -----
#
#
# case=3706, swExec=Not
# -----
#
#
# case=3707, swExec=Not
# -----
#
#
# case=3708, swExec=Not
# -----
#
#
# case=3709, swExec=Not
# -----
#
#
# case=3710, swExec=Not
# -----
#
#
# case=3711, swExec=Not
# -----
#
#
# case=3712, swExec=Not
# -----
#
#
# case=3713, swExec=Not
# -----
#
#
# case=3714, swExec=Not
# -----
#
#
# case=3715, swExec=Not
# -----
#
#
# case=3716, swExec=Not
# -----
#
#
# case=3717, swExec=Not
# -----
#
#
# case=3718, swExec=Not
# -----
#
#
# case=3719, swExec=Not
# -----
#
#
# case=3720, swExec=Not
# -----
#
#
# case=3721, swExec=Not
# -----
#
#
# case=3722, swExec=Not
# -----
#
#
# case=3723, swExec=Not
# -----
#
#
# case=3724, swExec=Not
# -----
#
#
# case=3725, swExec=Not
# -----
#
#
# case=3726, swExec=Not
# -----
#
#
# case=3727, swExec=Not
# -----
#
#
# case=3728, swExec=Not
# -----
#
#
# case=3729, swExec=Not
# -----
#
#
# case=3730, swExec=Not
# -----
#
#
# case=3731, swExec=Not
# -----
#
#
# case=3732, swExec=Not
# -----
#
#
# case=3733, swExec=Not
# -----
#
#
# case=3734, swExec=Not
# -----
#
#
# case=3735, swExec=Not
# -----
#
#
# case=3736, swExec=Not
# -----
#
#
# case=3737, swExec=Not
# -----
#
#
# case=3738, swExec=Not
# -----
#
#
# case=3739, swExec=Not
# -----
#
#
# case=3740, swExec=Not
# -----
#
#
# case=3741, swExec=Not
# -----
#
#
# case=3742, swExec=Not
# -----
#
#
# case=3743, swExec=Not
# -----
#
#
# case=3744, swExec=Not
# -----
#
#
# case=3745, swExec=Not
# -----
#
#
# case=3746, swExec=Not
# -----
#
#
# case=3747, swExec=Not
# -----
#
#
# case=3748, swExec=Not
# -----
#
#
# case=3749, swExec=Not
# -----
#
#
# case=3750, swExec=Not
# -----
#
#
# case=3751, swExec=Not
# -----
#
#
# case=3752, swExec=Not
# -----
#
#
# case=3753, swExec=Not
# -----
#
#
# case=3754, swExec=Not
# -----
#
#
# case=3755, swExec=Not
# -----
#
#
# case=3756, swExec=Not
# -----
#
#
# case=3757, swExec=Not
# -----
#
#
# case=3758, swExec=Not
# -----
#
#
# case=3759, swExec=Not
# -----
#
#
# case=3760, swExec=Not
# -----
#
#
# case=3761, swExec=Not
# -----
#
#
# case=3762, swExec=Not
# -----
#
#
# case=3763, swExec=Not
# -----
#
#
# case=3764, swExec=Not
# -----
#
#
# case=3765, swExec=Not
# -----
#
#
# case=3766, swExec=Not
# -----
#
#
# case=3767, swExec=Not
# -----
#
#
# case=3768, swExec=Not
# -----
#
#
# case=3769, swExec=Not
# -----
#
#
# case=3770, swExec=Not
# -----
#
#
# case=3771, swExec=Not
# -----
#
#
# case=3772, swExec=Not
# -----
#
#
# case=3773, swExec=Not
# -----
#
#
# case=3774, swExec=Not
# -----
#
#
# case=3775, swExec=Not
# -----
#
#
# case=3776, swExec=Not
# -----
#
#
# case=3777, swExec=Not
# -----
#
#
# case=3778, swExec=Not
# -----
#
#
# case=3779, swExec=Not
# -----
#
#
# case=3780, swExec=Not
# -----
#
#
# case=3781, swExec=Not
# -----
#
#
# case=3782, swExec=Not
# -----
#
#
# case=3783, swExec=Not
# -----
#
#
# case=3784, swExec=Not
# -----
#
#
# case=3785, swExec=Not
# -----
#
#
# case=3786, swExec=Not
# -----
#
#
# case=3787, swExec=Not
# -----
#
#
# case=3788, swExec=Not
# -----
#
#
# case=3789, swExec=Not
# -----
#
#
# case=3790, swExec=Not
# -----
#
#
# case=3791, swExec=Not
# -----
#
#
# case=3792, swExec=Not
# -----
#
#
# case=3793, swExec=Not
# -----
#
#
# case=3794, swExec=Not
# -----
#
#
# case=3795, swExec=Not
# -----
#
#
# case=3796, swExec=Not
# -----
#
#
# case=3797, swExec=Not
# -----
#
#
# case=3798, swExec=Not
# -----
#
#
# case=3799, swExec=Not
# -----
#
#
# case=3800, swExec=Not
# -----
#
#
# case=3801, swExec=Not
# -----
#
#
# case=3802, swExec=Not
# -----
#
#
# case=3803, swExec=Not
# -----
#
#
# case=3804, swExec=Not
# -----
#
#
# case=3805, swExec=Not
# -----
#
#
# case=3806, swExec=Not
# -----
#
#
# case=3807, swExec=Not
# -----
#
#
# case=3808, swExec=Not
# -----
#
#
# case=3809, swExec=Not
# -----
#
#
# case=3810, swExec=Not
# -----
#
#
# case=3811, swExec=Not
# -----
#
#
# case=3812, swExec=Not
# -----
#
#
# case=3813, swExec=Not
# -----
#
#
# case=3814, swExec=Not
# -----
#
#
# case=3815, swExec=Not
# -----
#
#
# case=3816, swExec=Not
# -----
#
#
# case=3817, swExec=Not
# -----
#
#
# case=3818, swExec=Not
# -----
#
#
# case=3819, swExec=Not
# -----
#
#
# case=3820, swExec=Not
# -----
#
#
# case=3821, swExec=Not
# -----
#
#
# case=3822, swExec=Not
# -----
#
#
# case=3823, swExec=Not
# -----
#
#
# case=3824, swExec=Not
# -----
#
#
# case=3825, swExec=Not
# -----
#
#
# case=3826, swExec=Not
# -----
#
#
# case=3827, swExec=Not
# -----
#
#
# case=3828, swExec=Not
# -----
#
#
# case=3829, swExec=Not
# -----
#
#
# case=3830, swExec=Not
# -----
#
#
# case=3831, swExec=Not
# -----
#
#
# case=3832, swExec=Not
# -----
#
#
# case=3833, swExec=Not
# -----
#
#
# case=3834, swExec=Not
# -----
#
#
# case=3835, swExec=Not
# -----
#
#
# case=3836, swExec=Not
# -----
#
#
# case=3837, swExec=Not
# -----
#
#
# case=3838, swExec=Not
# -----
#
#
# case=3839, swExec=Not
# -----
#
#
# case=3840, swExec=Not
# -----
#
#
# case=3841, swExec=Not
# -----
#
#
# case=3842, swExec=Not
# -----
#
#
# case=3843, swExec=Not
# -----
#
#
# case=3844, swExec=Not
# -----
#
#
# case=3845, swExec=Not
# -----
#
#
# case=3846, swExec=Not
# -----
#
#
# case=3847, swExec=Not
# -----
#
#
# case=3848, swExec=Not
# -----
#
#
# case=3849, swExec=Not
# -----
#
#
# case=3850, swExec=Not
# -----
#
#
# case=3851, swExec=Not
# -----
#
#
# case=3852, swExec=Not
# -----
#
#
# case=3853, swExec=Not
# -----
#
#
# case=3854, swExec=Not
# -----
#
#
# case=3855, swExec=Not
# -----
#
#
# case=3856, swExec=Not
# -----
#
#
# case=3857, swExec=Not
# -----
#
#
# case=3858, swExec=Not
# -----
#
#
# case=3859, swExec=Not
# -----
#
#
# case=3860, swExec=Not
# -----
#
#
# case=3861, swExec=Not
# -----
#
#
# case=3862, swExec=Not
# -----
#
#
# case=3863, swExec=Not
# -----
#
#
# case=3864, swExec=Not
# -----
#
#
# case=3865, swExec=Not
# -----
#
#
# case=3866, swExec=Not
# -----
#
#
# case=3867, swExec=Not
# -----
#
#
# case=3868, swExec=Not
# -----
#
#
# case=3869, swExec=Not
# -----
#
#
# case=3870, swExec=Not
# -----
#
#
# case=3871, swExec=Not
# -----
#
#
# case=3872, swExec=Not
# -----
#
#
# case=3873, swExec=Not
# -----
#
#
# case=3874, swExec=Not
# -----
#
#
# case=3875, swExec=Not
# -----
#
#
# case=3876, swExec=Not
# -----
#
#
# case=3877, swExec=Not
# -----
#
#
# case=3878, swExec=Not
# -----
#
#
# case=3879, swExec=Not
# -----
#
#
# case=3880, swExec=Not
# -----
#
#
# case=3881, swExec=Not
# -----
#
#
# case=3882, swExec=Not
# -----
#
#
# case=3883, swExec=Not
# -----
#
#
# case=3884, swExec=Not
# -----
#
#
# case=3885, swExec=Not
# -----
#
#
# case=3886, swExec=Not
# -----
#
#
# case=3887, swExec=Not
# -----
#
#
# case=3888, swExec=Not
# -----
#
#
# case=3889, swExec=Not
# -----
#
#
# case=3890, swExec=Not
# -----
#
#
# case=3891, swExec=Not
# -----
#
#
# case=3892, swExec=Not
# -----
#
#
# case=3893, swExec=Not
# -----
#
#
# case=3894, swExec=Not
# -----
#
#
# case=3895, swExec=Not
# -----
#
#
# case=3896, swExec=Not
# -----
#
#
# case=3897, swExec=Not
# -----
#
#
# case=3898, swExec=Not
# -----
#
#
# case=3899, swExec=Not
# -----
#
#
# case=3900, swExec=Not
# -----
#
#
# case=3901, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-39.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3901.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3901.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3901.csv")
# OMShell: 0
# -----
#
#
# case=3902, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3902.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3902.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3902.csv")
# OMShell: 0
# -----
#
#
# case=3903, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-40.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3903.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3903.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3903.csv")
# OMShell: 0
# -----
#
#
# case=3904, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3904.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3904.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3904.csv")
# OMShell: 0
# -----
#
#
# case=3905, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-41.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3905.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3905.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3905.csv")
# OMShell: 0
# -----
#
#
# case=3906, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3906.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3906.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3906.csv")
# OMShell: 0
# -----
#
#
# case=3907, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-42.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3907.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3907.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3907.csv")
# OMShell: 0
# -----
#
#
# case=3908, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3908.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3908.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3908.csv")
# OMShell: 0
# -----
#
#
# case=3909, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-43.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3909.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3909.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3909.csv")
# OMShell: 0
# -----
#
#
# case=3910, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3910.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3910.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3910.csv")
# OMShell: 0
# -----
#
#
# case=3911, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-44.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3911.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3911.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3911.csv")
# OMShell: 0
# -----
#
#
# case=3912, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3912.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3912.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3912.csv")
# OMShell: 0
# -----
#
#
# case=3913, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-45.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3913.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3913.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3913.csv")
# OMShell: 0
# -----
#
#
# case=3914, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3914.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3914.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3914.csv")
# OMShell: 0
# -----
#
#
# case=3915, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-46.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3915.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3915.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3915.csv")
# OMShell: 0
# -----
#
#
# case=3916, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3916.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3916.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3916.csv")
# OMShell: 0
# -----
#
#
# case=3917, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-47.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3917.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3917.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3917.csv")
# OMShell: 0
# -----
#
#
# case=3931, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-54.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3931.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3931.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3931.csv")
# OMShell: 0
# -----
#
#
# case=3932, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-55", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3932.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3932.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3932.csv")
# OMShell: 0
# -----
#
#
# case=3933, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-55.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# ...
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-64.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3951.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3951.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3951.csv")
# OMShell: 0
# -----
#
#
# case=3952, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-65", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3952.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3952.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3952.csv")
# OMShell: 0
# -----
#
#
# case=3953, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-65.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3953.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3953.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3953.csv")
# OMShell: 0
# -----
#
#
# case=3954, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-66", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3954.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3954.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3954.csv")
# OMShell: 0
# -----
#
#
# case=3955, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-66.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3955.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3955.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3955.csv")
# OMShell: 0
# -----
#
#
# case=3957, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-67.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3957.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3957.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3957.csv")
# OMShell: 0
# -----
#
#
# case=3958, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-68", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3958.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3958.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3958.csv")
# OMShell: 0
# -----
#
#
# case=3959, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-68.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3959.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3959.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3959.csv")
# OMShell: 0
# -----
#
#
# case=3960, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-69", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3960.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3960.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3960.csv")
# OMShell: 0
# -----
#
#
# case=3961, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-69.5", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3961.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3961.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3961.csv")
# OMShell: 0
# -----
#
#
# case=3962, swExec=Exec
# generating parameter setting xml fils...
# send: system("cp ThreeBodyOrbital00_init_parSweepOrg.xml ThreeBodyOrbital00_init.xml")
#
# i=1
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[1]", "-6778137", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[2]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "r3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[1]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[2]", "-10730", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=6
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "v3_init[3]", "0", "ThreeBodyOrbital00_init.xml")
# OMShell: True
# i=7
# send: setInitXmlStartValue("ThreeBodyOrbital00_init.xml", "phi_r2_deg_init", "-70", "ThreeBodyOrbital00_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp ThreeBodyOrbital00_init.xml ThreeBodyOrbital00_init_3962.xml")
# OMShell: 0
#
# ---- run simulation ----
# send: system("cp ThreeBodyOrbital00_init_3962.xml ThreeBodyOrbital00_init.xml")
#
# send: system("./ThreeBodyOrbital00 -override=startTime=0,stopTime=800000,stepSize=50.0 -r=ThreeBodyOrbital00_res_3962.csv")
# OMShell: 0
# -----
#
#
# ---------------------------------------------------------------------------
# ...simulation run completed.
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/AircraftDynamics
# ------------------------------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
