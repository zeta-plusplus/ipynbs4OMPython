# %% [markdown]
# <h1>Trivial.HydroTurbine_byPump_ex02</h1>
# <p>rev001</p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Use settings</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02'
nmModel='HydroTurbine_byPump_ex02'
stopTime=70.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/Trivial/HydroTurbine_byPump_ex02.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h2>Load libraries</h2>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- load Modelica Standard Library
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Building Model</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
print(''); print('...moving OMshell to temporary working directry')
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- build the model
print(''); print('...building the model, wait...')
strcmd= 'buildModel(' + fullpathModel + ', stopTime='+str(stopTime) + ', outputFormat="csv"' + ')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...model build finished.')

#-- save original parameter setting file
print(''); print('...Saving original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (fullpathModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# ...moving OMshell to temporary working directry
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...building the model, wait...
# send: buildModel(WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02, stopTime=70.0, outputFormat="csv")
# OMShell: ('/home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02', 'WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml')
# ...model build finished.
#
# ...Saving original parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml")
# OMShell: 0
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Print source code of model built</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

strcmd= 'list('+fullpathModel+')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print('source code of model build:')
print('')
print(str(msgOMShell)); 

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: list(WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02)
# source code of model build:
#
# model HydroTurbine_byPump_ex02
#   extends Modelica.Icons.Example;
#   //----------
#   replaceable package fluid1 = Modelica.Media.Water.StandardWaterOnePhase;
#   //replaceable package fluid1 = Modelica.Media.Air.DryAirNasa;
#   //redeclare package Medium = fluid1
#   //----------
#   inner Modelica.Fluid.System system annotation(
#     Placement(visible = true, transformation(origin = {-50, 90}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Fluid.Sources.Boundary_pT boundary(redeclare package Medium = fluid1, T = 1000, nPorts = 1, p = 10 * 101.325 * 1000, use_T_in = true, use_p_in = true) annotation(
#     Placement(visible = true, transformation(origin = {-110, -30}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Fluid.Machines.Pump trb(redeclare package Medium = fluid1, redeclare function flowCharacteristic = Modelica.Fluid.Machines.BaseClasses.PumpCharacteristics.quadraticFlow(V_flow_nominal = {0, -0.25, -0.50}, head_nominal = {-100, -70, 0}), redeclare function efficiencyCharacteristic = Modelica.Fluid.Machines.BaseClasses.PumpCharacteristics.constantEfficiency(eta_nominal = 0.9), N_nominal = 1000, V(displayUnit = "l") = 0.001, allowFlowReversal = true, checkValve = false, energyDynamics = Modelica.Fluid.Types.Dynamics.DynamicFreeInitial, m_flow_start = -10, massDynamics = Modelica.Fluid.Types.Dynamics.DynamicFreeInitial, nParallel = 1, p_b_start = 5 * system.p_start) annotation(
#     Placement(visible = true, transformation(origin = {-30, -30}, extent = {{10, -10}, {-10, 10}}, rotation = 0)));
#   Modelica.Mechanics.Rotational.Sensors.PowerSensor powerSensor1 annotation(
#     Placement(visible = true, transformation(origin = {-30, 30}, extent = {{-10, 10}, {10, -10}}, rotation = -90)));
#   Modelica.Fluid.Sensors.VolumeFlowRate volumeFlowRate1(redeclare package Medium = fluid1) annotation(
#     Placement(visible = true, transformation(origin = {20, -30}, extent = {{-10, 10}, {10, -10}}, rotation = 0)));
#   Modelica.Fluid.Sensors.VolumeFlowRate volumeFlowRate2(redeclare package Medium = fluid1) annotation(
#     Placement(visible = true, transformation(origin = {-80, -30}, extent = {{-10, 10}, {10, -10}}, rotation = 0)));
#   Modelica.Fluid.Sensors.MassFlowRate massFlowRate1(redeclare package Medium = fluid1) annotation(
#     Placement(visible = true, transformation(origin = {50, -30}, extent = {{-10, 10}, {10, -10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_N(duration = 10, height = 100, offset = 1000, startTime = 50) annotation(
#     Placement(visible = true, transformation(origin = {-150, 60}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Mechanics.Rotational.Sources.Speed speed1 annotation(
#     Placement(visible = true, transformation(origin = {-80, 60}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Fluid.Sensors.Pressure pressure1(redeclare package Medium = fluid1) annotation(
#     Placement(visible = true, transformation(origin = {80, -40}, extent = {{-10, -10}, {10, 10}}, rotation = 180)));
#   Modelica.Fluid.Sources.Boundary_pT boundary1(redeclare package Medium = fluid1, T = 288.15, nPorts = 1, p = 101.325 * 1000) annotation(
#     Placement(visible = true, transformation(origin = {140, -30}, extent = {{10, -10}, {-10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_p_in(duration = 10, height = 0 * 101.325 * 1000, offset = 5 * 101.325 * 1000, startTime = 30) annotation(
#     Placement(visible = true, transformation(origin = {-150, -10}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_T_in(duration = 10, height = 50, offset = 288.15, startTime = 30) annotation(
#     Placement(visible = true, transformation(origin = {-150, -40}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Math.UnitConversions.From_rpm from_rpm1 annotation(
#     Placement(visible = true, transformation(origin = {-120, 60}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Fluid.Valves.ValveLinear valveLinear1(redeclare package Medium = fluid1, dp_nominal(displayUnit = "Pa") = 100 * 1000, m_flow_nominal = 1000) annotation(
#     Placement(visible = true, transformation(origin = {110, -30}, extent = {{-10, -10}, {10, 10}}, rotation = 0)));
#   Modelica.Blocks.Sources.Ramp ramp_valve(duration = 10, height = -0.5, offset = 1.0, startTime = 10) annotation(
#     Placement(visible = true, transformation(origin = {110, 10}, extent = {{-10, -10}, {10, 10}}, rotation = -90)));
#   Modelica.Fluid.Sensors.SpecificEnthalpy specificEnthalpy(redeclare package Medium = fluid1) annotation(
#     Placement(visible = true, transformation(origin = {-50, -40}, extent = {{-10, -10}, {10, 10}}, rotation = 180)));
#   Modelica.Fluid.Sensors.SpecificEnthalpy specificEnthalpy1(redeclare package Medium = fluid1) annotation(
#     Placement(visible = true, transformation(origin = {0, -40}, extent = {{-10, -10}, {10, 10}}, rotation = 180)));
#   Modelica.Blocks.Math.Feedback dht_trb annotation(
#     Placement(visible = true, transformation(origin = {-70, -60}, extent = {{-10, 10}, {10, -10}}, rotation = -90)));
# equation
#   connect(ramp_valve.y, valveLinear1.opening) annotation(
#     Line(points = {{110, -1}, {110, -22}}, color = {0, 0, 127}));
#   connect(pressure1.port, valveLinear1.port_a) annotation(
#     Line(points = {{80, -30}, {100, -30}}, color = {0, 127, 255}));
#   connect(valveLinear1.port_b, boundary1.ports[1]) annotation(
#     Line(points = {{120, -30}, {130, -30}}, color = {0, 127, 255}));
#   connect(specificEnthalpy1.h_out, dht_trb.u2) annotation(
#     Line(points = {{-10, -40}, {-14, -40}, {-14, -60}, {-62, -60}}, color = {0, 0, 127}));
#   connect(specificEnthalpy.h_out, dht_trb.u1) annotation(
#     Line(points = {{-62, -40}, {-70, -40}, {-70, -52}}, color = {0, 0, 127}));
#   connect(specificEnthalpy1.port, volumeFlowRate1.port_a) annotation(
#     Line(points = {{0, -30}, {10, -30}, {10, -30}, {10, -30}}, color = {0, 127, 255}));
#   connect(trb.port_a, specificEnthalpy1.port) annotation(
#     Line(points = {{-20, -30}, {0, -30}, {0, -30}, {0, -30}}, color = {0, 127, 255}));
#   connect(specificEnthalpy.port, trb.port_b) annotation(
#     Line(points = {{-50, -30}, {-40, -30}, {-40, -30}, {-40, -30}}, color = {0, 127, 255}));
#   connect(volumeFlowRate2.port_b, specificEnthalpy.port) annotation(
#     Line(points = {{-70, -30}, {-50, -30}, {-50, -30}, {-50, -30}}, color = {0, 127, 255}));
#   connect(powerSensor1.flange_b, trb.shaft) annotation(
#     Line(points = {{-30, 20}, {-30, -20}}));
#   connect(speed1.flange, powerSensor1.flange_a) annotation(
#     Line(points = {{-70, 60}, {-30, 60}, {-30, 40}}));
#   connect(volumeFlowRate1.port_b, massFlowRate1.port_a) annotation(
#     Line(points = {{30, -30}, {40, -30}}, color = {0, 127, 255}));
#   connect(massFlowRate1.port_b, pressure1.port) annotation(
#     Line(points = {{60, -30}, {80, -30}}, color = {0, 127, 255}));
#   connect(ramp_N.y, from_rpm1.u) annotation(
#     Line(points = {{-139, 60}, {-132, 60}}, color = {0, 0, 127}));
#   connect(from_rpm1.y, speed1.w_ref) annotation(
#     Line(points = {{-108, 60}, {-92, 60}, {-92, 60}, {-92, 60}}, color = {0, 0, 127}));
#   connect(ramp_p_in.y, boundary.p_in) annotation(
#     Line(points = {{-139, -10}, {-130, -10}, {-130, -22}, {-122, -22}}, color = {0, 0, 127}));
#   connect(ramp_T_in.y, boundary.T_in) annotation(
#     Line(points = {{-139, -40}, {-133, -40}, {-133, -26}, {-123, -26}, {-123, -26}}, color = {0, 0, 127}));
#   connect(boundary.ports[1], volumeFlowRate2.port_a) annotation(
#     Line(points = {{-100, -30}, {-90, -30}}, color = {0, 127, 255}));
#   annotation(
#     experiment(StartTime = 0, StopTime = 50, Tolerance = 1e-06, Interval = 0.1),
#     __OpenModelica_simulationFlags(lv = "LOG_STATS", outputFormat = "mat", s = "dassl"),
#     Diagram(coordinateSystem(extent = {{-160, -80}, {160, 100}}), graphics = {Line(origin = {-64.5071, 30.002}, points = {{9.0238, -15.0238}, {7.0238, 12.9762}, {-8.9762, 14.9762}}, arrow = {Arrow.None, Arrow.Open}), Text(origin = {-170, 33}, extent = {{64, -1}, {112, -7}}, textString = "mechanical power"), Text(origin = {-132, 11}, extent = {{64, -1}, {148, -15}}, textString = "hydro turbine by 'pump' component")}),
#     __OpenModelica_commandLineOptions = "");
# end HydroTurbine_byPump_ex02;
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>  </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

strcmd= 'getSettings()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

strcmd= 'getComponents('+fullpathModel+')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

strcmd= 'getClassNames('+fullpathModel+')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: getSettings()
# OMShell: Compile command: clang++
# Temp folder path: /tmp
# Installation folder: /usr/bin/..
# Modelica path: /usr/bin/../lib/omlibrary:/home/ubuntu/.openmodelica/libraries/
#
#
# send: getComponents(WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02)
# OMShell: (('Modelica.Fluid.System', 'system', '', 'public', False, False, False, False, 'unspecified', 'inner', 'unspecified', ()), ('Modelica.Fluid.Sources.Boundary_pT', 'boundary', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Machines.Pump', 'trb', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Mechanics.Rotational.Sensors.PowerSensor', 'powerSensor1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Sensors.VolumeFlowRate', 'volumeFlowRate1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Sensors.VolumeFlowRate', 'volumeFlowRate2', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Sensors.MassFlowRate', 'massFlowRate1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Blocks.Sources.Ramp', 'ramp_N', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Mechanics.Rotational.Sources.Speed', 'speed1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Sensors.Pressure', 'pressure1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Sources.Boundary_pT', 'boundary1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Blocks.Sources.Ramp', 'ramp_p_in', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Blocks.Sources.Ramp', 'ramp_T_in', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Blocks.Math.UnitConversions.From_rpm', 'from_rpm1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Valves.ValveLinear', 'valveLinear1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Blocks.Sources.Ramp', 'ramp_valve', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Sensors.SpecificEnthalpy', 'specificEnthalpy', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Fluid.Sensors.SpecificEnthalpy', 'specificEnthalpy1', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()), ('Modelica.Blocks.Math.Feedback', 'dht_trb', '', 'public', False, False, False, False, 'unspecified', 'none', 'unspecified', ()))
#
# send: getClassNames(WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02)
# OMShell: ('fluid1',)
#
# send: getParameterValue(WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02)
# OMShell: None
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Run simulation, default setting</h1>

# %%
stopTime=80

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- reset _init.xml
print('...calling original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#-- run simulation with default parameter setting
print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
##### end if #####
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# ...calling original parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

strcmd= 'listVariables()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: listVariables()
# OMShell: ()
#
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Change multiple parameters </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRun=1
param2change=[
    "ramp_valve.height", "ramp_valve.startTime",
    "ramp_T_in.height", "ramp_T_in.startTime",
    "ramp_N.height", "ramp_N.startTime",
]
value2set=[
    -0.5, 10,
    50.0, 30,
    100.0, 50,
]
stopTime=80.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2change)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(fullpathModel+'_init.xml')+'", '+ '"'+param2change[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(fullpathModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# iRun=1
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml", "ramp_valve.height", "-0.5", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml", "ramp_valve.startTime", "10", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml", "ramp_T_in.height", "50.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml", "ramp_T_in.startTime", "30", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml", "ramp_N.height", "100.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml", "ramp_N.startTime", "50", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_1.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_1.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>parameter sweep, 1 parameter </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunBegin=2
iRunEnd=12
param2change="ramp_p_in.height"
valBegin=1.0*101.325*1000
deltaVal=0.2*101.325*1000
stopTime=80.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    iRun=i
    value2set=valBegin+(i-1)*deltaVal
    filenameXmlOrg=fullpathModel+'_init_org.xml'
    filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
    
    print(''); print('-----')
    print('iRun= '+ str(iRun))
    
    #-- overwrite parameter setting xml file
    print('...Overwriting parameter setting file...')
    strcmd= 'setInitXmlStartValue("' + filenameXmlOrg+'", '+ '"'+param2change+'", ' + '"'+str(value2set)+'", '+ '"'+fullpathModel+'_init.xml"' +')'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- save parameter setting file after overwriting
    print(''); print('...Saving parameter setting file...')
    strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- run simulation with default parameter setting
    print(''); print("...running simulation, wait...")
    if(os.name=='nt'):
        strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    elif(os.name=='posix'):
        strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    ##### end if #####

    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
    print('...simulation run finished.')
##### end for #####

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# -----
# iRun= 2
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "121590.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_2.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_2.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 3
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "141855.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_3.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_3.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 4
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "162120.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_4.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_4.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 5
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "182385.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_5.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_5.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 6
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "202650.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_6.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_6.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 7
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "222915.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_7.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_7.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 8
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "243180.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_8.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_8.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 9
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "263445.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_9.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_9.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 10
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "283710.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_10.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_10.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 11
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "303975.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_11.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_11.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 12
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_org.xml", "ramp_p_in.height", "324240.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_init_12.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_12.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process</h1>

# %%
n_df=100
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
#           time   speed1.phi    speed1.w  trb.medium.T  der(speed1.phi)  \
# 0     0.000000     0.000000  104.719755    293.150000       104.719755
# 1     0.140105    14.671770  104.719755    288.058254       104.719755
# 2     0.280210    29.343539  104.719755    288.058254       104.719755
# 3     0.420315    44.015309  104.719755    288.058254       104.719755
# 4     0.560420    58.687078  104.719755    288.058254       104.719755
# ..         ...          ...         ...           ...              ...
# 580  79.579685  8590.940331  115.191731    338.073420       115.191731
# 581  79.719790  8607.079277  115.191731    338.073420       115.191731
# 582  79.859895  8623.218224  115.191731    338.073420       115.191731
# 583  80.000000  8639.357170  115.191731    338.073420       115.191731
# 584  80.000000  8639.357170  115.191731    338.073420       115.191731
#
#      der(speed1.w)  der(trb.medium.T)    der(trb.U)    der(trb.m)  \
# 0              0.0      -3.049780e+03 -1.268508e+07  6.309806e-01
# 1              0.0       4.282176e-06  1.787980e-02 -6.443270e-10
# 2              0.0       6.192701e-08  2.585701e-04 -9.317983e-12
# 3              0.0       7.845712e-10  3.275900e-06 -1.180522e-13
# 4              0.0       4.893414e-10  2.043197e-06 -7.362983e-14
# ..             ...                ...           ...           ...
# 580            0.0       5.417220e-11  2.143119e-07 -2.940103e-14
# 581            0.0       5.131689e-11  2.030159e-07 -2.785136e-14
# 582            0.0       5.572321e-11  2.204479e-07 -3.024281e-14
# 583            0.0       5.286789e-11  2.091519e-07 -2.869314e-14
# 584            0.0       5.286789e-11  2.091519e-07 -2.869314e-14
#
#      der(trb.medium.h)  ...  volumeFlowRate2.port_a.m_flow  \
# 0        -1.275886e+07  ...                     597.717006
# 1         1.793293e-02  ...                     597.529730
# 2         2.593385e-04  ...                     597.529730
# 3         3.285634e-06  ...                     597.529730
# 4         2.049268e-06  ...                     597.529730
# ..                 ...  ...                            ...
# 580       2.266691e-07  ...                     612.265827
# 581       2.147218e-07  ...                     612.265827
# 582       2.331589e-07  ...                     612.265827
# 583       2.212116e-07  ...                     612.265827
# 584       2.212116e-07  ...                     612.265827
#
#      volumeFlowRate2.port_a.p  volumeFlowRate2.port_b.h_outflow  \
# 0                      506625                      63466.978845
# 1                      506625                      63466.978845
# 2                      506625                      63466.978845
# 3                      506625                      63466.978845
# 4                      506625                      63466.978845
# ..                        ...                               ...
# 580                    506625                     272478.219152
# 581                    506625                     272478.219152
# 582                    506625                     272478.219152
# 583                    506625                     272478.219152
# 584                    506625                     272478.219152
#
#      volumeFlowRate2.port_b.m_flow  volumeFlowRate2.port_b.p  \
# 0                      -597.717006                    506625
# 1                      -597.529730                    506625
# 2                      -597.529730                    506625
# 3                      -597.529730                    506625
# 4                      -597.529730                    506625
# ..                             ...                       ...
# 580                    -612.265827                    506625
# 581                    -612.265827                    506625
# 582                    -612.265827                    506625
# 583                    -612.265827                    506625
# 584                    -612.265827                    506625
#
#      boundary.medium.state.phase  boundary1.medium.state.phase  \
# 0                              1                             1
# 1                              1                             1
# 2                              1                             1
# 3                              1                             1
# 4                              1                             1
# ..                           ...                           ...
# 580                            1                             1
# 581                            1                             1
# 582                            1                             1
# 583                            1                             1
# 584                            1                             1
#
#      trb.heatTransfer.states[1].phase  trb.medium.state.phase  \
# 0                                   1                       1
# 1                                   1                       1
# 2                                   1                       1
# 3                                   1                       1
# 4                                   1                       1
# ..                                ...                     ...
# 580                                 1                       1
# 581                                 1                       1
# 582                                 1                       1
# 583                                 1                       1
# 584                                 1                       1
#
#      trb.monitoring.state.phase
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 580                           1
# 581                           1
# 582                           1
# 583                           1
# 584                           1
#
# [585 rows x 323 columns]

# %% [markdown]
# <h2>Read csv, array, specify start and end</h2>

# %%
i_df_begin=2
i_df_end=12


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

# %% [markdown]
# <h2>Read csv, selected case#</h2>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex02_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
#           time   speed1.phi    speed1.w  trb.medium.T  der(speed1.phi)  \
# 0     0.000000     0.000000  104.719755    293.150000       104.719755
# 1     0.140105    14.671770  104.719755    288.058254       104.719755
# 2     0.280210    29.343539  104.719755    288.058254       104.719755
# 3     0.420315    44.015309  104.719755    288.058254       104.719755
# 4     0.560420    58.687078  104.719755    288.058254       104.719755
# ..         ...          ...         ...           ...              ...
# 580  79.579685  8590.940331  115.191731    338.073420       115.191731
# 581  79.719790  8607.079277  115.191731    338.073420       115.191731
# 582  79.859895  8623.218224  115.191731    338.073420       115.191731
# 583  80.000000  8639.357170  115.191731    338.073420       115.191731
# 584  80.000000  8639.357170  115.191731    338.073420       115.191731
#
#      der(speed1.w)  der(trb.medium.T)    der(trb.U)    der(trb.m)  \
# 0              0.0      -3.049780e+03 -1.268508e+07  6.309806e-01
# 1              0.0       4.282176e-06  1.787980e-02 -6.443270e-10
# 2              0.0       6.192701e-08  2.585701e-04 -9.317983e-12
# 3              0.0       7.845712e-10  3.275900e-06 -1.180522e-13
# 4              0.0       4.893414e-10  2.043197e-06 -7.362983e-14
# ..             ...                ...           ...           ...
# 580            0.0       5.417220e-11  2.143119e-07 -2.940103e-14
# 581            0.0       5.131689e-11  2.030159e-07 -2.785136e-14
# 582            0.0       5.572321e-11  2.204479e-07 -3.024281e-14
# 583            0.0       5.286789e-11  2.091519e-07 -2.869314e-14
# 584            0.0       5.286789e-11  2.091519e-07 -2.869314e-14
#
#      der(trb.medium.h)  ...  volumeFlowRate2.port_a.m_flow  \
# 0        -1.275886e+07  ...                     597.717006
# 1         1.793293e-02  ...                     597.529730
# 2         2.593385e-04  ...                     597.529730
# 3         3.285634e-06  ...                     597.529730
# 4         2.049268e-06  ...                     597.529730
# ..                 ...  ...                            ...
# 580       2.266691e-07  ...                     612.265827
# 581       2.147218e-07  ...                     612.265827
# 582       2.331589e-07  ...                     612.265827
# 583       2.212116e-07  ...                     612.265827
# 584       2.212116e-07  ...                     612.265827
#
#      volumeFlowRate2.port_a.p  volumeFlowRate2.port_b.h_outflow  \
# 0                      506625                      63466.978845
# 1                      506625                      63466.978845
# 2                      506625                      63466.978845
# 3                      506625                      63466.978845
# 4                      506625                      63466.978845
# ..                        ...                               ...
# 580                    506625                     272478.219152
# 581                    506625                     272478.219152
# 582                    506625                     272478.219152
# 583                    506625                     272478.219152
# 584                    506625                     272478.219152
#
#      volumeFlowRate2.port_b.m_flow  volumeFlowRate2.port_b.p  \
# 0                      -597.717006                    506625
# 1                      -597.529730                    506625
# 2                      -597.529730                    506625
# 3                      -597.529730                    506625
# 4                      -597.529730                    506625
# ..                             ...                       ...
# 580                    -612.265827                    506625
# 581                    -612.265827                    506625
# 582                    -612.265827                    506625
# 583                    -612.265827                    506625
# 584                    -612.265827                    506625
#
#      boundary.medium.state.phase  boundary1.medium.state.phase  \
# 0                              1                             1
# 1                              1                             1
# 2                              1                             1
# 3                              1                             1
# 4                              1                             1
# ..                           ...                           ...
# 580                            1                             1
# 581                            1                             1
# 582                            1                             1
# 583                            1                             1
# 584                            1                             1
#
#      trb.heatTransfer.states[1].phase  trb.medium.state.phase  \
# 0                                   1                       1
# 1                                   1                       1
# 2                                   1                       1
# 3                                   1                       1
# 4                                   1                       1
# ..                                ...                     ...
# 580                                 1                       1
# 581                                 1                       1
# 582                                 1                       1
# 583                                 1                       1
# 584                                 1                       1
#
#      trb.monitoring.state.phase
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 580                           1
# 581                           1
# 582                           1
# 583                           1
# 584                           1
#
# [585 rows x 323 columns]

# %%
i_df=1

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'speed1.phi',
#  'speed1.w',
#  'trb.medium.T',
#  'der(speed1.phi)',
#  'der(speed1.w)',
#  'der(trb.medium.T)',
#  'der(trb.U)',
#  'der(trb.m)',
#  'der(trb.medium.h)',
#  'der(trb.medium.p)',
#  'der(trb.medium.u)',
#  'der(trb.rho)',
#  '$cse1.R',
#  '$cse1.T',
#  '$cse1.cp',
#  '$cse1.cv',
#  '$cse1.dpT',
#  '$cse1.h',
#  '$cse1.p',
#  '$cse1.pd',
#  '$cse1.pt',
#  '$cse1.rho',
#  '$cse1.s',
#  '$cse1.vp',
#  '$cse1.vt',
#  '$cse1.x',
#  '$cse10.R',
#  '$cse10.T',
#  '$cse10.cp',
#  '$cse10.cv',
#  '$cse10.dpT',
#  '$cse10.h',
#  '$cse10.p',
#  '$cse10.pd',
#  '$cse10.pt',
#  '$cse10.rho',
#  '$cse10.s',
#  '$cse10.vp',
#  '$cse10.vt',
#  '$cse10.x',
#  '$cse11.R',
#  '$cse11.T',
#  '$cse11.cp',
#  '$cse11.cv',
#  '$cse11.dpT',
#  '$cse11.h',
#  '$cse11.p',
#  '$cse11.pd',
#  '$cse11.pt',
#  '$cse11.rho',
#  '$cse11.s',
#  '$cse11.vp',
#  '$cse11.vt',
#  '$cse11.x',
#  '$cse2.R',
#  '$cse2.T',
#  '$cse2.cp',
#  '$cse2.cv',
#  '$cse2.dpT',
#  '$cse2.h',
#  '$cse2.p',
#  '$cse2.pd',
#  '$cse2.pt',
#  '$cse2.rho',
#  '$cse2.s',
#  '$cse2.vp',
#  '$cse2.vt',
#  '$cse2.x',
#  '$cse3.R',
#  '$cse3.T',
#  '$cse3.cp',
#  '$cse3.cv',
#  '$cse3.dpT',
#  '$cse3.h',
#  '$cse3.p',
#  '$cse3.pd',
#  '$cse3.pt',
#  '$cse3.rho',
#  '$cse3.s',
#  '$cse3.vp',
#  '$cse3.vt',
#  '$cse3.x',
#  '$cse5.R',
#  '$cse5.T',
#  '$cse5.cp',
#  '$cse5.cv',
#  '$cse5.dpT',
#  '$cse5.h',
#  '$cse5.p',
#  '$cse5.pd',
#  '$cse5.pt',
#  '$cse5.rho',
#  '$cse5.s',
#  '$cse5.vp',
#  '$cse5.vt',
#  '$cse5.x',
#  '$cse6.R',
#  '$cse6.T',
#  '$cse6.cp',
#  '$cse6.cv',
#  '$cse6.dpT',
#  '$cse6.h',
#  '$cse6.p',
#  '$cse6.pd',
#  '$cse6.pt',
#  '$cse6.rho',
#  '$cse6.s',
#  '$cse6.vp',
#  '$cse6.vt',
#  '$cse6.x',
#  '$cse7.R',
#  '$cse7.T',
#  '$cse7.cp',
#  '$cse7.cv',
#  '$cse7.dpT',
#  '$cse7.h',
#  '$cse7.p',
#  '$cse7.pd',
#  '$cse7.pt',
#  '$cse7.rho',
#  '$cse7.s',
#  '$cse7.vp',
#  '$cse7.vt',
#  '$cse7.x',
#  '$cse8.R',
#  '$cse8.T',
#  '$cse8.cp',
#  '$cse8.cv',
#  '$cse8.dpT',
#  '$cse8.h',
#  '$cse8.p',
#  '$cse8.pd',
#  '$cse8.pt',
#  '$cse8.rho',
#  '$cse8.s',
#  '$cse8.vp',
#  '$cse8.vt',
#  '$cse8.x',
#  'boundary.T_in',
#  'boundary.medium.MM',
#  'boundary.medium.R',
#  'boundary.medium.T_degC',
#  'boundary.medium.X[1]',
#  'boundary.medium.d',
#  'boundary.medium.p_bar',
#  'boundary.medium.sat.Tsat',
#  'boundary.medium.u',
#  'boundary.ports[1].h_outflow',
#  'boundary.ports[1].m_flow',
#  'boundary1.medium.MM',
#  'boundary1.medium.R',
#  'boundary1.medium.T_degC',
#  'boundary1.medium.X[1]',
#  'boundary1.medium.d',
#  'boundary1.medium.p_bar',
#  'boundary1.medium.sat.Tsat',
#  'boundary1.medium.u',
#  'boundary1.ports[1].h_outflow',
#  'dht_trb.u1',
#  'dht_trb.u2',
#  'dht_trb.y',
#  'from_rpm1.u',
#  'massFlowRate1.m_flow',
#  'powerSensor1.flange_b.tau',
#  'powerSensor1.power',
#  'pressure1.p',
#  'pressure1.port.h_outflow',
#  'pressure1.port.m_flow',
#  'ramp_valve.y',
#  'specificEnthalpy.port.h_outflow',
#  'specificEnthalpy.port.m_flow',
#  'specificEnthalpy1.port.h_outflow',
#  'specificEnthalpy1.port.m_flow',
#  'speed1.a',
#  'speed1.w_ref',
#  'trb.Hb_flow',
#  'trb.N',
#  'trb.U',
#  'trb.V_flow',
#  'trb.V_flow_single',
#  'trb.W_single',
#  'trb.Wb_flow',
#  'trb.dp_pump',
#  'trb.eta',
#  'trb.fluidVolume',
#  'trb.head',
#  'trb.heatTransfer.heatPorts[1].Q_flow',
#  'trb.heatTransfer.surfaceAreas[1]',
#  'trb.m',
#  'trb.m_flow_single',
#  'trb.mb_flow',
#  'trb.medium.MM',
#  'trb.medium.R',
#  'trb.medium.T_degC',
#  'trb.medium.X[1]',
#  'trb.medium.h',
#  'trb.medium.p',
#  'trb.medium.p_bar',
#  'trb.medium.sat.Tsat',
#  'trb.medium.u',
#  'trb.monitoring.state_in.T',
#  'trb.monitoring.state_in.d',
#  'trb.rho',
#  'trb.s',
#  'valveLinear1.V_flow',
#  'valveLinear1.dp',
#  'valveLinear1.port_a_T',
#  'valveLinear1.port_b_T',
#  'volumeFlowRate1.V_flow',
#  'volumeFlowRate2.V_flow',
#  '$cse1.phase',
#  '$cse1.region',
#  '$cse10.phase',
#  '$cse10.region',
#  '$cse11.phase',
#  '$cse11.region',
#  '$cse2.phase',
#  '$cse2.region',
#  '$cse3.phase',
#  '$cse3.region',
#  '$cse5.phase',
#  '$cse5.region',
#  '$cse6.phase',
#  '$cse6.region',
#  '$cse7.phase',
#  '$cse7.region',
#  '$cse8.phase',
#  '$cse8.region',
#  'boundary.medium.phase',
#  'boundary1.medium.phase',
#  'trb.medium.phase',
#  'trb.monitoring.state_in.phase',
#  'boundary.medium.T',
#  'boundary.medium.h',
#  'boundary.medium.p',
#  'boundary.medium.sat.psat',
#  'boundary.medium.state.T',
#  'boundary.medium.state.d',
#  'boundary.medium.state.h',
#  'boundary.medium.state.p',
#  'boundary.p_in',
#  'boundary.ports[1].p',
#  'boundary1.medium.h',
#  'boundary1.medium.state.d',
#  'boundary1.medium.state.h',
#  'boundary1.ports[1].m_flow',
#  'from_rpm1.y',
#  'massFlowRate1.port_a.h_outflow',
#  'massFlowRate1.port_a.m_flow',
#  'massFlowRate1.port_a.p',
#  'massFlowRate1.port_b.h_outflow',
#  'massFlowRate1.port_b.m_flow',
#  'massFlowRate1.port_b.p',
#  'powerSensor1.flange_a.phi',
#  'powerSensor1.flange_a.tau',
#  'powerSensor1.flange_b.phi',
#  'pressure1.port.p',
#  'ramp_N.y',
#  'ramp_T_in.y',
#  'ramp_p_in.y',
#  'specificEnthalpy.h_out',
#  'specificEnthalpy.port.p',
#  'specificEnthalpy1.h_out',
#  'specificEnthalpy1.port.p',
#  'speed1.flange.phi',
#  'speed1.flange.tau',
#  'trb.Qb_flow',
#  'trb.W_total',
#  'trb.heatTransfer.Q_flows[1]',
#  'trb.heatTransfer.Ts[1]',
#  'trb.heatTransfer.heatPorts[1].T',
#  'trb.heatTransfer.states[1].T',
#  'trb.heatTransfer.states[1].d',
#  'trb.heatTransfer.states[1].h',
#  'trb.heatTransfer.states[1].p',
#  'trb.m_flow',
#  'trb.medium.d',
#  'trb.medium.sat.psat',
#  'trb.medium.state.T',
#  'trb.medium.state.d',
#  'trb.medium.state.h',
#  'trb.medium.state.p',
#  'trb.monitoring.state.T',
#  'trb.monitoring.state.d',
#  'trb.monitoring.state.h',
#  'trb.monitoring.state.p',
#  'trb.monitoring.state_in.h',
#  'trb.monitoring.state_in.p',
#  'trb.omega',
#  'trb.phi',
#  'trb.port_a.h_outflow',
#  'trb.port_a.m_flow',
#  'trb.port_a.p',
#  'trb.port_b.h_outflow',
#  'trb.port_b.m_flow',
#  'trb.port_b.p',
#  'trb.shaft.phi',
#  'trb.shaft.tau',
#  'valveLinear1.m_flow',
#  'valveLinear1.opening',
#  'valveLinear1.port_a.h_outflow',
#  'valveLinear1.port_a.m_flow',
#  'valveLinear1.port_a.p',
#  'valveLinear1.port_b.h_outflow',
#  'valveLinear1.port_b.m_flow',
#  'volumeFlowRate1.port_a.h_outflow',
#  'volumeFlowRate1.port_a.m_flow',
#  'volumeFlowRate1.port_a.p',
#  'volumeFlowRate1.port_b.h_outflow',
#  'volumeFlowRate1.port_b.m_flow',
#  'volumeFlowRate1.port_b.p',
#  'volumeFlowRate2.port_a.h_outflow',
#  'volumeFlowRate2.port_a.m_flow',
#  'volumeFlowRate2.port_a.p',
#  'volumeFlowRate2.port_b.h_outflow',
#  'volumeFlowRate2.port_b.m_flow',
#  'volumeFlowRate2.port_b.p',
#  'boundary.medium.state.phase',
#  'boundary1.medium.state.phase',
#  'trb.heatTransfer.states[1].phase',
#  'trb.medium.state.phase',
#  'trb.monitoring.state.phase']

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
i_df=1
varName="valveLinear1.opening"
ylabel='opening [nond]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="boundary.medium.T"
ylabel='Temperature [degC]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]-273.15

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="trb.N"
ylabel='rot. speed [rpm]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=1
varName="powerSensor1.power"
ylabel='Power [kW]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]*(-1)/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName + ' *(-1)')
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="trb.port_b.m_flow"
ylabel='mass flow rate [kg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="volumeFlowRate2.V_flow"
ylabel='volume flow rate [m3/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="trb.medium.d"
ylabel='density [kg/m3]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="trb.dp_pump"
ylabel='pressure difference [kPaD]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="trb.head"
ylabel='head [m]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
#plt.ylim(1000, 1800)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="dht_trb.y"
ylabel='specific enthalpy [J/kg]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')
plt.ylim(200, 400)

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
xlabel='volume flow rate [m3/s]'
ylabel='pressure difference [kPaD]'

varName="volumeFlowRate2.V_flow"
var1= df[i_df].loc[:,varName]

varName="trb.dp_pump"
var2= df[i_df].loc[:,varName]/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(var1, var2, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
xlabel='rot. speed [rpm]'
ylabel='volume flow rate [m3/s]'

varName="trb.N"
var1= df[i_df].loc[:,varName]

varName="volumeFlowRate2.V_flow"
var2= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(var1, var2, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
xlabel='rot. speed [rpm]'
ylabel='pressure difference [kPaD]'

varName="trb.N"
var1= df[i_df].loc[:,varName]

varName="trb.dp_pump"
var2= df[i_df].loc[:,varName]/1000.0

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(var1, var2, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
xlabel='rot. speed [rpm]'
ylabel='power [kW]'

varName="trb.N"
var1= df[i_df].loc[:,varName]

varName="powerSensor1.power"
var2= df[i_df].loc[:,varName]/(-1.0*1000.0)

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(varName + ' *(-1)')
plt.plot(var1, var2, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
xlabel='rot. speed [rpm]'
ylabel='mass flow rate [kg/s]'

varName="trb.N"
var1= df[i_df].loc[:,varName]

varName="trb.port_b.m_flow"
var2= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(var1, var2, color='red')

plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Extract variables at specified time</h2>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------
