# %% [markdown]
# <h1>Trivial.HydroTurbine_byPump_ex01</h1>
# <p>rev001</p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Use settings</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01'
nmModel='HydroTurbine_byPump_ex01'
stopTime=70.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/Trivial/HydroTurbine_byPump_ex01.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h2>Load libraries</h2>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- load Modelica Standard Library
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Building Model</h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
print(''); print('...moving OMshell to temporary working directry')
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- build the model
print(''); print('...building the model, wait...')
strcmd= 'buildModel(' + fullpathModel + ', stopTime='+str(stopTime) + ', outputFormat="csv"' + ')'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...model build finished.')

#-- save original parameter setting file
print(''); print('...Saving original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (fullpathModel+'_init_org.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# ...moving OMshell to temporary working directry
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...building the model, wait...
# send: buildModel(WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01, stopTime=80, outputFormat="csv")
# OMShell: ('/home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01', 'WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml')
# ...model build finished.
#
# ...Saving original parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml")
# OMShell: 0
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Run simulation, default setting</h1>

# %%
stopTime=80

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- reset _init.xml
print('...calling original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#-- run simulation with default parameter setting
print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res.csv' +'")'
##### end if #####
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# ...calling original parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Change multiple parameters </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRun=1
param2change=[
    "ramp_N.height",
    "ramp_N.startTime",
    "ramp_p_in.height",
    "ramp_p_in.startTime",
    "ramp_T_in.height",
    "ramp_T_in.startTime",
]
value2set=[
    1000.0, 
    50,
    5.0*101.325*1000,
    10,
    50.0,
    30,
]
stopTime=80.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2change)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(fullpathModel+'_init.xml')+'", '+ '"'+param2change[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(fullpathModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# iRun=1
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml", "ramp_N.height", "1000.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml", "ramp_N.startTime", "50", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml", "ramp_p_in.height", "506625.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml", "ramp_p_in.startTime", "10", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml", "ramp_T_in.height", "50.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
# i=5
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml", "ramp_T_in.startTime", "30", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_1.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_1.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>parameter sweep, 1 parameter </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunBegin=2
iRunEnd=12
param2change="ramp_p_in.height"
valBegin=1.0*101.325*1000
deltaVal=0.2*101.325*1000
stopTime=80.0

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    iRun=i
    value2set=valBegin+(i-1)*deltaVal
    filenameXmlOrg=fullpathModel+'_init_org.xml'
    filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
    
    print(''); print('-----')
    print('iRun= '+ str(iRun))
    
    #-- overwrite parameter setting xml file
    print('...Overwriting parameter setting file...')
    strcmd= 'setInitXmlStartValue("' + filenameXmlOrg+'", '+ '"'+param2change+'", ' + '"'+str(value2set)+'", '+ '"'+fullpathModel+'_init.xml"' +')'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- save parameter setting file after overwriting
    print(''); print('...Saving parameter setting file...')
    strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- run simulation with default parameter setting
    print(''); print("...running simulation, wait...")
    if(os.name=='nt'):
        strcmd= 'system("' + fullpathModel + '.exe' + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    elif(os.name=='posix'):
        strcmd= 'system("' + './'+fullpathModel + ' -override stopTime='+str(stopTime) + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    ##### end if #####

    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
    print('...simulation run finished.')
##### end for #####

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# -----
# iRun= 2
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "121590.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_2.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_2.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 3
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "141855.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_3.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_3.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 4
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "162120.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_4.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_4.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 5
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "182385.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_5.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_5.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 6
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "202650.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_6.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_6.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 7
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "222915.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_7.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_7.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 8
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "243180.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_8.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_8.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 9
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "263445.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_9.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_9.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 10
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "283710.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_10.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_10.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 11
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "303975.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_11.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_11.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 12
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_org.xml", "ramp_p_in.height", "324240.0", "WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init.xml WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_init_12.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01 -override stopTime=80.0 -r=WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_12.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process</h1>

# %%
n_df=100
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
#       time    speed1.phi    speed1.w  trb.medium.T  der(speed1.phi)  \
# 0     0.00      0.000000  104.719755    293.150000       104.719755
# 1     0.16     16.755161  104.719755    287.907844       104.719755
# 2     0.32     33.510322  104.719755    287.907844       104.719755
# 3     0.48     50.265482  104.719755    287.907844       104.719755
# 4     0.64     67.020643  104.719755    287.907844       104.719755
# ..     ...           ...         ...           ...              ...
# 505  79.52  15083.501332  209.439510    287.907844       209.439510
# 506  79.68  15117.011653  209.439510    287.907844       209.439510
# 507  79.84  15150.521975  209.439510    287.907844       209.439510
# 508  80.00  15184.032297  209.439510    287.907844       209.439510
# 509  80.00  15184.032297  209.439510    287.907844       209.439510
#
#      der(speed1.w)  der(trb.medium.T)    der(trb.U)    der(trb.m)  \
# 0              0.0      -3.983240e+03 -1.656461e+07  8.273599e-01
# 1              0.0      -1.861099e-07 -7.770060e-04  2.786606e-11
# 2              0.0      -2.078532e-09 -8.677839e-06  3.112166e-13
# 3              0.0       2.732617e-11  1.140863e-07 -4.091520e-15
# 4              0.0       2.732633e-11  1.140870e-07 -4.091545e-15
# ..             ...                ...           ...           ...
# 505            0.0       2.788402e-13  1.164153e-09 -4.175047e-17
# 506            0.0       1.455538e-11  6.076848e-08 -2.179363e-15
# 507            0.0       1.455553e-11  6.076911e-08 -2.179386e-15
# 508            0.0       1.455546e-11  6.076880e-08 -2.179374e-15
# 509            0.0       1.455546e-11  6.076880e-08 -2.179374e-15
#
#      der(trb.medium.h)  ...  volumeFlowRate2.port_a.m_flow  \
# 0        -1.665777e+07  ...                     758.445647
# 1        -7.791006e-04  ...                     758.088223
# 2        -8.701231e-06  ...                     758.088223
# 3         1.143938e-07  ...                     758.088223
# 4         1.143945e-07  ...                     758.088223
# ..                 ...  ...                            ...
# 505       1.167291e-09  ...                    1128.716152
# 506       6.093229e-08  ...                    1128.716152
# 507       6.093292e-08  ...                    1128.716152
# 508       6.093261e-08  ...                    1128.716152
# 509       6.093261e-08  ...                    1128.716152
#
#      volumeFlowRate2.port_a.p  volumeFlowRate2.port_b.h_outflow  \
# 0                     1013250                      63951.680112
# 1                     1013250                      63951.680112
# 2                     1013250                      63951.680112
# 3                     1013250                      63951.680112
# 4                     1013250                      63951.680112
# ..                        ...                               ...
# 505                   1013250                      63951.680112
# 506                   1013250                      63951.680112
# 507                   1013250                      63951.680112
# 508                   1013250                      63951.680112
# 509                   1013250                      63951.680112
#
#      volumeFlowRate2.port_b.m_flow  volumeFlowRate2.port_b.p  \
# 0                      -758.445647                   1013250
# 1                      -758.088223                   1013250
# 2                      -758.088223                   1013250
# 3                      -758.088223                   1013250
# 4                      -758.088223                   1013250
# ..                             ...                       ...
# 505                   -1128.716152                   1013250
# 506                   -1128.716152                   1013250
# 507                   -1128.716152                   1013250
# 508                   -1128.716152                   1013250
# 509                   -1128.716152                   1013250
#
#      boundary.medium.state.phase  boundary1.medium.state.phase  \
# 0                              1                             1
# 1                              1                             1
# 2                              1                             1
# 3                              1                             1
# 4                              1                             1
# ..                           ...                           ...
# 505                            1                             1
# 506                            1                             1
# 507                            1                             1
# 508                            1                             1
# 509                            1                             1
#
#      trb.heatTransfer.states[1].phase  trb.medium.state.phase  \
# 0                                   1                       1
# 1                                   1                       1
# 2                                   1                       1
# 3                                   1                       1
# 4                                   1                       1
# ..                                ...                     ...
# 505                                 1                       1
# 506                                 1                       1
# 507                                 1                       1
# 508                                 1                       1
# 509                                 1                       1
#
#      trb.monitoring.state.phase
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 505                           1
# 506                           1
# 507                           1
# 508                           1
# 509                           1
#
# [510 rows x 260 columns]

# %% [markdown]
# <h2>Read csv, array, specify start and end</h2>

# %%
i_df_begin=2
i_df_end=12


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_2.csv
# i_df=3
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_3.csv
# i_df=4
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_4.csv
# i_df=5
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_5.csv
# i_df=6
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_6.csv
# i_df=7
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_7.csv
# i_df=8
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_8.csv
# i_df=9
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_9.csv
# i_df=10
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_10.csv
# i_df=11
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_11.csv
# i_df=12
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_12.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid

# %% [markdown]
# <h2>Read csv, selected case#</h2>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/WalkingInWorldOfThermoFluid.Trivial.HydroTurbine_byPump_ex01_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/WalkingInWorldOfThermoFluid
#       time    speed1.phi    speed1.w  trb.medium.T  der(speed1.phi)  \
# 0     0.00      0.000000  104.719755    293.150000       104.719755
# 1     0.16     16.755161  104.719755    287.907844       104.719755
# 2     0.32     33.510322  104.719755    287.907844       104.719755
# 3     0.48     50.265482  104.719755    287.907844       104.719755
# 4     0.64     67.020643  104.719755    287.907844       104.719755
# ..     ...           ...         ...           ...              ...
# 509  79.52  10894.721141  209.439510    337.765957       209.439510
# 510  79.68  10928.231463  209.439510    337.765957       209.439510
# 511  79.84  10961.741784  209.439510    337.765957       209.439510
# 512  80.00  10995.252106  209.439510    337.765957       209.439510
# 513  80.00  10995.252106  209.439510    337.765957       209.439510
#
#      der(speed1.w)  der(trb.medium.T)    der(trb.U)    der(trb.m)  \
# 0              0.0      -3.983240e+03 -1.656461e+07  8.273599e-01
# 1              0.0      -1.861099e-07 -7.770060e-04  2.786606e-11
# 2              0.0      -2.078532e-09 -8.677839e-06  3.112166e-13
# 3              0.0       2.732617e-11  1.140863e-07 -4.091520e-15
# 4              0.0       2.732633e-11  1.140870e-07 -4.091545e-15
# ..             ...                ...           ...           ...
# 509            0.0       1.176758e-12  4.656613e-09 -6.361351e-16
# 510            0.0       1.176758e-12  4.656613e-09 -6.361351e-16
# 511            0.0       1.176758e-12  4.656613e-09 -6.361351e-16
# 512            0.0       1.176758e-12  4.656613e-09 -6.361351e-16
# 513            0.0       1.176758e-12  4.656613e-09 -6.361351e-16
#
#      der(trb.medium.h)  ...  volumeFlowRate2.port_a.m_flow  \
# 0        -1.665777e+07  ...                     758.445647
# 1        -7.791006e-04  ...                     758.088223
# 2        -8.701231e-06  ...                     758.088223
# 3         1.143938e-07  ...                     758.088223
# 4         1.143945e-07  ...                     758.088223
# ..                 ...  ...                            ...
# 509       4.921020e-09  ...                    1182.299110
# 510       4.921020e-09  ...                    1182.299110
# 511       4.921020e-09  ...                    1182.299110
# 512       4.921020e-09  ...                    1182.299110
# 513       4.921020e-09  ...                    1182.299110
#
#      volumeFlowRate2.port_a.p  volumeFlowRate2.port_b.h_outflow  \
# 0                   1013250.0                      63951.680112
# 1                   1013250.0                      63951.680112
# 2                   1013250.0                      63951.680112
# 3                   1013250.0                      63951.680112
# 4                   1013250.0                      63951.680112
# ..                        ...                               ...
# 509                 1519875.0                     273317.807751
# 510                 1519875.0                     273317.807751
# 511                 1519875.0                     273317.807751
# 512                 1519875.0                     273317.807751
# 513                 1519875.0                     273317.807751
#
#      volumeFlowRate2.port_b.m_flow  volumeFlowRate2.port_b.p  \
# 0                      -758.445647                 1013250.0
# 1                      -758.088223                 1013250.0
# 2                      -758.088223                 1013250.0
# 3                      -758.088223                 1013250.0
# 4                      -758.088223                 1013250.0
# ..                             ...                       ...
# 509                   -1182.299110                 1519875.0
# 510                   -1182.299110                 1519875.0
# 511                   -1182.299110                 1519875.0
# 512                   -1182.299110                 1519875.0
# 513                   -1182.299110                 1519875.0
#
#      boundary.medium.state.phase  boundary1.medium.state.phase  \
# 0                              1                             1
# 1                              1                             1
# 2                              1                             1
# 3                              1                             1
# 4                              1                             1
# ..                           ...                           ...
# 509                            1                             1
# 510                            1                             1
# 511                            1                             1
# 512                            1                             1
# 513                            1                             1
#
#      trb.heatTransfer.states[1].phase  trb.medium.state.phase  \
# 0                                   1                       1
# 1                                   1                       1
# 2                                   1                       1
# 3                                   1                       1
# 4                                   1                       1
# ..                                ...                     ...
# 509                                 1                       1
# 510                                 1                       1
# 511                                 1                       1
# 512                                 1                       1
# 513                                 1                       1
#
#      trb.monitoring.state.phase
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 509                           1
# 510                           1
# 511                           1
# 512                           1
# 513                           1
#
# [514 rows x 260 columns]

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
i_df=1
varName="boundary.medium.p"
ylabel='Pressrue [Pa]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="boundary.medium.T"
ylabel='Temperature [K]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %%
i_df=1
varName="ramp_N.y"
ylabel='rot. speed [rpm]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.plot(time, var)
plt.title(varName)
plt.grid()
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
i_df=0
varName="PistonCylinder.pwrOut"
ylabel='Power [W]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')

# %%
i_df=0
varName="PistonCylinder.trqOut"
ylabel='Torque [Nm]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')

# %%
i_df=0
varName="PistonCylinder.OttoCycle.WoutCycle"
ylabel='Work [J]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')

# %%
i_df=0
varName="PistonCylinder.port_1.m_flow"
ylabel='mass flow rate [kg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')

# %%
i_df=0
varName="PistonCylinder.V_flow"
ylabel='volume flow rate [m3/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')

# %%
i_df=0
varName="PistonCylinder.y_m_flow_fuel"
ylabel='mass flow rate [kg/s]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]

fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title(varName)
plt.plot(time, var, color='red')

plt.grid()
print('------------------------------')

# %%
i_df=0
ylabel='Pressure [kPa]'

fig.append(plt.figure(figsize=(15,8)))
time= df[i_df].loc[:,'time']

varName="PistonCylinder.OttoCycle.fluidState_1.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

varName="PistonCylinder.OttoCycle.fluidState_2.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

varName="PistonCylinder.OttoCycle.fluidState_3.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

varName="PistonCylinder.OttoCycle.fluidState_4.p"
var= df[i_df].loc[:,varName]/1000
plt.plot(time, var, label=varName)

plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title('PistonCylinder.OttoCycle.fluidState.p')
plt.legend(bbox_to_anchor=(1.01, 1.01), loc='upper left', fontsize=12)
plt.grid()
print('------------------------------')

# %%
i_df=0
ylabel='Temperature [K]'

fig.append(plt.figure(figsize=(15,8)))
time= df[i_df].loc[:,'time']

varName="PistonCylinder.OttoCycle.fluidState_1.T"
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=varName)

varName="PistonCylinder.OttoCycle.fluidState_2.T"
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=varName)

varName="PistonCylinder.OttoCycle.fluidState_3.T"
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=varName)

varName="PistonCylinder.OttoCycle.fluidState_4.T"
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=varName)

plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title('PistonCylinder.OttoCycle.fluidState.T')
plt.legend(bbox_to_anchor=(1.01, 1.01), loc='upper left', fontsize=12)
plt.grid()
print('------------------------------')

# %%
i_df=0
varName="PistonCylinder.OttoCycle.effThermal"
ylabel='efficiency [nond]'

time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
fig.append(plt.figure(figsize=(15,8)))
plt.xlabel('time [s]')
plt.ylabel(ylabel)
#plt.ylim([0.5,0.6])
plt.plot(time, var, color='red')
plt.title(varName)

plt.grid()
print('------------------------------')

# %%
i_df=0
ylabel='Force [N]'

fig.append(plt.figure(figsize=(15,8)))
time= df[i_df].loc[:,'time']

varName="ExpToAmb.y_Fg"
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=varName, color='red')

plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title('Thrust by exhaust')
plt.grid()
print('------------------------------')

# %%
i_df=0
ylabel='Pressure [Pa]'

fig.append(plt.figure(figsize=(15,8)))
time= df[i_df].loc[:,'time']

varName="ExpToAmb.port_1.p"
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=varName, color='red')

plt.xlabel('time [s]')
plt.ylabel(ylabel)
plt.title('Exhaust Pressure')
plt.grid()
print('------------------------------')

# %% [markdown]
# <h2>Extract variables at specified time</h2>

# %%
i_df=0
tgtTime=5
widthTime=1

#******************************
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_p=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.OttoCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
    ##### end for #####
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
##### end for #####
print('------------------------------')

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=120)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=120)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=100)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')

# %%
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_v, y=arr_p, color='red', s=100)
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(v_curve_pv[i], p_curve_pv[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('p vs. v'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. volume [m3/kg]')
plt.ylabel('pressure [Pa]')
for i in range(0, 4):
    if((i==2-1)or(i==4-1)):
        root=[arr_v[i+1],arr_p[i+1]]
        head=[arr_v[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
''''''
print('------------------------------')

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
