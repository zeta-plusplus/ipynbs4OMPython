# %% [markdown]
# <h1>Visualize: FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01</h1>
# <h2>notebook: rev005: 2022/06/04</h2>
# <p>compatability with OpenModelica v1.17</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01'
nmModel='HX_ShellTube_parallel_discrete005_ex01'
stopTime=50.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/HeatTransfer/Examples/HeatTransferDevices/HX_ShellTube_parallel_discrete005_ex01.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------

# %% [markdown]
# <h1>---------------------------------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1>Post Process --- Read csv data into table object ---</h1>

# %% [markdown]
# <h2>Read csv, case of default parameter setting</h2>

# %%
i_df=0

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
#      time  Capacity_hotIn.u1  Capacity_hotIn.y         Cmax         Cmin  \
# 0     0.0        4195.423071       8390.846143  8390.846143  4210.565404
# 1     0.1        4195.423071       8390.846143  8390.846143  4210.565404
# 2     0.2        4195.423071       8390.846143  8390.846143  4210.565404
# 3     0.3        4195.423071       8390.846143  8390.846143  4210.565404
# 4     0.4        4195.423071       8390.846143  8390.846143  4210.565404
# ..    ...                ...               ...          ...          ...
# 499  49.7        4195.423071       8390.846143  8390.846143  4210.565404
# 500  49.8        4195.423071       8390.846143  8390.846143  4210.565404
# 501  49.9        4195.423071       8390.846143  8390.846143  4210.565404
# 502  50.0        4195.423071       8390.846143  8390.846143  4210.565404
# 503  50.0        4195.423071       8390.846143  8390.846143  4210.565404
#
#      Cp_coldIn.port.h_outflow  Cp_coldIn.port.m_flow  Cp_hotIn.port.h_outflow  \
# 0                84013.058153                      0             84013.058153
# 1                84013.058153                      0             84013.058153
# 2                84013.058153                      0             84013.058153
# 3                84013.058153                      0             84013.058153
# 4                84013.058153                      0             84013.058153
# ..                        ...                    ...                      ...
# 499              84013.058153                      0             84013.058153
# 500              84013.058153                      0             84013.058153
# 501              84013.058153                      0             84013.058153
# 502              84013.058153                      0             84013.058153
# 503              84013.058153                      0             84013.058153
#
#      Cp_hotIn.port.m_flow    Cratio  ...  volH.medium.phase  \
# 0                       0  0.501805  ...                  1
# 1                       0  0.501805  ...                  1
# 2                       0  0.501805  ...                  1
# 3                       0  0.501805  ...                  1
# 4                       0  0.501805  ...                  1
# ..                    ...       ...  ...                ...
# 499                     0  0.501805  ...                  1
# 500                     0  0.501805  ...                  1
# 501                     0  0.501805  ...                  1
# 502                     0  0.501805  ...                  1
# 503                     0  0.501805  ...                  1
#
#      volH.medium.state.phase  volH1.medium.phase  volH1.medium.state.phase  \
# 0                          1                   1                         1
# 1                          1                   1                         1
# 2                          1                   1                         1
# 3                          1                   1                         1
# 4                          1                   1                         1
# ..                       ...                 ...                       ...
# 499                        1                   1                         1
# 500                        1                   1                         1
# 501                        1                   1                         1
# 502                        1                   1                         1
# 503                        1                   1                         1
#
#      volH2.medium.phase  volH2.medium.state.phase  volH3.medium.phase  \
# 0                     1                         1                   1
# 1                     1                         1                   1
# 2                     1                         1                   1
# 3                     1                         1                   1
# 4                     1                         1                   1
# ..                  ...                       ...                 ...
# 499                   1                         1                   1
# 500                   1                         1                   1
# 501                   1                         1                   1
# 502                   1                         1                   1
# 503                   1                         1                   1
#
#      volH3.medium.state.phase  volH4.medium.phase  volH4.medium.state.phase
# 0                           1                   1                         1
# 1                           1                   1                         1
# 2                           1                   1                         1
# 3                           1                   1                         1
# 4                           1                   1                         1
# ..                        ...                 ...                       ...
# 499                         1                   1                         1
# 500                         1                   1                         1
# 501                         1                   1                         1
# 502                         1                   1                         1
# 503                         1                   1                         1
#
# [504 rows x 1024 columns]

# %% [markdown]
# <h1> list of columns on csv </h1>

# %%
i_df=0

print('list of variables on csv')
df[i_df].columns.tolist()
# Out:
# list of variables on csv
# ['time',
#  'Capacity_hotIn.u1',
#  'Capacity_hotIn.y',
#  'Cmax',
#  'Cmin',
#  'Cp_coldIn.port.h_outflow',
#  'Cp_coldIn.port.m_flow',
#  'Cp_hotIn.port.h_outflow',
#  'Cp_hotIn.port.m_flow',
#  'Cratio',
#  'NTU',
#  'Q_flow_actual.u[1]',
#  'Q_flow_actual.u[2]',
#  'Q_flow_actual.u[3]',
#  'Q_flow_actual.u[4]',
#  'Q_flow_actual.u[5]',
#  'Q_flow_actual.y',
#  'Q_flow_ideal.y',
#  'Rtotal',
#  'T_coldIn.T',
#  'T_coldIn.T_a_inflow',
#  'T_coldIn.T_b_inflow',
#  'T_coldIn.port_b.m_flow',
#  'T_coldOut.T',
#  'T_coldOut.T_a_inflow',
#  'T_coldOut.T_b_inflow',
#  'T_coldOut.port_a.m_flow',
#  'T_coldOut.port_b.m_flow',
#  'T_hotIn.T',
#  'T_hotIn.T_a_inflow',
#  'T_hotIn.T_b_inflow',
#  'T_hotIn.port_b.m_flow',
#  'T_hotOut.T',
#  'T_hotOut.T_a_inflow',
#  'T_hotOut.T_b_inflow',
#  'T_hotOut.port_a.m_flow',
#  'T_hotOut.port_b.m_flow',
#  'UAtotal',
#  'capacity_coldIn.y',
#  'convection.dT',
#  'convection1.dT',
#  'convection2.dT',
#  'convection3.dT',
#  'convection4.dT',
#  'convection5.dT',
#  'convection5.solid.T',
#  'convection6.dT',
#  'convection6.solid.T',
#  'convection7.dT',
#  'convection7.solid.T',
#  'convection8.dT',
#  'convection8.solid.T',
#  'convection9.dT',
#  'convection9.solid.T',
#  'effHX.y',
#  'effHX_theoretical',
#  'hAcold_discrete',
#  'hAhot_discrete',
#  'm_flow_cold.port_b.m_flow',
#  'm_flow_hot.port_b.m_flow',
#  'ramp_T_coldIn.y',
#  'ramp_T_hotIn.y',
#  'ramp_m_flow_cold.y',
#  'ramp_m_flow_hot.y',
#  'sink_coolant.T_in_internal',
#  'sink_coolant.X_in_internal[1]',
#  'sink_coolant.medium.MM',
#  'sink_coolant.medium.R',
#  'sink_coolant.medium.T',
#  'sink_coolant.medium.T_degC',
#  'sink_coolant.medium.X[1]',
#  'sink_coolant.medium.d',
#  'sink_coolant.medium.p_bar',
#  'sink_coolant.medium.sat.Tsat',
#  'sink_coolant.medium.u',
#  'sink_coolant.p_in_internal',
#  'sink_coolant.ports[1].h_outflow',
#  'sink_coolant.ports[1].m_flow',
#  'sink_hotFluid.T_in_internal',
#  'sink_hotFluid.X_in_internal[1]',
#  'sink_hotFluid.medium.MM',
#  'sink_hotFluid.medium.R',
#  'sink_hotFluid.medium.T',
#  'sink_hotFluid.medium.T_degC',
#  'sink_hotFluid.medium.X[1]',
#  'sink_hotFluid.medium.d',
#  'sink_hotFluid.medium.p_bar',
#  'sink_hotFluid.medium.sat.Tsat',
#  'sink_hotFluid.medium.u',
#  'sink_hotFluid.p_in_internal',
#  'sink_hotFluid.ports[1].h_outflow',
#  'sink_hotFluid.ports[1].m_flow',
#  'souce_coolant.X_in_internal[1]',
#  'souce_coolant.medium.MM',
#  'souce_coolant.medium.R',
#  'souce_coolant.medium.T',
#  'souce_coolant.medium.T_degC',
#  'souce_coolant.medium.X[1]',
#  'souce_coolant.medium.d',
#  'souce_coolant.medium.p_bar',
#  'souce_coolant.medium.sat.Tsat',
#  'souce_coolant.medium.u',
#  'souce_coolant.ports[1].h_outflow',
#  'souce_coolant.ports[1].m_flow',
#  'source_hotFluid.X_in_internal[1]',
#  'source_hotFluid.medium.MM',
#  'source_hotFluid.medium.R',
#  'source_hotFluid.medium.T',
#  'source_hotFluid.medium.T_degC',
#  'source_hotFluid.medium.X[1]',
#  'source_hotFluid.medium.d',
#  'source_hotFluid.medium.p_bar',
#  'source_hotFluid.medium.sat.Tsat',
#  'source_hotFluid.medium.u',
#  'source_hotFluid.ports[1].h_outflow',
#  'source_hotFluid.ports[1].m_flow',
#  'volC.U',
#  'volC.Wb_flow',
#  'volC.fluidLevel',
#  'volC.fluidVolume',
#  'volC.heatTransfer.Ts[1]',
#  'volC.heatTransfer.states[1].d',
#  'volC.heatTransfer.surfaceAreas[1]',
#  'volC.m',
#  'volC.m_flow_turbulent[1]',
#  'volC.m_flow_turbulent[2]',
#  'volC.mb_flow',
#  'volC.medium.MM',
#  'volC.medium.R',
#  'volC.medium.T_degC',
#  'volC.medium.X[1]',
#  'volC.medium.p_bar',
#  'volC.medium.sat.Tsat',
#  'volC.medium.u',
#  'volC.portAreas[1]',
#  'volC.portAreas[2]',
#  'volC.portInDensities[1]',
#  'volC.portInDensities[2]',
#  'volC.portVelocities[1]',
#  'volC.portVelocities[2]',
#  'volC.ports[2].h_outflow',
#  'volC.ports[1].m_flow',
#  'volC.ports[2].m_flow',
#  'volC.portsData_diameter[1]',
#  'volC.portsData_diameter[2]',
#  'volC.portsData_height[1]',
#  'volC.portsData_height[2]',
#  'volC.portsData_zeta_in[1]',
#  'volC.portsData_zeta_in[2]',
#  'volC.portsData_zeta_out[1]',
#  'volC.portsData_zeta_out[2]',
#  'volC.ports_E_flow[1]',
#  'volC.ports_E_flow[2]',
#  'volC.ports_H_flow[1]',
#  'volC.ports_H_flow[2]',
#  'volC.ports_penetration[1]',
#  'volC.ports_penetration[2]',
#  'volC.s[1]',
#  'volC.s[2]',
#  'volC1.U',
#  'volC1.Wb_flow',
#  'volC1.fluidLevel',
#  'volC1.fluidVolume',
#  'volC1.heatTransfer.Ts[1]',
#  'volC1.heatTransfer.states[1].d',
#  'volC1.heatTransfer.surfaceAreas[1]',
#  'volC1.m',
#  'volC1.m_flow_turbulent[1]',
#  'volC1.m_flow_turbulent[2]',
#  'volC1.mb_flow',
#  'volC1.medium.MM',
#  'volC1.medium.R',
#  'volC1.medium.T_degC',
#  'volC1.medium.X[1]',
#  'volC1.medium.p_bar',
#  'volC1.medium.sat.Tsat',
#  'volC1.medium.u',
#  'volC1.portAreas[1]',
#  'volC1.portAreas[2]',
#  'volC1.portInDensities[1]',
#  'volC1.portInDensities[2]',
#  'volC1.portVelocities[1]',
#  'volC1.portVelocities[2]',
#  'volC1.ports[2].h_outflow',
#  'volC1.ports[1].m_flow',
#  'volC1.ports[2].m_flow',
#  'volC1.portsData_diameter[1]',
#  'volC1.portsData_diameter[2]',
#  'volC1.portsData_height[1]',
#  'volC1.portsData_height[2]',
#  'volC1.portsData_zeta_in[1]',
#  'volC1.portsData_zeta_in[2]',
#  'volC1.portsData_zeta_out[1]',
#  'volC1.portsData_zeta_out[2]',
#  'volC1.ports_E_flow[1]',
#  'volC1.ports_E_flow[2]',
#  'volC1.ports_H_flow[1]',
#  'volC1.ports_H_flow[2]',
#  'volC1.ports_penetration[1]',
#  'volC1.ports_penetration[2]',
#  'volC1.s[1]',
#  'volC1.s[2]',
#  'volC2.U',
#  'volC2.Wb_flow',
#  'volC2.fluidLevel',
#  'volC2.fluidVolume',
#  'volC2.heatTransfer.Ts[1]',
#  'volC2.heatTransfer.states[1].d',
#  'volC2.heatTransfer.surfaceAreas[1]',
#  'volC2.m',
#  'volC2.m_flow_turbulent[1]',
#  'volC2.m_flow_turbulent[2]',
#  'volC2.mb_flow',
#  'volC2.medium.MM',
#  'volC2.medium.R',
#  'volC2.medium.T_degC',
#  'volC2.medium.X[1]',
#  'volC2.medium.p_bar',
#  'volC2.medium.sat.Tsat',
#  'volC2.medium.u',
#  'volC2.portAreas[1]',
#  'volC2.portAreas[2]',
#  'volC2.portInDensities[1]',
#  'volC2.portInDensities[2]',
#  'volC2.portVelocities[1]',
#  'volC2.portVelocities[2]',
#  'volC2.ports[2].h_outflow',
#  'volC2.ports[1].m_flow',
#  'volC2.ports[2].m_flow',
#  'volC2.portsData_diameter[1]',
#  'volC2.portsData_diameter[2]',
#  'volC2.portsData_height[1]',
#  'volC2.portsData_height[2]',
#  'volC2.portsData_zeta_in[1]',
#  'volC2.portsData_zeta_in[2]',
#  'volC2.portsData_zeta_out[1]',
#  'volC2.portsData_zeta_out[2]',
#  'volC2.ports_E_flow[1]',
#  'volC2.ports_E_flow[2]',
#  'volC2.ports_H_flow[1]',
#  'volC2.ports_H_flow[2]',
#  'volC2.ports_penetration[1]',
#  'volC2.ports_penetration[2]',
#  'volC2.s[1]',
#  'volC2.s[2]',
#  'volC3.U',
#  'volC3.Wb_flow',
#  'volC3.fluidLevel',
#  'volC3.fluidVolume',
#  'volC3.heatTransfer.Ts[1]',
#  'volC3.heatTransfer.states[1].d',
#  'volC3.heatTransfer.surfaceAreas[1]',
#  'volC3.m',
#  'volC3.m_flow_turbulent[1]',
#  'volC3.m_flow_turbulent[2]',
#  'volC3.mb_flow',
#  'volC3.medium.MM',
#  'volC3.medium.R',
#  'volC3.medium.T_degC',
#  'volC3.medium.X[1]',
#  'volC3.medium.p_bar',
#  'volC3.medium.sat.Tsat',
#  'volC3.medium.u',
#  'volC3.portAreas[1]',
#  'volC3.portAreas[2]',
#  'volC3.portInDensities[1]',
#  'volC3.portInDensities[2]',
#  'volC3.portVelocities[1]',
#  'volC3.portVelocities[2]',
#  'volC3.ports[2].h_outflow',
#  'volC3.ports[1].m_flow',
#  'volC3.ports[2].m_flow',
#  'volC3.portsData_diameter[1]',
#  'volC3.portsData_diameter[2]',
#  'volC3.portsData_height[1]',
#  'volC3.portsData_height[2]',
#  'volC3.portsData_zeta_in[1]',
#  'volC3.portsData_zeta_in[2]',
#  'volC3.portsData_zeta_out[1]',
#  'volC3.portsData_zeta_out[2]',
#  'volC3.ports_E_flow[1]',
#  'volC3.ports_E_flow[2]',
#  'volC3.ports_H_flow[1]',
#  'volC3.ports_H_flow[2]',
#  'volC3.ports_penetration[1]',
#  'volC3.ports_penetration[2]',
#  'volC3.s[1]',
#  'volC3.s[2]',
#  'volC4.U',
#  'volC4.Wb_flow',
#  'volC4.fluidLevel',
#  'volC4.fluidVolume',
#  'volC4.heatTransfer.Ts[1]',
#  'volC4.heatTransfer.states[1].d',
#  'volC4.heatTransfer.surfaceAreas[1]',
#  'volC4.m',
#  'volC4.m_flow_turbulent[1]',
#  'volC4.m_flow_turbulent[2]',
#  'volC4.mb_flow',
#  'volC4.medium.MM',
#  'volC4.medium.R',
#  'volC4.medium.T_degC',
#  'volC4.medium.X[1]',
#  'volC4.medium.p_bar',
#  'volC4.medium.u',
#  'volC4.portAreas[1]',
#  'volC4.portAreas[2]',
#  'volC4.portInDensities[1]',
#  'volC4.portInDensities[2]',
#  'volC4.portVelocities[1]',
#  'volC4.portVelocities[2]',
#  'volC4.ports[2].h_outflow',
#  'volC4.ports[1].m_flow',
#  'volC4.ports[2].m_flow',
#  'volC4.portsData_diameter[1]',
#  'volC4.portsData_diameter[2]',
#  'volC4.portsData_height[1]',
#  'volC4.portsData_height[2]',
#  'volC4.portsData_zeta_in[1]',
#  'volC4.portsData_zeta_in[2]',
#  'volC4.portsData_zeta_out[1]',
#  'volC4.portsData_zeta_out[2]',
#  'volC4.ports_E_flow[1]',
#  'volC4.ports_E_flow[2]',
#  'volC4.ports_H_flow[1]',
#  'volC4.ports_H_flow[2]',
#  'volC4.ports_penetration[1]',
#  'volC4.ports_penetration[2]',
#  'volC4.s[1]',
#  'volC4.s[2]',
#  'volC4.vessel_ps_static[2]',
#  'volH.U',
#  'volH.Wb_flow',
#  'volH.fluidLevel',
#  'volH.fluidVolume',
#  'volH.heatTransfer.Ts[1]',
#  'volH.heatTransfer.states[1].d',
#  'volH.heatTransfer.surfaceAreas[1]',
#  'volH.m',
#  'volH.m_flow_turbulent[1]',
#  'volH.m_flow_turbulent[2]',
#  'volH.mb_flow',
#  'volH.medium.MM',
#  'volH.medium.R',
#  'volH.medium.T_degC',
#  'volH.medium.X[1]',
#  'volH.medium.p_bar',
#  'volH.medium.sat.Tsat',
#  'volH.medium.u',
#  'volH.portAreas[1]',
#  'volH.portAreas[2]',
#  'volH.portInDensities[1]',
#  'volH.portInDensities[2]',
#  'volH.portVelocities[1]',
#  'volH.portVelocities[2]',
#  'volH.ports[2].h_outflow',
#  'volH.ports[1].m_flow',
#  'volH.ports[2].m_flow',
#  'volH.portsData_diameter[1]',
#  'volH.portsData_diameter[2]',
#  'volH.portsData_height[1]',
#  'volH.portsData_height[2]',
#  'volH.portsData_zeta_in[1]',
#  'volH.portsData_zeta_in[2]',
#  'volH.portsData_zeta_out[1]',
#  'volH.portsData_zeta_out[2]',
#  'volH.ports_E_flow[1]',
#  'volH.ports_E_flow[2]',
#  'volH.ports_H_flow[1]',
#  'volH.ports_H_flow[2]',
#  'volH.ports_penetration[1]',
#  'volH.ports_penetration[2]',
#  'volH.s[1]',
#  'volH.s[2]',
#  'volH1.U',
#  'volH1.Wb_flow',
#  'volH1.fluidLevel',
#  'volH1.fluidVolume',
#  'volH1.heatTransfer.Ts[1]',
#  'volH1.heatTransfer.states[1].d',
#  'volH1.heatTransfer.surfaceAreas[1]',
#  'volH1.m',
#  'volH1.m_flow_turbulent[1]',
#  'volH1.m_flow_turbulent[2]',
#  'volH1.mb_flow',
#  'volH1.medium.MM',
#  'volH1.medium.R',
#  'volH1.medium.T_degC',
#  'volH1.medium.X[1]',
#  'volH1.medium.p_bar',
#  'volH1.medium.sat.Tsat',
#  'volH1.medium.u',
#  'volH1.portAreas[1]',
#  'volH1.portAreas[2]',
#  'volH1.portInDensities[1]',
#  'volH1.portInDensities[2]',
#  'volH1.portVelocities[1]',
#  'volH1.portVelocities[2]',
#  'volH1.ports[2].h_outflow',
#  'volH1.ports[1].m_flow',
#  'volH1.ports[2].m_flow',
#  'volH1.portsData_diameter[1]',
#  'volH1.portsData_diameter[2]',
#  'volH1.portsData_height[1]',
#  'volH1.portsData_height[2]',
#  'volH1.portsData_zeta_in[1]',
#  'volH1.portsData_zeta_in[2]',
#  'volH1.portsData_zeta_out[1]',
#  'volH1.portsData_zeta_out[2]',
#  'volH1.ports_E_flow[1]',
#  'volH1.ports_E_flow[2]',
#  'volH1.ports_H_flow[1]',
#  'volH1.ports_H_flow[2]',
#  'volH1.ports_penetration[1]',
#  'volH1.ports_penetration[2]',
#  'volH1.s[1]',
#  'volH1.s[2]',
#  'volH2.U',
#  'volH2.Wb_flow',
#  'volH2.fluidLevel',
#  'volH2.fluidVolume',
#  'volH2.heatTransfer.Ts[1]',
#  'volH2.heatTransfer.states[1].d',
#  'volH2.heatTransfer.surfaceAreas[1]',
#  'volH2.m',
#  'volH2.m_flow_turbulent[1]',
#  'volH2.m_flow_turbulent[2]',
#  'volH2.mb_flow',
#  'volH2.medium.MM',
#  'volH2.medium.R',
#  'volH2.medium.T_degC',
#  'volH2.medium.X[1]',
#  'volH2.medium.p_bar',
#  'volH2.medium.sat.Tsat',
#  'volH2.medium.u',
#  'volH2.portAreas[1]',
#  'volH2.portAreas[2]',
#  'volH2.portInDensities[1]',
#  'volH2.portInDensities[2]',
#  'volH2.portVelocities[1]',
#  'volH2.portVelocities[2]',
#  'volH2.ports[2].h_outflow',
#  'volH2.ports[1].m_flow',
#  'volH2.ports[2].m_flow',
#  'volH2.portsData_diameter[1]',
#  'volH2.portsData_diameter[2]',
#  'volH2.portsData_height[1]',
#  'volH2.portsData_height[2]',
#  'volH2.portsData_zeta_in[1]',
#  'volH2.portsData_zeta_in[2]',
#  'volH2.portsData_zeta_out[1]',
#  'volH2.portsData_zeta_out[2]',
#  'volH2.ports_E_flow[1]',
#  'volH2.ports_E_flow[2]',
#  'volH2.ports_H_flow[1]',
#  'volH2.ports_H_flow[2]',
#  'volH2.ports_penetration[1]',
#  'volH2.ports_penetration[2]',
#  'volH2.s[1]',
#  'volH2.s[2]',
#  'volH3.U',
#  'volH3.Wb_flow',
#  'volH3.fluidLevel',
#  'volH3.fluidVolume',
#  'volH3.heatTransfer.Ts[1]',
#  'volH3.heatTransfer.states[1].d',
#  'volH3.heatTransfer.surfaceAreas[1]',
#  'volH3.m',
#  'volH3.m_flow_turbulent[1]',
#  'volH3.m_flow_turbulent[2]',
#  'volH3.mb_flow',
#  'volH3.medium.MM',
#  'volH3.medium.R',
#  'volH3.medium.T_degC',
#  'volH3.medium.X[1]',
#  'volH3.medium.p_bar',
#  'volH3.medium.sat.Tsat',
#  'volH3.medium.u',
#  'volH3.portAreas[1]',
#  'volH3.portAreas[2]',
#  'volH3.portInDensities[1]',
#  'volH3.portInDensities[2]',
#  'volH3.portVelocities[1]',
#  'volH3.portVelocities[2]',
#  'volH3.ports[2].h_outflow',
#  'volH3.ports[1].m_flow',
#  'volH3.ports[2].m_flow',
#  'volH3.portsData_diameter[1]',
#  'volH3.portsData_diameter[2]',
#  'volH3.portsData_height[1]',
#  'volH3.portsData_height[2]',
#  'volH3.portsData_zeta_in[1]',
#  'volH3.portsData_zeta_in[2]',
#  'volH3.portsData_zeta_out[1]',
#  'volH3.portsData_zeta_out[2]',
#  'volH3.ports_E_flow[1]',
#  'volH3.ports_E_flow[2]',
#  'volH3.ports_H_flow[1]',
#  'volH3.ports_H_flow[2]',
#  'volH3.ports_penetration[1]',
#  'volH3.ports_penetration[2]',
#  'volH3.s[1]',
#  'volH3.s[2]',
#  'volH4.U',
#  'volH4.Wb_flow',
#  'volH4.fluidLevel',
#  'volH4.fluidVolume',
#  'volH4.heatTransfer.Ts[1]',
#  'volH4.heatTransfer.states[1].d',
#  'volH4.heatTransfer.surfaceAreas[1]',
#  'volH4.m',
#  'volH4.m_flow_turbulent[1]',
#  'volH4.m_flow_turbulent[2]',
#  'volH4.mb_flow',
#  'volH4.medium.MM',
#  'volH4.medium.R',
#  'volH4.medium.T_degC',
#  'volH4.medium.X[1]',
#  'volH4.medium.p_bar',
#  'volH4.medium.sat.Tsat',
#  'volH4.medium.u',
#  'volH4.portAreas[1]',
#  'volH4.portAreas[2]',
#  'volH4.portInDensities[1]',
#  'volH4.portInDensities[2]',
#  'volH4.portVelocities[1]',
#  'volH4.portVelocities[2]',
#  'volH4.ports[2].h_outflow',
#  'volH4.ports[1].m_flow',
#  'volH4.ports[2].m_flow',
#  'volH4.portsData_diameter[1]',
#  'volH4.portsData_diameter[2]',
#  'volH4.portsData_height[1]',
#  'volH4.portsData_height[2]',
#  'volH4.portsData_zeta_in[1]',
#  'volH4.portsData_zeta_in[2]',
#  'volH4.portsData_zeta_out[1]',
#  'volH4.portsData_zeta_out[2]',
#  'volH4.ports_E_flow[1]',
#  'volH4.ports_E_flow[2]',
#  'volH4.ports_H_flow[1]',
#  'volH4.ports_H_flow[2]',
#  'volH4.ports_penetration[1]',
#  'volH4.ports_penetration[2]',
#  'volH4.s[1]',
#  'volH4.s[2]',
#  'volH4.vessel_ps_static[2]',
#  'sink_coolant.medium.phase',
#  'sink_hotFluid.medium.phase',
#  'souce_coolant.medium.phase',
#  'source_hotFluid.medium.phase',
#  'volC.heatTransfer.states[1].phase',
#  'volC1.heatTransfer.states[1].phase',
#  'volC2.heatTransfer.states[1].phase',
#  'volC3.heatTransfer.states[1].phase',
#  'volC4.heatTransfer.states[1].phase',
#  'volH.heatTransfer.states[1].phase',
#  'volH1.heatTransfer.states[1].phase',
#  'volH2.heatTransfer.states[1].phase',
#  'volH3.heatTransfer.states[1].phase',
#  'volH4.heatTransfer.states[1].phase',
#  'volC.inFlow[1]',
#  'volC.inFlow[2]',
#  'volC.regularFlow[1]',
#  'volC.regularFlow[2]',
#  'volC1.inFlow[1]',
#  'volC1.inFlow[2]',
#  'volC1.regularFlow[1]',
#  'volC1.regularFlow[2]',
#  'volC2.inFlow[1]',
#  'volC2.inFlow[2]',
#  'volC2.regularFlow[1]',
#  'volC2.regularFlow[2]',
#  'volC3.inFlow[1]',
#  'volC3.inFlow[2]',
#  'volC3.regularFlow[1]',
#  'volC3.regularFlow[2]',
#  'volC4.inFlow[1]',
#  'volC4.inFlow[2]',
#  'volC4.regularFlow[1]',
#  'volC4.regularFlow[2]',
#  'volH.inFlow[1]',
#  'volH.inFlow[2]',
#  'volH.regularFlow[1]',
#  'volH.regularFlow[2]',
#  'volH1.inFlow[1]',
#  'volH1.inFlow[2]',
#  'volH1.regularFlow[1]',
#  'volH1.regularFlow[2]',
#  'volH2.inFlow[1]',
#  'volH2.inFlow[2]',
#  'volH2.regularFlow[1]',
#  'volH2.regularFlow[2]',
#  'volH3.inFlow[1]',
#  'volH3.inFlow[2]',
#  'volH3.regularFlow[1]',
#  'volH3.regularFlow[2]',
#  'volH4.inFlow[1]',
#  'volH4.inFlow[2]',
#  'volH4.regularFlow[1]',
#  'volH4.regularFlow[2]',
#  'Capacity_hotIn.u2',
#  'Cp_coldIn.port.p',
#  'Cp_coldIn.y_Cp',
#  'Cp_hotIn.port.p',
#  'Cp_hotIn.y_Cp',
#  'T_coldIn.port_a.h_outflow',
#  'T_coldIn.port_a.m_flow',
#  'T_coldIn.port_a.p',
#  'T_coldIn.port_b.h_outflow',
#  'T_coldIn.port_b.p',
#  'T_coldOut.port_a.h_outflow',
#  'T_coldOut.port_a.p',
#  'T_coldOut.port_b.h_outflow',
#  'T_coldOut.port_b.p',
#  'T_hotIn.port_a.h_outflow',
#  'T_hotIn.port_a.m_flow',
#  'T_hotIn.port_a.p',
#  'T_hotIn.port_b.h_outflow',
#  'T_hotIn.port_b.p',
#  'T_hotOut.port_a.h_outflow',
#  'T_hotOut.port_a.p',
#  'T_hotOut.port_b.h_outflow',
#  'T_hotOut.port_b.p',
#  'capacity_coldIn.u1',
#  'capacity_coldIn.u2',
#  'convection.Gc',
#  'convection.Q_flow',
#  'convection.fluid.Q_flow',
#  'convection.fluid.T',
#  'convection.solid.Q_flow',
#  'convection.solid.T',
#  'convection1.Gc',
#  'convection1.Q_flow',
#  'convection1.fluid.Q_flow',
#  'convection1.fluid.T',
#  'convection1.solid.Q_flow',
#  'convection1.solid.T',
#  'convection2.Gc',
#  'convection2.Q_flow',
#  'convection2.fluid.Q_flow',
#  'convection2.fluid.T',
#  'convection2.solid.Q_flow',
#  'convection2.solid.T',
#  'convection3.Gc',
#  'convection3.Q_flow',
#  'convection3.fluid.Q_flow',
#  'convection3.fluid.T',
#  'convection3.solid.Q_flow',
#  'convection3.solid.T',
#  'convection4.Gc',
#  'convection4.Q_flow',
#  'convection4.fluid.Q_flow',
#  'convection4.fluid.T',
#  'convection4.solid.Q_flow',
#  'convection4.solid.T',
#  'convection5.Gc',
#  'convection5.Q_flow',
#  'convection5.fluid.Q_flow',
#  'convection5.fluid.T',
#  'convection5.solid.Q_flow',
#  'convection6.Gc',
#  'convection6.Q_flow',
#  'convection6.fluid.Q_flow',
#  'convection6.fluid.T',
#  'convection6.solid.Q_flow',
#  'convection7.Gc',
#  'convection7.Q_flow',
#  'convection7.fluid.Q_flow',
#  'convection7.fluid.T',
#  'convection7.solid.Q_flow',
#  'convection8.Gc',
#  'convection8.Q_flow',
#  'convection8.fluid.Q_flow',
#  'convection8.fluid.T',
#  'convection8.solid.Q_flow',
#  'convection9.Gc',
#  'convection9.Q_flow',
#  'convection9.fluid.Q_flow',
#  'convection9.fluid.T',
#  'convection9.solid.Q_flow',
#  'effHX.u1',
#  'effHX.u2',
#  'hA_Cold.y',
#  'hA_Hot.y',
#  'heatFlowSensor.Q_flow',
#  'heatFlowSensor.port_a.Q_flow',
#  'heatFlowSensor.port_a.T',
#  'heatFlowSensor.port_b.Q_flow',
#  'heatFlowSensor.port_b.T',
#  'heatFlowSensor1.Q_flow',
#  'heatFlowSensor1.port_a.Q_flow',
#  'heatFlowSensor1.port_a.T',
#  'heatFlowSensor1.port_b.Q_flow',
#  'heatFlowSensor1.port_b.T',
#  'heatFlowSensor2.Q_flow',
#  'heatFlowSensor2.port_a.Q_flow',
#  'heatFlowSensor2.port_a.T',
#  'heatFlowSensor2.port_b.Q_flow',
#  'heatFlowSensor2.port_b.T',
#  'heatFlowSensor3.Q_flow',
#  'heatFlowSensor3.port_a.Q_flow',
#  'heatFlowSensor3.port_a.T',
#  'heatFlowSensor3.port_b.Q_flow',
#  'heatFlowSensor3.port_b.T',
#  'heatFlowSensor4.Q_flow',
#  'heatFlowSensor4.port_a.Q_flow',
#  'heatFlowSensor4.port_a.T',
#  'heatFlowSensor4.port_b.Q_flow',
#  'heatFlowSensor4.port_b.T',
#  'm_flow_cold.m_flow',
#  'm_flow_cold.port_a.h_outflow',
#  'm_flow_cold.port_a.m_flow',
#  'm_flow_cold.port_a.p',
#  'm_flow_cold.port_b.h_outflow',
#  'm_flow_cold.port_b.p',
#  'm_flow_hot.m_flow',
#  'm_flow_hot.port_a.h_outflow',
#  'm_flow_hot.port_a.m_flow',
#  'm_flow_hot.port_a.p',
#  'm_flow_hot.port_b.h_outflow',
#  'm_flow_hot.port_b.p',
#  'sink_coolant.medium.h',
#  'sink_coolant.medium.p',
#  'sink_coolant.medium.sat.psat',
#  'sink_coolant.medium.state.T',
#  'sink_coolant.medium.state.d',
#  'sink_coolant.medium.state.h',
#  'sink_coolant.medium.state.p',
#  'sink_coolant.ports[1].p',
#  'sink_hotFluid.medium.h',
#  'sink_hotFluid.medium.p',
#  'sink_hotFluid.medium.sat.psat',
#  'sink_hotFluid.medium.state.T',
#  'sink_hotFluid.medium.state.d',
#  'sink_hotFluid.medium.state.h',
#  'sink_hotFluid.medium.state.p',
#  'sink_hotFluid.ports[1].p',
#  'souce_coolant.T_in',
#  'souce_coolant.T_in_internal',
#  'souce_coolant.m_flow_in',
#  'souce_coolant.m_flow_in_internal',
#  'souce_coolant.medium.h',
#  'souce_coolant.medium.p',
#  'souce_coolant.medium.sat.psat',
#  'souce_coolant.medium.state.T',
#  'souce_coolant.medium.state.d',
#  'souce_coolant.medium.state.h',
#  'souce_coolant.medium.state.p',
#  'souce_coolant.ports[1].p',
#  'source_hotFluid.T_in',
#  'source_hotFluid.T_in_internal',
#  'source_hotFluid.m_flow_in',
#  'source_hotFluid.m_flow_in_internal',
#  'source_hotFluid.medium.h',
#  'source_hotFluid.medium.p',
#  'source_hotFluid.medium.sat.psat',
#  'source_hotFluid.medium.state.T',
#  'source_hotFluid.medium.state.d',
#  'source_hotFluid.medium.state.h',
#  'source_hotFluid.medium.state.p',
#  'source_hotFluid.ports[1].p',
#  'volC.Hb_flow',
#  'volC.Qb_flow',
#  'volC.heatPort.Q_flow',
#  'volC.heatPort.T',
#  'volC.heatTransfer.Q_flows[1]',
#  'volC.heatTransfer.heatPorts[1].Q_flow',
#  'volC.heatTransfer.heatPorts[1].T',
#  'volC.heatTransfer.states[1].T',
#  'volC.heatTransfer.states[1].h',
#  'volC.heatTransfer.states[1].p',
#  'volC.medium.T',
#  'volC.medium.d',
#  'volC.medium.h',
#  'volC.medium.p',
#  'volC.medium.sat.psat',
#  'volC.medium.state.T',
#  'volC.medium.state.d',
#  'volC.medium.state.h',
#  'volC.medium.state.p',
#  'volC.ports[1].h_outflow',
#  'volC.ports[1].p',
#  'volC.ports[2].p',
#  'volC.vessel_ps_static[1]',
#  'volC.vessel_ps_static[2]',
#  'volC1.Hb_flow',
#  'volC1.Qb_flow',
#  'volC1.heatPort.Q_flow',
#  'volC1.heatPort.T',
#  'volC1.heatTransfer.Q_flows[1]',
#  'volC1.heatTransfer.heatPorts[1].Q_flow',
#  'volC1.heatTransfer.heatPorts[1].T',
#  'volC1.heatTransfer.states[1].T',
#  'volC1.heatTransfer.states[1].h',
#  'volC1.heatTransfer.states[1].p',
#  'volC1.medium.T',
#  'volC1.medium.d',
#  'volC1.medium.h',
#  'volC1.medium.p',
#  'volC1.medium.sat.psat',
#  'volC1.medium.state.T',
#  'volC1.medium.state.d',
#  'volC1.medium.state.h',
#  'volC1.medium.state.p',
#  'volC1.ports[1].h_outflow',
#  'volC1.ports[1].p',
#  'volC1.ports[2].p',
#  'volC1.vessel_ps_static[1]',
#  'volC1.vessel_ps_static[2]',
#  'volC2.Hb_flow',
#  'volC2.Qb_flow',
#  'volC2.heatPort.Q_flow',
#  'volC2.heatPort.T',
#  'volC2.heatTransfer.Q_flows[1]',
#  'volC2.heatTransfer.heatPorts[1].Q_flow',
#  'volC2.heatTransfer.heatPorts[1].T',
#  'volC2.heatTransfer.states[1].T',
#  'volC2.heatTransfer.states[1].h',
#  'volC2.heatTransfer.states[1].p',
#  'volC2.medium.T',
#  'volC2.medium.d',
#  'volC2.medium.h',
#  'volC2.medium.p',
#  'volC2.medium.sat.psat',
#  'volC2.medium.state.T',
#  'volC2.medium.state.d',
#  'volC2.medium.state.h',
#  'volC2.medium.state.p',
#  'volC2.ports[1].h_outflow',
#  'volC2.ports[1].p',
#  'volC2.ports[2].p',
#  'volC2.vessel_ps_static[1]',
#  'volC2.vessel_ps_static[2]',
#  'volC3.Hb_flow',
#  'volC3.Qb_flow',
#  'volC3.heatPort.Q_flow',
#  'volC3.heatPort.T',
#  'volC3.heatTransfer.Q_flows[1]',
#  'volC3.heatTransfer.heatPorts[1].Q_flow',
#  'volC3.heatTransfer.heatPorts[1].T',
#  'volC3.heatTransfer.states[1].T',
#  'volC3.heatTransfer.states[1].h',
#  'volC3.heatTransfer.states[1].p',
#  'volC3.medium.T',
#  'volC3.medium.d',
#  'volC3.medium.h',
#  'volC3.medium.p',
#  'volC3.medium.sat.psat',
#  'volC3.medium.state.T',
#  'volC3.medium.state.d',
#  'volC3.medium.state.h',
#  'volC3.medium.state.p',
#  'volC3.ports[1].h_outflow',
#  'volC3.ports[1].p',
#  'volC3.ports[2].p',
#  'volC3.vessel_ps_static[1]',
#  'volC3.vessel_ps_static[2]',
#  'volC4.Hb_flow',
#  'volC4.Qb_flow',
#  'volC4.heatPort.Q_flow',
#  'volC4.heatPort.T',
#  'volC4.heatTransfer.Q_flows[1]',
#  'volC4.heatTransfer.heatPorts[1].Q_flow',
#  'volC4.heatTransfer.heatPorts[1].T',
#  'volC4.heatTransfer.states[1].T',
#  'volC4.heatTransfer.states[1].h',
#  'volC4.heatTransfer.states[1].p',
#  'volC4.medium.T',
#  'volC4.medium.d',
#  'volC4.medium.h',
#  'volC4.medium.p',
#  'volC4.medium.sat.psat',
#  'volC4.medium.state.T',
#  'volC4.medium.state.d',
#  'volC4.medium.state.h',
#  'volC4.medium.state.p',
#  'volC4.ports[1].h_outflow',
#  'volC4.ports[1].p',
#  'volC4.ports[2].p',
#  'volC4.vessel_ps_static[1]',
#  'volH.Hb_flow',
#  'volH.Qb_flow',
#  'volH.heatPort.Q_flow',
#  'volH.heatPort.T',
#  'volH.heatTransfer.Q_flows[1]',
#  'volH.heatTransfer.heatPorts[1].Q_flow',
#  'volH.heatTransfer.heatPorts[1].T',
#  'volH.heatTransfer.states[1].T',
#  'volH.heatTransfer.states[1].h',
#  'volH.heatTransfer.states[1].p',
#  'volH.medium.T',
#  'volH.medium.d',
#  'volH.medium.h',
#  'volH.medium.p',
#  'volH.medium.sat.psat',
#  'volH.medium.state.T',
#  'volH.medium.state.d',
#  'volH.medium.state.h',
#  'volH.medium.state.p',
#  'volH.ports[1].h_outflow',
#  'volH.ports[1].p',
#  'volH.ports[2].p',
#  'volH.vessel_ps_static[1]',
#  'volH.vessel_ps_static[2]',
#  'volH1.Hb_flow',
#  'volH1.Qb_flow',
#  'volH1.heatPort.Q_flow',
#  'volH1.heatPort.T',
#  'volH1.heatTransfer.Q_flows[1]',
#  'volH1.heatTransfer.heatPorts[1].Q_flow',
#  'volH1.heatTransfer.heatPorts[1].T',
#  'volH1.heatTransfer.states[1].T',
#  'volH1.heatTransfer.states[1].h',
#  'volH1.heatTransfer.states[1].p',
#  'volH1.medium.T',
#  'volH1.medium.d',
#  'volH1.medium.h',
#  'volH1.medium.p',
#  'volH1.medium.sat.psat',
#  'volH1.medium.state.T',
#  'volH1.medium.state.d',
#  'volH1.medium.state.h',
#  'volH1.medium.state.p',
#  'volH1.ports[1].h_outflow',
#  'volH1.ports[1].p',
#  'volH1.ports[2].p',
#  'volH1.vessel_ps_static[1]',
#  'volH1.vessel_ps_static[2]',
#  'volH2.Hb_flow',
#  'volH2.Qb_flow',
#  'volH2.heatPort.Q_flow',
#  'volH2.heatPort.T',
#  'volH2.heatTransfer.Q_flows[1]',
#  'volH2.heatTransfer.heatPorts[1].Q_flow',
#  'volH2.heatTransfer.heatPorts[1].T',
#  'volH2.heatTransfer.states[1].T',
#  'volH2.heatTransfer.states[1].h',
#  'volH2.heatTransfer.states[1].p',
#  'volH2.medium.T',
#  'volH2.medium.d',
#  'volH2.medium.h',
#  'volH2.medium.p',
#  'volH2.medium.sat.psat',
#  'volH2.medium.state.T',
#  'volH2.medium.state.d',
#  'volH2.medium.state.h',
#  'volH2.medium.state.p',
#  'volH2.ports[1].h_outflow',
#  'volH2.ports[1].p',
#  'volH2.ports[2].p',
#  'volH2.vessel_ps_static[1]',
#  'volH2.vessel_ps_static[2]',
#  'volH3.Hb_flow',
#  'volH3.Qb_flow',
#  'volH3.heatPort.Q_flow',
#  'volH3.heatPort.T',
#  'volH3.heatTransfer.Q_flows[1]',
#  'volH3.heatTransfer.heatPorts[1].Q_flow',
#  'volH3.heatTransfer.heatPorts[1].T',
#  'volH3.heatTransfer.states[1].T',
#  'volH3.heatTransfer.states[1].h',
#  'volH3.heatTransfer.states[1].p',
#  'volH3.medium.T',
#  'volH3.medium.d',
#  'volH3.medium.h',
#  'volH3.medium.p',
#  'volH3.medium.sat.psat',
#  'volH3.medium.state.T',
#  'volH3.medium.state.d',
#  'volH3.medium.state.h',
#  'volH3.medium.state.p',
#  'volH3.ports[1].h_outflow',
#  'volH3.ports[1].p',
#  'volH3.ports[2].p',
#  'volH3.vessel_ps_static[1]',
#  'volH3.vessel_ps_static[2]',
#  'volH4.Hb_flow',
#  'volH4.Qb_flow',
#  'volH4.heatPort.Q_flow',
#  'volH4.heatPort.T',
#  'volH4.heatTransfer.Q_flows[1]',
#  'volH4.heatTransfer.heatPorts[1].Q_flow',
#  'volH4.heatTransfer.heatPorts[1].T',
#  'volH4.heatTransfer.states[1].T',
#  'volH4.heatTransfer.states[1].h',
#  'volH4.heatTransfer.states[1].p',
#  'volH4.medium.T',
#  'volH4.medium.d',
#  'volH4.medium.h',
#  'volH4.medium.p',
#  'volH4.medium.sat.psat',
#  'volH4.medium.state.T',
#  'volH4.medium.state.d',
#  'volH4.medium.state.h',
#  'volH4.medium.state.p',
#  'volH4.ports[1].h_outflow',
#  'volH4.ports[1].p',
#  'volH4.ports[2].p',
#  'volH4.vessel_ps_static[1]',
#  ...]

# %% [markdown]
# <h1>Read csv, selected case#</h1>

# %%
i_df=1

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
print("data read: "+ os.getcwd()+"/"+nmcsv)
df.insert(i_df, pd.read_csv(nmcsv))

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())

df[i_df]
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_1.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
#        time  Capacity_hotIn.u1  Capacity_hotIn.y         Cmax         Cmin  \
# 0      0.00        4195.423071       8390.846143  8390.846143  4210.565404
# 1      0.05        4195.423071       8390.846143  8390.846143  4210.565404
# 2      0.10        4195.423071       8390.846143  8390.846143  4210.565404
# 3      0.15        4195.423071       8390.846143  8390.846143  4210.565404
# 4      0.20        4195.423071       8390.846143  8390.846143  4210.565404
# ...     ...                ...               ...          ...          ...
# 999   49.85        4195.423071       8390.846143  8390.846143  4210.565404
# 1000  49.90        4195.423071       8390.846143  8390.846143  4210.565404
# 1001  49.95        4195.423071       8390.846143  8390.846143  4210.565404
# 1002  50.00        4195.423071       8390.846143  8390.846143  4210.565404
# 1003  50.00        4195.423071       8390.846143  8390.846143  4210.565404
#
#       Cp_coldIn.port.h_outflow  Cp_coldIn.port.m_flow  \
# 0                 84013.058153                      0
# 1                 84013.058153                      0
# 2                 84013.058153                      0
# 3                 84013.058153                      0
# 4                 84013.058153                      0
# ...                        ...                    ...
# 999               84013.058153                      0
# 1000              84013.058153                      0
# 1001              84013.058153                      0
# 1002              84013.058153                      0
# 1003              84013.058153                      0
#
#       Cp_hotIn.port.h_outflow  Cp_hotIn.port.m_flow    Cratio  ...  \
# 0                84013.058153                     0  0.501805  ...
# 1                84013.058153                     0  0.501805  ...
# 2                84013.058153                     0  0.501805  ...
# 3                84013.058153                     0  0.501805  ...
# 4                84013.058153                     0  0.501805  ...
# ...                       ...                   ...       ...  ...
# 999              84013.058153                     0  0.501805  ...
# 1000             84013.058153                     0  0.501805  ...
# 1001             84013.058153                     0  0.501805  ...
# 1002             84013.058153                     0  0.501805  ...
# 1003             84013.058153                     0  0.501805  ...
#
#       volH.medium.phase  volH.medium.state.phase  volH1.medium.phase  \
# 0                     1                        1                   1
# 1                     1                        1                   1
# 2                     1                        1                   1
# 3                     1                        1                   1
# 4                     1                        1                   1
# ...                 ...                      ...                 ...
# 999                   1                        1                   1
# 1000                  1                        1                   1
# 1001                  1                        1                   1
# 1002                  1                        1                   1
# 1003                  1                        1                   1
#
#       volH1.medium.state.phase  volH2.medium.phase  volH2.medium.state.phase  \
# 0                            1                   1                         1
# 1                            1                   1                         1
# 2                            1                   1                         1
# 3                            1                   1                         1
# 4                            1                   1                         1
# ...                        ...                 ...                       ...
# 999                          1                   1                         1
# 1000                         1                   1                         1
# 1001                         1                   1                         1
# 1002                         1                   1                         1
# 1003                         1                   1                         1
#
#       volH3.medium.phase  volH3.medium.state.phase  volH4.medium.phase  \
# 0                      1                         1                   1
# 1                      1                         1                   1
# 2                      1                         1                   1
# 3                      1                         1                   1
# 4                      1                         1                   1
# ...                  ...                       ...                 ...
# 999                    1                         1                   1
# 1000                   1                         1                   1
# 1001                   1                         1                   1
# 1002                   1                         1                   1
# 1003                   1                         1                   1
#
#       volH4.medium.state.phase
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
# ...                        ...
# 999                          1
# 1000                         1
# 1001                         1
# 1002                         1
# 1003                         1
#
# [1004 rows x 1024 columns]

# %% [markdown]
# <h1>Read csv, array, specify start and end</h1>

# %%
i_df_begin=2
i_df_end=22


#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(i_df_begin, i_df_end+1):
    i_df=i
    print('i_df='+str(i_df))
    nmcsv= fullpathModel + '_res_'+str(i_df)+'.csv'
    print("data read: "+ os.getcwd()+"/"+nmcsv)
    df.insert(i_df, pd.read_csv(nmcsv))
##### end for #####
    
#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# i_df=2
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_2.csv
# i_df=3
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_3.csv
# i_df=4
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_4.csv
# i_df=5
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_5.csv
# i_df=6
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_6.csv
# i_df=7
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_7.csv
# i_df=8
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_8.csv
# i_df=9
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_9.csv
# i_df=10
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_10.csv
# i_df=11
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_11.csv
# i_df=12
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_12.csv
# i_df=13
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_13.csv
# i_df=14
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_14.csv
# i_df=15
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_15.csv
# i_df=16
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_16.csv
# i_df=17
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_17.csv
# i_df=18
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_18.csv
# i_df=19
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_19.csv
# i_df=20
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_20.csv
# i_df=21
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_21.csv
# i_df=22
# data read: /home/ubuntu/OMPythonWork/FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_22.csv
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Post Process --- Visualization ---</h1>

# %%
fig=[]
i_fig=-1
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation results; Inputs</h2>

# %%
'''
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="fuelThrottle.u_kArea"
label="fuelThrottle.u_kArea"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color='blue')

#----------
plt.xlabel('time [s]')
plt.ylabel('valve opening [nond]')
plt.title(varName)

#plt.legend(loc='upper right', fontsize=12)
plt.xlim(0.0, 50.0)
plt.ylim(0.5, 1.0)
plt.grid()
'''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h2>Simulation Results; Outputs</h2>

# %%
'''
fig.append(plt.figure(figsize=(15,8)))

i_df=1
varName="PistonCylinder.Nmech"
label="PistonCylinder.Nmech"
time= df[i_df].loc[:,'time']
var= df[i_df].loc[:,varName]
plt.plot(time, var, label=label, color="red")

#----------
plt.xlabel('time [s]')
plt.ylabel('angular speed [rpm]')
plt.title(label)

#plt.legend(loc='center right', fontsize=12)
plt.xlim(0,50)
plt.ylim(1500, 2000)
plt.grid()
'''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Variables of multiple cases</h1>

# %%
n_dataSets=2
iDatBegin=2
iDatEnd=22

tgtTime=50
widthTime=0.005

varNameX=[]
varNameY=[]

varNameX=[
    "NTU",
    "NTU"
]

varNameY=[
    "effHX.y",
    "effHX_theoretical",
]

for i in range(iDatBegin, iDatEnd+1):
    #*** find the row of target time ***
    rowTgt=0
    for j in range(len(df[i])):
        if((tgtTime-widthTime <= df[i].at[j,'time']) and (df[i].at[j,'time'] <= tgtTime) ):
            rowTgt=j
            timeExtrd=df[i].at[j,'time']
            break
        ##### end if #####
    ##### end for #####
    val= df[i].at[rowTgt, 'UAtotal']
    print(i)
    print(val)
print('------------------------------')
val= df[1].at[rowTgt, 'hAhot_discrete']
print(val)
# Out:
# 2
# 250
# 3
# 250
# 4
# 250
# 5
# 250
# 6
# 250
# 7
# 250
# 8
# 250
# 9
# 250
# 10
# 250
# 11
# 250
# 12
# 250
# 13
# 250
# 14
# 250
# 15
# 250
# 16
# 250
# 17
# 250
# 18
# 250
# 19
# 250
# 20
# 250
# 21
# 250
# 22
# 250
# ------------------------------
# 100

# %% [markdown]
# <h1>Extract variables at specified time</h1>

# %%
'''
i_df=1
tgtTime=50
widthTime=1

#******************************
#*** find the row of target time ***
rowTgt=0
for i in range(len(df[i_df])):
    if((tgtTime-widthTime <= df[i_df].at[i,'time']) and (df[i_df].at[i,'time'] <= tgtTime) ):
        rowTgt=i
        timeExtrd=df[i_df].at[i,'time']
    ##### end if #####
##### end for #####

print("row extracted = "+str(rowTgt))
print("time of extracted = "+str(timeExtrd))

arr_h=[]
arr_s=[]
arr_v=[]
arr_T=[]
arr_u=[]
for i in range(1,5+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_h['+str(i)+']')]
    arr_h.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_s['+str(i)+']')]
    arr_s.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_v['+str(i)+']')]
    arr_v.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_T['+str(i)+']')]
    arr_T.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.arr_u['+str(i)+']')]
    arr_u.append(val)
##### end for #####

arr_V=[]
arr_p=[]
for i in range(1,8+1):
    # ***** extract specified variables of target row *****
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_p['+str(i)+']')]
    arr_p.append(val)
    val= df[i_df].at[rowTgt, ('PistonCylinder.arr_V['+str(i)+']')]
    arr_V.append(val)
##### end for #####

nPts= df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_hs[1].nPts')]
s_curve_hs=[[]]*4; h_curve_hs=[[]]*4
v_curve_pv=[[]]*4; p_curve_pv=[[]]*4
s_curve_Ts=[[]]*4; T_curve_Ts=[[]]*4
s_curve_us=[[]]*4; u_curve_us=[[]]*4
V_curve_pVol=[[]]*4; p_curve_pVol=[[]]*4

arrTemp_s_hs=[]; arrTemp_h_hs=[]
arrTemp_s_Ts=[]; arrTemp_T_Ts=[]
arrTemp_s_us=[]; arrTemp_u_us=[]
arrTemp_v_pv=[]; arrTemp_p_pv=[]
arrTemp_V_pVol=[]; arrTemp_p_pVol=[]

for j in range(1, 4+1):
    for i in range(1, nPts+1):
        # ***** extract specified variables of target row *****
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_hs['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_hs['+str(j)+'].arr_h['+str(i)+']')]; arrTemp_h_hs.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_Ts['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_Ts['+str(j)+'].arr_T['+str(i)+']')]; arrTemp_T_Ts.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_us['+str(j)+'].arr_s['+str(i)+']')]; arrTemp_s_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_us['+str(j)+'].arr_u['+str(i)+']')]; arrTemp_u_us.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pv['+str(j)+'].arr_v['+str(i)+']')]; arrTemp_v_pv.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pv['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pv.append(val)
        
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pVol['+str(j)+'].arr_V['+str(i)+']')]; arrTemp_V_pVol.append(val)
        val=df[i_df].at[rowTgt, ('PistonCylinder.DieselCycle.curve_pVol['+str(j)+'].arr_p['+str(i)+']')]; arrTemp_p_pVol.append(val)
    ##### end for #####
    
    s_curve_hs[j-1]=arrTemp_s_hs; arrTemp_s_hs=[]
    h_curve_hs[j-1]=arrTemp_h_hs; arrTemp_h_hs=[]
    s_curve_Ts[j-1]=arrTemp_s_Ts; arrTemp_s_Ts=[]
    T_curve_Ts[j-1]=arrTemp_T_Ts; arrTemp_T_Ts=[]
    s_curve_us[j-1]=arrTemp_s_us; arrTemp_s_us=[]
    u_curve_us[j-1]=arrTemp_u_us; arrTemp_u_us=[]
    v_curve_pv[j-1]=arrTemp_v_pv; arrTemp_v_pv=[]
    p_curve_pv[j-1]=arrTemp_p_pv; arrTemp_p_pv=[]
    
    V_curve_pVol[j-1]=arrTemp_V_pVol; arrTemp_V_pVol=[]
    p_curve_pVol[j-1]=arrTemp_p_pVol; arrTemp_p_pVol=[]
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(15,15)))
for i in range(4):
    if((i==1-1)or(i==3-1)):
        plt.plot(V_curve_pVol[i], p_curve_pVol[i], linestyle='dashed')
##### end for #####

plt.grid()
plt.title('p vs. V'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('volume [m3]')
plt.ylabel('pressure [Pa]')
for i in range(0, 8-1):
    if((i==1)or(i==3)or(i==4)or(i==6)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
    
    if((i==5)or(i==7)):
        root=[arr_V[i+1],arr_p[i+1]]
        head=[arr_V[i],arr_p[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.25, headwidth=6, headlength=6, connectionstyle='arc3',
                                    facecolor='black', edgecolor='black', linestyle='dashed')
                    )
    ##### end if #####
##### end for #####

plt.scatter(x=arr_V, y=arr_p, color='red', s=20)
'''
'''or(i==3)or(i==4)or(i==5)or(i==6)or(i==7)'''

print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_h, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_hs[i], h_curve_hs[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('h vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. enthalpy [J/kg]')
for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        plt.annotate('', xy=[arr_s[i+1],arr_h[i+1]], xytext=[arr_s[i],arr_h[i]],
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_u, color='red', s=60)

for i in range(4):
    plt.plot(s_curve_us[i], u_curve_us[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('u vs. s' + '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('spec. internal energy [J/kg]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_u[i+1]]
        head=[arr_s[i],arr_u[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=14, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %%
'''
fig.append(plt.figure(figsize=(10,10)))
plt.scatter(x=arr_s, y=arr_T, color='red', s=60)
for i in range(4):
    plt.plot(s_curve_Ts[i], T_curve_Ts[i], linestyle='dashed')
##### end for #####
plt.grid()
plt.title('T vs. s'+ '; at time:' + str(tgtTime) + '[s]')
plt.xlabel('spec. entropy [J/(kg*K)]')
plt.ylabel('Temperature [K]')

for i in range(0, 4):
    if((i==1-1)or(i==3-1)):
        root=[arr_s[i+1],arr_T[i+1]]
        head=[arr_s[i],arr_T[i]]
        plt.annotate('', xy=root, xytext=head,
                    arrowprops=dict(shrink=0, width=0.5, headwidth=8, headlength=12, connectionstyle='arc3',
                                    facecolor='gray', edgecolor='gray', linestyle='dashed')
                    )
##### end for #####
'''
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <p>----------------------------------------------------------------------</p>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------
