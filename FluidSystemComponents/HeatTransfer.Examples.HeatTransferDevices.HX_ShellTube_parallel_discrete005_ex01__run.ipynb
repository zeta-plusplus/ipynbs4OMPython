# %% [markdown]
# <h1>Run: FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01</h1>
# <h2>notebook: rev004</h2>
# <p>compatability with OpenModelica v1.17</p>
# <h2>memo: </h2>
# <p></p>

# %% [markdown]
# <h1>Load modules </h1>

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
import OMPython
from OMPython import OMCSessionZMQ
from OMPython import ModelicaSystem

import os
from os.path import expanduser

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import pathlib

from IPython.display import display, HTML
print('------------------------------')
# Out:
# ------------------------------

# %%
#****************************************
#    User must NOT edit code below 
#****************************************
# ----- prepare for post process -----
n_df=1000
df=[[]]*n_df
i_df= -1
print('----------')
# Out:
# ----------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Run simulation model #1</h1>

# %% [markdown]
# <h1>User settings: Library and Model information</h1>
# <p>Edit the strings below </p>

# %%
dirWorkRelToHome='/OMPythonWork'

#dirModelRelToLibDir='/Examples/ThermodynamicCycles'
libs2load=["PropulsionSystem", "FluidSystemComponents", "WalkingInWorldOfThermoFluid", "AircraftDynamics", "SystemModels", "InteractiveSimulation"]
fullpathModel='FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01'
nmModel='HX_ShellTube_parallel_discrete005_ex01'
stopTime=50.0
outputFormat='csv'
print('------------------------------')
# Out:
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
#*** get directory of this notebook
sys.path.append('..')
pathNotebook= os.getcwd()
print('------------------------------'); print('')

#*** distinguish OS
if(os.name=='nt'):
    dirHome=expanduser("~")
    typeOS='Windows (nt)'
elif(os.name=='posix'):
    dirHome=os.environ['HOME']
    typeOS= 'Linux or Mac (posix)'
##### end if #####

#*** direcotory of temporary work
dirWork= dirHome + dirWorkRelToHome

#*** get library directory
dirLib=''
sys.path.append('..')
dirLib= pathlib.Path('../../')
dirLib_upper1= pathlib.Path('../../')

dirLib= dirLib.resolve()
dirLib= str(dirLib)
dirLib= dirLib.replace('\\', '/')

dirLib_upper1= dirLib_upper1.resolve()

fullpathModelFile= str(dirLib_upper1)+'\\'+fullpathModel.replace('.','\\') +'.mo'
fullpathModelFile= fullpathModelFile.replace('\\', '/')


print("########## check user settings and related info. ##########")
print('-. This OS is: ' + typeOS)
print('-. Home directory of current environment is: ' + dirHome)
print("-. Temporary Working directory is: "+str(dirWork))
print('')
print('-. Directory of This notebook: '+ pathNotebook)
print('-. Directory of library which contains this notebook is: ' + str(dirLib))
print("-. Full path of Model to be ran is: " + fullpathModel)
print("-. Full path of Model file to be ran is: " + fullpathModelFile)

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
#
# ########## check user settings and related info. ##########
# -. This OS is: Linux or Mac (posix)
# -. Home directory of current environment is: /home/ubuntu
# -. Temporary Working directory is: /home/ubuntu/OMPythonWork
#
# -. Directory of This notebook: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# -. Directory of library which contains this notebook is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib
# -. Full path of Model to be ran is: FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01
# -. Full path of Model file to be ran is: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/HeatTransfer/Examples/HeatTransferDevices/HX_ShellTube_parallel_discrete005_ex01.mo
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------

# %% [markdown]
# <h1>Setup </h1>

# %%
#**************************************************
# ----- setup -----
#**************************************************
#****************************************
#    User must NOT edit code below 
#****************************************
omc= OMCSessionZMQ()

#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- move OMShell to working directory
strcmd= 'cd("' + dirWork + '")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#--------------------
#    set build option for old frontend
#    this option setting is neccesarry so that model written with older than Modelica 4.0.0 is ran by OpenModelica newer than 1.17.0
#--------------------
print(''); print('...front end setting, wait...')
strcmd='disableNewInstantiation()'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#    settings of command line options
#----------------------------------------
print(''); print('...front end setting, wait...')
strcmd='setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

#----------------------------------------
#-- load Modelica Standard Library
#----------------------------------------
msgOMShell=omc.sendExpression("loadModel(Modelica)")
print("OMShell: "+ str(msgOMShell)); print('')

print('...loading custom libraries, wait...')
for i in range(len(libs2load)):
    #-- load PropulsionSystem library
    print('i='+str(i))
    strcmd='loadFile("' + str(dirLib) +'/'+ libs2load[i] +'/package.mo' + '")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...load of custom libraries is completed')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# send: cd("/home/ubuntu/OMPythonWork")
# OMShell: /home/ubuntu/OMPythonWork
#
# ...front end setting, wait...
# send: disableNewInstantiation()
# OMShell: True
#
# OMShell error message:
#
#
#
# ...front end setting, wait...
# send: setCommandLineOptions("--matchingAlgorithm=PFPlusExt --indexReductionMethod=dummyDerivatives -d=initialization,evaluateAllParameters,NLSanalyticJacobian")
# OMShell: True
#
# OMShell error message:
#
#
# OMShell: True
#
# ...loading custom libraries, wait...
# i=0
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/PropulsionSystem/package.mo")
# OMShell: True
# i=1
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/FluidSystemComponents/package.mo")
# OMShell: True
# i=2
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/WalkingInWorldOfThermoFluid/package.mo")
# OMShell: True
# i=3
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/AircraftDynamics/package.mo")
# OMShell: True
# i=4
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/SystemModels/package.mo")
# OMShell: True
# i=5
# send: loadFile("/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/package.mo")
# OMShell: True
# ...load of custom libraries is completed
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------

# %% [markdown]
# <h1>Run simulation, default setting</h1>

# %%
iRun=0
startTime=0
stopTime=50
stepSize=0.1
#----------
numberOfIntervals=int((stopTime-startTime)/stepSize)
print('numberOfIntervals of simulation='+str(numberOfIntervals))
print('')

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

#-- reset _init.xml
print('...calling original parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

#-- run simulation with default parameter setting
print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe'  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + fullpathModel + '_res.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + fullpathModel + '_res.csv'  +'")'
##### end if #####
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

# --- get error message from OMShell ---
print('')
errMsg= omc.sendExpression('getErrorString()')
print('OMShell error message: ')
print(str(errMsg))
print('')

print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# numberOfIntervals of simulation=500
#
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# ...calling original parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.1 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res.csv")
# OMShell: 0
#
# OMShell error message:
# Notification: PropulsionSystem requested package Modelica of version 3.2.2. Modelica 3.2.3 is used instead which states that it is fully compatible without conversion script needed.
# Notification: FluidSystemComponents requested package Modelica of version 3.2.2. Modelica 3.2.3 is used instead which states that it is fully compatible without conversion script needed.
# Notification: AircraftDynamics requested package Modelica of version 3.2.2. Modelica 3.2.3 is used instead which states that it is fully compatible without conversion script needed.
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Examples/Output/dispVarPyConsole02_00_ex01.mo:17:104-17:108:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Examples/Output/dispVarPyConsole02_00_ex01.mo:17:104-17:122:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Output/dispVarPyConsole02_00.mo:18:37-18:41:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
# [/home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/InteractiveSimulation/Output/dispVarPyConsole02_00.mo:18:37-18:55:writable] Warning: Lexer treating \ as \\, since \P is not a valid Modelica escape sequence.
#
#
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>parameter sweep, 1 parameter </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRunBegin=2
iRunEnd=22
param2change="kSize"
valBegin=1.0
deltaVal=1.0

startTime=0
stopTime=50
stepSize=0.05

#----------
numberOfIntervals=int((stopTime-startTime)/stepSize)
print('numberOfIntervals of simulation='+str(numberOfIntervals))
print('')

#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

for i in range(iRunBegin, iRunEnd+1):
    iRun=i
    value2set=valBegin+(i-iRunBegin)*deltaVal
    filenameXmlOrg=fullpathModel+'_init_org.xml'
    filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
    
    print(''); print('-----')
    print('iRun= '+ str(iRun))
    
    #-- overwrite parameter setting xml file
    print('...Overwriting parameter setting file...')
    strcmd= 'setInitXmlStartValue("' + filenameXmlOrg+'", '+ '"'+param2change+'", ' + '"'+str(value2set)+'", '+ '"'+fullpathModel+'_init.xml"' +')'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- save parameter setting file after overwriting
    print(''); print('...Saving parameter setting file...')
    strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))

    #-- run simulation with default parameter setting
    print(''); print("...running simulation, wait...")
    if(os.name=='nt'):
        strcmd= 'system("' + fullpathModel + '.exe'  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
    elif(os.name=='posix'):
        strcmd= 'system("' + './'+fullpathModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv'  +'")'
    ##### end if #####
    
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
    print('...simulation run finished.')
##### end for #####

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# numberOfIntervals of simulation=1000
#
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
#
# -----
# iRun= 2
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "1.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_2.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_2.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 3
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "2.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_3.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_3.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 4
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "3.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_4.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_4.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 5
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "4.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_5.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_5.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 6
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "5.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_6.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_6.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 7
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "6.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_7.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_7.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 8
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "7.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_8.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_8.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 9
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "8.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_9.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_9.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 10
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "9.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_10.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_10.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 11
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "10.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_11.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_11.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 12
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "11.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_12.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_12.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 13
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "12.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_13.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_13.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 14
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "13.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_14.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_14.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 15
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "14.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_15.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_15.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 16
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "15.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_16.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_16.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 17
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "16.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_17.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_17.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 18
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "17.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_18.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_18.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 19
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "18.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_19.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_19.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 20
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "19.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_20.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_20.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 21
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "20.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_21.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_21.csv")
# OMShell: 0
# ...simulation run finished.
#
# -----
# iRun= 22
# ...Overwriting parameter setting file...
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml", "kSize", "21.0", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_22.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_22.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------

# %% [markdown]
# <h1>Run simulation</h1>
# <h2>Change multiple parameters, 1 case </h2>

# %%
#****************************************
#    User Setting section 
#****************************************
iRun=1
param2change=[
    'ramp_m_flow_hot.height',
    'ramp_T_hotIn.startTime',
    'ramp_m_flow_cold.height',
    'ramp_T_coldIn.startTime',
    
    'kSize'
]
value2set=[
    1,
    -5,
    1,
    5,
    
    5,
]

startTime=0
stopTime=50
stepSize=0.05

#----------
numberOfIntervals=int((stopTime-startTime)/stepSize)
print('numberOfIntervals of simulation='+str(numberOfIntervals))
print('')


#****************************************
#    User must NOT edit code below 
#****************************************
#***** move to temporary working directory *****
os.chdir(dirWork)
os.getcwd()
print("currend dir: "+os.getcwd())
print('------------------------------'); print('')

filenameXmlNew=fullpathModel+'_init_'+str(iRun)+'.xml'
#-- reset _init.xml
print('iRun='+str(iRun))
print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init_org.xml') +' '+ (fullpathModel+'_init.xml') +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell)); print('')

print('...editing parameter setting file, wait...')
for i in range(len(param2change)):
    #----------
    #-- overwrite parameter setting xml file
    #- index 0
    print('i='+str(i))
    strcmd= 'setInitXmlStartValue("' +(fullpathModel+'_init.xml')+'", '+ '"'+param2change[i]+'", ' + '"'+str(value2set[i])+'", '+ '"'+(fullpathModel+'_init.xml')+'")'
    print('send: '+strcmd)
    msgOMShell=omc.sendExpression(strcmd)
    print("OMShell: "+ str(msgOMShell))
##### end for #####
print('...edit of parameter setting file is completed.')

#----------
#-- save parameter setting file after overwriting
print(''); print('...Saving parameter setting file...')
strcmd= 'system("'+ 'cp '+ (fullpathModel+'_init.xml') +' '+ (filenameXmlNew) +'")'
print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))

#-- run simulation
print(''); print("...running simulation, wait...")
if(os.name=='nt'):
    strcmd= 'system("' + fullpathModel + '.exe'  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv' +'")'
elif(os.name=='posix'):
    strcmd= 'system("' + './'+fullpathModel  + ' -override=startTime='+str(startTime)+',stopTime='+str(stopTime)+',stepSize='+str(stepSize)  + ' -r=' + fullpathModel + '_res_'+ str(iRun) +'.csv'  +'")'
##### end if #####

print('send: '+strcmd)
msgOMShell=omc.sendExpression(strcmd)
print("OMShell: "+ str(msgOMShell))
print('...simulation run finished.')

#***** move back to notebook directory *****
print(''); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# numberOfIntervals of simulation=1000
#
# currend dir: /home/ubuntu/OMPythonWork
# ------------------------------
#
# iRun=1
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_org.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: 0
#
# ...editing parameter setting file, wait...
# i=0
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml", "ramp_m_flow_hot.height", "1", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
# i=1
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml", "ramp_T_hotIn.startTime", "-5", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
# i=2
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml", "ramp_m_flow_cold.height", "1", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
# i=3
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml", "ramp_T_coldIn.startTime", "5", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
# i=4
# send: setInitXmlStartValue("FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml", "kSize", "5", "FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml")
# OMShell: True
# ...edit of parameter setting file is completed.
#
# ...Saving parameter setting file...
# send: system("cp FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init.xml FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_init_1.xml")
# OMShell: 0
#
# ...running simulation, wait...
# send: system("./FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01 -override=startTime=0,stopTime=50,stepSize=0.05 -r=FluidSystemComponents.HeatTransfer.Examples.HeatTransferDevices.HX_ShellTube_parallel_discrete005_ex01_res_1.csv")
# OMShell: 0
# ...simulation run finished.
#
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------

# %% [markdown]
# <h1>===========================================================================</h1>

# %% [markdown]
# <h1>Process at the end of note</h1>

# %%
print(""); print('------------------------------')
os.chdir(pathNotebook)
print("move to directory of notebook")
print("currend dir, back to: "+os.getcwd())
print('------------------------------')
# Out:
# ------------------------------
# move to directory of notebook
# currend dir, back to: /home/ubuntu/Dropbox/01-sharedspace/modelica-shared/CustomLib/ipynbs4OMPython/FluidSystemComponents
# ------------------------------
